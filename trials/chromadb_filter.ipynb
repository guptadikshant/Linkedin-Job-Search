# %%
import os
import json
import chromadb
from chromadb.utils.embedding_functions.openai_embedding_function import OpenAIEmbeddingFunction

from dotenv import load_dotenv, find_dotenv

# %%
load_dotenv(find_dotenv())
# Out:
# True

# %%
client = chromadb.PersistentClient(path="./vector_database2")

# %%
collection = client.get_collection(
    name="linkedin_people_profiles_4",
    embedding_function=OpenAIEmbeddingFunction(api_key=os.environ["OPENAI_API_KEY"])
)

# %%
collection.query(
    query_texts="People with experience of 5 years",
    include=["documents", "metadatas"]
)
# Out:
# {'ids': [['ACoAAAbvohIBhdiLqQ5FCbtA40AFvg3f-T7fKfk',
#    'ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY',
#    'ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0',
#    'ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY',
#    'ACoAABIURlEB0IaIlQL8yLwChwLnQFDTIiBtFbY',
#    'ACoAACzqAZ8BNYEJjGPpk_l6DlwoAzZJUXVYd0Y',
#    'ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4',
#    'ACoAABBPpTkBE83UntVzca-RXL5ggcsfztv9RRs',
#    'ACoAACbYB28BGp07ec7sQFVsqdcNnzxVsBhwScc',
#    'ACoAACE9Q2MBe_i_ol-tkC8L5lAv12dRAZez-n0']],
#  'distances': None,
#  'metadatas': [[{'Agile Methodologies': 'Agile Methodologies',
#     'Artificial Intelligence (AI)': 'Artificial Intelligence (AI)',
#     'Artificial Neural Networks': 'Artificial Neural Networks',
#     'Character User Interface,Progress': 'Character User Interface,Progress',
#     'Computer Vision': 'Computer Vision',
#     'Core Java': 'Core Java',
#     'Data Analysis': 'Data Analysis',
#     'Data Science': 'Data Science',
#     'Deep Learning': 'Deep Learning',
#     'Linux': 'Linux',
#     'Machine Learning': 'Machine Learning',
#     'Machine Learning Algorithms': 'Machine Learning Algorithms',
#     'Neural Networks': 'Neural Networks',
#     'Oracle SQL Developer': 'Oracle SQL Developer',
#     'PL/SQL': 'PL/SQL',
#     'Predictive Modeling': 'Predictive Modeling',
#     'Progress 4GL': 'Progress 4GL',
#     'Python (Programming Language)': 'Python (Programming Language)',
#     'Requirements Analysis': 'Requirements Analysis',
#     'SQL': 'SQL',
#     'Shell Scripting': 'Shell Scripting',
#     'Software Development': 'Software Development',
#     'TensorFlow': 'TensorFlow',
#     'Unix': 'Unix',
#     'pl': 'pl'},
#    {'Agile Application Development': 'Agile Application Development',
#     'Alchemist': 'Alchemist',
#     'Amazon Web Services (AWS)': 'Amazon Web Services (AWS)',
#     'Artificial Intelligence (AI)': 'Artificial Intelligence (AI)',
#     'Artificial Neural Networks': 'Artificial Neural Networks',
#     'CA-Librarian': 'CA-Librarian',
#     'CA7': 'CA7',
#     'CICS': 'CICS',
#     'COBOL': 'COBOL',
#     'COBOLII': 'COBOLII',
#     'CRF design': 'CRF design',
#     'CRFs': 'CRFs',
#     'Ca datacom': 'Ca datacom',
#     'Control M': 'Control M',
#     'Core Java': 'Core Java',
#     'DB2': 'DB2',
#     'Data Analysis': 'Data Analysis',
#     'Data Science': 'Data Science',
#     'Data Visualization': 'Data Visualization',
#     'Django': 'Django',
#     'Django REST Framework': 'Django REST Framework',
#     'Docker Products': 'Docker Products',
#     'Endeavor': 'Endeavor',
#     'Financial Analysis': 'Financial Analysis',
#     'GNU Octave': 'GNU Octave',
#     'Git': 'Git',
#     'Google Analytics': 'Google Analytics',
#     'IBM DB2': 'IBM DB2',
#     'JCL': 'JCL',
#     'JavaScript': 'JavaScript',
#     'Job Control Language (JCL)': 'Job Control Language (JCL)',
#     'Machine Learning': 'Machine Learning',
#     'Microsoft Azure': 'Microsoft Azure',
#     'Microsoft SQL Server': 'Microsoft SQL Server',
#     'MongoDB': 'MongoDB',
#     'MySQL': 'MySQL',
#     'NoSQL': 'NoSQL',
#     'Pandas (Software)': 'Pandas (Software)',
#     'Python (Programming Language)': 'Python (Programming Language)',
#     'Scikit-Learn': 'Scikit-Learn',
#     'TensorFlow': 'TensorFlow',
#     'Time Management': 'Time Management',
#     'Ubuntu': 'Ubuntu',
#     'Xpediter': 'Xpediter',
#     'changeman': 'changeman',
#     'linux': 'linux'},
#    {'Amazon Web Services (AWS)': 'Amazon Web Services (AWS)',
#     'Chatbot Development': 'Chatbot Development',
#     'Core Java': 'Core Java',
#     'Data Science': 'Data Science',
#     'Decision Trees': 'Decision Trees',
#     'Deep Learning': 'Deep Learning',
#     'Ensemble Models': 'Ensemble Models',
#     'Flask': 'Flask',
#     'GBDT': 'GBDT',
#     'Generative AI': 'Generative AI',
#     'Gensim': 'Gensim',
#     'Google Cloud Platform (GCP)': 'Google Cloud Platform (GCP)',
#     'Java': 'Java',
#     'K-Nearest Neighbors (KNN)': 'K-Nearest Neighbors (KNN)',
#     'Keras': 'Keras',
#     'LLM': 'LLM',
#     'Linear Regression': 'Linear Regression',
#     'Linux': 'Linux',
#     'Logistic Regression': 'Logistic Regression',
#     'MLP': 'MLP',
#     'Machine Learning': 'Machine Learning',
#     'Machine Learning Algorithms': 'Machine Learning Algorithms',
#     'Microsoft Excel': 'Microsoft Excel',
#     'Naive bayes': 'Naive bayes',
#     'Natural Language Processing (NLP)': 'Natural Language Processing (NLP)',
#     'Pandas (Software)': 'Pandas (Software)',
#     'Predictive Modeling': 'Predictive Modeling',
#     'Predictive Modelling': 'Predictive Modelling',
#     'Python': 'Python',
#     'Python (Programming Language)': 'Python (Programming Language)',
#     'R programming': 'R programming',
#     'Random Forest': 'Random Forest',
#     'SQL': 'SQL',
#     'Scikit-Learn': 'Scikit-Learn',
#     'Speech Recognition': 'Speech Recognition',
#     'Statistical Modeling': 'Statistical Modeling',
#     'Statistics': 'Statistics',
#     'Support Vector Machine (SVM)': 'Support Vector Machine (SVM)',
#     'Tableau': 'Tableau',
#     'Text Classification': 'Text Classification',
#     'Topic Modeling': 'Topic Modeling',
#     'Transformer Models': 'Transformer Models',
#     'VBA': 'VBA',
#     'XGBoost': 'XGBoost',
#     'flair': 'flair',
#     'nltk': 'nltk',
#     'spaCy': 'spaCy',
#     'stanford coreNLP': 'stanford coreNLP',
#     'textblob': 'textblob',
#     'word2vec': 'word2vec'},
#    {'Amazon Web Services (AWS)': 'Amazon Web Services (AWS)',
#     'Artificial Intelligence (AI)': 'Artificial Intelligence (AI)',
#     'Artificial Neural Networks': 'Artificial Neural Networks',
#     'Big Data': 'Big Data',
#     'Big Data Analytics': 'Big Data Analytics',
#     'Big data': 'Big data',
#     'Communication': 'Communication',
#     'Computer Vision': 'Computer Vision',
#     'Convolutional Neural Networks (CNN)': 'Convolutional Neural Networks (CNN)',
#     'Data Analysis': 'Data Analysis',
#     'Data Analytics': 'Data Analytics',
#     'Data Modeling': 'Data Modeling',
#     'Data Science': 'Data Science',
#     'Data Structures': 'Data Structures',
#     'Data Visualization': 'Data Visualization',
#     'Data Warehousing': 'Data Warehousing',
#     'Data Wrangling': 'Data Wrangling',
#     'Databases': 'Databases',
#     'Deep Learning': 'Deep Learning',
#     'Docker Products': 'Docker Products',
#     'Enjoy Challenges': 'Enjoy Challenges',
#     'Generative AI': 'Generative AI',
#     'Image Processing': 'Image Processing',
#     'Image Segmentation': 'Image Segmentation',
#     'LangChain': 'LangChain',
#     'Large Language Models (LLM)': 'Large Language Models (LLM)',
#     'Machine Learning': 'Machine Learning',
#     'Microsoft Azure': 'Microsoft Azure',
#     'Natural Language Processing (NLP)': 'Natural Language Processing (NLP)',
#     'Neural Networks': 'Neural Networks',
#     'NumPy': 'NumPy',
#     'Object Detection': 'Object Detection',
#     'Object-Oriented Programming (OOP)': 'Object-Oriented Programming (OOP)',
#     'Oracle Database': 'Oracle Database',
#     'Predictive Modeling': 'Predictive Modeling',
#     'Probability': 'Probability',
#     'Problem Solving': 'Problem Solving',
#     'Programming': 'Programming',
#     'Public Relations': 'Public Relations',
#     'PySpark': 'PySpark',
#     'PyTorch': 'PyTorch',
#     'Python (Programming Language)': 'Python (Programming Language)',
#     'R': 'R',
#     'RDBMS': 'RDBMS',
#     'Recommender Systems': 'Recommender Systems',
#     'Recurrent Neural Networks (RNN)': 'Recurrent Neural Networks (RNN)',
#     'Relationship Building': 'Relationship Building',
#     'SQL': 'SQL',
#     'Statistics': 'Statistics',
#     'Team Leadership': 'Team Leadership',
#     'Team Management': 'Team Management',
#     'Teamwork': 'Teamwork',
#     'TensorFlow': 'TensorFlow',
#     'Time Management': 'Time Management',
#     'Transformer Models': 'Transformer Models',
#     'openai': 'openai'},
#    {'Automation': 'Automation',
#     'Azure Data Factory': 'Azure Data Factory',
#     'Azure Databricks': 'Azure Databricks',
#     'C++': 'C++',
#     'Computer Vision': 'Computer Vision',
#     'Fastai': 'Fastai',
#     'Flask': 'Flask',
#     'Image Processing': 'Image Processing',
#     'Java': 'Java',
#     'Machine Learning': 'Machine Learning',
#     'Microsoft Power BI': 'Microsoft Power BI',
#     'MySQL': 'MySQL',
#     'Programming': 'Programming',
#     'PySpark': 'PySpark',
#     'Python (Programming Language)': 'Python (Programming Language)',
#     'SQL': 'SQL',
#     'Tableau': 'Tableau',
#     'Time Series Analysis': 'Time Series Analysis',
#     'UiPath': 'UiPath',
#     'Windows': 'Windows'},
#    {'C (Programming Language)': 'C (Programming Language)',
#     'C++': 'C++',
#     'Communication': 'Communication',
#     'Dataiku DSS': 'Dataiku DSS',
#     'Deep Learning': 'Deep Learning',
#     'Elasticsearch': 'Elasticsearch',
#     'Flask': 'Flask',
#     'Google Cloud Platform (GCP)': 'Google Cloud Platform (GCP)',
#     'Machine Learning': 'Machine Learning',
#     'Natural Language Processing (NLP)': 'Natural Language Processing (NLP)',
#     'NoSQL': 'NoSQL',
#     'OpenCV': 'OpenCV',
#     'Presentation Skills': 'Presentation Skills',
#     'Public Speaking': 'Public Speaking',
#     'PySpark': 'PySpark',
#     'Python (Programming Language)': 'Python (Programming Language)',
#     'SQL': 'SQL',
#     'Selenium WebDriver': 'Selenium WebDriver',
#     'Teamwork': 'Teamwork'},
#    {'Algorithm Design': 'Algorithm Design',
#     'Analytical Skills': 'Analytical Skills',
#     'Apache Spark': 'Apache Spark',
#     'Applied Machine Learning': 'Applied Machine Learning',
#     'Cluster Analysis': 'Cluster Analysis',
#     'Computer Architecture': 'Computer Architecture',
#     'Cypher Query Language': 'Cypher Query Language',
#     'Data Mining': 'Data Mining',
#     'Data Visualization': 'Data Visualization',
#     'Deep Neural Networks (DNN)': 'Deep Neural Networks (DNN)',
#     'Java': 'Java',
#     'Linear Regression': 'Linear Regression',
#     'Logistic Regression': 'Logistic Regression',
#     'Machine Learning': 'Machine Learning',
#     'Natural Language Processing (NLP)': 'Natural Language Processing (NLP)',
#     'Neo4j': 'Neo4j',
#     'Object-Oriented Programming (OOP)': 'Object-Oriented Programming (OOP)',
#     'Optimization': 'Optimization',
#     'Pandas': 'Pandas',
#     'Predictive Analytics': 'Predictive Analytics',
#     'Problem Solving': 'Problem Solving',
#     'Python (Programming Language)': 'Python (Programming Language)',
#     'R (Programming Language)': 'R (Programming Language)',
#     'Regression Analysis': 'Regression Analysis',
#     'SQL': 'SQL',
#     'Statistical Data Analysis': 'Statistical Data Analysis',
#     'Statistical Learning': 'Statistical Learning',
#     'Statistics': 'Statistics',
#     'Tableau': 'Tableau',
#     'Teamwork': 'Teamwork',
#     'TensorFlow': 'TensorFlow',
#     'Transact-SQL (T-SQL)': 'Transact-SQL (T-SQL)',
#     'Unstructured Data': 'Unstructured Data'},
#    {'ADO.NET': 'ADO.NET',
#     'ASP.NET': 'ASP.NET',
#     'ASP.NET Core': 'ASP.NET Core',
#     'ASP.NET MVC': 'ASP.NET MVC',
#     'Angular': 'Angular',
#     'Azure Data Factory': 'Azure Data Factory',
#     'Azure Databricks': 'Azure Databricks',
#     'C#': 'C#',
#     'Entity Framework': 'Entity Framework',
#     'Extract, Transform, Load (ETL)': 'Extract, Transform, Load (ETL)',
#     'Microsoft SQL Server': 'Microsoft SQL Server',
#     'Python (Programming Language)': 'Python (Programming Language)',
#     'SQL Server Integration Services (SSIS)': 'SQL Server Integration Services (SSIS)',
#     'SQL Server Reporting Services (SSRS)': 'SQL Server Reporting Services (SSRS)'},
#    {'Data Management': 'Data Management',
#     'Data Science': 'Data Science',
#     'Data Visualization': 'Data Visualization',
#     'Databricks ': 'Databricks ',
#     'Machine Learning': 'Machine Learning',
#     'Natural Language Processing (NLP)': 'Natural Language Processing (NLP)',
#     'PySpark': 'PySpark',
#     'Python (Programming Language)': 'Python (Programming Language)',
#     'R': 'R',
#     'SQL': 'SQL',
#     'Statistical Data Analysis': 'Statistical Data Analysis',
#     'Statistics': 'Statistics',
#     'Tableau': 'Tableau',
#     'Team Leadership': 'Team Leadership',
#     'Team Management': 'Team Management'},
#    {'Analytics': 'Analytics',
#     'C (Programming Language)': 'C (Programming Language)',
#     'C++': 'C++',
#     'Computer Vision': 'Computer Vision',
#     'Data Analysis': 'Data Analysis',
#     'Data Analytics': 'Data Analytics',
#     'Data Science': 'Data Science',
#     'Databases': 'Databases',
#     'Deep Learning': 'Deep Learning',
#     'English': 'English',
#     'Information Technology': 'Information Technology',
#     'MLOps': 'MLOps',
#     'Machine Learning': 'Machine Learning',
#     'Microsoft Excel': 'Microsoft Excel',
#     'Microsoft Office': 'Microsoft Office',
#     'Microsoft PowerPoint': 'Microsoft PowerPoint',
#     'Microsoft SQL Server': 'Microsoft SQL Server',
#     'Python (Programming Language)': 'Python (Programming Language)',
#     'Quality Control': 'Quality Control',
#     'SQL': 'SQL',
#     'Tableau': 'Tableau',
#     'Visual Basic': 'Visual Basic',
#     'Visual Basic for Applications (VBA)': 'Visual Basic for Applications (VBA)'}]],
#  'embeddings': None,
#  'documents': [['{"summary": "Experience in Cognitive Computing with leverage of Machine Learning, Deep Learning, Artificial Intelligence, Natural Language Processing skills . Data driven analyst with the ability to apply ML/DL/NLP/Computer Vision Techniques and leverage algorithms to solve real world problems. Established ability in deploying effective predictive/NLP/Computer Vision models across banking/HealthCare industries to accurately forecast and deliver proven results. Strong understanding of Oracle DB and PLSQL with data migration exp\\u00e9rience. Domain Knowledge of SupplyChain/finance/banking/Retail domain with communication skills, excellent product and process design knowledge. Domain HealthCare,Mortgage Banking, Consumer, Commercial Lending, Escrow, Loan processing and servicing, Deposits. Onsite experience (US/UK) with business domain experience in Retail and supply chain with special focus on Customer engagement and managing end-user expectations. Experience in Analysis, Design, Development, Customization, Bug fixes, Enhancement, Support and Implementation.\\n\\n\\nData Science, Machine Learning, Deep Learning and AI technologies.Strong understanding of Databases Oracle, Progress 4GL, PLSQL. Excellent Domain Knowledge of finance/banking/Retail domain with communication skills, excellent product and process design knowledge.Strong knowledge of Data Migration and Implementation.. \\n\\nAreas of Expertise: Data Science Machine Learning, Deep Learning and AI technologies.\\n\\nWeb App - Flask, Django.\\n\\nDomain - Mortgage Banking,Insurance Claim Processing Money Laundering, Investment Banking, Lending, Escrow, Loan processing and servicing. Credit Cards,Healthcare\\n\\nDatabase - Oracle,Progress 4GL,Mongo Db\\n\\nLanguages - Python ,PLSQL,Progress4GL,Shell Script\\n\\nVersioning - SVN,Github\\nCloud : IBM Cloud, AWS,AZURE,Kubernates\\nOthers : Dockers,CICD\\n\\n\\n\\n\\n10+ years of experience in exploring and understanding various business models in Finance,Healthcare,Retail and Supply chain domain with special focus on implementation according to client requirements.\\n\\u2022\\tExperience in client interaction for requirement gathering and feasibility analysis at various levels including end users, project managers, and business analysts. Possess good business acumen interacting with various 3rd parties in the same project. Onsite experience (UK) with business domain experience in Retail and supply chain with special focus on customer engagement and managing end-user expectations.", "industryName": "Information Technology & Services", "lastName": "Aneja", "locationName": "India", "firstName": "Isha", "headline": "Data Scientist IBM", "img_253_253": "800_800/profile-displayphoto-shrink_800_800/0/1516520225939?e=1731542400&v=beta&t=MK0pDwNOQmYNXZS1hxvX1-2NsHeY1lAP4O8njFxDsMs", "public_id": "isha-aneja-642b7a32", "experience": [{"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "IBM", "timePeriod": {"startDate": {"month": 12, "year": 2021}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"locationName": "New Delhi Area, India", "geoLocationName": "New Delhi Area, India", "companyName": "Fiserv", "timePeriod": {"endDate": {"month": 1, "year": 2022}, "startDate": {"month": 12, "year": 2017}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Technical Lead"}, {"locationName": "Noida Area, India", "geoLocationName": "Noida Area, India", "companyName": "Birlasoft", "timePeriod": {"endDate": {"month": 12, "year": 2017}, "startDate": {"month": 8, "year": 2016}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Senior Software Engineer"}, {"locationName": "banglore", "geoLocationName": "banglore", "companyName": "Capgemini", "timePerio ...
#    '{"summary": "Experience Data Science professional with demonstrated history of working in IT service industry. Experienced in executing data driven solutions to increase efficiency, accuracy and utility of internal data processing. Skilled in natural language processing with practioner knowledge on Web Analytics. Strong information technology professional with a Bachelor of Technology (BTech) from Uttar Pradesh Technical University. ", "industryName": "Information Technology & Services", "lastName": "Mathur", "locationName": "India", "firstName": "Tushar", "headline": "Data Scientist", "img_413_413": "800_800/profile-displayphoto-shrink_800_800/0/1627636616827?e=1731542400&v=beta&t=622aY-HtcQSxqycM6kkJLZJgkr1xzh3_7jhWSE28UXg", "public_id": "tushar-mathur-79a23120", "experience": [{"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "Coforge", "timePeriod": {"startDate": {"month": 8, "year": 2022}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Analytics Lead"}, {"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "EXL", "timePeriod": {"endDate": {"month": 8, "year": 2022}, "startDate": {"month": 8, "year": 2021}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Technical Lead"}, {"locationName": "Noida Area, India", "geoLocationName": "Noida Area, India", "companyName": "Sopra Steria", "timePeriod": {"endDate": {"month": 7, "year": 2021}, "startDate": {"month": 7, "year": 2019}}, "description": "Working on information extraction project in which we focuses on creating structured representation of unstructured/structured texts by extracting relevant entities from them, using machine learning and AI process thereby making the data analysis realizable.", "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Module Lead"}, {"locationName": "Noida Area, India", "geoLocationName": "Noida Area, India", "companyName": "Sopra Steria", "timePeriod": {"endDate": {"month": 6, "year": 2019}, "startDate": {"month": 10, "year": 2017}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Senior Software Engineer", "honors": ["urn:li:fs_honor:(ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY,1097608354)"]}, {"locationName": "Gurgaon, India", "geoLocationName": "Gurgaon, India", "companyName": "Infosys", "timePeriod": {"endDate": {"month": 10, "year": 2017}, "startDate": {"month": 10, "year": 2016}}, "description": "\\u2022Working knowledge of Agile and Waterfall models.\\n\\u2022Working in full project life cycle involving Requirement Analysis, Testing and Implementation phases.\\n\\u2022Extensive coding and modifying programs using COBOL, DB2 and JCL as per the requests of business departments.\\n\\u2022Involved in Preparing Unit test cases, doing test data setup and performing Unit testing, User Acceptance Testing.\\n\\u2022Works on envisioning of requirement for future analysis.", "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Senior System Engineer", "honors": ["urn:li:fs_honor:(ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY,1304876652)", "urn:li:fs_honor:(ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY,1020421066)"]}], "education": [{"timePeriod": {"endDate": {"year": 2014}, "startDate": {"year": 2010}}, "degreeName": "Bachelor of Technology (BTech)", "schoolName": "Uttar Pradesh Technical University", "fieldOfStudy": "Electrical, Electronics and Communications Engineering"}], "languages": [{"name": "English", "proficiency": "PROFESSIONAL_WORKING"}, {"name": "Hindi", "proficiency": "NATIVE_OR_BILINGUAL"}], "publications": [], "certifications": [{"authority": "Coursera", "name": "IBM Data Science Speciali ...
#    '{"summary": "\\u2022\\tExperience of 7 years as Data Scientist (August 2016 \\u2013 Till Date) in implementing advanced analytics and predictive modelling algorithms such as Sequence models, Machine translation, Text summarization, Voice enabled Bot (using GPT2, Deepspeech and Azure cognitive services),Text Extraction using BERT and Spacy, Text Classification, Credit Risk analysis, Logistic regression, Decision tree ,Ensemble models, KNN, PCA, t-SNE, Linear regression, Clustering (k-means, Agglomerative)\\n\\u2022\\tExperience of 1.6 years (Nov 2014 \\u2013 Aug 2016) in Siebel CRM.\\n\\u2022\\tWell converse with Python(Pandas, Numpy, Scikit-Learn, Keras, matplotlib.pyplot, seaborn), Flask API, ML model deployments, AWS Services, linux, SQL ,Core Java and Siebel CRM.", "industryName": "Information Technology & Services", "lastName": "Kharbanda", "locationName": "India", "firstName": "Sumeet", "headline": "Looking for Data Science Opportunities  | Manager - Data Scientist @ EXL | NLP | Freelancer", "img_450_450": "800_800/profile-displayphoto-shrink_800_800/0/1517470892367?e=1731542400&v=beta&t=WkpZbUOBkt9zAX7RDthG9tVfXjgi3i-bat3dRDqpGgw", "public_id": "sumeet-data-scientist", "experience": [{"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "EXL", "timePeriod": {"startDate": {"month": 4, "year": 2022}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Manager - Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "EXL", "timePeriod": {"endDate": {"month": 4, "year": 2022}, "startDate": {"month": 11, "year": 2020}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Technical Lead - Data Scientist"}, {"courses": ["urn:li:fs_course:(ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0,504009401)", "urn:li:fs_course:(ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0,504035397)"], "locationName": "Gurgaon, Haryana, India", "geoLocationName": "Gurgaon, Haryana, India", "companyName": "UnitedHealth Group", "timePeriod": {"endDate": {"month": 11, "year": 2020}, "startDate": {"month": 8, "year": 2019}}, "description": "Development and deployment of machine learning models in python, text analytics,disease prediction, voice bot and chat bot.", "company": {"employeeCountRange": {"start": 10001}, "industries": ["Hospital & Health Care"]}, "title": "Associate Data Scientist"}, {"locationName": "Gurgaon, Haryana, India", "geoLocationName": "Gurgaon, Haryana, India", "companyName": "dunnhumby", "timePeriod": {"endDate": {"month": 8, "year": 2019}, "startDate": {"month": 6, "year": 2019}}, "description": "Adhoc analysis of retail client, worked on pyspark, python, SQL, excel dashboards", "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Marketing and Advertising"]}, "title": "Applied Data Scientist"}, {"courses": ["urn:li:fs_course:(ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0,503992293)"], "locationName": "Chandigarh Area, India", "geoLocationName": "Chandigarh Area, India", "companyName": "Infosys", "timePeriod": {"endDate": {"month": 5, "year": 2019}, "startDate": {"month": 4, "year": 2018}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Technology Analyst"}], "education": [{"school": {"objectUrn": "urn:li:school:354045", "entityUrn": "urn:li:fs_miniSchool:354045", "active": true, "schoolName": "International Institute of Information Technology Bangalore", "trackingId": "F/PLHzg7RgerGGAq0r8C2g==", "logoUrl": "https://media.licdn.com/dms/image/v2/D560BAQEocmV8HEnx7w/company-logo_"}, "timePeriod": {"endDate": {"year": 2021}, "startDate": {"year": 2020}}, "degreeName": "PGC", "schoolName": "International Institute of Information Technology Bangalore", "fieldOfStudy": "Data Science"}, {"school": {"objectUrn" ...
#    '{"summary": "4+ years of work experience solving business problems with the application of Data Science. Master of Data Science, Monash University (Melbourne). Proficient in Generative AI, Computer Vision and Predictive Modeling. With a strong grip over mathematics, deep learning and machine learning algorithms, capable to transform business requirements into data science formulations and implementing the solutions in an efficient and scalable fashion.\\n\\nCreating impactful AI solutions at R Systems, my focus is on designing cutting-edge generative AI technologies. With a Master\'s degree in Data Science from Monash University, I apply rigorous academic training to address complex client challenges. Our team\'s contribution has significantly enhanced the RAG Application\'s accuracy, showcasing a blend of innovation and practical application.\\n\\nMy core competencies lie in Large Language Models and transformative AI, underpinned by data collection, preprocessing, model development, and deployment. These skills have enabled us to deliver tailored solutions that not only meet but exceed our clients\' business objectives. The dedication to continual learning and improvement is what drives the team and myself to achieve excellence in the ever-evolving field of data science.", "industryName": "Computer Software", "lastName": "Nain", "locationName": "India", "birthDate": {"month": 1, "day": 24}, "firstName": "Rakesh", "headline": "Data Scientist @ R Systems | Master\'s in Data Science", "public_id": "rakeshnain", "experience": [{"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "R Systems", "timePeriod": {"startDate": {"month": 8, "year": 2023}}, "description": "Roles and Responsibilities:\\n- Tackle client challenges by designing and implement end-to-end data science solutions using generative AI (LLMs, Large Multi-Modals and their finetuning based on the use cases) or traditional machine learning from data collection, preprocessing to model development and deployment\\n- I ensure optimal model performance, engage in cross-functional collaboration, and deliver insights to clients through effective communication.\\n- My role contributes to R systems consultancy prowess in delivering innovative and impactful solutions that address diverse business needs of clients.\\n\\nAchievements:\\n- Increased the RAG Application accuracy by 40%.", "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"companyName": "Intello Labs", "timePeriod": {"endDate": {"month": 8, "year": 2023}, "startDate": {"month": 12, "year": 2021}}, "description": "Roles and Responsibilities:\\n- Develop state-of-the-art machine learning and deep learning algorithms/models for visual recognition tasks, such as segmentation and detection.\\n- Collaborate closely with multidisciplinary teams of software engineers, hardware engineers, business leaders and other key players to develop Artificial Intelligent machines.\\n- Data Collection, EDA, Data Cleaning, ML Model Development(R&D) and deployment.\\n\\nAchievements:\\n- Developed object detection and instance segmentation algorithm taking around 50 times less RAM in training with only twice extra time in inference as compared to present state-of-the-art algorithms in the market.\\n- Improved grains classification results by 20%, and fruits defect detection results by 12%.", "company": {"employeeCountRange": {"start": 51, "end": 200}, "industries": ["Information Technology and Services"]}, "title": "Deep Learning Engineer"}, {"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "DishTV", "timePeriod": {"endDate": {"month": 10, "year": 2018}, "startDate": {"month": 6, "year": 2017}}, "description": "Roles and Responsibilities:\\nStarted as a Software Developer in the \\u201cMy DishTV\\u201d Android App pr ...
#    '{"summary": "Experienced Data Scientist with a demonstrated history of working in the computer software industry. Skilled in Computer Vision, Power BI, Image Processing, Text Extraction using Python Programming. Strong engineering professional with a PG Diploma focused in Data Science from Great Lakes Institute of Management, Gurgaon. ", "industryName": "Computer Software", "lastName": "Khandelwal", "locationName": "India", "firstName": "Sushant", "headline": "Data Scientist | AI | ML | Python | SQL |  Automation | Analytics | Azure", "public_id": "sushant-khandelwal-7296b785", "experience": [{"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Optum", "timePeriod": {"startDate": {"month": 8, "year": 2022}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Hospital & Health Care"]}, "title": "Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Info-X Software Technology Pvt Ltd", "timePeriod": {"endDate": {"month": 8, "year": 2022}, "startDate": {"month": 12, "year": 2020}}, "description": "1. Document(s) Automation \\u2013 Automated the manual process of saving various documents with the help of python using libraries like numpy, pandas, google.cloud.vision and pyodbc. The python script automated the task by reading the relevant email, downloading the attachment, extracting the required text using OCR, and saving it into the database.\\n2. Created dashboards using PowerBI for Customers and Vendors visualization, and help them analyze the trends and generate various insights.\\n3. Managed container/vessel tracking process using UI Path, SQL, and Python scripts.", "company": {"employeeCountRange": {"start": 51, "end": 200}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"locationName": "Hyderabad Area, India", "geoLocationName": "Hyderabad Area, India", "companyName": "Sgmoid", "timePeriod": {"endDate": {"month": 8, "year": 2020}, "startDate": {"month": 11, "year": 2019}}, "description": "1. Created Image Classification models to detect retinal morbidity using Fastai.\\n2. Worked on an Image Regeneration project using GANs.\\n3. Managed data entry Automation projects using UI Path and Python scripts.", "company": {"employeeCountRange": {"start": 2, "end": 10}, "industries": ["Computer Software"]}, "title": "Data Scientist"}, {"locationName": "Delhi, India", "geoLocationName": "Delhi, India", "companyName": "MOHAN THREAD MILLS PRIVATE LIMITED", "timePeriod": {"endDate": {"month": 3, "year": 2019}, "startDate": {"month": 2, "year": 2017}}, "company": {"industries": ["Textiles"]}, "title": "Family Business"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Binary Semantics Ltd.", "timePeriod": {"endDate": {"month": 1, "year": 2017}, "startDate": {"month": 10, "year": 2014}}, "description": "Managed e-commerce projects for multiple clients using their data analytically and also ensuring a better user experience. Helped clients accelerate revenue growth by analysing performance and operational excellence such as feed optimization, new product feature adoption, and data/price monitoring.", "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Computer Software"]}, "title": "Analyst"}], "education": [{"school": {"objectUrn": "urn:li:school:3153365", "entityUrn": "urn:li:fs_miniSchool:3153365", "active": true, "schoolName": "Great Lakes Institute of Management Gurgaon", "trackingId": "ulXQTL3HR+C2XNd4/1MXng==", "logoUrl": "https://media.licdn.com/dms/image/v2/D560BAQG2V_xZ3Ou0KQ/company-logo_"}, "timePeriod": {"endDate": {"month": 10, "year": 2019}, "startDate": {"month": 4, "year": 2019}}, "degreeName": "PG Diploma", "schoolName": "Great Lakes Institute of Management, Gurgaon", "fieldOfStudy": "Data Science"}, {"school": {"objectUrn": "urn:li:school:189141", "enti ...
#    '{"summary": "Experienced Data Scientist with ~4 years specializing in machine learning, NLP, and deep learning. Proficient in algorithms like Random Forest, Boosting, and Decision Tree Classifiers. Skilled in TensorFlow, Keras, and NLTK for developing high-performance applications in language modeling, predictive analytics, and statistical analysis. Seeking opportunities to apply expertise in Python programming and collaborate on impactful projects. Committed to delivering innovative solutions that drive positive change and excel in diverse challenges. Passionate about leveraging skills for groundbreaking advancements in machine learning and NLP domains, ready to make a meaningful impact through transformative outcomes", "industryName": "Computer Software", "lastName": "Bhatnagar", "locationName": "India", "firstName": "Riya", "headline": "Data Scientist", "img_364_364": "800_800/profile-displayphoto-shrink_800_800/0/1722322822594?e=1731542400&v=beta&t=KMBpt7qjNpOBlrzuhlFTslOk6BLEx_geDeR4zXpRwBI", "public_id": "riya-bhatnagar-653434190", "experience": [{"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Fractal", "timePeriod": {"startDate": {"month": 1, "year": 2024}}, "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Management Consulting"]}, "title": "Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "ZS", "timePeriod": {"endDate": {"month": 11, "year": 2023}, "startDate": {"month": 12, "year": 2021}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Management Consulting"]}, "title": "Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Dew Solutions Pvt Ltd", "timePeriod": {"endDate": {"month": 12, "year": 2021}, "startDate": {"month": 6, "year": 2020}}, "company": {"employeeCountRange": {"start": 501, "end": 1000}, "industries": ["Information Technology and Services"]}, "title": "Data Science Engineer"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Dew Solutions Pvt Ltd", "timePeriod": {"endDate": {"month": 5, "year": 2020}, "startDate": {"month": 11, "year": 2019}}, "company": {"employeeCountRange": {"start": 501, "end": 1000}, "industries": ["Information Technology and Services"]}, "title": "Data Science Intern"}, {"locationName": "Jaipur, Rajasthan", "geoLocationName": "Jaipur, Rajasthan", "companyName": "CDAC ATC Jaipur", "timePeriod": {"endDate": {"month": 8, "year": 2018}, "startDate": {"month": 6, "year": 2018}}, "company": {"employeeCountRange": {"start": 11, "end": 50}, "industries": ["Computer Software"]}, "title": "Android Trainee"}], "education": [{"school": {"objectUrn": "urn:li:school:3185138", "entityUrn": "urn:li:fs_miniSchool:3185138", "active": true, "schoolName": "Rajasthan Technical University", "trackingId": "mn/j+M5mTi2YXuElWpE6nQ==", "logoUrl": "https://media.licdn.com/dms/image/v2/C510BAQGUb3DKT_yHeQ/company-logo_"}, "fieldOfStudyUrn": "urn:li:fs_fieldOfStudy:100189", "degreeName": "Bachelor of Technology - BTech(Hons.)", "schoolName": "Rajasthan Technical University", "fieldOfStudy": "Computer Science"}, {"schoolName": "St.Mary\'s Convent Sr.Sec School"}], "languages": [{"name": "English", "proficiency": "FULL_PROFESSIONAL"}, {"name": "Hindi", "proficiency": "FULL_PROFESSIONAL"}], "publications": [], "certifications": [{"authority": "Coursera", "name": "Introduction to Data Science in Python", "timePeriod": {"startDate": {"month": 4, "year": 2019}}, "licenseNumber": "JT2NVMKHH6NP"}, {"authority": "Coursera", "name": "Machine Learning", "timePeriod": {"startDate": {"month": 4, "year": 2019}}, "licenseNumber": "CWJ2YXZHQFLU"}, {"authority": "Coursera", "name": "Neural Networks and Deep Learning", "timePeriod": {"startDate": {"month": 5, "year": 2019}}, "licenseNumber": "KFHKTR7ZQN6H"}, ...
#    '{"summary": "Experienced data scientist with a track record of translating complex data into actionable insights across diverse sectors spanning FMCG, Sports and Supply Chain.", "industryName": "Information Technology & Services", "lastName": "Srivastava", "locationName": "India", "firstName": "Vidur", "headline": "Data Scientist", "public_id": "vidur-srivastava-a45b85143", "experience": [{"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Tredence Inc.", "timePeriod": {"startDate": {"month": 7, "year": 2024}}, "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Management Consulting"]}, "title": "Data Scientist"}, {"locationName": "Bengaluru, Karnataka, India", "geoLocationName": "Bengaluru, Karnataka, India", "companyName": "Tiger Analytics", "timePeriod": {"endDate": {"month": 5, "year": 2024}, "startDate": {"month": 5, "year": 2022}}, "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Management Consulting"]}, "title": "Senior Analyst"}, {"companyName": "Wicky", "timePeriod": {"endDate": {"month": 4, "year": 2022}, "startDate": {"month": 1, "year": 2022}}, "company": {"employeeCountRange": {"start": 2, "end": 10}, "industries": ["Sports"]}, "title": "Software Engineer - MLE"}, {"locationName": "Pune, Maharashtra, India", "geoLocationName": "Pune, Maharashtra, India", "companyName": "Infosys", "timePeriod": {"endDate": {"month": 1, "year": 2022}, "startDate": {"month": 1, "year": 2022}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Senior System Engineer"}, {"locationName": "Pune, Maharashtra, India", "geoLocationName": "Pune, Maharashtra, India", "companyName": "Infosys", "timePeriod": {"endDate": {"month": 1, "year": 2022}, "startDate": {"month": 12, "year": 2019}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "System Engineer"}], "education": [{"school": {"objectUrn": "urn:li:school:478063", "entityUrn": "urn:li:fs_miniSchool:478063", "active": true, "schoolName": "BITS Pilani Work Integrated Learning Programmes", "trackingId": "H8cT6DVoT/G2/tt6yeOlUQ==", "logoUrl": "https://media.licdn.com/dms/image/v2/D560BAQFl6CQfOjKJkA/company-logo_"}, "timePeriod": {"endDate": {"month": 9, "year": 2022}, "startDate": {"month": 9, "year": 2021}}, "degreeName": "Post Graduate Certificate", "schoolName": "BITS Pilani Work Integrated Learning Programmes", "fieldOfStudy": "Artificial Intelligence and Machine Learning"}, {"school": {"objectUrn": "urn:li:school:213631", "entityUrn": "urn:li:fs_miniSchool:213631", "active": true, "schoolName": "Jaypee Institute of Information Technology, Noida", "trackingId": "PWG20fOeR7qAGxC+nAC8Uw=="}, "timePeriod": {"endDate": {"year": 2019}, "startDate": {"year": 2015}}, "degreeName": "Bachelor of Technology", "schoolName": "Jaypee Institute of Information Technology, Noida", "fieldOfStudy": "Electronics and Communications Engineering", "degreeUrn": "urn:li:fs_degree:250"}], "languages": [], "publications": [], "certifications": [], "projects": [], "urn_id": "ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4"}',
#    '{"summary": "10+ Years of  working experience in Data Engineering and Full Stack Software Engineer.\\n\\nAs a Data Engineer at Optum, I design, develop, maintain data pipelines and perform different data transformation by maintaining 99.9% data accuracy which support multiple teams data requirement at organization level which helps them in taking the right decision.\\n\\nSkill: Azure Databricks, Azure Data Factory, PySpark, Python and SQL Server.\\n\\nFull Stack Software Engineering.\\nSkills: ASP.NET, MVC, ASP.NET Core, Microsoft SQL Server and SQL Server Reporting Services (SSRS).", "industryName": "Computer Software", "lastName": "Singh", "birthDate": {"month": 6, "day": 24}, "firstName": "Manjit", "headline": "Data Scientist", "public_id": "manjit-singh-27579177", "experience": [{"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Optum", "timePeriod": {"startDate": {"month": 10, "year": 2021}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Hospital & Health Care"]}, "title": "Data Scientist"}, {"locationName": "New Delhi Area, India", "geoLocationName": "New Delhi Area, India", "companyName": "Frankfinn Aviation Services Pvt. Limited", "timePeriod": {"endDate": {"month": 10, "year": 2021}, "startDate": {"month": 10, "year": 2015}}, "description": "Software Engineer", "title": "Software Engineer"}, {"locationName": "New Delhi Area, India", "geoLocationName": "New Delhi Area, India", "companyName": "IAP Company Pvt. Ltd.", "timePeriod": {"endDate": {"month": 9, "year": 2015}, "startDate": {"month": 10, "year": 2014}}, "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Information Technology and Services"]}, "title": "Software developer"}], "education": [{"grade": "A+", "timePeriod": {"endDate": {"year": 2013}, "startDate": {"year": 2010}}, "fieldOfStudyUrn": "urn:li:fs_fieldOfStudy:100189", "degreeName": "Master of Computer Applications (MCA)", "schoolName": "Rustamji institute of technology", "fieldOfStudy": "Computer Science", "degreeUrn": "urn:li:fs_degree:594"}, {"timePeriod": {"endDate": {"year": 2010}, "startDate": {"year": 2007}}, "fieldOfStudyUrn": "urn:li:fs_fieldOfStudy:100189", "degreeName": "BCA", "schoolName": "Janhit institute of technology", "fieldOfStudy": "Computer Science"}], "languages": [], "publications": [], "certifications": [{"authority": "Coursera", "name": "Introduction to Microsoft Azure Cloud Services", "timePeriod": {"startDate": {"month": 4, "year": 2022}}, "licenseNumber": "4CKKABHHX9J9"}, {"authority": "Coursera", "name": "Programming for Everybody (Getting Started with Python)", "timePeriod": {"startDate": {"month": 7, "year": 2022}}, "licenseNumber": "PJPCU2AKRCDJ"}, {"authority": "Coursera", "name": "Python Data Structures", "licenseNumber": "JMY8GLFZKPZA"}, {"authority": "Coursera", "name": "Microsoft Azure for Data Engineering", "timePeriod": {"startDate": {"month": 3, "year": 2023}}, "licenseNumber": "HX8TFMEVJWZM"}], "projects": [], "urn_id": "ACoAABBPpTkBE83UntVzca-RXL5ggcsfztv9RRs"}',
#    '{"summary": "Experienced Data Scientist with a demonstrated history of working in the information technology and services industry. Skilled in Statistical Data Analysis, Data Science, Data Visualization, R, and Tableau. Strong information technology professional with a Master of Business Administration - MBA focused in Data Science from NIIT University..", "industryName": "Information Technology & Services", "lastName": "Singh", "locationName": "India", "firstName": "Navdeep", "headline": "Data Scientist", "public_id": "navdeep-singh-613300162", "experience": [{"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "adidas", "timePeriod": {"startDate": {"month": 6, "year": 2023}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Sporting Goods"]}, "title": "Data Scientist"}, {"locationName": "Greater Noida", "geoLocationName": "Greater Noida", "companyName": "Coforge", "timePeriod": {"endDate": {"month": 6, "year": 2023}, "startDate": {"month": 11, "year": 2020}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"locationName": "Greater Noida", "geoLocationName": "Greater Noida", "companyName": "NIIT Technologies Limited", "timePeriod": {"endDate": {"month": 10, "year": 2020}, "startDate": {"month": 11, "year": 2019}}, "company": {"employeeCountRange": {"start": 5001, "end": 10000}, "industries": ["Information Technology and Services"]}, "title": "Data Science Intern"}, {"companyName": "BT", "timePeriod": {"endDate": {"month": 7, "year": 2018}, "startDate": {"month": 9, "year": 2015}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Telecommunications"]}, "title": "Network design and planning Subject Matter Expert"}, {"companyName": "iYogi", "timePeriod": {"endDate": {"month": 9, "year": 2015}, "startDate": {"month": 2, "year": 2015}}, "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Information Technology and Services"]}, "title": "Technical Support Analyst"}], "education": [{"school": {"objectUrn": "urn:li:school:3244301", "entityUrn": "urn:li:fs_miniSchool:3244301", "active": true, "schoolName": "NIIT University", "trackingId": "4T16e7qKQu+Oz2wfYaoskA==", "logoUrl": "https://media.licdn.com/dms/image/v2/C510BAQFTJxBhS3gthg/company-logo_"}, "timePeriod": {"endDate": {"year": 2020}, "startDate": {"year": 2018}}, "degreeName": "Master of Business Administration - MBA", "schoolName": "NIIT University", "fieldOfStudy": "Data Science", "degreeUrn": "urn:li:fs_degree:700"}, {"school": {"objectUrn": "urn:li:school:362046", "entityUrn": "urn:li:fs_miniSchool:362046", "active": true, "schoolName": "Maharishi Markandeshwar (Deemed to be University) Official", "trackingId": "pSqRYVTHQ/iZ04drc7GXvw==", "logoUrl": "https://media.licdn.com/dms/image/v2/C4D0BAQF9HmCerZ7k-g/company-logo_"}, "timePeriod": {"endDate": {"year": 2012}, "startDate": {"year": 2008}}, "degreeName": "Bachelor of Technology - BTech", "schoolName": "Maharishi Markandeshwar University, Mullana", "fieldOfStudy": "Electronics and Communications Engineering", "degreeUrn": "urn:li:fs_degree:250"}], "languages": [], "publications": [], "certifications": [], "projects": [], "urn_id": "ACoAACbYB28BGp07ec7sQFVsqdcNnzxVsBhwScc"}',
#    '{"summary": "Experienced Data Scientist/Analyst with a demonstrated history of working in the computer software industry. I\'m interested in data science, machine learning, and their applications to real-world problems. I believe that humans are made for innovative work and thus all monotonous and time-consuming work should be handled by machines. I enjoy working with data, creating models, predicting and finding insights to solve business problems.", "industryName": "Information Technology & Services", "lastName": "Batra", "locationName": "India", "firstName": "Ritaksh", "headline": "Data Scientist", "public_id": "ritaksh-batra-82b915136", "experience": [{"locationName": "India", "geoLocationName": "India", "companyName": "Encora Inc.", "timePeriod": {"startDate": {"month": 4, "year": 2024}}, "company": {"employeeCountRange": {"start": 5001, "end": 10000}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "CEREBRUMX", "timePeriod": {"endDate": {"month": 4, "year": 2024}, "startDate": {"month": 7, "year": 2022}}, "company": {"employeeCountRange": {"start": 11, "end": 50}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Xceedance", "timePeriod": {"endDate": {"month": 7, "year": 2022}, "startDate": {"month": 11, "year": 2020}}, "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Insurance"]}, "title": "Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "GlobalLogic", "timePeriod": {"endDate": {"month": 7, "year": 2020}, "startDate": {"month": 3, "year": 2018}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Computer Software"]}, "title": "Senior Data Science Analyst "}], "education": [{"grade": "6.2 cgpa", "timePeriod": {"endDate": {"year": 2017}, "startDate": {"year": 2013}}, "description": "no description about me.", "degreeName": "Bachelor of Technology (BTech)", "schoolName": "Dept. of Instrumentation(USIC),kurukshetra university kurukshetra", "fieldOfStudy": "field control instrumentation", "degreeUrn": "urn:li:fs_degree:250"}, {"grade": "6.5 cgpa", "timePeriod": {"endDate": {"year": 2014}, "startDate": {"year": 2011}}, "degreeName": "diploma holder", "schoolName": "govt.polytechnic ambala city", "fieldOfStudy": " Electronics and Communications Engineering"}], "languages": [], "publications": [], "certifications": [{"authority": "Google", "name": "Advanced Google Analytics for Data Analysis ", "timePeriod": {"endDate": {"month": 10, "year": 2022}, "startDate": {"month": 10, "year": 2019}}}, {"authority": "iNeuron.ai", "name": "Machine Learning Masters", "timePeriod": {"startDate": {"month": 9, "year": 2020}}}, {"authority": "iNeuron.ai", "name": "Deep Learning Masters", "timePeriod": {"startDate": {"month": 11, "year": 2020}}}, {"authority": "iNeuron.ai", "name": "Natural Language Processing Master", "timePeriod": {"startDate": {"month": 11, "year": 2020}}}], "projects": [], "urn_id": "ACoAACE9Q2MBe_i_ol-tkC8L5lAv12dRAZez-n0"}']],
#  'uris': None,
#  'data': None,
#  'included': ['documents', 'metadatas']}

# %%
retrieved_documents = collection.query(
    query_texts="People with experience of 5 years",
    n_results=7,
    include=["documents"],
    where={
        "$or":[
            {"Data Science": "Data Science"},
            {"Machine Learning": "Machine Learning"},
            {"Python": "Python"},
            {"Statistical Techniques": "Statistical Techniques"},
            {"Software Engineering": "Software Engineering"}
        ]
    }
)["documents"]

# %%
retrieved_documents[0]
# Out:
# ['{"summary": "Experience in Cognitive Computing with leverage of Machine Learning, Deep Learning, Artificial Intelligence, Natural Language Processing skills . Data driven analyst with the ability to apply ML/DL/NLP/Computer Vision Techniques and leverage algorithms to solve real world problems. Established ability in deploying effective predictive/NLP/Computer Vision models across banking/HealthCare industries to accurately forecast and deliver proven results. Strong understanding of Oracle DB and PLSQL with data migration exp\\u00e9rience. Domain Knowledge of SupplyChain/finance/banking/Retail domain with communication skills, excellent product and process design knowledge. Domain HealthCare,Mortgage Banking, Consumer, Commercial Lending, Escrow, Loan processing and servicing, Deposits. Onsite experience (US/UK) with business domain experience in Retail and supply chain with special focus on Customer engagement and managing end-user expectations. Experience in Analysis, Design, Development, Customization, Bug fixes, Enhancement, Support and Implementation.\\n\\n\\nData Science, Machine Learning, Deep Learning and AI technologies.Strong understanding of Databases Oracle, Progress 4GL, PLSQL. Excellent Domain Knowledge of finance/banking/Retail domain with communication skills, excellent product and process design knowledge.Strong knowledge of Data Migration and Implementation.. \\n\\nAreas of Expertise: Data Science Machine Learning, Deep Learning and AI technologies.\\n\\nWeb App - Flask, Django.\\n\\nDomain - Mortgage Banking,Insurance Claim Processing Money Laundering, Investment Banking, Lending, Escrow, Loan processing and servicing. Credit Cards,Healthcare\\n\\nDatabase - Oracle,Progress 4GL,Mongo Db\\n\\nLanguages - Python ,PLSQL,Progress4GL,Shell Script\\n\\nVersioning - SVN,Github\\nCloud : IBM Cloud, AWS,AZURE,Kubernates\\nOthers : Dockers,CICD\\n\\n\\n\\n\\n10+ years of experience in exploring and understanding various business models in Finance,Healthcare,Retail and Supply chain domain with special focus on implementation according to client requirements.\\n\\u2022\\tExperience in client interaction for requirement gathering and feasibility analysis at various levels including end users, project managers, and business analysts. Possess good business acumen interacting with various 3rd parties in the same project. Onsite experience (UK) with business domain experience in Retail and supply chain with special focus on customer engagement and managing end-user expectations.", "industryName": "Information Technology & Services", "lastName": "Aneja", "locationName": "India", "firstName": "Isha", "headline": "Data Scientist IBM", "img_253_253": "800_800/profile-displayphoto-shrink_800_800/0/1516520225939?e=1731542400&v=beta&t=MK0pDwNOQmYNXZS1hxvX1-2NsHeY1lAP4O8njFxDsMs", "public_id": "isha-aneja-642b7a32", "experience": [{"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "IBM", "timePeriod": {"startDate": {"month": 12, "year": 2021}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"locationName": "New Delhi Area, India", "geoLocationName": "New Delhi Area, India", "companyName": "Fiserv", "timePeriod": {"endDate": {"month": 1, "year": 2022}, "startDate": {"month": 12, "year": 2017}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Technical Lead"}, {"locationName": "Noida Area, India", "geoLocationName": "Noida Area, India", "companyName": "Birlasoft", "timePeriod": {"endDate": {"month": 12, "year": 2017}, "startDate": {"month": 8, "year": 2016}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Senior Software Engineer"}, {"locationName": "banglore", "geoLocationName": "banglore", "companyName": "Capgemini", "timePeriod": {"endDate": ...
#  '{"summary": "Experience Data Science professional with demonstrated history of working in IT service industry. Experienced in executing data driven solutions to increase efficiency, accuracy and utility of internal data processing. Skilled in natural language processing with practioner knowledge on Web Analytics. Strong information technology professional with a Bachelor of Technology (BTech) from Uttar Pradesh Technical University. ", "industryName": "Information Technology & Services", "lastName": "Mathur", "locationName": "India", "firstName": "Tushar", "headline": "Data Scientist", "img_413_413": "800_800/profile-displayphoto-shrink_800_800/0/1627636616827?e=1731542400&v=beta&t=622aY-HtcQSxqycM6kkJLZJgkr1xzh3_7jhWSE28UXg", "public_id": "tushar-mathur-79a23120", "experience": [{"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "Coforge", "timePeriod": {"startDate": {"month": 8, "year": 2022}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Analytics Lead"}, {"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "EXL", "timePeriod": {"endDate": {"month": 8, "year": 2022}, "startDate": {"month": 8, "year": 2021}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Technical Lead"}, {"locationName": "Noida Area, India", "geoLocationName": "Noida Area, India", "companyName": "Sopra Steria", "timePeriod": {"endDate": {"month": 7, "year": 2021}, "startDate": {"month": 7, "year": 2019}}, "description": "Working on information extraction project in which we focuses on creating structured representation of unstructured/structured texts by extracting relevant entities from them, using machine learning and AI process thereby making the data analysis realizable.", "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Module Lead"}, {"locationName": "Noida Area, India", "geoLocationName": "Noida Area, India", "companyName": "Sopra Steria", "timePeriod": {"endDate": {"month": 6, "year": 2019}, "startDate": {"month": 10, "year": 2017}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Senior Software Engineer", "honors": ["urn:li:fs_honor:(ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY,1097608354)"]}, {"locationName": "Gurgaon, India", "geoLocationName": "Gurgaon, India", "companyName": "Infosys", "timePeriod": {"endDate": {"month": 10, "year": 2017}, "startDate": {"month": 10, "year": 2016}}, "description": "\\u2022Working knowledge of Agile and Waterfall models.\\n\\u2022Working in full project life cycle involving Requirement Analysis, Testing and Implementation phases.\\n\\u2022Extensive coding and modifying programs using COBOL, DB2 and JCL as per the requests of business departments.\\n\\u2022Involved in Preparing Unit test cases, doing test data setup and performing Unit testing, User Acceptance Testing.\\n\\u2022Works on envisioning of requirement for future analysis.", "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Senior System Engineer", "honors": ["urn:li:fs_honor:(ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY,1304876652)", "urn:li:fs_honor:(ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY,1020421066)"]}], "education": [{"timePeriod": {"endDate": {"year": 2014}, "startDate": {"year": 2010}}, "degreeName": "Bachelor of Technology (BTech)", "schoolName": "Uttar Pradesh Technical University", "fieldOfStudy": "Electrical, Electronics and Communications Engineering"}], "languages": [{"name": "English", "proficiency": "PROFESSIONAL_WORKING"}, {"name": "Hindi", "proficiency": "NATIVE_OR_BILINGUAL"}], "publications": [], "certifications": [{"authority": "Coursera", "name": "IBM Data Science Specializa ...
#  '{"summary": "\\u2022\\tExperience of 7 years as Data Scientist (August 2016 \\u2013 Till Date) in implementing advanced analytics and predictive modelling algorithms such as Sequence models, Machine translation, Text summarization, Voice enabled Bot (using GPT2, Deepspeech and Azure cognitive services),Text Extraction using BERT and Spacy, Text Classification, Credit Risk analysis, Logistic regression, Decision tree ,Ensemble models, KNN, PCA, t-SNE, Linear regression, Clustering (k-means, Agglomerative)\\n\\u2022\\tExperience of 1.6 years (Nov 2014 \\u2013 Aug 2016) in Siebel CRM.\\n\\u2022\\tWell converse with Python(Pandas, Numpy, Scikit-Learn, Keras, matplotlib.pyplot, seaborn), Flask API, ML model deployments, AWS Services, linux, SQL ,Core Java and Siebel CRM.", "industryName": "Information Technology & Services", "lastName": "Kharbanda", "locationName": "India", "firstName": "Sumeet", "headline": "Looking for Data Science Opportunities  | Manager - Data Scientist @ EXL | NLP | Freelancer", "img_450_450": "800_800/profile-displayphoto-shrink_800_800/0/1517470892367?e=1731542400&v=beta&t=WkpZbUOBkt9zAX7RDthG9tVfXjgi3i-bat3dRDqpGgw", "public_id": "sumeet-data-scientist", "experience": [{"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "EXL", "timePeriod": {"startDate": {"month": 4, "year": 2022}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Manager - Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "EXL", "timePeriod": {"endDate": {"month": 4, "year": 2022}, "startDate": {"month": 11, "year": 2020}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Technical Lead - Data Scientist"}, {"courses": ["urn:li:fs_course:(ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0,504009401)", "urn:li:fs_course:(ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0,504035397)"], "locationName": "Gurgaon, Haryana, India", "geoLocationName": "Gurgaon, Haryana, India", "companyName": "UnitedHealth Group", "timePeriod": {"endDate": {"month": 11, "year": 2020}, "startDate": {"month": 8, "year": 2019}}, "description": "Development and deployment of machine learning models in python, text analytics,disease prediction, voice bot and chat bot.", "company": {"employeeCountRange": {"start": 10001}, "industries": ["Hospital & Health Care"]}, "title": "Associate Data Scientist"}, {"locationName": "Gurgaon, Haryana, India", "geoLocationName": "Gurgaon, Haryana, India", "companyName": "dunnhumby", "timePeriod": {"endDate": {"month": 8, "year": 2019}, "startDate": {"month": 6, "year": 2019}}, "description": "Adhoc analysis of retail client, worked on pyspark, python, SQL, excel dashboards", "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Marketing and Advertising"]}, "title": "Applied Data Scientist"}, {"courses": ["urn:li:fs_course:(ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0,503992293)"], "locationName": "Chandigarh Area, India", "geoLocationName": "Chandigarh Area, India", "companyName": "Infosys", "timePeriod": {"endDate": {"month": 5, "year": 2019}, "startDate": {"month": 4, "year": 2018}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Technology Analyst"}], "education": [{"school": {"objectUrn": "urn:li:school:354045", "entityUrn": "urn:li:fs_miniSchool:354045", "active": true, "schoolName": "International Institute of Information Technology Bangalore", "trackingId": "F/PLHzg7RgerGGAq0r8C2g==", "logoUrl": "https://media.licdn.com/dms/image/v2/D560BAQEocmV8HEnx7w/company-logo_"}, "timePeriod": {"endDate": {"year": 2021}, "startDate": {"year": 2020}}, "degreeName": "PGC", "schoolName": "International Institute of Information Technology Bangalore", "fieldOfStudy": "Data Science"}, {"school": {"objectUrn":  ...
#  '{"summary": "4+ years of work experience solving business problems with the application of Data Science. Master of Data Science, Monash University (Melbourne). Proficient in Generative AI, Computer Vision and Predictive Modeling. With a strong grip over mathematics, deep learning and machine learning algorithms, capable to transform business requirements into data science formulations and implementing the solutions in an efficient and scalable fashion.\\n\\nCreating impactful AI solutions at R Systems, my focus is on designing cutting-edge generative AI technologies. With a Master\'s degree in Data Science from Monash University, I apply rigorous academic training to address complex client challenges. Our team\'s contribution has significantly enhanced the RAG Application\'s accuracy, showcasing a blend of innovation and practical application.\\n\\nMy core competencies lie in Large Language Models and transformative AI, underpinned by data collection, preprocessing, model development, and deployment. These skills have enabled us to deliver tailored solutions that not only meet but exceed our clients\' business objectives. The dedication to continual learning and improvement is what drives the team and myself to achieve excellence in the ever-evolving field of data science.", "industryName": "Computer Software", "lastName": "Nain", "locationName": "India", "birthDate": {"month": 1, "day": 24}, "firstName": "Rakesh", "headline": "Data Scientist @ R Systems | Master\'s in Data Science", "public_id": "rakeshnain", "experience": [{"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "R Systems", "timePeriod": {"startDate": {"month": 8, "year": 2023}}, "description": "Roles and Responsibilities:\\n- Tackle client challenges by designing and implement end-to-end data science solutions using generative AI (LLMs, Large Multi-Modals and their finetuning based on the use cases) or traditional machine learning from data collection, preprocessing to model development and deployment\\n- I ensure optimal model performance, engage in cross-functional collaboration, and deliver insights to clients through effective communication.\\n- My role contributes to R systems consultancy prowess in delivering innovative and impactful solutions that address diverse business needs of clients.\\n\\nAchievements:\\n- Increased the RAG Application accuracy by 40%.", "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"companyName": "Intello Labs", "timePeriod": {"endDate": {"month": 8, "year": 2023}, "startDate": {"month": 12, "year": 2021}}, "description": "Roles and Responsibilities:\\n- Develop state-of-the-art machine learning and deep learning algorithms/models for visual recognition tasks, such as segmentation and detection.\\n- Collaborate closely with multidisciplinary teams of software engineers, hardware engineers, business leaders and other key players to develop Artificial Intelligent machines.\\n- Data Collection, EDA, Data Cleaning, ML Model Development(R&D) and deployment.\\n\\nAchievements:\\n- Developed object detection and instance segmentation algorithm taking around 50 times less RAM in training with only twice extra time in inference as compared to present state-of-the-art algorithms in the market.\\n- Improved grains classification results by 20%, and fruits defect detection results by 12%.", "company": {"employeeCountRange": {"start": 51, "end": 200}, "industries": ["Information Technology and Services"]}, "title": "Deep Learning Engineer"}, {"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "DishTV", "timePeriod": {"endDate": {"month": 10, "year": 2018}, "startDate": {"month": 6, "year": 2017}}, "description": "Roles and Responsibilities:\\nStarted as a Software Developer in the \\u201cMy DishTV\\u201d Android App proj ...
#  '{"summary": "Experienced Data Scientist with a demonstrated history of working in the computer software industry. Skilled in Computer Vision, Power BI, Image Processing, Text Extraction using Python Programming. Strong engineering professional with a PG Diploma focused in Data Science from Great Lakes Institute of Management, Gurgaon. ", "industryName": "Computer Software", "lastName": "Khandelwal", "locationName": "India", "firstName": "Sushant", "headline": "Data Scientist | AI | ML | Python | SQL |  Automation | Analytics | Azure", "public_id": "sushant-khandelwal-7296b785", "experience": [{"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Optum", "timePeriod": {"startDate": {"month": 8, "year": 2022}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Hospital & Health Care"]}, "title": "Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Info-X Software Technology Pvt Ltd", "timePeriod": {"endDate": {"month": 8, "year": 2022}, "startDate": {"month": 12, "year": 2020}}, "description": "1. Document(s) Automation \\u2013 Automated the manual process of saving various documents with the help of python using libraries like numpy, pandas, google.cloud.vision and pyodbc. The python script automated the task by reading the relevant email, downloading the attachment, extracting the required text using OCR, and saving it into the database.\\n2. Created dashboards using PowerBI for Customers and Vendors visualization, and help them analyze the trends and generate various insights.\\n3. Managed container/vessel tracking process using UI Path, SQL, and Python scripts.", "company": {"employeeCountRange": {"start": 51, "end": 200}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"locationName": "Hyderabad Area, India", "geoLocationName": "Hyderabad Area, India", "companyName": "Sgmoid", "timePeriod": {"endDate": {"month": 8, "year": 2020}, "startDate": {"month": 11, "year": 2019}}, "description": "1. Created Image Classification models to detect retinal morbidity using Fastai.\\n2. Worked on an Image Regeneration project using GANs.\\n3. Managed data entry Automation projects using UI Path and Python scripts.", "company": {"employeeCountRange": {"start": 2, "end": 10}, "industries": ["Computer Software"]}, "title": "Data Scientist"}, {"locationName": "Delhi, India", "geoLocationName": "Delhi, India", "companyName": "MOHAN THREAD MILLS PRIVATE LIMITED", "timePeriod": {"endDate": {"month": 3, "year": 2019}, "startDate": {"month": 2, "year": 2017}}, "company": {"industries": ["Textiles"]}, "title": "Family Business"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Binary Semantics Ltd.", "timePeriod": {"endDate": {"month": 1, "year": 2017}, "startDate": {"month": 10, "year": 2014}}, "description": "Managed e-commerce projects for multiple clients using their data analytically and also ensuring a better user experience. Helped clients accelerate revenue growth by analysing performance and operational excellence such as feed optimization, new product feature adoption, and data/price monitoring.", "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Computer Software"]}, "title": "Analyst"}], "education": [{"school": {"objectUrn": "urn:li:school:3153365", "entityUrn": "urn:li:fs_miniSchool:3153365", "active": true, "schoolName": "Great Lakes Institute of Management Gurgaon", "trackingId": "ulXQTL3HR+C2XNd4/1MXng==", "logoUrl": "https://media.licdn.com/dms/image/v2/D560BAQG2V_xZ3Ou0KQ/company-logo_"}, "timePeriod": {"endDate": {"month": 10, "year": 2019}, "startDate": {"month": 4, "year": 2019}}, "degreeName": "PG Diploma", "schoolName": "Great Lakes Institute of Management, Gurgaon", "fieldOfStudy": "Data Science"}, {"school": {"objectUrn": "urn:li:school:189141", "entity ...
#  '{"summary": "Experienced Data Scientist with ~4 years specializing in machine learning, NLP, and deep learning. Proficient in algorithms like Random Forest, Boosting, and Decision Tree Classifiers. Skilled in TensorFlow, Keras, and NLTK for developing high-performance applications in language modeling, predictive analytics, and statistical analysis. Seeking opportunities to apply expertise in Python programming and collaborate on impactful projects. Committed to delivering innovative solutions that drive positive change and excel in diverse challenges. Passionate about leveraging skills for groundbreaking advancements in machine learning and NLP domains, ready to make a meaningful impact through transformative outcomes", "industryName": "Computer Software", "lastName": "Bhatnagar", "locationName": "India", "firstName": "Riya", "headline": "Data Scientist", "img_364_364": "800_800/profile-displayphoto-shrink_800_800/0/1722322822594?e=1731542400&v=beta&t=KMBpt7qjNpOBlrzuhlFTslOk6BLEx_geDeR4zXpRwBI", "public_id": "riya-bhatnagar-653434190", "experience": [{"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Fractal", "timePeriod": {"startDate": {"month": 1, "year": 2024}}, "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Management Consulting"]}, "title": "Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "ZS", "timePeriod": {"endDate": {"month": 11, "year": 2023}, "startDate": {"month": 12, "year": 2021}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Management Consulting"]}, "title": "Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Dew Solutions Pvt Ltd", "timePeriod": {"endDate": {"month": 12, "year": 2021}, "startDate": {"month": 6, "year": 2020}}, "company": {"employeeCountRange": {"start": 501, "end": 1000}, "industries": ["Information Technology and Services"]}, "title": "Data Science Engineer"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Dew Solutions Pvt Ltd", "timePeriod": {"endDate": {"month": 5, "year": 2020}, "startDate": {"month": 11, "year": 2019}}, "company": {"employeeCountRange": {"start": 501, "end": 1000}, "industries": ["Information Technology and Services"]}, "title": "Data Science Intern"}, {"locationName": "Jaipur, Rajasthan", "geoLocationName": "Jaipur, Rajasthan", "companyName": "CDAC ATC Jaipur", "timePeriod": {"endDate": {"month": 8, "year": 2018}, "startDate": {"month": 6, "year": 2018}}, "company": {"employeeCountRange": {"start": 11, "end": 50}, "industries": ["Computer Software"]}, "title": "Android Trainee"}], "education": [{"school": {"objectUrn": "urn:li:school:3185138", "entityUrn": "urn:li:fs_miniSchool:3185138", "active": true, "schoolName": "Rajasthan Technical University", "trackingId": "mn/j+M5mTi2YXuElWpE6nQ==", "logoUrl": "https://media.licdn.com/dms/image/v2/C510BAQGUb3DKT_yHeQ/company-logo_"}, "fieldOfStudyUrn": "urn:li:fs_fieldOfStudy:100189", "degreeName": "Bachelor of Technology - BTech(Hons.)", "schoolName": "Rajasthan Technical University", "fieldOfStudy": "Computer Science"}, {"schoolName": "St.Mary\'s Convent Sr.Sec School"}], "languages": [{"name": "English", "proficiency": "FULL_PROFESSIONAL"}, {"name": "Hindi", "proficiency": "FULL_PROFESSIONAL"}], "publications": [], "certifications": [{"authority": "Coursera", "name": "Introduction to Data Science in Python", "timePeriod": {"startDate": {"month": 4, "year": 2019}}, "licenseNumber": "JT2NVMKHH6NP"}, {"authority": "Coursera", "name": "Machine Learning", "timePeriod": {"startDate": {"month": 4, "year": 2019}}, "licenseNumber": "CWJ2YXZHQFLU"}, {"authority": "Coursera", "name": "Neural Networks and Deep Learning", "timePeriod": {"startDate": {"month": 5, "year": 2019}}, "licenseNumber": "KFHKTR7ZQN6H"}, { ...
#  '{"summary": "Experienced data scientist with a track record of translating complex data into actionable insights across diverse sectors spanning FMCG, Sports and Supply Chain.", "industryName": "Information Technology & Services", "lastName": "Srivastava", "locationName": "India", "firstName": "Vidur", "headline": "Data Scientist", "public_id": "vidur-srivastava-a45b85143", "experience": [{"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Tredence Inc.", "timePeriod": {"startDate": {"month": 7, "year": 2024}}, "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Management Consulting"]}, "title": "Data Scientist"}, {"locationName": "Bengaluru, Karnataka, India", "geoLocationName": "Bengaluru, Karnataka, India", "companyName": "Tiger Analytics", "timePeriod": {"endDate": {"month": 5, "year": 2024}, "startDate": {"month": 5, "year": 2022}}, "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Management Consulting"]}, "title": "Senior Analyst"}, {"companyName": "Wicky", "timePeriod": {"endDate": {"month": 4, "year": 2022}, "startDate": {"month": 1, "year": 2022}}, "company": {"employeeCountRange": {"start": 2, "end": 10}, "industries": ["Sports"]}, "title": "Software Engineer - MLE"}, {"locationName": "Pune, Maharashtra, India", "geoLocationName": "Pune, Maharashtra, India", "companyName": "Infosys", "timePeriod": {"endDate": {"month": 1, "year": 2022}, "startDate": {"month": 1, "year": 2022}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Senior System Engineer"}, {"locationName": "Pune, Maharashtra, India", "geoLocationName": "Pune, Maharashtra, India", "companyName": "Infosys", "timePeriod": {"endDate": {"month": 1, "year": 2022}, "startDate": {"month": 12, "year": 2019}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "System Engineer"}], "education": [{"school": {"objectUrn": "urn:li:school:478063", "entityUrn": "urn:li:fs_miniSchool:478063", "active": true, "schoolName": "BITS Pilani Work Integrated Learning Programmes", "trackingId": "H8cT6DVoT/G2/tt6yeOlUQ==", "logoUrl": "https://media.licdn.com/dms/image/v2/D560BAQFl6CQfOjKJkA/company-logo_"}, "timePeriod": {"endDate": {"month": 9, "year": 2022}, "startDate": {"month": 9, "year": 2021}}, "degreeName": "Post Graduate Certificate", "schoolName": "BITS Pilani Work Integrated Learning Programmes", "fieldOfStudy": "Artificial Intelligence and Machine Learning"}, {"school": {"objectUrn": "urn:li:school:213631", "entityUrn": "urn:li:fs_miniSchool:213631", "active": true, "schoolName": "Jaypee Institute of Information Technology, Noida", "trackingId": "PWG20fOeR7qAGxC+nAC8Uw=="}, "timePeriod": {"endDate": {"year": 2019}, "startDate": {"year": 2015}}, "degreeName": "Bachelor of Technology", "schoolName": "Jaypee Institute of Information Technology, Noida", "fieldOfStudy": "Electronics and Communications Engineering", "degreeUrn": "urn:li:fs_degree:250"}], "languages": [], "publications": [], "certifications": [], "projects": [], "urn_id": "ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4"}']

# %% [markdown]
# # Some Other Retrieval Techniques

# %% [markdown]
# ### 1. Normal Technique

# %%
# Setting up Langsmith

os.environ['LANGCHAIN_TRACING_V2'] = 'true'
os.environ['LANGCHAIN_ENDPOINT'] = 'https://api.smith.langchain.com'
os.environ['LANGCHAIN_API_KEY'] = os.getenv("LANGCHAIN_API_KEY")

# %%
JOB_DESCRIPTION = """
Save Data Scientist - India  at Netflix
About the job
Netflix is one of the world leading entertainment services with 278 million paid memberships in over 190 countries enjoying TV series, films and games across a wide variety of genres and languages. Members can play, pause and resume watching as much as they want, anytime, anywhere, and can change their plans at any time.

The Role

Netflix is one of the world's leading entertainment services, with 270 million paid memberships in over 190 countries enjoying TV series, films and games across a wide variety of genres and languages. Members can play, pause and resume watching as much as the want, anytime, anywhere, and can change their plans at any time. Our mission to entertain the world is anchored in our content, and data is a crucial component in shaping our comprehensive content strategy. We focus on creating analytical products that support our content partners in their complex and nuanced decision-making processes. We are a highly collaborative team that partners across Netflix to drive impact. We are seeking a talented Senior Data Scientist to provide key insights to our content decision makers in India. You will generate insights by scoping and executing deep dive analysis with local partner analytics teams, Consumer Insights and Finance & Strategy. In success, you will collaborate on existing priorities but also will propose and execute on new opportunities. This role features ample opportunity for project ownership and will support impactful decision-making. In this role you will

Be a strategic thought partner with business stakeholders to define high impact analytical problems and innovative ways to solve them with data.
Develop statistical models explaining viewership, content engagement, and other key behavioral patterns
Build dashboards and visualization that enables stakeholders to self-serve metrics and trends effectively. 
Actively socialize and educate, aiding on interpretation
Translate analytic insights into actionable recommendations for business or content improvement, and communicate these findings clearly to a broad audienceIdentify and proactively socialize regional insights, including those that may generalize to opportunities in other markets

What you will bring

Exceptional interpersonal and communication skills to influence stakeholders using clear insights and recommendations
Exceptional thought partnership to build credibility and relationships with stakeholders
Strong statistical knowledge: understanding of predictive modeling; ability to tease out incrementality vs. correlations, confounder identification and amelioration, etc.
Basic understanding of experimentation including power calculations and interpretation of results
Strong SQL skills and experience with distributed analytic processing technologies (S3, Presto, Hive & Spark)
Strong skills in Python or R
Highly effective in engaging with diverse stakeholders and adept at cultivating strong partnerships. P
assionate about communicating difficult concepts to non-technical audiencesSelf-starter who thrives under a high level of autonomy.
Exceptional interpersonal and communication skills.
Enthusiastic about Netflix culture

We are an equal opportunity employer and celebrate diversity, recognizing that diversity of thought and background builds stronger teams. We approach diversity and inclusion seriously and thoughtfully. We do not discriminate on the basis of race, ethnicity, religion, color, place of birth, sex, gender identity or expression, sexual orientation, age, marital status, military service status or disability status.
"""

# %%
from langchain_core.prompts.chat import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq

# %%
def get_candidates_profiles(relevant_docs: list[str], job_description: str) -> str:
    PROMT_TEMPLATE = [
        (
            "system",
            "Act as a HR of a company who is looking for some candidates to fill a job position",
        ),
        (
            "ai",
            """
            You will be given a job description and some candidates profiles. You first need to analyse the\
            job description step-by-step. After that analyse each job profile. Once all these done\
            then you need to compare each job profile with the job description and then report out 3 potential\
            candidate which is most suitable for the job.\
            
            ###
            The output should contain the candidate name, his years of experience, his job skills and his linkedin profile url, his present company (NO PREAMBLE)
            ###
            
            ***YOUR ANASWER SHOULD COMES FROM THE GIVEN JOB PROFILES ONLY AND NOTHING ELSE.***
            """,
        ),
        (
            "human",
            (
                "Job Description: {job_description} \n\n Candidates Profiles: {candidate_profiles}"
            ),
        ),
    ]

    job_search_prompt = ChatPromptTemplate.from_messages(PROMT_TEMPLATE)

    llama_model = ChatGroq(
        api_key=os.environ["GROQ_API_KEY"], model="llama-3.1-70b-versatile"
    )

    # Creating Chain for retrieval
    chain = job_search_prompt | llama_model | StrOutputParser()

    return chain.invoke(
        {"candidate_profiles": relevant_docs, "job_description": job_description}
    )

# %%
result = get_candidates_profiles(
    relevant_docs=retrieved_documents[0],
    job_description=JOB_DESCRIPTION
)

# %%
print(result)
# Out:
# After analyzing the job description and the candidates' profiles, I've identified the top three candidates who are most suitable for the Senior Data Scientist position at Netflix India. Here are their profiles:
#
# **Candidate 1: Sakshi Narwani**
#
# * Years of experience: 4+
# * Job skills: Data Science, Machine Learning, Python, R, SQL, Predictive Modeling, Data Visualization
# * LinkedIn profile: https://www.linkedin.com/in/sakshinarwani/
# * Current company: EXL
# * Education: PG Diploma in Data Science from International Institute of Information Technology Bangalore
#
# **Candidate 2: Sumeet Kharbanda**
#
# * Years of experience: 7+
# * Job skills: Data Science, Machine Learning, Python, SQL, Predictive Modeling, Natural Language Processing
# * LinkedIn profile: https://www.linkedin.com/in/sumeet-data-scientist/
# * Current company: EXL
# * Education: PG Diploma in Data Science from International Institute of Information Technology Bangalore
#
# **Candidate 3: Rakesh Nain**
#
# * Years of experience: 4+
# * Job skills: Data Science, Machine Learning, Python, SQL, Predictive Modeling, Generative AI, Computer Vision
# * LinkedIn profile: https://www.linkedin.com/in/rakeshnain/
# * Current company: R Systems
# * Education: Master's degree in Data Science from Monash University
#
# These candidates have a strong background in data science and machine learning, with experience in predictive modeling, data visualization, and natural language processing. They also have a good understanding of programming languages such as Python and SQL. Additionally, they have a strong educational background in data science and related fields.

# %%
def extract_keywords(job_description: str) -> str:    
    simple_prompt = """
    You will be given a job description. You need to analyse the job description completely first step by step
    and after that you need to extract  TOP 5 IMPORTANT keywords which are essential for this job description.

    <Output Format>
    Print the final output in comma separated list (NO PREAMBLE). NOTHING ELSE NEEDED IN THE OUTPUT.
    </Output Format>

    *** YOUR OUTPUT SHOULD COME ONLY FROM THE PROVIDED DATA AND NOTHING ELSE. DO NOT ASSUME ANYTHING FROM YOUR SIDE."

    Job Description: {job_description}
    """

    promt = ChatPromptTemplate.from_template(simple_prompt)

    chain = (
        promt
        | llama_model
        | StrOutputParser()
    )

    return chain.invoke(job_description)

# %%
keywords = extract_keywords(JOB_DESCRIPTION)

# %%
print(keywords)
# Out:
# Data Scientist, Statistical Modeling, Python, Data Analysis, Machine Learning

# %%
keywords_list = keywords.split(", ")

keywords_list
# Out:
# ['Data Scientist',
#  'Statistical Modeling',
#  'Python',
#  'Data Analysis',
#  'Machine Learning']

# %%
retrieved_documents = collection.query(
    query_texts=JOB_DESCRIPTION,
    n_results=7,
    include=["documents"],
    where={
        "$or":[
            {keywords_list[0]: keywords_list[0]},
            {keywords_list[1]: keywords_list[1]},
            {keywords_list[2]: keywords_list[2]},
            {keywords_list[3]: keywords_list[3]},
            {keywords_list[4]: keywords_list[4]},
        ]
    }
)["documents"]

# %%
retrieved_documents
# Out:
# [['{"summary": "As a Data Science professional holding a Post Graduate Diploma, I am deeply committed to the process of extracting actionable insights from complex datasets. My expertise spans a broad spectrum of data-related domains, encompassing advanced data analytics and machine learning techniques. I have honed my proficiency in utilizing an extensive array of cutting-edge tools and technologies, ensuring that I possess the versatility required to excel in diverse data-driven environments. My dedication to harnessing the power of data for informed decision-making is a driving force behind my professional endeavors.", "industryName": "Information Technology & Services", "lastName": "Narwani", "locationName": "India", "firstName": "Sakshi", "headline": "Data Scientist", "img_641_641": "800_800/profile-displayphoto-shrink_800_800/0/1694867340481?e=1731542400&v=beta&t=CjqB-VZoSUqQEhpxAXAAl60m-ssqzvotpYlrElmXu0c", "public_id": "sakshinarwani", "experience": [{"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "EXL", "timePeriod": {"startDate": {"month": 12, "year": 2021}}, "description": "Creating a predictive model with the aim of identifying zero-cost claims, thereby streamlining and enhancing the overall efficiency and effectiveness of operations within the claims department.\\n\\nImplementing Generalized Linear Model (GLM) modules as part of a strategic effort to optimize various operational processes and procedures, leading to increased efficiency and improved outcomes.\\n\\nCollaborated with a prominent US-based insurance company to address data-driven challenges within the realm of attorney representation in Claims Analytics. My role encompassed the exploration and resolution of complex issues, leveraging data insights to enhance the decision-making process and streamline attorney representation strategies.", "company": {"employeeCountRange": {"start": 10001}, "industries": ["Insurance"]}, "title": "Assistant Manager Analytics Consultant"}, {"companyName": "upGrad", "timePeriod": {"startDate": {"month": 1, "year": 2022}}, "description": "Providing expert guidance to prospective learners, aiding them in making well-informed decisions regarding their professional education journey. This involves offering comprehensive information, personalized advice, and valuable insights to empower individuals to choose the most suitable educational path aligned with their career aspirations and goals.", "company": {"employeeCountRange": {"start": 10001}, "industries": ["E-Learning"]}, "title": "Student Mentor"}, {"companyName": "Accenture in India", "timePeriod": {"endDate": {"month": 11, "year": 2021}, "startDate": {"month": 11, "year": 2020}}, "description": "Designed and developed a sophisticated predictive model for a Financial Services (FS) client. This project centered on the utilization of Market Mix Modelling (MMM) techniques to provide the business with a comprehensive understanding of the influence that various marketing channels exert on sales and return on investment (ROI).", "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Application Development Analyst"}, {"companyName": "Accenture in India", "timePeriod": {"endDate": {"month": 11, "year": 2020}, "startDate": {"month": 11, "year": 2018}}, "description": "In the Financial Services (FS) domain, my role as a Data Analyst encompassed a multifaceted set of responsibilities:\\n1. Data Analysis: Conducted comprehensive data intelligence and analysis using an array of tools including MS SQL and Python.\\n2. Big Data Management: Oversaw the maintenance of data within a robust big data environment, ensuring its integrity and accessibility.\\n3. Reporting: Generated detailed reports that presented insights derived from data analysis, contributing to informed decision-making.\\n4. Ad Hoc Support: Responded promptly to ad hoc data queries, offering agile solutio ...
#   '{"summary": "\\u2022\\tExperience of 7 years as Data Scientist (August 2016 \\u2013 Till Date) in implementing advanced analytics and predictive modelling algorithms such as Sequence models, Machine translation, Text summarization, Voice enabled Bot (using GPT2, Deepspeech and Azure cognitive services),Text Extraction using BERT and Spacy, Text Classification, Credit Risk analysis, Logistic regression, Decision tree ,Ensemble models, KNN, PCA, t-SNE, Linear regression, Clustering (k-means, Agglomerative)\\n\\u2022\\tExperience of 1.6 years (Nov 2014 \\u2013 Aug 2016) in Siebel CRM.\\n\\u2022\\tWell converse with Python(Pandas, Numpy, Scikit-Learn, Keras, matplotlib.pyplot, seaborn), Flask API, ML model deployments, AWS Services, linux, SQL ,Core Java and Siebel CRM.", "industryName": "Information Technology & Services", "lastName": "Kharbanda", "locationName": "India", "firstName": "Sumeet", "headline": "Looking for Data Science Opportunities  | Manager - Data Scientist @ EXL | NLP | Freelancer", "img_450_450": "800_800/profile-displayphoto-shrink_800_800/0/1517470892367?e=1731542400&v=beta&t=WkpZbUOBkt9zAX7RDthG9tVfXjgi3i-bat3dRDqpGgw", "public_id": "sumeet-data-scientist", "experience": [{"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "EXL", "timePeriod": {"startDate": {"month": 4, "year": 2022}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Manager - Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "EXL", "timePeriod": {"endDate": {"month": 4, "year": 2022}, "startDate": {"month": 11, "year": 2020}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Technical Lead - Data Scientist"}, {"courses": ["urn:li:fs_course:(ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0,504009401)", "urn:li:fs_course:(ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0,504035397)"], "locationName": "Gurgaon, Haryana, India", "geoLocationName": "Gurgaon, Haryana, India", "companyName": "UnitedHealth Group", "timePeriod": {"endDate": {"month": 11, "year": 2020}, "startDate": {"month": 8, "year": 2019}}, "description": "Development and deployment of machine learning models in python, text analytics,disease prediction, voice bot and chat bot.", "company": {"employeeCountRange": {"start": 10001}, "industries": ["Hospital & Health Care"]}, "title": "Associate Data Scientist"}, {"locationName": "Gurgaon, Haryana, India", "geoLocationName": "Gurgaon, Haryana, India", "companyName": "dunnhumby", "timePeriod": {"endDate": {"month": 8, "year": 2019}, "startDate": {"month": 6, "year": 2019}}, "description": "Adhoc analysis of retail client, worked on pyspark, python, SQL, excel dashboards", "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Marketing and Advertising"]}, "title": "Applied Data Scientist"}, {"courses": ["urn:li:fs_course:(ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0,503992293)"], "locationName": "Chandigarh Area, India", "geoLocationName": "Chandigarh Area, India", "companyName": "Infosys", "timePeriod": {"endDate": {"month": 5, "year": 2019}, "startDate": {"month": 4, "year": 2018}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Technology Analyst"}], "education": [{"school": {"objectUrn": "urn:li:school:354045", "entityUrn": "urn:li:fs_miniSchool:354045", "active": true, "schoolName": "International Institute of Information Technology Bangalore", "trackingId": "F/PLHzg7RgerGGAq0r8C2g==", "logoUrl": "https://media.licdn.com/dms/image/v2/D560BAQEocmV8HEnx7w/company-logo_"}, "timePeriod": {"endDate": {"year": 2021}, "startDate": {"year": 2020}}, "degreeName": "PGC", "schoolName": "International Institute of Information Technology Bangalore", "fieldOfStudy": "Data Science"}, {"school": {"objectUrn": ...
#   '{"summary": "Analytics professional who thrives on data and insights. I like to leverage my problem solving and analytical skills to help businesses in making key strategic decisions. I consider myself a highly motivated professional who looks forward to getting out of the comfort zone and doing some real rigorous work!\\n\\nPrimary Skills:\\n\\u2022 Python - Data Analysis (Numpy, Pandas, Scikit-learn, etc.) \\n\\u2022 SQL, Google BigQuery \\n\\u2022 Visualizations - Power BI, Tableau \\n\\u2022 Python scripting and automations\\n\\u2022 Linux/UNIX server management\\n\\u2022 Docker for application deployment", "industryName": "Information Technology & Services", "lastName": "Kotnala", "locationName": "India", "firstName": "Deepankar", "headline": "Data Scientist | IIIT Bangalore", "img_401_401": "800_800/profile-framedphoto-shrink_800_800/0/1724930913918?e=1726506000&v=beta&t=NVm9wimch5B2zxDqE27-0dJJbCAKd9nP72Rh_bylN9g", "public_id": "deepankarkotnala", "experience": [{"locationName": "India", "geoLocationName": "India", "companyName": "TCG Digital", "timePeriod": {"startDate": {"month": 8, "year": 2022}}, "company": {"employeeCountRange": {"start": 201, "end": 500}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"locationName": "India", "geoLocationName": "India", "companyName": "Genpact", "timePeriod": {"endDate": {"month": 8, "year": 2022}, "startDate": {"month": 10, "year": 2020}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Management Consulting"]}, "title": "Data Analyst"}, {"locationName": "Mumbai", "geoLocationName": "Mumbai", "companyName": "Capgemini", "timePeriod": {"endDate": {"month": 4, "year": 2019}, "startDate": {"month": 2, "year": 2016}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Associate Consultant", "honors": ["urn:li:fs_honor:(ACoAABJ97q0BFcxSTVQ9_y1dgDAXNMpNiUtF93k,1124134592)"]}], "education": [{"courses": ["urn:li:fs_course:(ACoAABJ97q0BFcxSTVQ9_y1dgDAXNMpNiUtF93k,1598967561)"], "school": {"objectUrn": "urn:li:school:354045", "entityUrn": "urn:li:fs_miniSchool:354045", "active": true, "schoolName": "International Institute of Information Technology Bangalore", "trackingId": "gMf/o6kMQkGrqcV3+3LAuA==", "logoUrl": "https://media.licdn.com/dms/image/v2/D560BAQEocmV8HEnx7w/company-logo_"}, "grade": "A (3.7/4 CGPA)", "timePeriod": {"endDate": {"year": 2019}, "startDate": {"year": 2018}}, "description": "PGD in Data Science and Machine Learning \\nGathering and manipulating data, applying concepts of data analytics to extract meaningful insights, building machine learning models for predictions, APIs and Flask ML applications \\nTools used: Python, R, MySQL, Excel, Tableau", "degreeName": "Post Graduate Diploma", "schoolName": "International Institute of Information Technology \\u2013 Bangalore", "fieldOfStudy": "Data Science and Machine Learning"}, {"school": {"objectUrn": "urn:li:school:827010", "entityUrn": "urn:li:fs_miniSchool:827010", "active": true, "schoolName": "COER University", "trackingId": "gi5BP5FNQ/CPHMQ+ulwXlg==", "logoUrl": "https://media.licdn.com/dms/image/v2/C4D0BAQG75W6BLYdJAQ/company-logo_"}, "timePeriod": {"endDate": {"year": 2015}, "startDate": {"year": 2011}}, "degreeName": "Bachelor of Technology (B.Tech.)", "schoolName": "College of Engineering Roorkee", "fieldOfStudy": "Electronics and Telecommunication Engineering"}], "languages": [{"name": "English", "proficiency": "FULL_PROFESSIONAL"}, {"name": "Hindi", "proficiency": "FULL_PROFESSIONAL"}], "publications": [], "certifications": [{"authority": "International Institute of Information Technology Bangalore", "name": "Post Graduate Diploma in Data Science & Machine Learning", "timePeriod": {"startDate": {"month": 7, "year": 2019}}, "licenseNumber": "13397060"}, {"authority": "NVIDIA", "name": "NVIDIA - Fundamentals of Accelerated Data Science with RAPIDS", "timePeriod": {"startDate": {"month": ...
#   '{"summary": "4+ years of work experience solving business problems with the application of Data Science. Master of Data Science, Monash University (Melbourne). Proficient in Generative AI, Computer Vision and Predictive Modeling. With a strong grip over mathematics, deep learning and machine learning algorithms, capable to transform business requirements into data science formulations and implementing the solutions in an efficient and scalable fashion.\\n\\nCreating impactful AI solutions at R Systems, my focus is on designing cutting-edge generative AI technologies. With a Master\'s degree in Data Science from Monash University, I apply rigorous academic training to address complex client challenges. Our team\'s contribution has significantly enhanced the RAG Application\'s accuracy, showcasing a blend of innovation and practical application.\\n\\nMy core competencies lie in Large Language Models and transformative AI, underpinned by data collection, preprocessing, model development, and deployment. These skills have enabled us to deliver tailored solutions that not only meet but exceed our clients\' business objectives. The dedication to continual learning and improvement is what drives the team and myself to achieve excellence in the ever-evolving field of data science.", "industryName": "Computer Software", "lastName": "Nain", "locationName": "India", "birthDate": {"month": 1, "day": 24}, "firstName": "Rakesh", "headline": "Data Scientist @ R Systems | Master\'s in Data Science", "public_id": "rakeshnain", "experience": [{"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "R Systems", "timePeriod": {"startDate": {"month": 8, "year": 2023}}, "description": "Roles and Responsibilities:\\n- Tackle client challenges by designing and implement end-to-end data science solutions using generative AI (LLMs, Large Multi-Modals and their finetuning based on the use cases) or traditional machine learning from data collection, preprocessing to model development and deployment\\n- I ensure optimal model performance, engage in cross-functional collaboration, and deliver insights to clients through effective communication.\\n- My role contributes to R systems consultancy prowess in delivering innovative and impactful solutions that address diverse business needs of clients.\\n\\nAchievements:\\n- Increased the RAG Application accuracy by 40%.", "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"companyName": "Intello Labs", "timePeriod": {"endDate": {"month": 8, "year": 2023}, "startDate": {"month": 12, "year": 2021}}, "description": "Roles and Responsibilities:\\n- Develop state-of-the-art machine learning and deep learning algorithms/models for visual recognition tasks, such as segmentation and detection.\\n- Collaborate closely with multidisciplinary teams of software engineers, hardware engineers, business leaders and other key players to develop Artificial Intelligent machines.\\n- Data Collection, EDA, Data Cleaning, ML Model Development(R&D) and deployment.\\n\\nAchievements:\\n- Developed object detection and instance segmentation algorithm taking around 50 times less RAM in training with only twice extra time in inference as compared to present state-of-the-art algorithms in the market.\\n- Improved grains classification results by 20%, and fruits defect detection results by 12%.", "company": {"employeeCountRange": {"start": 51, "end": 200}, "industries": ["Information Technology and Services"]}, "title": "Deep Learning Engineer"}, {"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "DishTV", "timePeriod": {"endDate": {"month": 10, "year": 2018}, "startDate": {"month": 6, "year": 2017}}, "description": "Roles and Responsibilities:\\nStarted as a Software Developer in the \\u201cMy DishTV\\u201d Android App pro ...
#   '{"summary": "Experienced Data Scientist/Analyst with a demonstrated history of working in the computer software industry. I\'m interested in data science, machine learning, and their applications to real-world problems. I believe that humans are made for innovative work and thus all monotonous and time-consuming work should be handled by machines. I enjoy working with data, creating models, predicting and finding insights to solve business problems.", "industryName": "Information Technology & Services", "lastName": "Batra", "locationName": "India", "firstName": "Ritaksh", "headline": "Data Scientist", "public_id": "ritaksh-batra-82b915136", "experience": [{"locationName": "India", "geoLocationName": "India", "companyName": "Encora Inc.", "timePeriod": {"startDate": {"month": 4, "year": 2024}}, "company": {"employeeCountRange": {"start": 5001, "end": 10000}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "CEREBRUMX", "timePeriod": {"endDate": {"month": 4, "year": 2024}, "startDate": {"month": 7, "year": 2022}}, "company": {"employeeCountRange": {"start": 11, "end": 50}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Xceedance", "timePeriod": {"endDate": {"month": 7, "year": 2022}, "startDate": {"month": 11, "year": 2020}}, "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Insurance"]}, "title": "Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "GlobalLogic", "timePeriod": {"endDate": {"month": 7, "year": 2020}, "startDate": {"month": 3, "year": 2018}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Computer Software"]}, "title": "Senior Data Science Analyst "}], "education": [{"grade": "6.2 cgpa", "timePeriod": {"endDate": {"year": 2017}, "startDate": {"year": 2013}}, "description": "no description about me.", "degreeName": "Bachelor of Technology (BTech)", "schoolName": "Dept. of Instrumentation(USIC),kurukshetra university kurukshetra", "fieldOfStudy": "field control instrumentation", "degreeUrn": "urn:li:fs_degree:250"}, {"grade": "6.5 cgpa", "timePeriod": {"endDate": {"year": 2014}, "startDate": {"year": 2011}}, "degreeName": "diploma holder", "schoolName": "govt.polytechnic ambala city", "fieldOfStudy": " Electronics and Communications Engineering"}], "languages": [], "publications": [], "certifications": [{"authority": "Google", "name": "Advanced Google Analytics for Data Analysis ", "timePeriod": {"endDate": {"month": 10, "year": 2022}, "startDate": {"month": 10, "year": 2019}}}, {"authority": "iNeuron.ai", "name": "Machine Learning Masters", "timePeriod": {"startDate": {"month": 9, "year": 2020}}}, {"authority": "iNeuron.ai", "name": "Deep Learning Masters", "timePeriod": {"startDate": {"month": 11, "year": 2020}}}, {"authority": "iNeuron.ai", "name": "Natural Language Processing Master", "timePeriod": {"startDate": {"month": 11, "year": 2020}}}], "projects": [], "urn_id": "ACoAACE9Q2MBe_i_ol-tkC8L5lAv12dRAZez-n0"}',
#   '{"summary": "Experienced Data Scientist with a demonstrated history of working in the computer software industry. Skilled in Computer Vision, Power BI, Image Processing, Text Extraction using Python Programming. Strong engineering professional with a PG Diploma focused in Data Science from Great Lakes Institute of Management, Gurgaon. ", "industryName": "Computer Software", "lastName": "Khandelwal", "locationName": "India", "firstName": "Sushant", "headline": "Data Scientist | AI | ML | Python | SQL |  Automation | Analytics | Azure", "public_id": "sushant-khandelwal-7296b785", "experience": [{"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Optum", "timePeriod": {"startDate": {"month": 8, "year": 2022}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Hospital & Health Care"]}, "title": "Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Info-X Software Technology Pvt Ltd", "timePeriod": {"endDate": {"month": 8, "year": 2022}, "startDate": {"month": 12, "year": 2020}}, "description": "1. Document(s) Automation \\u2013 Automated the manual process of saving various documents with the help of python using libraries like numpy, pandas, google.cloud.vision and pyodbc. The python script automated the task by reading the relevant email, downloading the attachment, extracting the required text using OCR, and saving it into the database.\\n2. Created dashboards using PowerBI for Customers and Vendors visualization, and help them analyze the trends and generate various insights.\\n3. Managed container/vessel tracking process using UI Path, SQL, and Python scripts.", "company": {"employeeCountRange": {"start": 51, "end": 200}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"locationName": "Hyderabad Area, India", "geoLocationName": "Hyderabad Area, India", "companyName": "Sgmoid", "timePeriod": {"endDate": {"month": 8, "year": 2020}, "startDate": {"month": 11, "year": 2019}}, "description": "1. Created Image Classification models to detect retinal morbidity using Fastai.\\n2. Worked on an Image Regeneration project using GANs.\\n3. Managed data entry Automation projects using UI Path and Python scripts.", "company": {"employeeCountRange": {"start": 2, "end": 10}, "industries": ["Computer Software"]}, "title": "Data Scientist"}, {"locationName": "Delhi, India", "geoLocationName": "Delhi, India", "companyName": "MOHAN THREAD MILLS PRIVATE LIMITED", "timePeriod": {"endDate": {"month": 3, "year": 2019}, "startDate": {"month": 2, "year": 2017}}, "company": {"industries": ["Textiles"]}, "title": "Family Business"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Binary Semantics Ltd.", "timePeriod": {"endDate": {"month": 1, "year": 2017}, "startDate": {"month": 10, "year": 2014}}, "description": "Managed e-commerce projects for multiple clients using their data analytically and also ensuring a better user experience. Helped clients accelerate revenue growth by analysing performance and operational excellence such as feed optimization, new product feature adoption, and data/price monitoring.", "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Computer Software"]}, "title": "Analyst"}], "education": [{"school": {"objectUrn": "urn:li:school:3153365", "entityUrn": "urn:li:fs_miniSchool:3153365", "active": true, "schoolName": "Great Lakes Institute of Management Gurgaon", "trackingId": "ulXQTL3HR+C2XNd4/1MXng==", "logoUrl": "https://media.licdn.com/dms/image/v2/D560BAQG2V_xZ3Ou0KQ/company-logo_"}, "timePeriod": {"endDate": {"month": 10, "year": 2019}, "startDate": {"month": 4, "year": 2019}}, "degreeName": "PG Diploma", "schoolName": "Great Lakes Institute of Management, Gurgaon", "fieldOfStudy": "Data Science"}, {"school": {"objectUrn": "urn:li:school:189141", "entit ...
#   '{"summary": "Experienced Data Scientist with ~4 years specializing in machine learning, NLP, and deep learning. Proficient in algorithms like Random Forest, Boosting, and Decision Tree Classifiers. Skilled in TensorFlow, Keras, and NLTK for developing high-performance applications in language modeling, predictive analytics, and statistical analysis. Seeking opportunities to apply expertise in Python programming and collaborate on impactful projects. Committed to delivering innovative solutions that drive positive change and excel in diverse challenges. Passionate about leveraging skills for groundbreaking advancements in machine learning and NLP domains, ready to make a meaningful impact through transformative outcomes", "industryName": "Computer Software", "lastName": "Bhatnagar", "locationName": "India", "firstName": "Riya", "headline": "Data Scientist", "img_364_364": "800_800/profile-displayphoto-shrink_800_800/0/1722322822594?e=1731542400&v=beta&t=KMBpt7qjNpOBlrzuhlFTslOk6BLEx_geDeR4zXpRwBI", "public_id": "riya-bhatnagar-653434190", "experience": [{"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Fractal", "timePeriod": {"startDate": {"month": 1, "year": 2024}}, "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Management Consulting"]}, "title": "Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "ZS", "timePeriod": {"endDate": {"month": 11, "year": 2023}, "startDate": {"month": 12, "year": 2021}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Management Consulting"]}, "title": "Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Dew Solutions Pvt Ltd", "timePeriod": {"endDate": {"month": 12, "year": 2021}, "startDate": {"month": 6, "year": 2020}}, "company": {"employeeCountRange": {"start": 501, "end": 1000}, "industries": ["Information Technology and Services"]}, "title": "Data Science Engineer"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Dew Solutions Pvt Ltd", "timePeriod": {"endDate": {"month": 5, "year": 2020}, "startDate": {"month": 11, "year": 2019}}, "company": {"employeeCountRange": {"start": 501, "end": 1000}, "industries": ["Information Technology and Services"]}, "title": "Data Science Intern"}, {"locationName": "Jaipur, Rajasthan", "geoLocationName": "Jaipur, Rajasthan", "companyName": "CDAC ATC Jaipur", "timePeriod": {"endDate": {"month": 8, "year": 2018}, "startDate": {"month": 6, "year": 2018}}, "company": {"employeeCountRange": {"start": 11, "end": 50}, "industries": ["Computer Software"]}, "title": "Android Trainee"}], "education": [{"school": {"objectUrn": "urn:li:school:3185138", "entityUrn": "urn:li:fs_miniSchool:3185138", "active": true, "schoolName": "Rajasthan Technical University", "trackingId": "mn/j+M5mTi2YXuElWpE6nQ==", "logoUrl": "https://media.licdn.com/dms/image/v2/C510BAQGUb3DKT_yHeQ/company-logo_"}, "fieldOfStudyUrn": "urn:li:fs_fieldOfStudy:100189", "degreeName": "Bachelor of Technology - BTech(Hons.)", "schoolName": "Rajasthan Technical University", "fieldOfStudy": "Computer Science"}, {"schoolName": "St.Mary\'s Convent Sr.Sec School"}], "languages": [{"name": "English", "proficiency": "FULL_PROFESSIONAL"}, {"name": "Hindi", "proficiency": "FULL_PROFESSIONAL"}], "publications": [], "certifications": [{"authority": "Coursera", "name": "Introduction to Data Science in Python", "timePeriod": {"startDate": {"month": 4, "year": 2019}}, "licenseNumber": "JT2NVMKHH6NP"}, {"authority": "Coursera", "name": "Machine Learning", "timePeriod": {"startDate": {"month": 4, "year": 2019}}, "licenseNumber": "CWJ2YXZHQFLU"}, {"authority": "Coursera", "name": "Neural Networks and Deep Learning", "timePeriod": {"startDate": {"month": 5, "year": 2019}}, "licenseNumber": "KFHKTR7ZQN6H"},  ...
