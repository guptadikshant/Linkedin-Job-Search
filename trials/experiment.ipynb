# %%
import os
import json
import pandas as pd
from linkedin_api import Linkedin
import chromadb
from chromadb.utils.embedding_functions.openai_embedding_function import OpenAIEmbeddingFunction
from dotenv import load_dotenv, find_dotenv

# %%
load_dotenv(find_dotenv())
# Out:
# True

# %%
# Authenticate using any Linkedin account credentials
api = Linkedin(
    username=os.environ["LINKEDIN_USERNAME"],
    password=os.environ["LINKEDIN_PASSWORD"]
)

# %%
SEARCH_KEYWORD = "Data Scientist"

# %%
all_peoples = api.search_people(
    keywords=SEARCH_KEYWORD,
    limit=20
)

all_peoples
# Out:
# [{'urn_id': 'ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist @ Hunch',
#   'location': 'Gurugram',
#   'name': 'Sahil Maheshwari'},
#  {'urn_id': 'ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist',
#   'location': 'Gurugram',
#   'name': 'Vidur Srivastava'},
#  {'urn_id': 'ACoAAAbvohIBhdiLqQ5FCbtA40AFvg3f-T7fKfk',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist IBM',
#   'location': 'Noida',
#   'name': 'Isha Aneja'},
#  {'urn_id': 'ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist',
#   'location': 'Noida',
#   'name': 'Tushar Mathur'},
#  {'urn_id': 'ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY',
#   'distance': 'DISTANCE_2',
#   'jobtitle': "Data Scientist @ R Systems | Master's in Data Science",
#   'location': 'Gurugram',
#   'name': 'Rakesh Nain'},
#  {'urn_id': 'ACoAACeUD1cBHSiBiEFTJnJc3WWxAnH1y_1erQA',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist | IIT Roorkee',
#   'location': 'Katni',
#   'name': 'Shreeyash Geda'},
#  {'urn_id': 'ACoAACzqAZ8BNYEJjGPpk_l6DlwoAzZJUXVYd0Y',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist',
#   'location': 'Gurgaon',
#   'name': 'Riya Bhatnagar'},
#  {'urn_id': 'ACoAABJ97q0BFcxSTVQ9_y1dgDAXNMpNiUtF93k',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist | IIIT Bangalore',
#   'location': 'Gurugram',
#   'name': 'Deepankar Kotnala'},
#  {'urn_id': 'ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Looking for Data Science Opportunities | Manager - Data Scientist @ EXL | NLP | Freelancer',
#   'location': 'Gurgaon',
#   'name': 'Sumeet Kharbanda'},
#  {'urn_id': 'ACoAACR1zh0BnySZente_0caSEZGn2Qx1I8I_78',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist at Demandbase | Data Science, IIITB | Statistics, DU',
#   'location': 'New Delhi',
#   'name': 'Amya Gupta'},
#  {'urn_id': 'ACoAAA_8N7UBcb426isJoolyZrF0Lgh2oyOZbcc',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist/Principal at Gartner',
#   'location': 'Gurgaon',
#   'name': 'Puneet Aggarwal'},
#  {'urn_id': 'ACoAACX92-ABB7kKVBi6f_EXf2zXIOObQpB9Js4',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Lead Data Scientist at EY | Ex - IBM',
#   'location': 'Gurugram',
#   'name': 'Saatvik Sharma'},
#  {'urn_id': 'ACoAACMdmgABEKidiIRTUeY4ZC_etvTvOPPAWRA',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist at TCS',
#   'location': 'New Delhi',
#   'name': 'Shakshi Neha'},
#  {'urn_id': 'ACoAABIURlEB0IaIlQL8yLwChwLnQFDTIiBtFbY',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist | AI | ML | Python | SQL | Automation | Analytics | Azure',
#   'location': 'Faridabad',
#   'name': 'Sushant Khandelwal'},
#  {'urn_id': 'ACoAACA43R8Buv3_11zWBpYvQ0u3_u_S89F3Clc',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist',
#   'location': 'Gurugram',
#   'name': 'Ajay Anand Verma'},
#  {'urn_id': 'ACoAACu4NbUBH95IDJX8ynU_hDNCiu4uWC3F4qI',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist at Piramal Finance',
#   'location': 'North Delhi',
#   'name': 'Abhishek Gupta'},
#  {'urn_id': 'ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist | IIT Kharagpur',
#   'location': 'New Delhi',
#   'name': 'Tushar Singh Soam'},
#  {'urn_id': 'ACoAACuf0GEBxqLlm79WsFe0eagVOHzxvQhltaA',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data scientist | AI | ML | DL',
#   'location': 'Gurugram',
#   'name': 'Nishchay S.'},
#  {'urn_id': 'ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist at SAP Labs',
#   'location': 'New Delhi',
#   'name': 'Diksha Garg'},
#  {'urn_id': 'ACoAAC1VcqsByzp1o1GEmybISevasiO7VjSe39U',
#   'distance': 'DISTANCE_2',
#   'jobtitle': "Data Scientist @Mastercard AI Garage | IIT Roorkee @'23",
#   'location': 'Chandigarh, India',
#   'name': 'Himank Sehgal'}]

# %%
all_peoples_df = pd.DataFrame(all_peoples)

# %%
people_urn_ids = []
for row, col in all_peoples_df.iterrows():
    people_urn_ids.append(col["urn_id"])

people_urn_ids
# Out:
# ['ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano',
#  'ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4',
#  'ACoAAAbvohIBhdiLqQ5FCbtA40AFvg3f-T7fKfk',
#  'ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY',
#  'ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY',
#  'ACoAACeUD1cBHSiBiEFTJnJc3WWxAnH1y_1erQA',
#  'ACoAACzqAZ8BNYEJjGPpk_l6DlwoAzZJUXVYd0Y',
#  'ACoAABJ97q0BFcxSTVQ9_y1dgDAXNMpNiUtF93k',
#  'ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0',
#  'ACoAACR1zh0BnySZente_0caSEZGn2Qx1I8I_78',
#  'ACoAAA_8N7UBcb426isJoolyZrF0Lgh2oyOZbcc',
#  'ACoAACX92-ABB7kKVBi6f_EXf2zXIOObQpB9Js4',
#  'ACoAACMdmgABEKidiIRTUeY4ZC_etvTvOPPAWRA',
#  'ACoAABIURlEB0IaIlQL8yLwChwLnQFDTIiBtFbY',
#  'ACoAACA43R8Buv3_11zWBpYvQ0u3_u_S89F3Clc',
#  'ACoAACu4NbUBH95IDJX8ynU_hDNCiu4uWC3F4qI',
#  'ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w',
#  'ACoAACuf0GEBxqLlm79WsFe0eagVOHzxvQhltaA',
#  'ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8',
#  'ACoAAC1VcqsByzp1o1GEmybISevasiO7VjSe39U']

# %%
from collections import defaultdict

peoples_profiles: dict[str, list] = defaultdict(list)

for urn_id in people_urn_ids:
    try:
        profile_details = api.get_profile(urn_id=urn_id)
        skills = api.get_profile_skills(urn_id=urn_id)
        peoples_profiles[urn_id].append(
            {
                "profile_details": profile_details,
                "skills": skills
            }
        )
    except KeyError:
        continue

peoples_profiles
# Out:
# defaultdict(list,
#             {'ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano': [{'profile_details': {'summary': '11+ years of experience with a proven track record of driving revenue growth and operational efficiency through data-driven solutions. Skilled in data manipulation, visualization, statistical inference, machine learning, and MLOps with strong theoretical foundations. Effective communication skills, adept at distilling complex ideas and concepts into easy-to- understand language. Experienced in leading end-to-end ML projects and solving the unique challenges that come with them.',
#                 'industryName': 'Information Technology & Services',
#                 'lastName': 'Maheshwari',
#                 'locationName': 'India',
#                 'student': False,
#                 'geoCountryName': 'India',
#                 'geoCountryUrn': 'urn:li:fs_geo:102713980',
#                 'geoLocationBackfilled': False,
#                 'elt': False,
#                 'industryUrn': 'urn:li:fs_industry:96',
#                 'firstName': 'Sahil',
#                 'entityUrn': 'urn:li:fs_profile:ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano',
#                 'geoLocation': {'geoUrn': 'urn:li:fs_geo:115884833'},
#                 'geoLocationName': 'Gurugram, Haryana',
#                 'location': {'basicLocation': {'countryCode': 'in'}},
#                 'headline': 'Data Scientist @ Hunch',
#                 'displayPictureUrl': 'https://media.licdn.com/dms/image/v2/D4D03AQFCjROuwLEpBA/profile-displayphoto-shrink_',
#                 'img_100_100': '100_100/profile-displayphoto-shrink_100_100/0/1689423987177?e=1730937600&v=beta&t=FObGCVF3uHBj1tH5GuQDsSyuuRYcoZ7tfgwZgDX9rX8',
#                 'img_200_200': '200_200/profile-displayphoto-shrink_200_200/0/1689423987177?e=1730937600&v=beta&t=gbEufBZvMXYrP7YxAbyxRCR9c8wCu63E_-Kzo5GFn_0',
#                 'img_400_400': '400_400/profile-displayphoto-shrink_400_400/0/1689423987177?e=1730937600&v=beta&t=sZJWQZxfMli96LMQDOE1SieX9Dh98-fJ8LCTIa3e10k',
#                 'img_767_767': '800_800/profile-displayphoto-shrink_800_800/0/1689423987177?e=1730937600&v=beta&t=zE1kkXG1wELZXalEKDI132DONfV1ftaXKaf_CvM7xro',
#                 'profile_id': 'ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano',
#                 'profile_urn': 'urn:li:fs_miniProfile:ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano',
#                 'member_urn': 'urn:li:member:106525219',
#                 'public_id': 'maheshwarisahil',
#                 'experience': [{'locationName': 'Delhi, India',
#                   'entityUrn': 'urn:li:fs_position:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,2290853727)',
#                   'geoLocationName': 'Delhi, India',
#                   'geoUrn': 'urn:li:fs_geo:106187582',
#                   'companyName': 'Hunch',
#                   'timePeriod': {'startDate': {'month': 11, 'year': 2023}},
#                   'company': {'employeeCountRange': {'start': 51, 'end': 200},
#                    'industries': ['Internet']},
#                   'title': 'Head of Data Science',
#                   'region': 'urn:li:fs_region:(in,0)',
#                   'companyUrn': 'urn:li:fs_miniCompany:88052284',
#                   'companyLogoUrl': 'https://media.licdn.com/dms/image/v2/D560BAQE2hbXh1N6iZw/company-logo_'},
#                  {'locationName': 'Bengaluru, Karnataka, India',
#                   'entityUrn': 'urn:li:fs_position:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,1686796541)',
#                   'geoLocationName': 'Bengaluru, Karnataka, India',
#                   'geoUrn': 'urn:li:fs_geo:105214831',
#                   'companyName': 'SIXT Research & Development India',
#                   'timePeriod': {'endDate': {'month': 8, 'year': 2023},
#                    'startDate': {'month': 10, 'year': 2020}},
#                   'description': 'Led strategically important DS projects through their complete ML lifecycle. Also responsible for solution research and team mentoring.\n\nDynamic Pricing\n• Delivered a sustainable margin uplift of >3% using elasticity-based pricing models\n• Built a faster and more reliable AB testing framework solving problems in traditional AB testing like\npeeking, high sample variance, independence of p-values and effect sizes, etc.\n\nFleet Optimization\n• Improved demand forecasting error using Bayesian hierarchical models\n• Developed a price-demand relationship model from natural price variations data using GMM to handle price endogeneity\n• Implemented ML-driven simulations to optimize long-term inventory planning',
#                   'company': {'employeeCountRange': {'start': 201, 'end': 500},
#                    'industries': ['Computer Software']},
#                   'title': 'Staff Data Scientist',
#                   'region': 'urn:li:fs_region:(in,0)',
#                   'companyUrn': 'urn:li:fs_miniCompany:13370997',
#                   'companyLogoUrl': 'https://media.licdn.com/dms/image/v2/D560BAQEd3fH-yexPQw/company-logo_'},
#                  {'locationName': 'Bengaluru Area, India',
#                   'entityUrn': 'urn:li:fs_position:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,1367542545)',
#                   'geoLocationName': 'Bengaluru Area, India',
#                   'geoUrn': 'urn:li:fs_geo:105307040',
#                   'companyName': 'ThoughtWorks',
#                   'timePeriod': {'endDate': {'month': 10, 'year': 2020},
#                    'startDate': {'month': 9, 'year': 2018}},
#                   'description': 'Led DS teams and collaborated with other cross-functional teams to build and deliver\ncomprehensive solutions, with DS as a key component.\n\nDynamic Pricing for a brick-&-mortar Retail giant\n• Delivered an average margin increase of €9K per month per store using a SARIMAX-based price-demand model\n• Built a risk control strategy in absence of the test data by defining custom metrics for model’s stability. \n\nSearch Optimization for a leading Knowledge Consulting Firm\n• Improved search results’ relevance considerably using word2Vec, hierarchical clustering with hashing, and tf-idf.',
#                   'company': {'employeeCountRange': {'start': 10001},
#                    'industries': ['Information Technology and Services']},
#                   'title': 'Lead Data Scientist',
#                   'region': 'urn:li:fs_region:(in,7127)',
#                   'companyUrn': 'urn:li:fs_miniCompany:157356',
#                   'companyLogoUrl': 'https://media.licdn.com/dms/image/v2/C4E0BAQE5QBG-mhja9g/company-logo_'},
#                  {'locationName': 'Bengaluru Area, India',
#                   'entityUrn': 'urn:li:fs_position:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,1064089389)',
#                   'geoLocationName': 'Bengaluru Area, India',
#                   'geoUrn': 'urn:li:fs_geo:105307040',
#                   'companyName': 'Happiest Minds Technologies',
#                   'timePeriod': {'endDate': {'month': 9, 'year': 2018},
#                    'startDate': {'month': 7, 'year': 2017}},
#                   'description': '•\tTime series forecasting for multiple domains like energy, manufacturing, retail, etc. Handled high frequency data (minute level) which is usually not well handled by popular implementations of ARIMA\n•\tImage classification using Inception model to automate identification of damaged devices\n•\tOptimization of predictive model to handle incremental data by maintaining data preparation pipeline',
#                   'company': {'employeeCountRange': {'start': 5001,
#                     'end': 10000},
#                    'industries': ['Information Technology and Services']},
#                   'title': 'Senior Data Scientist',
#                   'region': 'urn:li:fs_region:(in,7127)',
#                   'companyUrn': 'urn:li:fs_miniCompany:2315800',
#                   'companyLogoUrl': 'https://media.licdn.com/dms/image/v2/C560BAQHWwtin8dPOIg/company-logo_'},
#                  {'entityUrn': 'urn:li:fs_position:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,753911489)',
#                   'companyName': 'Happiest Minds Technologies',
#                   'timePeriod': {'endDate': {'month': 7, 'year': 2017},
#                    'startDate': {'month': 11, 'year': 2015}},
#                   'description': '•\tReal time recommendations system for a retail client. Used non-conventional similarity measures resulting in more relevant recommendations\n•\tPrediction of claim propensity and time to claim, for an insurance intermediary, to enable risk based pricing. Also, determined factors causing the claim\n•\tDashboard development on R Shiny and Tableau for actionable business insights\n',
#                   'company': {'employeeCountRange': {'start': 5001,
#                     'end': 10000},
#                    'industries': ['Information Technology and Services']},
#                   'title': 'Junior Data Scientist',
#                   'companyUrn': 'urn:li:fs_miniCompany:2315800',
#                   'companyLogoUrl': 'https://media.licdn.com/dms/image/v2/C560BAQHWwtin8dPOIg/company-logo_'}],
#                 'education': [{'projects': ['urn:li:fs_project:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,26)',
#                    'urn:li:fs_project:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,1052741438)',
#                    'urn:li:fs_project:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,1053363621)'],
#                   'entityUrn': 'urn:li:fs_education:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,187975176)',
#                   'grade': '7.02/10',
#                   'timePeriod': {'endDate': {'year': 2014},
#                    'startDate': {'year': 2012}},
#                   'description': '•\tMember of Finance Forum, TAPMI\n•\tMember of Leader Support Group , Brand Scan Project\n•\tCleared FLIP certification on “Finance and Banking Fundamentals”\n•\tWas among the top 5 teams from all over India in XIMB’s Inter B-school Competition on Microfinance\n•\tVolunteered for Joyfest (Social Initiative, TAPMI)\n•\tWon first prize in “Naach” – dance competition in TAPMI’s intra-college cultural event',
#                   'testScores': ['urn:li:fs_testScore:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,46)'],
#                   'degreeName': 'Post Graduate Diploma in Management',
#                   'schoolName': 'T.A. Pai Management Institute',
#                   'fieldOfStudy': 'Finance, General'},
#                  {'entityUrn': 'urn:li:fs_education:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,155172511)',
#                   'grade': '67.44%',
#                   'timePeriod': {'endDate': {'year': 2009},
#                    'startDate': {'year': 2005}},
#                   'degreeName': 'Bachelor of Engineering (B.Eng.)',
#                   'schoolName': 'Apeejay College of Engineering',
#                   'fieldOfStudy': 'Electrical, Electronics and Communications Engineering'},
#                  {'entityUrn': 'urn:li:fs_education:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,155170405)',
#                   'grade': '75.60%',
#                   'timePeriod': {'endDate': {'year': 2005},
#                    'startDate': {'year': 2004}},
#                   'degreeName': 'Higher School Certificate',
#                   'schoolName': 'Chiranjiv Bharati School, Gurgaon',
#                   'fieldOfStudy': 'Science'}],
#                 'languages': [{'name': 'English',
#                   'proficiency': 'FULL_PROFESSIONAL'},
#                  {'name': 'Hindi', 'proficiency': 'NATIVE_OR_BILINGUAL'}],
#                 'publications': [],
#                 'certifications': [{'authority': 'edX',
#                   'name': 'edX Honor Code Certificate for The Analytics Edge',
#                   'company': {'objectUrn': 'urn:li:company:2746406',
#                    'entityUrn': 'urn:li:fs_miniCompany:2746406',
#                    'name': 'edX',
#                    'showcase': False,
#                    'active': True,
#                    'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#                        'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1688142646299/edx_logo?e=1733961600&v=beta&t=JF1Y_Ua2sIxwpI6C-ot0skHT8Wy6xx76NE_GtbRgozw',
#                        'expiresAt': 1733961600000,
#                        'height': 200},
#                       {'width': 100,
#                        'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1688142646299/edx_logo?e=1733961600&v=beta&t=F10JSsIPKmCFuDMUoVNtVl7yoG8Udl1qhAI4rzxhG10',
#                        'expiresAt': 1733961600000,
#                        'height': 100},
#                       {'width': 400,
#                        'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1688142646299/edx_logo?e=1733961600&v=beta&t=e7c6-rh_RhJq28pEjffCghZDGZrrpjiBXaxHrSYYmYg',
#                        'expiresAt': 1733961600000,
#                        'height': 400}],
#                      'rootUrl': 'https://media.licdn.com/dms/image/v2/D4E0BAQFG13a41008Dg/company-logo_'}},
#                    'universalName': 'edx',
#                    'dashCompanyUrn': 'urn:li:fsd_company:2746406',
#                    'trackingId': 'M0ML3jEORA+fJ50VBTDXZg=='},
#                   'companyUrn': 'urn:li:fs_miniCompany:2746406',
#                   'url': 'https://s3.amazonaws.com/verify.edx.org/downloads/af77b807dc8d444a97db89e4b80fdc4b/Certificate.pdf'},
#                  {'authority': 'DataCamp',
#                   'name': 'Data Analysis in R, the data.table Way',
#                   'timePeriod': {'startDate': {'month': 6, 'year': 2015}},
#                   'licenseNumber': '26bf88ce460d74689e517a49720f7e5a6ae83d72',
#                   'company': {'objectUrn': 'urn:li:company:3227175',
#                    'entityUrn': 'urn:li:fs_miniCompany:3227175',
#                    'name': 'DataCamp',
#                    'showcase': False,
#                    'active': True,
#                    'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#                        'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1630577190840/datacampinc_logo?e=1733961600&v=beta&t=dBQZ9qHt8RRwxj-JsDDFlH5t-8uvClUK5JkYc3n4-Ak',
#                        'expiresAt': 1733961600000,
#                        'height': 200},
#                       {'width': 100,
#                        'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1630577190840/datacampinc_logo?e=1733961600&v=beta&t=3Ie74EknSD6Fbe9s6rzKc3ZtOs1Y5L_UYrffWI_3nN8',
#                        'expiresAt': 1733961600000,
#                        'height': 100},
#                       {'width': 400,
#                        'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1630577190840/datacampinc_logo?e=1733961600&v=beta&t=CLN3uQtArzn2HQK2pEu-XId4qiwc14Y3XUI-0fYT2u8',
#                        'expiresAt': 1733961600000,
#                        'height': 400}],
#                      'rootUrl': 'https://media.licdn.com/dms/image/v2/C4D0BAQHoE9F6A76mOQ/company-logo_'}},
#                    'universalName': 'datacampinc',
#                    'dashCompanyUrn': 'urn:li:fsd_company:3227175',
#                    'trackingId': 'nq14nrAeTTeUrfFNnh3jpA=='},
#                   'displaySource': 'datacamp.com',
#                   'companyUrn': 'urn:li:fs_miniCompany:3227175',
#                   'url': 'https://www.datacamp.com/courses/data-table-data-manipulation-r-tutorial?utm_source=LinkedIn&utm_medium=Certificate&utm_content=Certificate&utm_campaign=Linkedin-Certificate'},
#                  {'authority': 'Finitiatives Learning India Pvt Ltd',
#                   'name': 'Finance and Banking Fundamentals',
#                   'company': {'objectUrn': 'urn:li:company:244521',
#                    'entityUrn': 'urn:li:fs_miniCompany:244521',
#                    'name': 'Finitiatives Learning India Pvt Ltd. (FLIP)',
#                    'showcase': False,
#                    'active': True,
#                    'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#                        'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1631346827669?e=1733961600&v=beta&t=BE7A__TFZk9a_KVfdmTh6wxSQiWAXJewbbApWt-WEQw',
#                        'expiresAt': 1733961600000,
#                        'height': 200},
#                       {'width': 100,
#                        'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1631346827670?e=1733961600&v=beta&t=R8JJ31KikT5lUlXPvDvc1JhXl9Dk9fxQiU648r0IG28',
#                        'expiresAt': 1733961600000,
#                        'height': 100},
#                       {'width': 400,
#                        'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1631346827670?e=1733961600&v=beta&t=pQ7TXJPbudkKkXi7YlJMwmyHn1RvrzsUMXkW0fnODJg',
#                        'expiresAt': 1733961600000,
#                        'height': 400}],
#                      'rootUrl': 'https://media.licdn.com/dms/image/v2/C4E0BAQHYJAV-ROnmpw/company-logo_'}},
#                    'universalName': 'finitiatives-learning-india-pvt-ltd',
#                    'dashCompanyUrn': 'urn:li:fsd_company:244521',
#                    'trackingId': 'xwgQiajDQ/qa/k5rMpB0fw=='},
#                   'companyUrn': 'urn:li:fs_miniCompany:244521'},
#                  {'authority': 'Cognizant',
#                   'name': 'Level 1: Payment Cards',
#                   'company': {'objectUrn': 'urn:li:company:1680',
#                    'entityUrn': 'urn:li:fs_miniCompany:1680',
#                    'name': 'Cognizant',
#                    'showcase': False,
#                    'active': True,
#                    'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#                        'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1719839886088/cognizant_logo?e=1733961600&v=beta&t=Ra7kzBCsuBdyaUXT2I-5u9AbWK-22n2SP5OQYthtvYI',
#                        'expiresAt': 1733961600000,
#                        'height': 200},
#                       {'width': 100,
#                        'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1719839886088/cognizant_logo?e=1733961600&v=beta&t=dqbSqWyVPKPHlzHdXIDnAc4PSeGVyK3lgmIo-bBKa0E',
#                        'expiresAt': 1733961600000,
#                        'height': 100},
#                       {'width': 400,
#                        'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1719839886088/cognizant_logo?e=1733961600&v=beta&t=CaihStD5XioJleJEF9R_fzZVhWvG86H0JI2J4JwozDo',
#                        'expiresAt': 1733961600000,
#                        'height': 400}],
#                      'rootUrl': 'https://media.licdn.com/dms/image/v2/D4E0BAQHjkUYrDIUKYA/company-logo_'}},
#                    'universalName': 'cognizant',
#                    'dashCompanyUrn': 'urn:li:fsd_company:1680',
#                    'trackingId': 'AKbp3zAoQjmWn5hOX1sykg=='},
#                   'companyUrn': 'urn:li:fs_miniCompany:1680'},
#                  {'authority': 'OutSystems',
#                   'name': 'Outsystems Associate Developer',
#                   'company': {'objectUrn': 'urn:li:company:16663',
#                    'entityUrn': 'urn:li:fs_miniCompany:16663',
#                    'name': 'OutSystems',
#                    'showcase': False,
#                    'active': True,
#                    'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#                        'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1685646588896/outsystems_logo?e=1733961600&v=beta&t=y9amNE0da-NqQN7q5SMy-ioKpOQc1R7cVrkiKbWteUQ',
#                        'expiresAt': 1733961600000,
#                        'height': 200},
#                       {'width': 100,
#                        'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1685646588896/outsystems_logo?e=1733961600&v=beta&t=GeKTUpRMRxFMcqQlwntVqhyDpknYqYnH4YaOWpV6uvY',
#                        'expiresAt': 1733961600000,
#                        'height': 100},
#                       {'width': 400,
#                        'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1685646588896/outsystems_logo?e=1733961600&v=beta&t=oSvwmrOPXJ-EbII1rpMG2DyBIgKkQD-xLjycceiXB-w',
#                        'expiresAt': 1733961600000,
#                        'height': 400}],
#                      'rootUrl': 'https://media.licdn.com/dms/image/v2/D4E0BAQFAUPTkiqMqqA/company-logo_'}},
#                    'universalName': 'outsystems',
#                    'dashCompanyUrn': 'urn:li:fsd_company:16663',
#                    'trackingId': 'o8ijF95iRLed34Yn0DhfFA=='},
#                   'companyUrn': 'urn:li:fs_miniCompany:16663'},
#                  {'authority': 'NIIT',
#                   'name': 'Programming in "C"',
#                   'timePeriod': {'startDate': {'month': 8, 'year': 2006}}},
#                  {'authority': 'Oracle',
#                   'name': 'Oracle Certified Java SE 6 Programmer',
#                   'timePeriod': {'startDate': {'month': 1, 'year': 2011}}}],
#                 'volunteer': [{'role': 'Volunteer',
#                   'companyName': 'Teach For India',
#                   'cause': 'EDUCATION',
#                   'company': {'miniCompany': {'objectUrn': 'urn:li:company:356833',
#                     'entityUrn': 'urn:li:fs_miniCompany:356833',
#                     'name': 'Teach For India',
#                     'showcase': False,
#                     'active': True,
#                     'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#                         'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1630671094456/teach_for_india_logo?e=1733961600&v=beta&t=Yv7YVQcuBZUQq1YhttGKNv-SFcJW_dOw_LGmo594OhQ',
#                         'expiresAt': 1733961600000,
#                         'height': 200},
#                        {'width': 100,
#                         'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1630671094457/teach_for_india_logo?e=1733961600&v=beta&t=fJOhdimC5k3SL8E0slF81-C5Zrm3-IK9DqyyQegdKVA',
#                         'expiresAt': 1733961600000,
#                         'height': 100},
#                        {'width': 400,
#                         'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1630671094457/teach_for_india_logo?e=1733961600&v=beta&t=-x0NTXTE_JHk_PGD3Fde6CTl4qKuJPUHPCcXDEFHmWU',
#                         'expiresAt': 1733961600000,
#                         'height': 400}],
#                       'rootUrl': 'https://media.licdn.com/dms/image/v2/C560BAQEaDE_wvYMOJA/company-logo_'}},
#                     'universalName': 'teach-for-india',
#                     'dashCompanyUrn': 'urn:li:fsd_company:356833',
#                     'trackingId': 'SJEHnmmISD62Q8lir0wsNQ=='}},
#                   'companyUrn': 'urn:li:fs_miniCompany:356833'},
#                  {'role': 'Data Scientist',
#                   'companyName': 'DataKind',
#                   'timePeriod': {'endDate': {'month': 12, 'year': 2016},
#                    'startDate': {'month': 5, 'year': 2015}},
#                   'cause': 'CIVIL_RIGHTS',
#                   'description': 'Predicted probability of a complaint getting resolved for Janaagraha - IChangeMyCity',
#                   'company': {'miniCompany': {'objectUrn': 'urn:li:company:2543012',
#                     'entityUrn': 'urn:li:fs_miniCompany:2543012',
#                     'name': 'DataKind',
#                     'showcase': False,
#                     'active': True,
#                     'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#                         'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1672632890503/datakind_logo?e=1733961600&v=beta&t=tDu4IusUfDCfeV8uENURTCqmpcrGJbARYgctDArnTnM',
#                         'expiresAt': 1733961600000,
#                         'height': 200},
#                        {'width': 100,
#                         'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1672632890503/datakind_logo?e=1733961600&v=beta&t=ceSLVzMkhO771bD9UUy3kLogjfDROW--Md8DMBcKRVg',
#                         'expiresAt': 1733961600000,
#                         'height': 100},
#                        {'width': 400,
#                         'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1672632890503/datakind_logo?e=1733961600&v=beta&t=3WGhxmAhlMr_fKdUY-jN6k5WK-PEeRZ0-teiVvjKUSY',
#                         'expiresAt': 1733961600000,
#                         'height': 400}],
#                       'rootUrl': 'https://media.licdn.com/dms/image/v2/C4E0BAQHooSXF1b5fiA/company-logo_'}},
#                     'universalName': 'datakind',
#                     'dashCompanyUrn': 'urn:li:fsd_company:2543012',
#                     'trackingId': 'YR10fPasSqmZzDACKfwzRw=='}},
#                   'companyUrn': 'urn:li:fs_miniCompany:2543012'}],
#                 'honors': [],
#                 'projects': [{'members': [{'member': {'firstName': 'Sahil',
#                      'lastName': 'Maheshwari',
#                      'dashEntityUrn': 'urn:li:fsd_profile:ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano',
#                      'occupation': 'Data Scientist @ Hunch',
#                      'objectUrn': 'urn:li:member:106525219',
#                      'entityUrn': 'urn:li:fs_miniProfile:ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano',
#                      'publicIdentifier': 'maheshwarisahil',
#                      'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#                          'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1689423987177?e=1730937600&v=beta&t=FObGCVF3uHBj1tH5GuQDsSyuuRYcoZ7tfgwZgDX9rX8',
#                          'expiresAt': 1730937600000,
#                          'height': 100},
#                         {'width': 200,
#                          'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1689423987177?e=1730937600&v=beta&t=gbEufBZvMXYrP7YxAbyxRCR9c8wCu63E_-Kzo5GFn_0',
#                          'expiresAt': 1730937600000,
#                          'height': 200},
#                         {'width': 400,
#                          'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1689423987177?e=1730937600&v=beta&t=sZJWQZxfMli96LMQDOE1SieX9Dh98-fJ8LCTIa3e10k',
#                          'expiresAt': 1730937600000,
#                          'height': 400},
#                         {'width': 767,
#                          'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1689423987177?e=1730937600&v=beta&t=zE1kkXG1wELZXalEKDI132DONfV1ftaXKaf_CvM7xro',
#                          'expiresAt': 1730937600000,
#                          'height': 767}],
#                        'rootUrl': 'https://media.licdn.com/dms/image/v2/D4D03AQFCjROuwLEpBA/profile-displayphoto-shrink_'}},
#                      'trackingId': 'matN8WmyS2m5AeV16a3KQQ=='},
#                     'entityUrn': 'urn:li:fs_contributor:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,1052379663,1)',
#                     'profileUrn': 'urn:li:fs_miniProfile:ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano'}],
#                   'timePeriod': {'endDate': {'month': 4, 'year': 2015},
#                    'startDate': {'month': 4, 'year': 2015}},
#                   'description': '- Built a logistic regression model to predict probability of a complaint getting resolved\n- Tools: R for data wrangling, text analysis, model building and testing, and visualization',
#                   'title': 'Pro bono data analysis for Janaagraha - IChangeMyCity'},
#                  {'members': [{'member': {'firstName': 'Sahil',
#                      'lastName': 'Maheshwari',
#                      'dashEntityUrn': 'urn:li:fsd_profile:ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano',
#                      'occupation': 'Data Scientist @ Hunch',
#                      'objectUrn': 'urn:li:member:106525219',
#                      'entityUrn': 'urn:li:fs_miniProfile:ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano',
#                      'publicIdentifier': 'maheshwarisahil',
#                      'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#                          'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1689423987177?e=1730937600&v=beta&t=FObGCVF3uHBj1tH5GuQDsSyuuRYcoZ7tfgwZgDX9rX8',
#                          'expiresAt': 1730937600000,
#                          'height': 100},
#                         {'width': 200,
#                          'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1689423987177?e=1730937600&v=beta&t=gbEufBZvMXYrP7YxAbyxRCR9c8wCu63E_-Kzo5GFn_0',
#                          'expiresAt': 1730937600000,
#                          'height': 200},
#                         {'width': 400,
#                          'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1689423987177?e=1730937600&v=beta&t=sZJWQZxfMli96LMQDOE1SieX9Dh98-fJ8LCTIa3e10k',
#                          'expiresAt': 1730937600000,
#                          'height': 400},
#                         {'width': 767,
#                          'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1689423987177?e=1730937600&v=beta&t=zE1kkXG1wELZXalEKDI132DONfV1ftaXKaf_CvM7xro',
#                          'expiresAt': 1730937600000,
#                          'height': 767}],
#                        'rootUrl': 'https://media.licdn.com/dms/image/v2/D4D03AQFCjROuwLEpBA/profile-displayphoto-shrink_'}},
#                      'trackingId': 'matN8WmyS2m5AeV16a3KQQ=='},
#                     'entityUrn': 'urn:li:fs_contributor:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,1052502866,1)',
#                     'profileUrn': 'urn:li:fs_miniProfile:ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano'}],
#                   'timePeriod': {'endDate': {'month': 11, 'year': 2014},
#                    'startDate': {'month': 11, 'year': 2014}},
#                   'description': '- Stock selection by balancing return and Sortino ratio \n- Tools: Python (NumPy, Pandas)',
#                   'title': 'Stock Analysis'},
#                  {'occupation': 'urn:li:fs_education:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,187975176)',
#                   'members': [{'member': {'firstName': 'Sahil',
#                      'lastName': 'Maheshwari',
#                      'dashEntityUrn': 'urn:li:fsd_profile:ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano',
#                      'occupation': 'Data Scientist @ Hunch',
#                      'objectUrn': 'urn:li:member:106525219',
#                      'entityUrn': 'urn:li:fs_miniProfile:ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano',
#                      'publicIdentifier': 'maheshwarisahil',
#                      'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#                          'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1689423987177?e=1730937600&v=beta&t=FObGCVF3uHBj1tH5GuQDsSyuuRYcoZ7tfgwZgDX9rX8',
#                          'expiresAt': 1730937600000,
#                          'height': 100},
#                         {'width': 200,
#                          'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1689423987177?e=1730937600&v=beta&t=gbEufBZvMXYrP7YxAbyxRCR9c8wCu63E_-Kzo5GFn_0',
#                          'expiresAt': 1730937600000,
#                          'height': 200},
#                         {'width': 400,
#                          'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1689423987177?e=1730937600&v=beta&t=sZJWQZxfMli96LMQDOE1SieX9Dh98-fJ8LCTIa3e10k',
#                          'expiresAt': 1730937600000,
#                          'height': 400},
#                         {'width': 767,
#                          'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1689423987177?e=1730937600&v=beta&t=zE1kkXG1wELZXalEKDI132DONfV1ftaXKaf_CvM7xro',
#                          'expiresAt': 1730937600000,
#                          'height': 767}],
#                        'rootUrl': 'https://media.licdn.com/dms/image/v2/D4D03AQFCjROuwLEpBA/profile-displayphoto-shrink_'}},
#                      'trackingId': 'matN8WmyS2m5AeV16a3KQQ=='},
#                     'entityUrn': 'urn:li:fs_contributor:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,1053363621,1)',
#                     'profileUrn': 'urn:li:fs_miniProfile:ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano'},
#                    {'member': {'firstName': 'Ankit',
#                      'lastName': 'Thakrar',
#                      'dashEntityUrn': 'urn:li:fsd_profile:ACoAAAxAFpoBlsFucRfmaa3FP3pLak68OjPovbg',
#                      'occupation': 'Partnerships @ Yellow.ai | Partnerships, Alliances, Strategy |',
#                      'objectUrn': 'urn:li:member:205526682',
#                      'entityUrn': 'urn:li:fs_miniProfile:ACoAAAxAFpoBlsFucRfmaa3FP3pLak68OjPovbg',
#                      'publicIdentifier': 'ankitthakrar',
#                      'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#                          'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1577426089046?e=1730937600&v=beta&t=PYdRCXbT8gMl8Nx8VgSUdOCau3n1E28x6-2pLMDXQy4',
#                          'expiresAt': 1730937600000,
#                          'height': 100},
#                         {'width': 200,
#                          'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1577426089020?e=1730937600&v=beta&t=nEYHThiSsXwuYK9Zkj-fVd6EuY2GGjORJXklvebZ-RY',
#                          'expiresAt': 1730937600000,
#                          'height': 200},
#                         {'width': 400,
#                          'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1577426089085?e=1730937600&v=beta&t=-3MzhH4jlRV8qUGKpXN0Igz6omOTbBo1uPhjyVpK83k',
#                          'expiresAt': 1730937600000,
#                          'height': 400},
#                         {'width': 500,
#                          'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1577426089120?e=1730937600&v=beta&t=APEgNF_dvr3bCLZtRoFNlv_f-nTzxU3rAt7KXM0k5jk',
#                          'expiresAt': 1730937600000,
#                          'height': 500}],
#                        'rootUrl': 'https://media.licdn.com/dms/image/v2/C5103AQFX8ol6SvPZMA/profile-displayphoto-shrink_'}},
#                      'trackingId': 'aWsZca5PTPOkw4u4jnSmKA=='},
#                     'entityUrn': 'urn:li:fs_contributor:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,1053363621,2)',
#                     'profileUrn': 'urn:li:fs_miniProfile:ACoAAAxAFpoBlsFucRfmaa3FP3pLak68OjPovbg'},
#                    {'name': 'Lakshay Garg',
#                     'entityUrn': 'urn:li:fs_contributor:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,1053363621,3)'}],
#                   'timePeriod': {'endDate': {'month': 1, 'year': 2014},
#                    'startDate': {'month': 1, 'year': 2014}},
#                   'description': 'Financial Modeling using time value of money, cost of capital, and Monte Carlo analysis on MS Excel',
#                   'title': 'Delhi Airport Metro Express Financial Modeling'},
#                  {'occupation': 'urn:li:fs_education:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,187975176)',
#                   'members': [{'member': {'firstName': 'Sahil',
#                      'lastName': 'Maheshwari',
#                      'dashEntityUrn': 'urn:li:fsd_profile:ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano',
#                      'occupation': 'Data Scientist @ Hunch',
#                      'objectUrn': 'urn:li:member:106525219',
#                      'entityUrn': 'urn:li:fs_miniProfile:ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano',
#                      'publicIdentifier': 'maheshwarisahil',
#                      'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#                          'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1689423987177?e=1730937600&v=beta&t=FObGCVF3uHBj1tH5GuQDsSyuuRYcoZ7tfgwZgDX9rX8',
#                          'expiresAt': 1730937600000,
#                          'height': 100},
#                         {'width': 200,
#                          'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1689423987177?e=1730937600&v=beta&t=gbEufBZvMXYrP7YxAbyxRCR9c8wCu63E_-Kzo5GFn_0',
#                          'expiresAt': 1730937600000,
#                          'height': 200},
#                         {'width': 400,
#                          'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1689423987177?e=1730937600&v=beta&t=sZJWQZxfMli96LMQDOE1SieX9Dh98-fJ8LCTIa3e10k',
#                          'expiresAt': 1730937600000,
#                          'height': 400},
#                         {'width': 767,
#                          'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1689423987177?e=1730937600&v=beta&t=zE1kkXG1wELZXalEKDI132DONfV1ftaXKaf_CvM7xro',
#                          'expiresAt': 1730937600000,
#                          'height': 767}],
#                        'rootUrl': 'https://media.licdn.com/dms/image/v2/D4D03AQFCjROuwLEpBA/profile-displayphoto-shrink_'}},
#                      'trackingId': 'matN8WmyS2m5AeV16a3KQQ=='},
#                     'entityUrn': 'urn:li:fs_contributor:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,26,27)',
#                     'profileUrn': 'urn:li:fs_miniProfile:ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano'},
#                    {'member': {'firstName': 'Lakshay',
#                      'lastName': 'Garg',
#                      'dashEntityUrn': 'urn:li:fsd_profile:ACoAAAmEb4gBHlTas_TXj9Dx-2JyfmEF2KzEm1E',
#                      'occupation': 'Director at Aamro Group of Companies',
#                      'objectUrn': 'urn:li:member:159674248',
#                      'entityUrn': 'urn:li:fs_miniProfile:ACoAAAmEb4gBHlTas_TXj9Dx-2JyfmEF2KzEm1E',
#                      'publicIdentifier': 'lakshaygarg91',
#                      'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#                          'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1517403293558?e=1730937600&v=beta&t=d0dClBdrxyggrwTC2EQKgJobW9OH0l3UXoOfx9ffvmM',
#                          'expiresAt': 1730937600000,
#                          'height': 100},
#                         {'width': 190,
#                          'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1517403293329?e=1730937600&v=beta&t=KEzbGaOgsPtgyXJ193XsnRAmN6ClIuWXQ29pAwr17_k',
#                          'expiresAt': 1730937600000,
#                          'height': 190},
#                         {'width': 190,
#                          'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1517403293329?e=1730937600&v=beta&t=4DGvtcMQadvno5o3oDIWX9vNlXOxHHargRTNOLoOzJA',
#                          'expiresAt': 1730937600000,
#                          'height': 190},
#                         {'width': 190,
#                          'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1517403293322?e=1730937600&v=beta&t=IhmbqKrTbdH-qGJKXszcBl6lYTojjyJKKR2wDzqDR7c',
#                          'expiresAt': 1730937600000,
#                          'height': 190}],
#                        'rootUrl': 'https://media.licdn.com/dms/image/v2/C5603AQEFU_IROEL__A/profile-displayphoto-shrink_'}},
#                      'trackingId': 'QzyWf+NZRAq/9BhGd1yMSA=='},
#                     'entityUrn': 'urn:li:fs_contributor:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,26,28)',
#                     'profileUrn': 'urn:li:fs_miniProfile:ACoAAAmEb4gBHlTas_TXj9Dx-2JyfmEF2KzEm1E'}],
#                   'timePeriod': {'endDate': {'month': 8, 'year': 2013},
#                    'startDate': {'month': 6, 'year': 2013}},
#                   'description': 'We did strategic analysis, accounting analysis, financial analysis, cash flow analysis and valuation using FCFF and two stage divident growth model',
#                   'title': 'Equity Research Report on HDFC Bank'},
#                  {'occupation': 'urn:li:fs_education:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,187975176)',
#                   'members': [{'member': {'firstName': 'Sahil',
#                      'lastName': 'Maheshwari',
#                      'dashEntityUrn': 'urn:li:fsd_profile:ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano',
#                      'occupation': 'Data Scientist @ Hunch',
#                      'objectUrn': 'urn:li:member:106525219',
#                      'entityUrn': 'urn:li:fs_miniProfile:ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano',
#                      'publicIdentifier': 'maheshwarisahil',
#                      'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#                          'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1689423987177?e=1730937600&v=beta&t=FObGCVF3uHBj1tH5GuQDsSyuuRYcoZ7tfgwZgDX9rX8',
#                          'expiresAt': 1730937600000,
#                          'height': 100},
#                         {'width': 200,
#                          'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1689423987177?e=1730937600&v=beta&t=gbEufBZvMXYrP7YxAbyxRCR9c8wCu63E_-Kzo5GFn_0',
#                          'expiresAt': 1730937600000,
#                          'height': 200},
#                         {'width': 400,
#                          'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1689423987177?e=1730937600&v=beta&t=sZJWQZxfMli96LMQDOE1SieX9Dh98-fJ8LCTIa3e10k',
#                          'expiresAt': 1730937600000,
#                          'height': 400},
#                         {'width': 767,
#                          'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1689423987177?e=1730937600&v=beta&t=zE1kkXG1wELZXalEKDI132DONfV1ftaXKaf_CvM7xro',
#                          'expiresAt': 1730937600000,
#                          'height': 767}],
#                        'rootUrl': 'https://media.licdn.com/dms/image/v2/D4D03AQFCjROuwLEpBA/profile-displayphoto-shrink_'}},
#                      'trackingId': 'matN8WmyS2m5AeV16a3KQQ=='},
#                     'entityUrn': 'urn:li:fs_contributor:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,1052741438,1)',
#                     'profileUrn': 'urn:li:fs_miniProfile:ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano'}],
#                   'timePeriod': {'endDate': {'month': 2, 'year': 2013},
#                    'startDate': {'month': 11, 'year': 2012}},
#                   'description': 'Market research for Anne French hair removal cream by Pfizer to understand buying behavior and product usage pattern. Data collection, analysis (Excel & Access), and reporting',
#                   'title': 'Market research for Anne French hair removal cream, Pfizer'}],
#                 'skills': [{'name': 'Probability Theory'},
#                  {'name': 'Probabilistic Programming'},
#                  {'name': 'Amazon Web Services (AWS)'},
#                  {'name': 'Mathematics'}],
#                 'urn_id': 'ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano'},
#                'skills': [{'name': 'Probability Theory'},
#                 {'name': 'Probabilistic Programming'},
#                 {'name': 'Amazon Web Services (AWS)'},
#                 {'name': 'Mathematics'},
#                 {'name': 'Artificial Neural Networks'},
#                 {'name': 'Natural Language Processing (NLP)'},
#                 {'name': 'Software Development'},
#                 {'name': 'Credit Scoring'},
#                 {'name': 'Business Development'},
#                 {'name': 'Risk Based Pricing'},
#                 {'name': 'Price Elasticity'},
#                 {'name': 'Genetic Algorithms'},
#                 {'name': 'Causal Inference'},
#                 {'name': 'Time Series Forecasting'},
#                 {'name': 'Recommender Systems'},
#                 {'name': 'team lead'},
#                 {'name': 'Team Mentoring'},
#                 {'name': 'A/B Testing'},
#                 {'name': 'Dynamic Pricing'},
#                 {'name': 'Inventory Optimization'},
#                 {'name': 'MLOps'},
#                 {'name': 'Business Strategy'},
#                 {'name': 'Machine Learning'},
#                 {'name': 'Deep Learning'},
#                 {'name': 'Statistical Data Analysis'},
#                 {'name': 'Statistical Modeling'},
#                 {'name': 'SQL'},
#                 {'name': 'R'},
#                 {'name': 'Microsoft Excel'},
#                 {'name': 'Tableau'},
#                 {'name': 'C'},
#                 {'name': 'Java'},
#                 {'name': 'Data Analytics'},
#                 {'name': 'Data Science'},
#                 {'name': 'Statistics'},
#                 {'name': 'Artificial Intelligence (AI)'},
#                 {'name': 'Python (Programming Language)'},
#                 {'name': 'Data Mining'},
#                 {'name': 'Algorithms'},
#                 {'name': 'Data Visualization'},
#                 {'name': 'Bayesian inference'},
#                 {'name': 'Design of Experiments (DOE)'},
#                 {'name': 'Reinforcement Learning'},
#                 {'name': 'Automated Machine Learning (AutoML)'},
#                 {'name': 'Graphical Models'}]}],
#              'ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4': [{'profile_details': {'summary': 'Experienced data scientist with a track record of translating complex data into actionable insights across diverse sectors spanning FMCG, Sports and Supply Chain.',
#                 'industryName': 'Information Technology & Services',
#                 'lastName': 'Srivastava',
#                 'locationName': 'India',
#                 'student': False,
#                 'geoCountryName': 'India',
#                 'geoCountryUrn': 'urn:li:fs_geo:102713980',
#                 'geoLocationBackfilled': False,
#                 'elt': False,
#                 'industryUrn': 'urn:li:fs_industry:96',
#                 'firstName': 'Vidur',
#                 'entityUrn': 'urn:li:fs_profile:ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4',
#                 'geoLocation': {'geoUrn': 'urn:li:fs_geo:115884833'},
#                 'geoLocationName': 'Gurugram, Haryana',
#                 'location': {'basicLocation': {'countryCode': 'in'}},
#                 'headline': 'Data Scientist',
#                 'displayPictureUrl': 'https://media.licdn.com/dms/image/v2/D4D03AQG459-q4wJe2A/profile-displayphoto-shrink_',
#                 'img_100_100': '100_100/profile-displayphoto-shrink_100_100/0/1691662091391?e=1730937600&v=beta&t=_FDWMEueZ2aiSGWh0iFqxwOdIgTg7AIuUqaTCU0jPaA',
#                 'img_200_200': '200_200/profile-displayphoto-shrink_200_200/0/1691662091391?e=1730937600&v=beta&t=PNFj3T3N2D2aEKJ38rJDiieT5k1KEfzaclOkW74iwqM',
#                 'img_400_400': '400_400/profile-displayphoto-shrink_400_400/0/1691662091391?e=1730937600&v=beta&t=_1jj8jqDJap3PP827j2xO-0lmVvXBPdDymGxzoXiYj8',
#                 'img_800_800': '800_800/profile-displayphoto-shrink_800_800/0/1691662091391?e=1730937600&v=beta&t=mcO7E9GymbQBr-aa-B4n3i43nMIK9dzl2iouf2EOXXw',
#                 'profile_id': 'ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4',
#                 'profile_urn': 'urn:li:fs_miniProfile:ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4',
#                 'member_urn': 'urn:li:member:585180053',
#                 'public_id': 'vidur-srivastava-a45b85143',
#                 'experience': [{'locationName': 'Gurugram, Haryana, India',
#                   'entityUrn': 'urn:li:fs_position:(ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4,2429449395)',
#                   'geoLocationName': 'Gurugram, Haryana, India',
#                   'geoUrn': 'urn:li:fs_geo:115884833',
#                   'companyName': 'Tredence Inc.',
#                   'timePeriod': {'startDate': {'month': 7, 'year': 2024}},
#                   'company': {'employeeCountRange': {'start': 1001,
#                     'end': 5000},
#                    'industries': ['Management Consulting']},
#                   'title': 'Data Scientist',
#                   'region': 'urn:li:fs_region:(in,0)',
#                   'companyUrn': 'urn:li:fs_miniCompany:5208967',
# ...
#                   'company': {'objectUrn': 'urn:li:company:2453129',
#                    'entityUrn': 'urn:li:fs_miniCompany:2453129',
#                    'name': 'Coursera',
#                    'showcase': False,
#                    'active': True,
#                    'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#                        'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1630530042036/coursera_logo?e=1733961600&v=beta&t=oz6pqKAJrBmg-fGKcpqqNFRIFGRcS123rQhC5X5jtQg',
#                        'expiresAt': 1733961600000,
#                        'height': 200},
#                       {'width': 100,
#                        'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1630530042036/coursera_logo?e=1733961600&v=beta&t=yrvzYS6CyS7jahwqvetli83vjChB6I8TGbqBMNP9sFE',
#                        'expiresAt': 1733961600000,
#                        'height': 100},
#                       {'width': 400,
#                        'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1630530042036/coursera_logo?e=1733961600&v=beta&t=aF0UMMh4zW46fP_z_yVX9w66mYuZcyzarAc3XhREIdo',
#                        'expiresAt': 1733961600000,
#                        'height': 400}],
#                      'rootUrl': 'https://media.licdn.com/dms/image/v2/C4D0BAQGexnfBxeEG-g/company-logo_'}},
#                    'universalName': 'coursera',
#                    'dashCompanyUrn': 'urn:li:fsd_company:2453129',
#                    'trackingId': 'zW/MLt5hTfyilkfns9wF3A=='},
#                   'displaySource': 'coursera.org',
#                   'companyUrn': 'urn:li:fs_miniCompany:2453129',
#                   'url': 'https://www.coursera.org/account/accomplishments/certificate/SF7V6BBJQHMD'},
#                  {'authority': 'Coursera',
#                   'name': 'Sequence Models',
#                   'timePeriod': {'startDate': {'month': 2, 'year': 2021}},
#                   'licenseNumber': 'CS4VKM2RNYYV',
#                   'company': {'objectUrn': 'urn:li:company:2453129',
#                    'entityUrn': 'urn:li:fs_miniCompany:2453129',
#                    'name': 'Coursera',
#                    'showcase': False,
#                    'active': True,
#                    'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#                        'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1630530042036/coursera_logo?e=1733961600&v=beta&t=oz6pqKAJrBmg-fGKcpqqNFRIFGRcS123rQhC5X5jtQg',
#                        'expiresAt': 1733961600000,
#                        'height': 200},
#                       {'width': 100,
#                        'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1630530042036/coursera_logo?e=1733961600&v=beta&t=yrvzYS6CyS7jahwqvetli83vjChB6I8TGbqBMNP9sFE',
#                        'expiresAt': 1733961600000,
#                        'height': 100},
#                       {'width': 400,
#                        'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1630530042036/coursera_logo?e=1733961600&v=beta&t=aF0UMMh4zW46fP_z_yVX9w66mYuZcyzarAc3XhREIdo',
#                        'expiresAt': 1733961600000,
#                        'height': 400}],
#                      'rootUrl': 'https://media.licdn.com/dms/image/v2/C4D0BAQGexnfBxeEG-g/company-logo_'}},
#                    'universalName': 'coursera',
#                    'dashCompanyUrn': 'urn:li:fsd_company:2453129',
#                    'trackingId': 'hn693h+3Q62Ogjeezg+fFg=='},
#                   'displaySource': 'coursera.org',
#                   'companyUrn': 'urn:li:fs_miniCompany:2453129',
#                   'url': 'https://www.coursera.org/account/accomplishments/certificate/CS4VKM2RNYYV'},
#                  {'authority': 'Coursera',
#                   'name': 'Deep Learning Specialisation',
#                   'timePeriod': {'startDate': {'month': 2, 'year': 2021}},
#                   'licenseNumber': ' PQS2B4L2JQ37',
#                   'company': {'objectUrn': 'urn:li:company:2453129',
#                    'entityUrn': 'urn:li:fs_miniCompany:2453129',
#                    'name': 'Coursera',
#                    'showcase': False,
#                    'active': True,
#                    'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#                        'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1630530042036/coursera_logo?e=1733961600&v=beta&t=oz6pqKAJrBmg-fGKcpqqNFRIFGRcS123rQhC5X5jtQg',
#                        'expiresAt': 1733961600000,
#                        'height': 200},
#                       {'width': 100,
#                        'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1630530042036/coursera_logo?e=1733961600&v=beta&t=yrvzYS6CyS7jahwqvetli83vjChB6I8TGbqBMNP9sFE',
#                        'expiresAt': 1733961600000,
#                        'height': 100},
#                       {'width': 400,
#                        'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1630530042036/coursera_logo?e=1733961600&v=beta&t=aF0UMMh4zW46fP_z_yVX9w66mYuZcyzarAc3XhREIdo',
#                        'expiresAt': 1733961600000,
#                        'height': 400}],
#                      'rootUrl': 'https://media.licdn.com/dms/image/v2/C4D0BAQGexnfBxeEG-g/company-logo_'}},
#                    'universalName': 'coursera',
#                    'dashCompanyUrn': 'urn:li:fsd_company:2453129',
#                    'trackingId': 'aFcogeKSRLS0cE8KhQfjDQ=='},
#                   'displaySource': 'coursera.org',
#                   'companyUrn': 'urn:li:fs_miniCompany:2453129',
#                   'url': 'https://www.coursera.org/account/accomplishments/specialization/certificate/PQS2B4L2JQ37'},
#                  {'authority': 'Coursera',
#                   'name': 'Predicting Employee Turnover with scikit-learn',
#                   'timePeriod': {'startDate': {'month': 12, 'year': 2020}},
#                   'licenseNumber': '4CM8HE2PTZ4G',
#                   'company': {'objectUrn': 'urn:li:company:2453129',
#                    'entityUrn': 'urn:li:fs_miniCompany:2453129',
#                    'name': 'Coursera',
#                    'showcase': False,
#                    'active': True,
#                    'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#                        'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1630530042036/coursera_logo?e=1733961600&v=beta&t=oz6pqKAJrBmg-fGKcpqqNFRIFGRcS123rQhC5X5jtQg',
#                        'expiresAt': 1733961600000,
#                        'height': 200},
#                       {'width': 100,
#                        'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1630530042036/coursera_logo?e=1733961600&v=beta&t=yrvzYS6CyS7jahwqvetli83vjChB6I8TGbqBMNP9sFE',
#                        'expiresAt': 1733961600000,
#                        'height': 100},
#                       {'width': 400,
#                        'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1630530042036/coursera_logo?e=1733961600&v=beta&t=aF0UMMh4zW46fP_z_yVX9w66mYuZcyzarAc3XhREIdo',
#                        'expiresAt': 1733961600000,
#                        'height': 400}],
#                      'rootUrl': 'https://media.licdn.com/dms/image/v2/C4D0BAQGexnfBxeEG-g/company-logo_'}},
#                    'universalName': 'coursera',
#                    'dashCompanyUrn': 'urn:li:fsd_company:2453129',
#                    'trackingId': 'P4WhcJ2BQxajd50+qzNEtw=='},
#                   'displaySource': 'coursera.org',
#                   'companyUrn': 'urn:li:fs_miniCompany:2453129',
#                   'url': 'https://www.coursera.org/account/accomplishments/certificate/4CM8HE2PTZ4G'},
#                  {'authority': 'Coursera',
#                   'name': 'Multiple Linear Regression with scikit-learn',
#                   'timePeriod': {'startDate': {'month': 12, 'year': 2020}},
#                   'licenseNumber': ' 9E2CJ7KNVMSY',
#                   'company': {'objectUrn': 'urn:li:company:2453129',
#                    'entityUrn': 'urn:li:fs_miniCompany:2453129',
#                    'name': 'Coursera',
#                    'showcase': False,
#                    'active': True,
#                    'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#                        'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1630530042036/coursera_logo?e=1733961600&v=beta&t=oz6pqKAJrBmg-fGKcpqqNFRIFGRcS123rQhC5X5jtQg',
#                        'expiresAt': 1733961600000,
#                        'height': 200},
#                       {'width': 100,
#                        'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1630530042036/coursera_logo?e=1733961600&v=beta&t=yrvzYS6CyS7jahwqvetli83vjChB6I8TGbqBMNP9sFE',
#                        'expiresAt': 1733961600000,
#                        'height': 100},
#                       {'width': 400,
#                        'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1630530042036/coursera_logo?e=1733961600&v=beta&t=aF0UMMh4zW46fP_z_yVX9w66mYuZcyzarAc3XhREIdo',
#                        'expiresAt': 1733961600000,
#                        'height': 400}],
#                      'rootUrl': 'https://media.licdn.com/dms/image/v2/C4D0BAQGexnfBxeEG-g/company-logo_'}},
#                    'universalName': 'coursera',
#                    'dashCompanyUrn': 'urn:li:fsd_company:2453129',
#                    'trackingId': 'boswl4vTQVevMAjS4OJIoA=='},
#                   'displaySource': 'coursera.org',
#                   'companyUrn': 'urn:li:fs_miniCompany:2453129',
#                   'url': 'https://www.coursera.org/account/accomplishments/certificate/9E2CJ7KNVMSY'}],
#                 'volunteer': [{'role': 'Fundraising Manager',
#                   'companyName': 'NSS IIT Roorkee',
#                   'timePeriod': {'startDate': {'month': 7, 'year': 2019}},
#                   'cause': 'SOCIAL_SERVICES',
#                   'company': {'miniCompany': {'objectUrn': 'urn:li:company:13174287',
#                     'entityUrn': 'urn:li:fs_miniCompany:13174287',
#                     'name': 'NSS IIT Roorkee',
#                     'showcase': False,
#                     'active': True,
#                     'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#                         'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1657703666268?e=1733961600&v=beta&t=Kuqy0G597CfxXaGIBtxWRNd8155omCo_4ncD7aJKyaY',
#                         'expiresAt': 1733961600000,
#                         'height': 200},
#                        {'width': 100,
#                         'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1657703666268?e=1733961600&v=beta&t=yLLMotKgLcCiJ_bZYa8G8mzvgTTDMb_enD5OsVctFGk',
#                         'expiresAt': 1733961600000,
#                         'height': 100},
#                        {'width': 400,
#                         'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1657703666268?e=1733961600&v=beta&t=x58iGALobHLR3qnyXbiMf4nqEZfVOplBVYdzNYyGbUk',
#                         'expiresAt': 1733961600000,
#                         'height': 400}],
#                       'rootUrl': 'https://media.licdn.com/dms/image/v2/C4D0BAQHpf8u_D-iyEg/company-logo_'}},
#                     'universalName': 'nssiitr',
#                     'dashCompanyUrn': 'urn:li:fsd_company:13174287',
#                     'trackingId': 'Z6YR+OBvRpevgNinb//gUA=='}},
#                   'companyUrn': 'urn:li:fs_miniCompany:13174287'}],
#                 'honors': [{'description': 'Participated in the Bosch’s Model Extraction Attack for Video Classification where the task was to come up with model extraction strategies for models like Swin Transformer and Movinet\nWere awarded with the Gold Medal for our performance',
#                   'title': 'Gold Medal , Inter IIT Tech Meet 10.0',
#                   'issueDate': {'month': 3, 'year': 2022},
#                   'issuer': 'IIT Guwahati'}],
#                 'projects': [{'occupation': 'urn:li:fs_education:(ACoAAC1VcqsByzp1o1GEmybISevasiO7VjSe39U,610306762)',
#                   'members': [{'member': {'firstName': 'Himank',
#                      'lastName': 'Sehgal',
#                      'dashEntityUrn': 'urn:li:fsd_profile:ACoAAC1VcqsByzp1o1GEmybISevasiO7VjSe39U',
#                      'occupation': "Data Scientist @Mastercard AI Garage | IIT Roorkee @'23",
#                      'objectUrn': 'urn:li:member:760574635',
#                      'entityUrn': 'urn:li:fs_miniProfile:ACoAAC1VcqsByzp1o1GEmybISevasiO7VjSe39U',
#                      'backgroundImage': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 407,
#                          'fileIdentifyingUrlPathSegment': '200_800/profile-displaybackgroundimage-shrink_200_800/0/1576058244271?e=1730937600&v=beta&t=WBfq78E3El-3K3KBXfk_Tf_-1Im_LoblxDyPtCTZyQk',
#                          'expiresAt': 1730937600000,
#                          'height': 101},
#                         {'width': 407,
#                          'fileIdentifyingUrlPathSegment': '350_1400/profile-displaybackgroundimage-shrink_350_1400/0/1576058244295?e=1730937600&v=beta&t=E-VBfoCxLE_Jn8knqd_ILtjlTnilJVW8O6mLMv9jDW8',
#                          'expiresAt': 1730937600000,
#                          'height': 101}],
#                        'rootUrl': 'https://media.licdn.com/dms/image/v2/C5116AQGrn8XfwiW4Wg/profile-displaybackgroundimage-shrink_'}},
#                      'publicIdentifier': 'himank-sehgal-43786b192',
#                      'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#                          'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1686727951150?e=1730937600&v=beta&t=AtWs9pDQauuNF27I9wDsWZpN7-5dZiD7rlrP0wWWyxk',
#                          'expiresAt': 1730937600000,
#                          'height': 100},
#                         {'width': 200,
#                          'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1686727951150?e=1730937600&v=beta&t=u-ytgn2l2zi6ItiTeMQ02a38ZBOoLKZ8SKuygF_qF3Q',
#                          'expiresAt': 1730937600000,
#                          'height': 200},
#                         {'width': 400,
#                          'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1686727951150?e=1730937600&v=beta&t=cQvnZvr8y_U8pXTaTTyKZTV-Dl0YMsoqiVcOKqL_Us0',
#                          'expiresAt': 1730937600000,
#                          'height': 400},
#                         {'width': 800,
#                          'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1686727951150?e=1730937600&v=beta&t=w-t9F_b-kJmaWwj0r6RuSkRxw4f7sT4zG6iliVyLBUM',
#                          'expiresAt': 1730937600000,
#                          'height': 800}],
#                        'rootUrl': 'https://media.licdn.com/dms/image/v2/D4D03AQGT_HXOWv2P1A/profile-displayphoto-shrink_'}},
#                      'trackingId': 'xA8H4WfbQYG+npaDPZn33g=='},
#                     'entityUrn': 'urn:li:fs_contributor:(ACoAAC1VcqsByzp1o1GEmybISevasiO7VjSe39U,1954625747,247541898)',
#                     'profileUrn': 'urn:li:fs_miniProfile:ACoAAC1VcqsByzp1o1GEmybISevasiO7VjSe39U'}],
#                   'timePeriod': {'startDate': {'month': 10, 'year': 2019}},
#                   'description': 'A small sized 4-legged robot fitted with a camera which can be used for several purposes like spying , search and rescue operations.',
#                   'title': 'Robotic Bug'}],
#                 'skills': [{'name': 'Engineering'},
#                  {'name': 'Electrical Engineering'},
#                  {'name': 'Case Studies'},
#                  {'name': 'Management'}],
#                 'urn_id': 'ACoAAC1VcqsByzp1o1GEmybISevasiO7VjSe39U'},
#                'skills': [{'name': 'Engineering'},
#                 {'name': 'Electrical Engineering'},
#                 {'name': 'Case Studies'},
#                 {'name': 'Management'},
#                 {'name': 'Fundraising'}]}]})

# %%
# code to clean up unnecessary details
for key, values in peoples_profiles.items():
    for val in values:
        for k1, v1 in val.items():
            if isinstance(v1, dict):
                if "student" in v1:
                    del v1["student"]
                if "geoCountryUrn" in v1:
                    del v1["geoCountryUrn"]
                if "geoLocationBackfilled" in v1:
                    del v1["geoLocationBackfilled"]
                if "entityUrn" in v1:
                    del v1["entityUrn"]
                if "geoCountryName" in v1:
                    del v1["geoCountryName"]
                if "elt" in v1:
                    del v1["elt"]
                if "profilePictureOriginalImage" in v1:
                    del v1["profilePictureOriginalImage"]
                if "industryUrn" in v1:
                    del v1["industryUrn"]
                if "profilePicture" in v1:
                    del v1["profilePicture"]
                if "geoLocation" in v1:
                    del v1["geoLocation"]
                if "geoLocationName" in v1:
                    del v1["geoLocationName"]
                if "location" in v1:
                    del v1["location"]
                if "backgroundPicture" in v1:
                    del v1["backgroundPicture"]
                if "backgroundPictureOriginalImage" in v1:
                    del v1["backgroundPictureOriginalImage"]
                if "displayPictureUrl" in v1:
                    del v1["displayPictureUrl"]
                if "img_400_400" in v1:
                    del v1["img_400_400"]
                if "img_200_200" in v1:
                    del v1["img_200_200"]
                if "img_800_800" in v1:
                    del v1["img_800_800"]
                if "img_100_100" in v1:
                    del v1["img_100_100"]
                if "img_767_767" in v1:
                    del v1["img_767_767"]
                if "profile_id" in v1:
                    del v1["profile_id"]
                if "profile_urn" in v1:
                    del v1["profile_urn"]
                if "member_urn" in v1:
                    del v1["member_urn"]
                if "volunteer" in v1:
                    del v1["volunteer"]
                if "honors" in v1:
                    del v1["honors"]
                if "experience" in v1:
                    for ele in v1["experience"]:
                        if "entityUrn" in ele:
                            del ele["entityUrn"]
                        if "geoUrn" in ele:
                            del ele["geoUrn"]
                        if "region" in ele:
                            del ele["region"]
                        if "companyUrn" in ele:
                            del ele["companyUrn"]
                        if "companyLogoUrl" in ele:
                            del ele["companyLogoUrl"]
                if "education" in v1:
                    for ele in v1["education"]:
                        if "entityUrn" in ele:
                            del ele["entityUrn"]
                        for sch in ele.get("school", []):
                            if "objectUrn" in ele:
                                del ele["objectUrn"]
                            if "entityUrn" in ele:
                                del ele["entityUrn"]
                            if "trackingId" in ele:
                                del ele["trackingId"]
                            if "logoUrl" in ele:
                                del ele["logoUrl"]
                            if "schoolUrn" in ele:
                                del ele["schoolUrn"]
                if "certifications" in v1:
                    for ele in v1["certifications"]:
                        if "company" in ele:
                                del ele["company"]
                        if "displaySource" in ele:
                                del ele["displaySource"]
                        if "companyUrn" in ele:
                                del ele["companyUrn"]
                        if "url" in ele:
                                del ele["url"]
                if "projects" in v1:
                    for ele in v1["projects"]:
                        if "members" in ele:
                                del ele["members"]

# %%
for urn_id, profile_info in peoples_profiles.items():
    for info in profile_info:
        for k,v in info.items():
            if k == "profile_details":
                for k1,v1 in v.items():
                    if k1 != "skills":
                        a = [k1,v1]
                        print(a)
# Out:
# ['summary', '11+ years of experience with a proven track record of driving revenue growth and operational efficiency through data-driven solutions. Skilled in data manipulation, visualization, statistical inference, machine learning, and MLOps with strong theoretical foundations. Effective communication skills, adept at distilling complex ideas and concepts into easy-to- understand language. Experienced in leading end-to-end ML projects and solving the unique challenges that come with them.']
# ['industryName', 'Information Technology & Services']
# ['lastName', 'Maheshwari']
# ['locationName', 'India']
# ['firstName', 'Sahil']
# ['headline', 'Data Scientist @ Hunch']
# ['public_id', 'maheshwarisahil']
# ['experience', [{'locationName': 'Delhi, India', 'geoLocationName': 'Delhi, India', 'companyName': 'Hunch', 'timePeriod': {'startDate': {'month': 11, 'year': 2023}}, 'company': {'employeeCountRange': {'start': 51, 'end': 200}, 'industries': ['Internet']}, 'title': 'Head of Data Science'}, {'locationName': 'Bengaluru, Karnataka, India', 'geoLocationName': 'Bengaluru, Karnataka, India', 'companyName': 'SIXT Research & Development India', 'timePeriod': {'endDate': {'month': 8, 'year': 2023}, 'startDate': {'month': 10, 'year': 2020}}, 'description': 'Led strategically important DS projects through their complete ML lifecycle. Also responsible for solution research and team mentoring.\n\nDynamic Pricing\n• Delivered a sustainable margin uplift of >3% using elasticity-based pricing models\n• Built a faster and more reliable AB testing framework solving problems in traditional AB testing like\npeeking, high sample variance, independence of p-values and effect sizes, etc.\n\nFleet Optimization\n• Improved demand forecasting error using Bayesian hierarchical models\n• Developed a price-demand relationship model from natural price variations data using GMM to handle price endogeneity\n• Implemented ML-driven simulations to optimize long-term inventory planning', 'company': {'employeeCountRange': {'start': 201, 'end': 500}, 'industries': ['Computer Software']}, 'title': 'Staff Data Scientist'}, {'locationName': 'Bengaluru Area, India', 'geoLocationName': 'Bengaluru Area, India', 'companyName': 'ThoughtWorks', 'timePeriod': {'endDate': {'month': 10, 'year': 2020}, 'startDate': {'month': 9, 'year': 2018}}, 'description': 'Led DS teams and collaborated with other cross-functional teams to build and deliver\ncomprehensive solutions, with DS as a key component.\n\nDynamic Pricing for a brick-&-mortar Retail giant\n• Delivered an average margin increase of €9K per month per store using a SARIMAX-based price-demand model\n• Built a risk control strategy in absence of the test data by defining custom metrics for model’s stability. \n\nSearch Optimization for a leading Knowledge Consulting Firm\n• Improved search results’ relevance considerably using word2Vec, hierarchical clustering with hashing, and tf-idf.', 'company': {'employeeCountRange': {'start': 10001}, 'industries': ['Information Technology and Services']}, 'title': 'Lead Data Scientist'}, {'locationName': 'Bengaluru Area, India', 'geoLocationName': 'Bengaluru Area, India', 'companyName': 'Happiest Minds Technologies', 'timePeriod': {'endDate': {'month': 9, 'year': 2018}, 'startDate': {'month': 7, 'year': 2017}}, 'description': '•\tTime series forecasting for multiple domains like energy, manufacturing, retail, etc. Handled high frequency data (minute level) which is usually not well handled by popular implementations of ARIMA\n•\tImage classification using Inception model to automate identification of damaged devices\n•\tOptimization of predictive model to handle incremental data by maintaining data preparation pipeline', 'company': {'employeeCountRange': {'start': 5001, 'end': 10000}, 'industries': ['Information Technology and Services']}, 'title': 'Senior Data Scientist'}, {'companyName': 'Happiest Minds Technologies', 'timePeriod': {'endDate': {'month': 7, 'year': 2017}, 'startDate': {'month': 11, 'year': 2015}}, 'description': '•\tReal time recommendations system for a retail client. Used non-conventional similarity measures resulting in more relevant recommendations\n•\tPrediction of claim propensity and time to claim, for an insurance intermediary, to enable risk based pricing. Also, determined factors causing the claim\n•\tDashboard development on R Shiny and Tableau for actionable business insights\n', 'company': {'employeeCountRange': {'start': 5001, 'end': 10000}, 'industries': ['Information Technology and Services']}, 'title': 'Junior Data Scientist'}]]
# ['education', [{'projects': ['urn:li:fs_project:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,26)', 'urn:li:fs_project:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,1052741438)', 'urn:li:fs_project:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,1053363621)'], 'grade': '7.02/10', 'timePeriod': {'endDate': {'year': 2014}, 'startDate': {'year': 2012}}, 'description': '•\tMember of Finance Forum, TAPMI\n•\tMember of Leader Support Group , Brand Scan Project\n•\tCleared FLIP certification on “Finance and Banking Fundamentals”\n•\tWas among the top 5 teams from all over India in XIMB’s Inter B-school Competition on Microfinance\n•\tVolunteered for Joyfest (Social Initiative, TAPMI)\n•\tWon first prize in “Naach” – dance competition in TAPMI’s intra-college cultural event', 'testScores': ['urn:li:fs_testScore:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,46)'], 'degreeName': 'Post Graduate Diploma in Management', 'schoolName': 'T.A. Pai Management Institute', 'fieldOfStudy': 'Finance, General'}, {'grade': '67.44%', 'timePeriod': {'endDate': {'year': 2009}, 'startDate': {'year': 2005}}, 'degreeName': 'Bachelor of Engineering (B.Eng.)', 'schoolName': 'Apeejay College of Engineering', 'fieldOfStudy': 'Electrical, Electronics and Communications Engineering'}, {'grade': '75.60%', 'timePeriod': {'endDate': {'year': 2005}, 'startDate': {'year': 2004}}, 'degreeName': 'Higher School Certificate', 'schoolName': 'Chiranjiv Bharati School, Gurgaon', 'fieldOfStudy': 'Science'}]]
# ['languages', [{'name': 'English', 'proficiency': 'FULL_PROFESSIONAL'}, {'name': 'Hindi', 'proficiency': 'NATIVE_OR_BILINGUAL'}]]
# ['publications', []]
# ['certifications', [{'authority': 'edX', 'name': 'edX Honor Code Certificate for The Analytics Edge'}, {'authority': 'DataCamp', 'name': 'Data Analysis in R, the data.table Way', 'timePeriod': {'startDate': {'month': 6, 'year': 2015}}, 'licenseNumber': '26bf88ce460d74689e517a49720f7e5a6ae83d72'}, {'authority': 'Finitiatives Learning India Pvt Ltd', 'name': 'Finance and Banking Fundamentals'}, {'authority': 'Cognizant', 'name': 'Level 1: Payment Cards'}, {'authority': 'OutSystems', 'name': 'Outsystems Associate Developer'}, {'authority': 'NIIT', 'name': 'Programming in "C"', 'timePeriod': {'startDate': {'month': 8, 'year': 2006}}}, {'authority': 'Oracle', 'name': 'Oracle Certified Java SE 6 Programmer', 'timePeriod': {'startDate': {'month': 1, 'year': 2011}}}]]
# ['projects', [{'timePeriod': {'endDate': {'month': 4, 'year': 2015}, 'startDate': {'month': 4, 'year': 2015}}, 'description': '- Built a logistic regression model to predict probability of a complaint getting resolved\n- Tools: R for data wrangling, text analysis, model building and testing, and visualization', 'title': 'Pro bono data analysis for Janaagraha - IChangeMyCity'}, {'timePeriod': {'endDate': {'month': 11, 'year': 2014}, 'startDate': {'month': 11, 'year': 2014}}, 'description': '- Stock selection by balancing return and Sortino ratio \n- Tools: Python (NumPy, Pandas)', 'title': 'Stock Analysis'}, {'occupation': 'urn:li:fs_education:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,187975176)', 'timePeriod': {'endDate': {'month': 1, 'year': 2014}, 'startDate': {'month': 1, 'year': 2014}}, 'description': 'Financial Modeling using time value of money, cost of capital, and Monte Carlo analysis on MS Excel', 'title': 'Delhi Airport Metro Express Financial Modeling'}, {'occupation': 'urn:li:fs_education:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,187975176)', 'timePeriod': {'endDate': {'month': 8, 'year': 2013}, 'startDate': {'month': 6, 'year': 2013}}, 'description': 'We did strategic analysis, accounting analysis, financial analysis, cash flow analysis and valuation using FCFF and two stage divident growth model', 'title': 'Equity Research Report on HDFC Bank'}, {'occupation': 'urn:li:fs_education:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,187975176)', 'timePeriod': {'endDate': {'month': 2, 'year': 2013}, 'startDate': {'month': 11, 'year': 2012}}, 'description': 'Market research for Anne French hair removal cream by Pfizer to understand buying behavior and product usage pattern. Data collection, analysis (Excel & Access), and reporting', 'title': 'Market research for Anne French hair removal cream, Pfizer'}]]
# ['urn_id', 'ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano']
# ['summary', 'Experienced data scientist with a track record of translating complex data into actionable insights across diverse sectors spanning FMCG, Sports and Supply Chain.']
# ['industryName', 'Information Technology & Services']
# ['lastName', 'Srivastava']
# ['locationName', 'India']
# ['firstName', 'Vidur']
# ['headline', 'Data Scientist']
# ['public_id', 'vidur-srivastava-a45b85143']
# ['experience', [{'locationName': 'Gurugram, Haryana, India', 'geoLocationName': 'Gurugram, Haryana, India', 'companyName': 'Tredence Inc.', 'timePeriod': {'startDate': {'month': 7, 'year': 2024}}, 'company': {'employeeCountRange': {'start': 1001, 'end': 5000}, 'industries': ['Management Consulting']}, 'title': 'Data Scientist'}, {'locationName': 'Bengaluru, Karnataka, India', 'geoLocationName': 'Bengaluru, Karnataka, India', 'companyName': 'Tiger Analytics', 'timePeriod': {'endDate': {'month': 5, 'year': 2024}, 'startDate': {'month': 5, 'year': 2022}}, 'company': {'employeeCountRange': {'start': 1001, 'end': 5000}, 'industries': ['Management Consulting']}, 'title': 'Senior Analyst'}, {'companyName': 'Wicky', 'timePeriod': {'endDate': {'month': 4, 'year': 2022}, 'startDate': {'month': 1, 'year': 2022}}, 'company': {'employeeCountRange': {'start': 2, 'end': 10}, 'industries': ['Sports']}, 'title': 'Software Engineer - MLE'}, {'locationName': 'Pune, Maharashtra, India', 'geoLocationName': 'Pune, Maharashtra, India', 'companyName': 'Infosys', 'timePeriod': {'endDate': {'month': 1, 'year': 2022}, 'startDate': {'month': 1, 'year': 2022}}, 'company': {'employeeCountRange': {'start': 10001}, 'industries': ['Information Technology and Services']}, 'title': 'Senior System Engineer'}, {'locationName': 'Pune, Maharashtra, India', 'geoLocationName': 'Pune, Maharashtra, India', 'companyName': 'Infosys', 'timePeriod': {'endDate': {'month': 1, 'year': 2022}, 'startDate': {'month': 12, 'year': 2019}}, 'company': {'employeeCountRange': {'start': 10001}, 'industries': ['Information Technology and Services']}, 'title': 'System Engineer'}]]
# ['education', [{'school': {'objectUrn': 'urn:li:school:478063', 'entityUrn': 'urn:li:fs_miniSchool:478063', 'active': True, 'schoolName': 'BITS Pilani Work Integrated Learning Programmes', 'trackingId': 'rJEv7uc/R0i5OFhL57LoeA==', 'logoUrl': 'https://media.licdn.com/dms/image/v2/D560BAQFl6CQfOjKJkA/company-logo_'}, 'timePeriod': {'endDate': {'month': 9, 'year': 2022}, 'startDate': {'month': 9, 'year': 2021}}, 'degreeName': 'Post Graduate Certificate', 'schoolName': 'BITS Pilani Work Integrated Learning Programmes', 'fieldOfStudy': 'Artificial Intelligence and Machine Learning'}, {'school': {'objectUrn': 'urn:li:school:213631', 'entityUrn': 'urn:li:fs_miniSchool:213631', 'active': True, 'schoolName': 'Jaypee Institute of Information Technology, Noida', 'trackingId': 'OKzNsLtIQwOUcgxKeIoz8A=='}, 'timePeriod': {'endDate': {'year': 2019}, 'startDate': {'year': 2015}}, 'degreeName': 'Bachelor of Technology', 'schoolName': 'Jaypee Institute of Information Technology, Noida', 'fieldOfStudy': 'Electronics and Communications Engineering', 'degreeUrn': 'urn:li:fs_degree:250'}]]
# ['languages', []]
# ['publications', []]
# ['certifications', []]
# ['projects', []]
# ['urn_id', 'ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4']
# ['summary', 'Experience in Cognitive Computing with leverage of Machine Learning, Deep Learning, Artificial Intelligence, Natural Language Processing skills . Data driven analyst with the ability to apply ML/DL/NLP/Computer Vision Techniques and leverage algorithms to solve real world problems. Established ability in deploying effective predictive/NLP/Computer Vision models across banking/HealthCare industries to accurately forecast and deliver proven results. Strong understanding of Oracle DB and PLSQL with data migration expérience. Domain Knowledge of SupplyChain/finance/banking/Retail domain with communication skills, excellent product and process design knowledge. Domain HealthCare,Mortgage Banking, Consumer, Commercial Lending, Escrow, Loan processing and servicing, Deposits. Onsite experience (US/UK) with business domain experience in Retail and supply chain with special focus on Customer engagement and managing end-user expectations. Experience in Analysis, Design, Development, Customization, Bug fixes, Enhancement, Support and Implementation.\n\n\nData Science, Machine Learning, Deep Learning and AI technologies.Strong understanding of Databases Oracle, Progress 4GL, PLSQL. Excellent Domain Knowledge of finance/banking/Retail domain with communication skills, excellent product and process design knowledge.Strong knowledge of Data Migration and Implementation.. \n\nAreas of Expertise: Data Science Machine Learning, Deep Learning and AI technologies.\n\nWeb App - Flask, Django.\n\nDomain - Mortgage Banking,Insurance Claim Processing Money Laundering, Investment Banking, Lending, Escrow, Loan processing and servicing. Credit Cards,Healthcare\n\nDatabase - Oracle,Progress 4GL,Mongo Db\n\nLanguages - Python ,PLSQL,Progress4GL,Shell Script\n\nVersioning - SVN,Github\nCloud : IBM Cloud, AWS,AZURE,Kubernates\nOthers : Dockers,CICD\n\n\n\n\n10+ years of experience in exploring and understanding various business models in Finance,Healthcare,Retail and Supply chain domain with special focus on implementation according to client requirements.\n•\tExperience in client interaction for requirement gathering and feasibility analysis at various levels including end users, project managers, and business analysts. Possess good business acumen interacting with various 3rd parties in the same project. Onsite experience (UK) with business domain experience in Retail and supply chain with special focus on customer engagement and managing end-user expectations.']
# ['industryName', 'Information Technology & Services']
# ['lastName', 'Aneja']
# ['locationName', 'India']
# ['firstName', 'Isha']
# ['headline', 'Data Scientist IBM']
# ['img_253_253', '800_800/profile-displayphoto-shrink_800_800/0/1516520225939?e=1730937600&v=beta&t=Y-NS63ItyMgsdVJIR_DcgSb-qbTolbfpcsM606r7v6I']
# ['public_id', 'isha-aneja-642b7a32']
# ['experience', [{'locationName': 'Noida, Uttar Pradesh, India', 'geoLocationName': 'Noida, Uttar Pradesh, India', 'companyName': 'IBM', 'timePeriod': {'startDate': {'month': 12, 'year': 2021}}, 'company': {'employeeCountRange': {'start': 10001}, 'industries': ['Information Technology and Services']}, 'title': 'Data Scientist'}, {'locationName': 'New Delhi Area, India', 'geoLocationName': 'New Delhi Area, India', 'companyName': 'Fiserv', 'timePeriod': {'endDate': {'month': 1, 'year': 2022}, 'startDate': {'month': 12, 'year': 2017}}, 'company': {'employeeCountRange': {'start': 10001}, 'industries': ['Information Technology and Services']}, 'title': 'Technical Lead'}, {'locationName': 'Noida Area, India', 'geoLocationName': 'Noida Area, India', 'companyName': 'Birlasoft', 'timePeriod': {'endDate': {'month': 12, 'year': 2017}, 'startDate': {'month': 8, 'year': 2016}}, 'company': {'employeeCountRange': {'start': 10001}, 'industries': ['Information Technology and Services']}, 'title': 'Senior Software Engineer'}, {'locationName': 'banglore', 'geoLocationName': 'banglore', 'companyName': 'Capgemini', 'timePeriod': {'endDate': {'month': 8, 'year': 2016}, 'startDate': {'month': 11, 'year': 2014}}, 'company': {'employeeCountRange': {'start': 10001}, 'industries': ['Information Technology and Services']}, 'title': 'Technical Team Lead'}, {'locationName': 'Noida Area, India', 'geoLocationName': 'Noida Area, India', 'companyName': 'JK Technosoft Limited.', 'timePeriod': {'endDate': {'month': 10, 'year': 2014}, 'startDate': {'month': 9, 'year': 2011}}, 'company': {'employeeCountRange': {'start': 501, 'end': 1000}, 'industries': ['Management Consulting']}, 'title': 'Senior Software Engineer'}]]
# ['education', [{'school': {'objectUrn': 'urn:li:school:13535', 'entityUrn': 'urn:li:fs_miniSchool:13535', 'active': True, 'schoolName': 'Kurukshetra University', 'trackingId': 'dHzLVrgCR8OjqnvBQicOOA==', 'logoUrl': 'https://media.licdn.com/dms/image/v2/C510BAQFk-1FhZJmk9Q/company-logo_'}, 'timePeriod': {'endDate': {'year': 2011}, 'startDate': {'year': 2008}}, 'degreeName': 'Masters of Computer Applications', 'schoolName': 'Kurukshetra University', 'fieldOfStudy': 'Computer Science'}, {'school': {'objectUrn': 'urn:li:school:13535', 'entityUrn': 'urn:li:fs_miniSchool:13535', 'active': True, 'schoolName': 'Kurukshetra University', 'trackingId': 'cDJI7SEETUaLYybvgWuOuw==', 'logoUrl': 'https://media.licdn.com/dms/image/v2/C510BAQFk-1FhZJmk9Q/company-logo_'}, 'timePeriod': {'endDate': {'year': 2008}, 'startDate': {'year': 2005}}, 'degreeName': 'Bachelor of computer Applications', 'schoolName': 'Kurukshetra University', 'fieldOfStudy': 'Computer Science'}]]
# ['languages', [{'name': 'English', 'proficiency': 'NATIVE_OR_BILINGUAL'}]]
# ['publications', []]
# ['certifications', [{'authority': 'IBM', 'name': 'IBM Certified Advocate - Cloud v1', 'timePeriod': {'startDate': {'month': 3, 'year': 2022}}}, {'authority': 'expert.ai', 'name': 'Expert.ai Pro', 'timePeriod': {'startDate': {'month': 2, 'year': 2022}}}, {'authority': 'IBM', 'name': 'IBM Cloud Pak for Data V3.5.x Essentials', 'timePeriod': {'startDate': {'month': 7, 'year': 2022}}}, {'authority': 'IBM', 'name': 'IBM Cloud Pak for Data V3.5.x Data Science', 'timePeriod': {'startDate': {'month': 7, 'year': 2022}}}, {'authority': 'Amazon Web Services (AWS)', 'name': 'AWS Certified Cloud Practitioner', 'timePeriod': {'endDate': {'month': 8, 'year': 2025}, 'startDate': {'month': 8, 'year': 2022}}}, {'authority': 'Amazon Web Services (AWS)', 'name': 'AWS Certified Machine Learning – Specialty', 'timePeriod': {'endDate': {'month': 9, 'year': 2025}, 'startDate': {'month': 9, 'year': 2022}}}, {'authority': 'Microsoft', 'name': 'Microsoft Certified: Azure AI Engineer Associate', 'timePeriod': {'endDate': {'month': 9, 'year': 2024}, 'startDate': {'month': 9, 'year': 2023}}, 'licenseNumber': '4C3C15CAB831C53E'}, {'authority': 'Microsoft', 'name': 'Microsoft Certified: Azure Data Scientist Associate', 'timePeriod': {'endDate': {'month': 9, 'year': 2024}, 'startDate': {'month': 9, 'year': 2023}}, 'licenseNumber': '962F38933DAC4393'}, {'authority': 'IBM', 'name': 'Healthcare Insights and Solutions (Silver)', 'timePeriod': {'startDate': {'month': 5, 'year': 2024}}}]]
# ['projects', []]
# ['urn_id', 'ACoAAAbvohIBhdiLqQ5FCbtA40AFvg3f-T7fKfk']
# ['summary', 'Experience Data Science professional with demonstrated history of working in IT service industry. Experienced in executing data driven solutions to increase efficiency, accuracy and utility of internal data processing. Skilled in natural language processing with practioner knowledge on Web Analytics. Strong information technology professional with a Bachelor of Technology (BTech) from Uttar Pradesh Technical University. ']
# ['industryName', 'Information Technology & Services']
# ['lastName', 'Mathur']
# ['locationName', 'India']
# ['firstName', 'Tushar']
# ['headline', 'Data Scientist']
# ['img_413_413', '800_800/profile-displayphoto-shrink_800_800/0/1627636616827?e=1730937600&v=beta&t=x9srqsltLWc2l7StlzDDIhorDInTYG12-UOqNW3FfWI']
# ['public_id', 'tushar-mathur-79a23120']
# ['experience', [{'locationName': 'Noida, Uttar Pradesh, India', 'geoLocationName': 'Noida, Uttar Pradesh, India', 'companyName': 'Coforge', 'timePeriod': {'startDate': {'month': 8, 'year': 2022}}, 'company': {'employeeCountRange': {'start': 10001}, 'industries': ['Information Technology and Services']}, 'title': 'Analytics Lead'}, {'locationName': 'Noida, Uttar Pradesh, India', 'geoLocationName': 'Noida, Uttar Pradesh, India', 'companyName': 'EXL', 'timePeriod': {'endDate': {'month': 8, 'year': 2022}, 'startDate': {'month': 8, 'year': 2021}}, 'company': {'employeeCountRange': {'start': 10001}, 'industries': ['Information Technology and Services']}, 'title': 'Technical Lead'}, {'locationName': 'Noida Area, India', 'geoLocationName': 'Noida Area, India', 'companyName': 'Sopra Steria', 'timePeriod': {'endDate': {'month': 7, 'year': 2021}, 'startDate': {'month': 7, 'year': 2019}}, 'description': 'Working on information extraction project in which we focuses on creating structured representation of unstructured/structured texts by extracting relevant entities from them, using machine learning and AI process thereby making the data analysis realizable.', 'company': {'employeeCountRange': {'start': 10001}, 'industries': ['Information Technology and Services']}, 'title': 'Module Lead'}, {'locationName': 'Noida Area, India', 'geoLocationName': 'Noida Area, India', 'companyName': 'Sopra Steria', 'timePeriod': {'endDate': {'month': 6, 'year': 2019}, 'startDate': {'month': 10, 'year': 2017}}, 'company': {'employeeCountRange': {'start': 10001}, 'industries': ['Information Technology and Services']}, 'title': 'Senior Software Engineer', 'honors': ['urn:li:fs_honor:(ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY,1097608354)']}, {'locationName': 'Gurgaon, India', 'geoLocationName': 'Gurgaon, India', 'companyName': 'Infosys', 'timePeriod': {'endDate': {'month': 10, 'year': 2017}, 'startDate': {'month': 10, 'year': 2016}}, 'description': '•Working knowledge of Agile and Waterfall models.\n•Working in full project life cycle involving Requirement Analysis, Testing and Implementation phases.\n•Extensive coding and modifying programs using COBOL, DB2 and JCL as per the requests of business departments.\n•Involved in Preparing Unit test cases, doing test data setup and performing Unit testing, User Acceptance Testing.\n•Works on envisioning of requirement for future analysis.', 'company': {'employeeCountRange': {'start': 10001}, 'industries': ['Information Technology and Services']}, 'title': 'Senior System Engineer', 'honors': ['urn:li:fs_honor:(ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY,1304876652)', 'urn:li:fs_honor:(ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY,1020421066)']}]]
# ['education', [{'timePeriod': {'endDate': {'year': 2014}, 'startDate': {'year': 2010}}, 'degreeName': 'Bachelor of Technology (BTech)', 'schoolName': 'Uttar Pradesh Technical University', 'fieldOfStudy': 'Electrical, Electronics and Communications Engineering'}]]
# ['languages', [{'name': 'English', 'proficiency': 'PROFESSIONAL_WORKING'}, {'name': 'Hindi', 'proficiency': 'NATIVE_OR_BILINGUAL'}]]
# ['publications', []]
# ['certifications', [{'authority': 'Coursera', 'name': 'IBM Data Science Specialization', 'timePeriod': {'startDate': {'month': 9, 'year': 2019}}, 'licenseNumber': '4X9MSFRHX56Z'}, {'authority': 'Google', 'name': 'Google Analytics Cerification', 'timePeriod': {'endDate': {'month': 7, 'year': 2021}, 'startDate': {'month': 7, 'year': 2020}}, 'licenseNumber': '55467797'}]]
# ['projects', []]
# ['urn_id', 'ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY']
# ['summary', "4+ years of work experience solving business problems with the application of Data Science. Master of Data Science, Monash University (Melbourne). Proficient in Generative AI, Computer Vision and Predictive Modeling. With a strong grip over mathematics, deep learning and machine learning algorithms, capable to transform business requirements into data science formulations and implementing the solutions in an efficient and scalable fashion.\n\nCreating impactful AI solutions at R Systems, my focus is on designing cutting-edge generative AI technologies. With a Master's degree in Data Science from Monash University, I apply rigorous academic training to address complex client challenges. Our team's contribution has significantly enhanced the RAG Application's accuracy, showcasing a blend of innovation and practical application.\n\nMy core competencies lie in Large Language Models and transformative AI, underpinned by data collection, preprocessing, model development, and deployment. These skills have enabled us to deliver tailored solutions that not only meet but exceed our clients' business objectives. The dedication to continual learning and improvement is what drives the team and myself to achieve excellence in the ever-evolving field of data science."]
# ['industryName', 'Computer Software']
# ['lastName', 'Nain']
# ['locationName', 'India']
# ['birthDate', {'month': 1, 'day': 24}]
# ['firstName', 'Rakesh']
# ['headline', "Data Scientist @ R Systems | Master's in Data Science"]
# ['public_id', 'rakeshnain']
# ['experience', [{'locationName': 'Noida, Uttar Pradesh, India', 'geoLocationName': 'Noida, Uttar Pradesh, India', 'companyName': 'R Systems', 'timePeriod': {'startDate': {'month': 8, 'year': 2023}}, 'description': 'Roles and Responsibilities:\n- Tackle client challenges by designing and implement end-to-end data science solutions using generative AI (LLMs, Large Multi-Modals and their finetuning based on the use cases) or traditional machine learning from data collection, preprocessing to model development and deployment\n- I ensure optimal model performance, engage in cross-functional collaboration, and deliver insights to clients through effective communication.\n- My role contributes to R systems consultancy prowess in delivering innovative and impactful solutions that address diverse business needs of clients.\n\nAchievements:\n- Increased the RAG Application accuracy by 40%.', 'company': {'employeeCountRange': {'start': 1001, 'end': 5000}, 'industries': ['Information Technology and Services']}, 'title': 'Data Scientist'}, {'companyName': 'Intello Labs', 'timePeriod': {'endDate': {'month': 8, 'year': 2023}, 'startDate': {'month': 12, 'year': 2021}}, 'description': 'Roles and Responsibilities:\n- Develop state-of-the-art machine learning and deep learning algorithms/models for visual recognition tasks, such as segmentation and detection.\n- Collaborate closely with multidisciplinary teams of software engineers, hardware engineers, business leaders and other key players to develop Artificial Intelligent machines.\n- Data Collection, EDA, Data Cleaning, ML Model Development(R&D) and deployment.\n\nAchievements:\n- Developed object detection and instance segmentation algorithm taking around 50 times less RAM in training with only twice extra time in inference as compared to present state-of-the-art algorithms in the market.\n- Improved grains classification results by 20%, and fruits defect detection results by 12%.', 'company': {'employeeCountRange': {'start': 51, 'end': 200}, 'industries': ['Information Technology and Services']}, 'title': 'Deep Learning Engineer'}, {'locationName': 'Noida, Uttar Pradesh, India', 'geoLocationName': 'Noida, Uttar Pradesh, India', 'companyName': 'DishTV', 'timePeriod': {'endDate': {'month': 10, 'year': 2018}, 'startDate': {'month': 6, 'year': 2017}}, 'description': 'Roles and Responsibilities:\nStarted as a Software Developer in the “My DishTV” Android App project but later shifted to Zee5 OTT Project as a Data Scientist, where key roles and responsibilities were:\n- Exploring and preparing machine learning approaches to perform personal recommendations.\n- Data collection, preprocessing, analysis, analyzing performance metrics, building and tuning hyperparameters of models.\n- Presenting information/results to higher management using data visualization techniques.\n\nAchievements:\n- Increased CTR by 15% and take-rate by 10%.\n\nTechnologies used: Python, Pandas, scikit-learn, NumPy, Matplotlib', 'company': {'employeeCountRange': {'start': 1001, 'end': 5000}, 'industries': ['Broadcast Media']}, 'title': 'Software Developer - Machine Learning'}]]
# ['education', [{'projects': ['urn:li:fs_project:(ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY,268411520)', 'urn:li:fs_project:(ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY,1130990444)'], 'description': 'Coursework Units:\nFIT9132 Introduction to databases\nFIT9133 Programming foundations in python\nFIT9134 Computer architecture and operating systems\nMAT9004 Mathematical foundations for data science\nFIT5145 Introduction to data science\nFIT5147 Data exploration and visualisation\nFIT5195 Business intelligence and data warehousing\nFIT5197 Statistical data modelling\nFIT5047 Fundamentals of artificial intelligence\nFIT5149 Applied data analysis\nFIT5196 Data wrangling\nFIT5202 Data processing for big data\nFIT5120 Industry experience studio project\nFIT5122 Professional practice\nFIT5215 Deep Learning', 'degreeName': "Master's degree", 'school': {'objectUrn': 'urn:li:school:10231', 'entityUrn': 'urn:li:fs_miniSchool:10231', 'active': True, 'schoolName': 'Monash University', 'trackingId': 'dPCShfgxQ9ynGmCA6r9X+g==', 'logoUrl': 'https://media.licdn.com/dms/image/v2/D560BAQEp8cQSkbCXRw/company-logo_'}, 'activities': 'Monash Data Science Society', 'grade': 'GPA 2.8 (4.0 GPA scale) | WAM 71.1 %', 'timePeriod': {'endDate': {'year': 2021}, 'startDate': {'year': 2019}}, 'schoolName': 'Monash University', 'fieldOfStudy': 'Data Science', 'degreeUrn': 'urn:li:fs_degree:500'}, {'description': 'Coursework Units:\nApplied mathematics | Computer programming | Data structure | Theory of computation | Database management systems | Object oriented programming | Algorithm design and analysis | Digital Communication | Software engineering | Computer networks | Web engineering | Artificial intelligence | Advance DBMS | Software testing | Wireless communication | Mobile computing | Machine learning', 'degreeName': "Bachelor's degree", 'school': {'objectUrn': 'urn:li:school:13486', 'entityUrn': 'urn:li:fs_miniSchool:13486', 'active': True, 'schoolName': 'Guru Gobind Singh Indraprastha University', 'trackingId': 'qRRY8ZlsQzyvQ4Vq049r0w==', 'logoUrl': 'https://media.licdn.com/dms/image/v2/C510BAQGnw20J7HynZA/company-logo_'}, 'activities': 'Techno-Cultural Fest Organiser Society. Coordinated Street Dance event in the Techno-Cultural Festival(Corona-The Carnival).', 'grade': '66.25%', 'timePeriod': {'endDate': {'year': 2017}, 'startDate': {'year': 2013}}, 'fieldOfStudyUrn': 'urn:li:fs_fieldOfStudy:100189', 'schoolName': 'Guru Gobind Singh Indraprastha University', 'fieldOfStudy': 'Computer Science', 'degreeUrn': 'urn:li:fs_degree:200'}]]
# ['languages', [{'name': 'English', 'proficiency': 'FULL_PROFESSIONAL'}, {'name': 'Hindi', 'proficiency': 'FULL_PROFESSIONAL'}]]
# ['publications', [{'date': {'month': 1, 'year': 2021, 'day': 2}, 'name': 'Big data Analysis of Road Crash Data using PySpark with PySpark Tutorial', 'publisher': 'medium.com', 'description': 'In this article, I will be using data about road crashes in South Australia. Data is given by The Department of Planning, Transport and Infrastructure ( DPTI ), South Australia. I will be using PySpark and try to do small Data Analysis using parallel computing with a brief overview of PySpark concepts.\nI will be demonstrating parallel computing using three types of data structures: RDDs, PySpark DataFrame, SparkSQL.', 'url': 'https://medium.com/rakesh-nain/big-data-analysis-of-road-crash-data-using-pyspark-with-pyspark-tutorial-c78ff2c35588?source=friends_link&sk=ffa8c610a9a4f411ead67e35aa1c50e9', 'authors': [{'member': {'firstName': 'Rakesh', 'lastName': 'Nain', 'dashEntityUrn': 'urn:li:fsd_profile:ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY', 'occupation': "Data Scientist @ R Systems | Master's in Data Science", 'objectUrn': 'urn:li:member:533688180', 'entityUrn': 'urn:li:fs_miniProfile:ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY', 'backgroundImage': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 800, 'fileIdentifyingUrlPathSegment': '200_800/profile-displaybackgroundimage-shrink_200_800/0/1612960954446?e=1730937600&v=beta&t=i2QRQJRutCGtKW0qhvu0PL_s_vkhg7sSfyv9dwukb-k', 'expiresAt': 1730937600000, 'height': 200}, {'width': 1400, 'fileIdentifyingUrlPathSegment': '350_1400/profile-displaybackgroundimage-shrink_350_1400/0/1612960954446?e=1730937600&v=beta&t=WCYvfDKrWIDuUHEOTB_6hjiDhaLIvIqlbIyYPXv77Mk', 'expiresAt': 1730937600000, 'height': 350}], 'rootUrl': 'https://media.licdn.com/dms/image/v2/C5616AQHdmILFQvk1eg/profile-displaybackgroundimage-shrink_'}}, 'publicIdentifier': 'rakeshnain', 'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 400, 'fileIdentifyingUrlPathSegment': '400_400/profile-framedphoto-shrink_400_400/0/1723188501992?e=1726300800&v=beta&t=4Svr7unIjJlyEkn_pyXkhQeeCTx5lD77gUyJR7sPd3M', 'expiresAt': 1726300800000, 'height': 400}, {'width': 200, 'fileIdentifyingUrlPathSegment': '200_200/profile-framedphoto-shrink_200_200/0/1723188501992?e=1726300800&v=beta&t=uC8lfQFgaK_DQ7_BMZBOM7opz1Vdlr95Y6NiGYm5fWU', 'expiresAt': 1726300800000, 'height': 200}, {'width': 800, 'fileIdentifyingUrlPathSegment': '800_800/profile-framedphoto-shrink_800_800/0/1723188501992?e=1726300800&v=beta&t=ccmNpaanF_RA_inQ3JfJGremNJMzjFtcm1PicZTQQsk', 'expiresAt': 1726300800000, 'height': 800}, {'width': 100, 'fileIdentifyingUrlPathSegment': '100_100/profile-framedphoto-shrink_100_100/0/1723188501953?e=1726300800&v=beta&t=SvyrFVGBmj8MwDGsfDaRHzLanR5dj9vMCgMdX7VYVqU', 'expiresAt': 1726300800000, 'height': 100}], 'rootUrl': 'https://media.licdn.com/dms/image/v2/D5635AQHtHFOJ6m9dAg/profile-framedphoto-shrink_'}}, 'trackingId': 'xq+yxQLGQ8OlkTopZFuhhA=='}, 'profileUrn': 'urn:li:fs_miniProfile:ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY'}]}, {'date': {'month': 12, 'year': 2020, 'day': 28}, 'name': 'Using python collecting real-world data by web scraping real estate website and doing data wrangling', 'publisher': 'medium.com', 'description': 'In any data science project one of the most asked questions is how to get the data, where is the data. I would say there is plenty of data around you, you just need to extract it. For example, on the internet, there are millions of petabytes of data available and most of it is free. All you need to know is how to extract it and make it useful for your organisation. I would say any type of organisation can make use of the free data available on the internet for their business gains. They can use web scraping to extract it.\n\nFor demonstrating web scrapping in this article I will be scraping data from domian.com. Domain.com is a real estate website. I will be scrapping the price, number of bedrooms, number of bathrooms, number of parking, address and location(latitude and longitude) of each house in Me ...
# ['certifications', [{'authority': 'Coursera', 'name': 'What is Data Science?', 'timePeriod': {'startDate': {'month': 12, 'year': 2019}}, 'licenseNumber': 'YHDPH7SBRSFF'}, {'authority': 'Coursera', 'name': 'Python for Data Science and AI', 'timePeriod': {'startDate': {'month': 12, 'year': 2019}}, 'licenseNumber': 'HEA5DX74UHQP'}, {'authority': 'Coursera', 'name': 'R Programming', 'timePeriod': {'startDate': {'month': 12, 'year': 2019}}, 'licenseNumber': 'WWWMTUUQBJ54'}, {'authority': 'Coursera', 'name': 'Machine Learning', 'timePeriod': {'startDate': {'month': 1, 'year': 2020}}, 'licenseNumber': 'MYWSH3J3RZTS'}, {'authority': 'Coursera', 'name': 'Applied Text Mining in Python', 'timePeriod': {'startDate': {'month': 1, 'year': 2020}}, 'licenseNumber': '8MFH3U7JNJMB'}, {'authority': 'Udemy', 'name': 'Artificial Intelligence A-Z', 'timePeriod': {'startDate': {'month': 1, 'year': 2020}}, 'licenseNumber': 'UC-GRC6IIG7'}, {'authority': 'Udemy', 'name': 'Machine Learning A-Z: Hands-On Python & R In Data Science', 'timePeriod': {'startDate': {'month': 2, 'year': 2020}}, 'licenseNumber': 'UC-f7f8311a-e79c-4915-b14e-8bcc2ad84fa4'}, {'authority': 'Coursera', 'name': 'Applied Machine Learning in Python', 'timePeriod': {'startDate': {'month': 1, 'year': 2020}}, 'licenseNumber': 'E9WQQBDT5QQX'}, {'authority': 'Udemy', 'name': 'Deep Learning A-Z: Hands On Artificial Neural Networks', 'timePeriod': {'startDate': {'month': 3, 'year': 2020}}, 'licenseNumber': 'UC-f2fc0c06-4d07-4bc8-8917-73939b77dff9'}]]
# ['projects', [{'timePeriod': {'endDate': {'month': 12, 'year': 2022}, 'startDate': {'month': 12, 'year': 2022}}, 'description': 'Improving the automation of detection of breast cancer in screening mammograms and hence enabling radiologists to be more accurate and efficient. Dataset (314 GB, 54713 files) was provided by Radiological Society of North America.', 'title': 'Screening Mammography Breast Cancer Detection'}, {'timePeriod': {'endDate': {'month': 2, 'year': 2021}, 'startDate': {'month': 1, 'year': 2021}}, 'description': 'Scientific document classification is a key step for managing research articles and papers in forums like arxiv, Google Scholar and Microsoft Academic. In this project, we have given some abstracts crawled from arXiv, the task is to develop classification models which can make predictions and return the corresponding scientific fields of the source documents. Different from coarse grained classification tasks like sentiment analysis, this is a fine grained classification task where there are 100 filed classes in total.', 'title': 'Scientific Document Classification', 'url': 'https://github.com/RakeshNain/Scientific-Document-Classification.git'}, {'timePeriod': {'endDate': {'month': 1, 'year': 2021}, 'startDate': {'month': 12, 'year': 2020}}, 'description': 'In this project, we are interested in exploring machine learning approaches to predict the demands for bike sharing based on relevant data such as weather, season, holiday, etc, which are known to influence the demands for bike renting. The aim is to build statistical learning models that can predict how many bikes are required in a particular area at a particular time, and identify the major factors that affect the bike demand.', 'title': 'Predict Bike-Sharing need in Metropolitan Area', 'url': 'https://github.com/RakeshNain/Predict-Bike-Sharing-need-in-Metropolitan-Area.git'}, {'timePeriod': {'endDate': {'month': 12, 'year': 2020}, 'startDate': {'month': 11, 'year': 2020}}, 'description': 'Scraping advertised houses data from domain.com (real estate website) and then wrangling that data.\n\nI have scrapped  the price, number of bedrooms, number of bathrooms, number of parking, address and location(latitude and longitude) of each house in Melbourne, Australia. And then cleaned that data, impute the missing data using best techniques so that data will have minimum bias.', 'title': 'Web scraping and wrangling data from a realestate website(domain.com)', 'url': 'https://github.com/RakeshNain/realestate_data_web_scraping.git'}, {'timePeriod': {'endDate': {'month': 10, 'year': 2020}, 'startDate': {'month': 9, 'year': 2020}}, 'description': 'In this project, I am exploring machine learning approaches to predict the burned area of bushfires by using meteorological data that are known to influence the wild fires. The dataset that we are going to use here were originally collected from the northeast region of Portugal between January 2000 and December 2003. It contains geographical information, fire weather indices, and the corresponding weather conditions. The aim is to build statistical models that can predict the burned area of the bushfires.', 'title': 'Bushfire Analysis and Prediction using Meteorological Data', 'url': 'https://github.com/RakeshNain/Bushfire-Analysis-using-Meteorological-Data.git'}, {'occupation': 'urn:li:fs_education:(ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY,605578723)', 'timePeriod': {'endDate': {'month': 9, 'year': 2020}, 'startDate': {'month': 8, 'year': 2020}}, 'description': 'In this project, I have used data about road crashes in South Australia. Data is given by The Department of Planning, Transport and Infrastructure ( DPTI ), South Australia. I have used PySpark and try to do small Data Analysis using parallel computing and data parallelism.', 'title': 'Big data Analysis of South Australia Road Crash Data using PySpark', 'url': 'https://github.com/RakeshNain/Big-data-Analysis-of-Road-Crash-Data-using-PySpark-with-PySpark-Tutori ...
# ['urn_id', 'ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY']
# ['industryName', 'Computer Software']
# ['lastName', 'Geda']
# ['locationName', 'India']
# ['firstName', 'Shreeyash']
# ['headline', 'Data Scientist | IIT Roorkee']
# ['img_444_444', '800_800/profile-displayphoto-shrink_800_800/0/1535872675158?e=1730937600&v=beta&t=3wuztGClM2JiWnU-pCmTBpPQDibLwUpt3-f2KPflaak']
# ['public_id', 'sgeda']
# ['experience', [{'locationName': 'Gurugram, Haryana, India', 'geoLocationName': 'Gurugram, Haryana, India', 'companyName': 'Trexquant Investment LP', 'timePeriod': {'startDate': {'month': 11, 'year': 2023}}, 'company': {'employeeCountRange': {'start': 51, 'end': 200}, 'industries': ['Financial Services']}, 'title': 'Data Scientist '}, {'locationName': 'India', 'geoLocationName': 'India', 'companyName': 'Bidgely', 'timePeriod': {'endDate': {'month': 10, 'year': 2023}, 'startDate': {'month': 7, 'year': 2021}}, 'company': {'employeeCountRange': {'start': 51, 'end': 200}, 'industries': ['Computer Software']}, 'title': 'Data Scientist'}, {'locationName': 'India', 'geoLocationName': 'India', 'companyName': 'Bidgely', 'timePeriod': {'endDate': {'month': 7, 'year': 2020}, 'startDate': {'month': 5, 'year': 2020}}, 'company': {'employeeCountRange': {'start': 51, 'end': 200}, 'industries': ['Computer Software']}, 'title': 'Data Science Intern'}, {'locationName': 'Malaysia', 'geoLocationName': 'Malaysia', 'companyName': 'Universiti Malaya', 'timePeriod': {'endDate': {'month': 8, 'year': 2019}, 'startDate': {'month': 5, 'year': 2019}}, 'company': {'employeeCountRange': {'start': 1001, 'end': 5000}, 'industries': ['Education Management']}, 'title': 'Research Internship'}]]
# ['education', [{'school': {'objectUrn': 'urn:li:school:13502', 'entityUrn': 'urn:li:fs_miniSchool:13502', 'active': True, 'schoolName': 'Indian Institute of Technology, Roorkee', 'trackingId': 'S9mYsQzASwqmuFigYlrGfA==', 'logoUrl': 'https://media.licdn.com/dms/image/v2/C510BAQFxnsvax1W4UQ/company-logo_'}, 'grade': '9.47 / 10', 'timePeriod': {'endDate': {'year': 2021}, 'startDate': {'year': 2017}}, 'degreeName': 'BTech - Bachelor of Technology', 'schoolName': 'Indian Institute of Technology, Roorkee', 'fieldOfStudy': 'Electrical engineering'}, {'school': {'objectUrn': 'urn:li:school:5373000', 'entityUrn': 'urn:li:fs_miniSchool:5373000', 'active': True, 'schoolName': 'Dakshana Foundation', 'trackingId': 'RYPAMcdhR7C2nzZMiZucGw==', 'logoUrl': 'https://media.licdn.com/dms/image/v2/C4D0BAQEtH7QGVKsuag/company-logo_'}, 'timePeriod': {'endDate': {'month': 6, 'year': 2017}, 'startDate': {'month': 6, 'year': 2016}}, 'schoolName': 'Dakshana Foundation'}, {'school': {'objectUrn': 'urn:li:school:3209814', 'entityUrn': 'urn:li:fs_miniSchool:3209814', 'active': True, 'schoolName': 'Jawahar Navodaya Vidyalaya (JNV)', 'trackingId': 'E7rGUCMMTMKDr+lokN6qCg==', 'logoUrl': 'https://media.licdn.com/dms/image/v2/C510BAQGK87VYL7oZLw/company-logo_'}, 'timePeriod': {'endDate': {'month': 3, 'year': 2016}, 'startDate': {'month': 7, 'year': 2009}}, 'schoolName': 'Jawahar Navodaya Vidyalaya (JNV)'}]]
# ['languages', []]
# ['publications', [{'date': {'month': 11, 'year': 2022, 'day': 4}, 'name': 'LOAD FORECASTING FOR INDIVIDUAL HOMES  USING AMI DATA', 'publisher': 'Metering India 2022', 'url': 'https://drive.google.com/file/d/16DarwxYE4f30CpvrjSWrU5ZIXpXXpR9D/view?usp=sharing', 'authors': [{'member': {'firstName': 'Shreeyash', 'lastName': 'Geda', 'dashEntityUrn': 'urn:li:fsd_profile:ACoAACeUD1cBHSiBiEFTJnJc3WWxAnH1y_1erQA', 'occupation': 'Data Scientist | IIT Roorkee', 'objectUrn': 'urn:li:member:664014679', 'entityUrn': 'urn:li:fs_miniProfile:ACoAACeUD1cBHSiBiEFTJnJc3WWxAnH1y_1erQA', 'publicIdentifier': 'sgeda', 'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100, 'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1535872675177?e=1730937600&v=beta&t=QBgHyBVhDEiSu6vaxhgovKGl_1v-RaL4mtWKS8khuaw', 'expiresAt': 1730937600000, 'height': 100}, {'width': 200, 'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1535872675140?e=1730937600&v=beta&t=9dH9yjJM3655CMvY2TNcpKCjzIA79K5yiAkYS435jEw', 'expiresAt': 1730937600000, 'height': 200}, {'width': 400, 'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1535872675209?e=1730937600&v=beta&t=-1Wuvs0XqPkcL5JJKgoWt-dJgh399xbbbbWy9P40JEw', 'expiresAt': 1730937600000, 'height': 400}, {'width': 444, 'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1535872675158?e=1730937600&v=beta&t=3wuztGClM2JiWnU-pCmTBpPQDibLwUpt3-f2KPflaak', 'expiresAt': 1730937600000, 'height': 444}], 'rootUrl': 'https://media.licdn.com/dms/image/v2/C5103AQG2BXZVyGG5aw/profile-displayphoto-shrink_'}}, 'trackingId': 'Uo++NkAKStKlEx9sKno/uQ=='}, 'profileUrn': 'urn:li:fs_miniProfile:ACoAACeUD1cBHSiBiEFTJnJc3WWxAnH1y_1erQA'}]}, {'date': {'month': 2, 'year': 2022, 'day': 4}, 'name': 'Short Term Load Forecasting for Dynamic Clusters using Deep Learning', 'publisher': 'INDIA SMART UTILITY WEEK (ISUW) 2022', 'url': 'https://drive.google.com/file/d/1oPxN8_M8RL3zU6AoF1eypJdYcw7eqhax/view?usp=sharing', 'authors': [{'member': {'firstName': 'Shreeyash', 'lastName': 'Geda', 'dashEntityUrn': 'urn:li:fsd_profile:ACoAACeUD1cBHSiBiEFTJnJc3WWxAnH1y_1erQA', 'occupation': 'Data Scientist | IIT Roorkee', 'objectUrn': 'urn:li:member:664014679', 'entityUrn': 'urn:li:fs_miniProfile:ACoAACeUD1cBHSiBiEFTJnJc3WWxAnH1y_1erQA', 'publicIdentifier': 'sgeda', 'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100, 'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1535872675177?e=1730937600&v=beta&t=QBgHyBVhDEiSu6vaxhgovKGl_1v-RaL4mtWKS8khuaw', 'expiresAt': 1730937600000, 'height': 100}, {'width': 200, 'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1535872675140?e=1730937600&v=beta&t=9dH9yjJM3655CMvY2TNcpKCjzIA79K5yiAkYS435jEw', 'expiresAt': 1730937600000, 'height': 200}, {'width': 400, 'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1535872675209?e=1730937600&v=beta&t=-1Wuvs0XqPkcL5JJKgoWt-dJgh399xbbbbWy9P40JEw', 'expiresAt': 1730937600000, 'height': 400}, {'width': 444, 'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1535872675158?e=1730937600&v=beta&t=3wuztGClM2JiWnU-pCmTBpPQDibLwUpt3-f2KPflaak', 'expiresAt': 1730937600000, 'height': 444}], 'rootUrl': 'https://media.licdn.com/dms/image/v2/C5103AQG2BXZVyGG5aw/profile-displayphoto-shrink_'}}, 'trackingId': 'Uo++NkAKStKlEx9sKno/uQ=='}, 'profileUrn': 'urn:li:fs_miniProfile:ACoAACeUD1cBHSiBiEFTJnJc3WWxAnH1y_1erQA'}]}]]
# ...
# ['urn_id', 'ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w']
# ['industryName', 'Information Technology & Services']
# ['lastName', 'S.']
# ['locationName', 'India']
# ['firstName', 'Nishchay']
# ['headline', 'Data scientist | AI | ML | DL']
# ['public_id', 'nishchay-s-829139185']
# ['experience', [{'locationName': 'Gurugram, Haryana, India', 'geoLocationName': 'Gurugram, Haryana, India', 'companyName': 'Great Learning', 'timePeriod': {'startDate': {'month': 9, 'year': 2021}}, 'company': {'employeeCountRange': {'start': 1001, 'end': 5000}, 'industries': ['E-Learning']}, 'title': 'Data Scientist'}, {'locationName': 'Mumbai, Maharashtra, India', 'geoLocationName': 'Mumbai, Maharashtra, India', 'companyName': 'BOX8', 'timePeriod': {'endDate': {'month': 9, 'year': 2020}, 'startDate': {'month': 9, 'year': 2019}}, 'company': {'employeeCountRange': {'start': 1001, 'end': 5000}, 'industries': ['Food & Beverages']}, 'title': 'Junior operations manager'}]]
# ['education', [{'school': {'objectUrn': 'urn:li:school:193010', 'entityUrn': 'urn:li:fs_miniSchool:193010', 'active': True, 'schoolName': 'JECRC University', 'trackingId': 'wC7WHlEpQQKCHyqHPVsKqA==', 'logoUrl': 'https://media.licdn.com/dms/image/v2/D560BAQGY3YahdKzETg/company-logo_'}, 'timePeriod': {'endDate': {'year': 2018}}, 'fieldOfStudyUrn': 'urn:li:fs_fieldOfStudy:100342', 'degreeName': 'Bachelor of Technology - BTech', 'schoolName': 'JECRC University', 'fieldOfStudy': 'Civil Engineering', 'degreeUrn': 'urn:li:fs_degree:250'}]]
# ['languages', []]
# ['publications', []]
# ['certifications', [{'authority': 'Cognitive Class', 'name': 'Python for Data Science', 'timePeriod': {'startDate': {'month': 8, 'year': 2021}}, 'licenseNumber': '9031a1854ad9453a853afed41d66c11d'}, {'authority': 'IBM', 'name': 'Python for Data Science', 'timePeriod': {'startDate': {'month': 8, 'year': 2021}}}, {'authority': 'Cognitive Class', 'name': 'Machine Learning with Python', 'timePeriod': {'startDate': {'month': 8, 'year': 2021}}, 'licenseNumber': '8be72c0caea64cc1adadb9368836eff3'}, {'authority': 'IBM', 'name': 'Machine Learning with Python - Level 1', 'timePeriod': {'startDate': {'month': 8, 'year': 2021}}}, {'authority': 'Cognitive Class', 'name': 'SQL and Relational Databases 101', 'timePeriod': {'startDate': {'month': 8, 'year': 2021}}, 'licenseNumber': '4d31579dc5a94ff3bcb330933362a46d'}, {'authority': 'Cognitive Class', 'name': 'IBM Chatbot', 'timePeriod': {'startDate': {'month': 1, 'year': 2022}}, 'licenseNumber': '14f2d95b130e4c23a02747507fdf89af'}, {'authority': 'IBM', 'name': 'Build Your Own Chatbot - Level 1', 'timePeriod': {'startDate': {'month': 1, 'year': 2022}}}]]
# ['projects', []]
# ['urn_id', 'ACoAACuf0GEBxqLlm79WsFe0eagVOHzxvQhltaA']
# ['summary', 'Experienced Researcher with a demonstrated history of working in the information technology and services industry. Skilled in Linux, Research, Programming, Python (Programming Language), and Reinforcement Learning. Strong research professional with a Master of Technology - MTech focused in Computer Science from Indraprastha Institute of Information Technology, Delhi. ']
# ['industryName', 'Computer Software']
# ['lastName', 'Garg']
# ['locationName', 'India']
# ['firstName', 'Diksha']
# ['headline', 'Data Scientist at SAP Labs']
# ['public_id', 'diksha-garg-1b5b7a125']
# ['experience', [{'locationName': 'Bengaluru, Karnataka, India', 'geoLocationName': 'Bengaluru, Karnataka, India', 'companyName': 'SAP Labs India', 'timePeriod': {'startDate': {'month': 8, 'year': 2022}}, 'company': {'employeeCountRange': {'start': 10001}, 'industries': ['Computer Software']}, 'title': 'Data Scientist'}, {'locationName': 'Bengaluru, Karnataka, India', 'geoLocationName': 'Bengaluru, Karnataka, India', 'companyName': 'Tata Consultancy Services', 'timePeriod': {'endDate': {'month': 8, 'year': 2022}, 'startDate': {'month': 7, 'year': 2018}}, 'company': {'employeeCountRange': {'start': 10001}, 'industries': ['Information Technology and Services']}, 'title': 'Machine Learning Researcher', 'honors': ['urn:li:fs_honor:(ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8,1101172354)', 'urn:li:fs_honor:(ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8,1101273034)', 'urn:li:fs_honor:(ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8,964835261)']}]]
# ['education', [{'courses': ['urn:li:fs_course:(ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8,1101534940)'], 'school': {'objectUrn': 'urn:li:school:373028', 'entityUrn': 'urn:li:fs_miniSchool:373028', 'active': True, 'schoolName': 'Indraprastha Institute of Information Technology, Delhi', 'trackingId': 'kDA+c2mFR9S/wDUlDYTKFw==', 'logoUrl': 'https://media.licdn.com/dms/image/v2/C560BAQG8G8yRaFuoBQ/company-logo_'}, 'grade': 'CGPA - 8.58', 'timePeriod': {'endDate': {'month': 7, 'year': 2018}, 'startDate': {'month': 7, 'year': 2016}}, 'fieldOfStudyUrn': 'urn:li:fs_fieldOfStudy:100189', 'degreeName': 'Master of Technology - MTech', 'schoolName': 'Indraprastha Institute of Information Technology, Delhi', 'fieldOfStudy': 'Computer Science', 'degreeUrn': 'urn:li:fs_degree:584'}, {'school': {'objectUrn': 'urn:li:school:13426', 'entityUrn': 'urn:li:fs_miniSchool:13426', 'active': True, 'schoolName': 'Banasthali Vidyapith', 'trackingId': 'Btowl/21RbynIRSzqYbWQw==', 'logoUrl': 'https://media.licdn.com/dms/image/v2/C4D0BAQE5b9Z6j_5cFA/company-logo_'}, 'grade': 'Gold Medalist', 'timePeriod': {'endDate': {'month': 7, 'year': 2016}, 'startDate': {'month': 7, 'year': 2012}}, 'fieldOfStudyUrn': 'urn:li:fs_fieldOfStudy:100176', 'degreeName': 'Bachelor of Technology - BTech', 'schoolName': 'Banasthali Vidyapith', 'fieldOfStudy': 'Information Technology', 'honors': ['urn:li:fs_honor:(ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8,1102003546)'], 'degreeUrn': 'urn:li:fs_degree:250'}]]
# ['languages', [{'name': 'English', 'proficiency': 'FULL_PROFESSIONAL'}, {'name': 'Hindi', 'proficiency': 'NATIVE_OR_BILINGUAL'}]]
# ['publications', [{'date': {'month': 2, 'year': 2022, 'day': 17}, 'name': 'Learning to Liquidate Forex using Optimal Stopping via Adaptive Top-K Regression', 'publisher': 'AAAI-22', 'authors': [{'member': {'firstName': 'Diksha', 'lastName': 'Garg', 'dashEntityUrn': 'urn:li:fsd_profile:ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8', 'occupation': 'Data Scientist at SAP Labs', 'objectUrn': 'urn:li:member:519475097', 'entityUrn': 'urn:li:fs_miniProfile:ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8', 'publicIdentifier': 'diksha-garg-1b5b7a125', 'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100, 'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1660751582730?e=1730937600&v=beta&t=-RGN9x2V1GdHqeE9VQLG206vXQV8GEOMGELB4zz3guY', 'expiresAt': 1730937600000, 'height': 100}, {'width': 200, 'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1660751582730?e=1730937600&v=beta&t=C7itH1E0GGSk0nd2ewpcuSl1KG--mxeOjRkY7T-k97I', 'expiresAt': 1730937600000, 'height': 200}, {'width': 400, 'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1660751582730?e=1730937600&v=beta&t=qGHooOiNTma6VKcQSAfcZv6ocPoolQ3UKQ75FwuG7Ts', 'expiresAt': 1730937600000, 'height': 400}, {'width': 800, 'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1660751582730?e=1730937600&v=beta&t=VA_yEY3MU1aKsn1S9sZ4n6hs76iRm_nNBYFEYE7Ceuo', 'expiresAt': 1730937600000, 'height': 800}], 'rootUrl': 'https://media.licdn.com/dms/image/v2/C4D03AQFCIsqVogTXrQ/profile-displayphoto-shrink_'}}, 'trackingId': 'jX77d/m4RV+Oje4HlWmjCA=='}, 'profileUrn': 'urn:li:fs_miniProfile:ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8'}]}, {'date': {'month': 12, 'year': 2020, 'day': 16}, 'name': 'Batch-Constrained Distributional Reinforcement Learning for Session-based Recommendation', 'publisher': 'NeurIPS', 'url': 'https://arxiv.org/abs/2012.08984', 'authors': [{'member': {'firstName': 'Diksha', 'lastName': 'Garg', 'dashEntityUrn': 'urn:li:fsd_profile:ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8', 'occupation': 'Data Scientist at SAP Labs', 'objectUrn': 'urn:li:member:519475097', 'entityUrn': 'urn:li:fs_miniProfile:ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8', 'publicIdentifier': 'diksha-garg-1b5b7a125', 'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100, 'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1660751582730?e=1730937600&v=beta&t=-RGN9x2V1GdHqeE9VQLG206vXQV8GEOMGELB4zz3guY', 'expiresAt': 1730937600000, 'height': 100}, {'width': 200, 'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1660751582730?e=1730937600&v=beta&t=C7itH1E0GGSk0nd2ewpcuSl1KG--mxeOjRkY7T-k97I', 'expiresAt': 1730937600000, 'height': 200}, {'width': 400, 'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1660751582730?e=1730937600&v=beta&t=qGHooOiNTma6VKcQSAfcZv6ocPoolQ3UKQ75FwuG7Ts', 'expiresAt': 1730937600000, 'height': 400}, {'width': 800, 'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1660751582730?e=1730937600&v=beta&t=VA_yEY3MU1aKsn1S9sZ4n6hs76iRm_nNBYFEYE7Ceuo', 'expiresAt': 1730937600000, 'height': 800}], 'rootUrl': 'https://media.licdn.com/dms/image/v2/C4D03AQFCIsqVogTXrQ/profile-displayphoto-shrink_'}}, 'trackingId': 'jX77d/m4RV+Oje4HlWmjCA=='}, 'profileUrn': 'urn:li:fs_miniProfile:ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8'}]}, {'date': {'month': 11, 'year': 2019, 'day': 1}, 'name': 'NISER: Normalized Item and Session Representations with Graph Neural Networks', 'publisher': 'CIKM', 'url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=3mgfhFQAAAAJ&citation_for_view=3mgfhFQAAAAJ:U3qCfcK-7lkC', 'authors': [{'member': {'firstName': 'Diksha', 'lastName': 'Garg', 'dashEntityUrn': 'urn:li:fsd_profile:ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8', 'occupation': 'Data Scientist at SAP Labs', 'objectUrn': 'urn:li:member:519475097', 'entityUrn': 'urn:li:fs ...
# ['certifications', [{'authority': 'Cutshort', 'name': 'Cutshort Certified C - Basic', 'timePeriod': {'startDate': {'month': 5, 'year': 2022}}, 'licenseNumber': '66946'}, {'authority': 'Cutshort', 'name': 'Cutshort Certified Algorithms - Advanced', 'timePeriod': {'startDate': {'month': 5, 'year': 2022}}, 'licenseNumber': '66934'}]]
# ['projects', []]
# ['urn_id', 'ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8']
# ['summary', 'I work at AI Garage division at MasterCard as a Data Scientist\nI am interested in the domain of Machine Learning and Deep Learning. Previously, I worked as an intern in a startup where my work involved using Computer Vision and Deep Learning techniques for monitoring cancer growth. I also worked as a research intern at IIITD, which involved improving the current network architectures for skeleton detection.  I love to work on challenging problems which can be solved through AI\nI am interested in Applied Research Opportunities in Computer Vision and NLP']
# ['industryName', 'Financial Services']
# ['lastName', 'Sehgal']
# ['locationName', 'India']
# ['birthDate', {'month': 6, 'day': 23}]
# ['firstName', 'Himank']
# ['headline', "Data Scientist @Mastercard AI Garage | IIT Roorkee @'23"]
# ['public_id', 'himank-sehgal-43786b192']
# ['experience', [{'locationName': 'Gurugram, Haryana, India', 'geoLocationName': 'Gurugram, Haryana, India', 'companyName': 'Mastercard AI Garage', 'timePeriod': {'startDate': {'month': 6, 'year': 2023}}, 'company': {'employeeCountRange': {'start': 51, 'end': 200}, 'industries': ['Information Technology and Services']}, 'title': 'Data Scientist'}, {'locationName': 'India', 'geoLocationName': 'India', 'companyName': 'Data Science Group, IIT Roorkee', 'timePeriod': {'endDate': {'month': 7, 'year': 2023}, 'startDate': {'month': 4, 'year': 2021}}, 'description': 'Data Science Group, IIT Roorkee is a student organization, part of the umbrella organization Software Development Section that aims to work on innovative open source projects in the domain of Machine Learning, Deep Learning & Reinforcement Learning, bridging the gap between research and industry.', 'company': {'employeeCountRange': {'start': 11, 'end': 50}, 'industries': ['Computer Software']}, 'title': 'Member'}, {'locationName': 'India', 'geoLocationName': 'India', 'companyName': 'onRec, IIT R', 'timePeriod': {'endDate': {'month': 7, 'year': 2023}, 'startDate': {'month': 4, 'year': 2021}}, 'company': {'employeeCountRange': {'start': 11, 'end': 50}, 'industries': ['Computer Software']}, 'title': 'Joint Secretary'}, {'locationName': 'Gurugram, Haryana, India', 'geoLocationName': 'Gurugram, Haryana, India', 'companyName': 'American Express', 'timePeriod': {'endDate': {'month': 7, 'year': 2022}, 'startDate': {'month': 5, 'year': 2022}}, 'company': {'employeeCountRange': {'start': 10001}, 'industries': ['Financial Services']}, 'title': 'Data Analyst Intern'}, {'locationName': 'India', 'geoLocationName': 'India', 'companyName': 'Skit.ai', 'timePeriod': {'endDate': {'month': 5, 'year': 2022}, 'startDate': {'month': 3, 'year': 2022}}, 'company': {'employeeCountRange': {'start': 201, 'end': 500}, 'industries': ['Computer Software']}, 'title': 'Machine Learning Intern'}]]
# ['education', [{'projects': ['urn:li:fs_project:(ACoAAC1VcqsByzp1o1GEmybISevasiO7VjSe39U,1954625747)'], 'school': {'objectUrn': 'urn:li:school:13502', 'entityUrn': 'urn:li:fs_miniSchool:13502', 'active': True, 'schoolName': 'Indian Institute of Technology, Roorkee', 'trackingId': 'd9aDgxd1Rhy6Wapob+UlSQ==', 'logoUrl': 'https://media.licdn.com/dms/image/v2/C510BAQFxnsvax1W4UQ/company-logo_'}, 'timePeriod': {'endDate': {'year': 2023}, 'startDate': {'year': 2019}}, 'degreeName': 'electrical Engineering', 'schoolName': 'Indian Institute of Technology, Roorkee', 'fieldOfStudy': 'Electrical Engineering Technologies/Technicians'}, {'school': {'objectUrn': 'urn:li:school:3239487', 'entityUrn': 'urn:li:fs_miniSchool:3239487', 'active': True, 'schoolName': 'Stepping Stones Sr. Sec. School', 'trackingId': '2EL23xoWREa1hUqUpugBFg=='}, 'grade': 'Class 12-94%', 'timePeriod': {'endDate': {'year': 2019}, 'startDate': {'year': 2017}}, 'schoolName': 'Stepping Stones Sr. Sec. School'}, {'grade': 'CGPA-10', 'schoolName': 'Delhi Public School -Chandigarh'}]]
# ['languages', []]
# ['publications', []]
# ['certifications', [{'authority': 'Coursera', 'name': 'Neural Networks and Deep Learning', 'timePeriod': {'startDate': {'month': 11, 'year': 2020}}, 'licenseNumber': 'RK5NUWT55U9P'}, {'authority': 'Coursera', 'name': 'Improving Deep Neural Networks: Hyperparameter tuning, Regularization and Optimization', 'timePeriod': {'startDate': {'month': 11, 'year': 2020}}, 'licenseNumber': 'BSLTSR3USEM2'}, {'authority': 'Coursera', 'name': 'Structuring Machine Learning Projects', 'timePeriod': {'startDate': {'month': 12, 'year': 2020}}, 'licenseNumber': ' FRFCMXJCKC8D'}, {'authority': 'Coursera', 'name': 'Convolutional Neural Networks', 'timePeriod': {'startDate': {'month': 12, 'year': 2020}}, 'licenseNumber': 'SF7V6BBJQHMD'}, {'authority': 'Coursera', 'name': 'Sequence Models', 'timePeriod': {'startDate': {'month': 2, 'year': 2021}}, 'licenseNumber': 'CS4VKM2RNYYV'}, {'authority': 'Coursera', 'name': 'Deep Learning Specialisation', 'timePeriod': {'startDate': {'month': 2, 'year': 2021}}, 'licenseNumber': ' PQS2B4L2JQ37'}, {'authority': 'Coursera', 'name': 'Predicting Employee Turnover with scikit-learn', 'timePeriod': {'startDate': {'month': 12, 'year': 2020}}, 'licenseNumber': '4CM8HE2PTZ4G'}, {'authority': 'Coursera', 'name': 'Multiple Linear Regression with scikit-learn', 'timePeriod': {'startDate': {'month': 12, 'year': 2020}}, 'licenseNumber': ' 9E2CJ7KNVMSY'}]]
# ['projects', [{'occupation': 'urn:li:fs_education:(ACoAAC1VcqsByzp1o1GEmybISevasiO7VjSe39U,610306762)', 'timePeriod': {'startDate': {'month': 10, 'year': 2019}}, 'description': 'A small sized 4-legged robot fitted with a camera which can be used for several purposes like spying , search and rescue operations.', 'title': 'Robotic Bug'}]]
# ['urn_id', 'ACoAAC1VcqsByzp1o1GEmybISevasiO7VjSe39U']

# %%
# Store data into chromadb
ids = []
documents = []
metadatas = []

for urn_id, profile_info in peoples_profiles.items():
    for info in profile_info:
        ids.append(urn_id)
        documents.append({k1: v1 for k, v in info.items() if k == "profile_details" for k1, v1 in v.items() if k1 != "skills"})
        metadatas.append({"skills": info["skills"]})

# %%
documents
# Out:
# [{'summary': '11+ years of experience with a proven track record of driving revenue growth and operational efficiency through data-driven solutions. Skilled in data manipulation, visualization, statistical inference, machine learning, and MLOps with strong theoretical foundations. Effective communication skills, adept at distilling complex ideas and concepts into easy-to- understand language. Experienced in leading end-to-end ML projects and solving the unique challenges that come with them.',
#   'industryName': 'Information Technology & Services',
#   'lastName': 'Maheshwari',
#   'locationName': 'India',
#   'firstName': 'Sahil',
#   'headline': 'Data Scientist @ Hunch',
#   'public_id': 'maheshwarisahil',
#   'experience': [{'locationName': 'Delhi, India',
#     'geoLocationName': 'Delhi, India',
#     'companyName': 'Hunch',
#     'timePeriod': {'startDate': {'month': 11, 'year': 2023}},
#     'company': {'employeeCountRange': {'start': 51, 'end': 200},
#      'industries': ['Internet']},
#     'title': 'Head of Data Science'},
#    {'locationName': 'Bengaluru, Karnataka, India',
#     'geoLocationName': 'Bengaluru, Karnataka, India',
#     'companyName': 'SIXT Research & Development India',
#     'timePeriod': {'endDate': {'month': 8, 'year': 2023},
#      'startDate': {'month': 10, 'year': 2020}},
#     'description': 'Led strategically important DS projects through their complete ML lifecycle. Also responsible for solution research and team mentoring.\n\nDynamic Pricing\n• Delivered a sustainable margin uplift of >3% using elasticity-based pricing models\n• Built a faster and more reliable AB testing framework solving problems in traditional AB testing like\npeeking, high sample variance, independence of p-values and effect sizes, etc.\n\nFleet Optimization\n• Improved demand forecasting error using Bayesian hierarchical models\n• Developed a price-demand relationship model from natural price variations data using GMM to handle price endogeneity\n• Implemented ML-driven simulations to optimize long-term inventory planning',
#     'company': {'employeeCountRange': {'start': 201, 'end': 500},
#      'industries': ['Computer Software']},
#     'title': 'Staff Data Scientist'},
#    {'locationName': 'Bengaluru Area, India',
#     'geoLocationName': 'Bengaluru Area, India',
#     'companyName': 'ThoughtWorks',
#     'timePeriod': {'endDate': {'month': 10, 'year': 2020},
#      'startDate': {'month': 9, 'year': 2018}},
#     'description': 'Led DS teams and collaborated with other cross-functional teams to build and deliver\ncomprehensive solutions, with DS as a key component.\n\nDynamic Pricing for a brick-&-mortar Retail giant\n• Delivered an average margin increase of €9K per month per store using a SARIMAX-based price-demand model\n• Built a risk control strategy in absence of the test data by defining custom metrics for model’s stability. \n\nSearch Optimization for a leading Knowledge Consulting Firm\n• Improved search results’ relevance considerably using word2Vec, hierarchical clustering with hashing, and tf-idf.',
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Information Technology and Services']},
#     'title': 'Lead Data Scientist'},
#    {'locationName': 'Bengaluru Area, India',
#     'geoLocationName': 'Bengaluru Area, India',
#     'companyName': 'Happiest Minds Technologies',
#     'timePeriod': {'endDate': {'month': 9, 'year': 2018},
#      'startDate': {'month': 7, 'year': 2017}},
#     'description': '•\tTime series forecasting for multiple domains like energy, manufacturing, retail, etc. Handled high frequency data (minute level) which is usually not well handled by popular implementations of ARIMA\n•\tImage classification using Inception model to automate identification of damaged devices\n•\tOptimization of predictive model to handle incremental data by maintaining data preparation pipeline',
#     'company': {'employeeCountRange': {'start': 5001, 'end': 10000},
#      'industries': ['Information Technology and Services']},
#     'title': 'Senior Data Scientist'},
#    {'companyName': 'Happiest Minds Technologies',
#     'timePeriod': {'endDate': {'month': 7, 'year': 2017},
#      'startDate': {'month': 11, 'year': 2015}},
#     'description': '•\tReal time recommendations system for a retail client. Used non-conventional similarity measures resulting in more relevant recommendations\n•\tPrediction of claim propensity and time to claim, for an insurance intermediary, to enable risk based pricing. Also, determined factors causing the claim\n•\tDashboard development on R Shiny and Tableau for actionable business insights\n',
#     'company': {'employeeCountRange': {'start': 5001, 'end': 10000},
#      'industries': ['Information Technology and Services']},
#     'title': 'Junior Data Scientist'}],
#   'education': [{'projects': ['urn:li:fs_project:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,26)',
#      'urn:li:fs_project:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,1052741438)',
#      'urn:li:fs_project:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,1053363621)'],
#     'grade': '7.02/10',
#     'timePeriod': {'endDate': {'year': 2014}, 'startDate': {'year': 2012}},
#     'description': '•\tMember of Finance Forum, TAPMI\n•\tMember of Leader Support Group , Brand Scan Project\n•\tCleared FLIP certification on “Finance and Banking Fundamentals”\n•\tWas among the top 5 teams from all over India in XIMB’s Inter B-school Competition on Microfinance\n•\tVolunteered for Joyfest (Social Initiative, TAPMI)\n•\tWon first prize in “Naach” – dance competition in TAPMI’s intra-college cultural event',
#     'testScores': ['urn:li:fs_testScore:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,46)'],
#     'degreeName': 'Post Graduate Diploma in Management',
#     'schoolName': 'T.A. Pai Management Institute',
#     'fieldOfStudy': 'Finance, General'},
#    {'grade': '67.44%',
#     'timePeriod': {'endDate': {'year': 2009}, 'startDate': {'year': 2005}},
#     'degreeName': 'Bachelor of Engineering (B.Eng.)',
#     'schoolName': 'Apeejay College of Engineering',
#     'fieldOfStudy': 'Electrical, Electronics and Communications Engineering'},
#    {'grade': '75.60%',
#     'timePeriod': {'endDate': {'year': 2005}, 'startDate': {'year': 2004}},
#     'degreeName': 'Higher School Certificate',
#     'schoolName': 'Chiranjiv Bharati School, Gurgaon',
#     'fieldOfStudy': 'Science'}],
#   'languages': [{'name': 'English', 'proficiency': 'FULL_PROFESSIONAL'},
#    {'name': 'Hindi', 'proficiency': 'NATIVE_OR_BILINGUAL'}],
#   'publications': [],
#   'certifications': [{'authority': 'edX',
#     'name': 'edX Honor Code Certificate for The Analytics Edge'},
#    {'authority': 'DataCamp',
#     'name': 'Data Analysis in R, the data.table Way',
#     'timePeriod': {'startDate': {'month': 6, 'year': 2015}},
#     'licenseNumber': '26bf88ce460d74689e517a49720f7e5a6ae83d72'},
#    {'authority': 'Finitiatives Learning India Pvt Ltd',
#     'name': 'Finance and Banking Fundamentals'},
#    {'authority': 'Cognizant', 'name': 'Level 1: Payment Cards'},
#    {'authority': 'OutSystems', 'name': 'Outsystems Associate Developer'},
#    {'authority': 'NIIT',
#     'name': 'Programming in "C"',
#     'timePeriod': {'startDate': {'month': 8, 'year': 2006}}},
#    {'authority': 'Oracle',
#     'name': 'Oracle Certified Java SE 6 Programmer',
#     'timePeriod': {'startDate': {'month': 1, 'year': 2011}}}],
#   'projects': [{'timePeriod': {'endDate': {'month': 4, 'year': 2015},
#      'startDate': {'month': 4, 'year': 2015}},
#     'description': '- Built a logistic regression model to predict probability of a complaint getting resolved\n- Tools: R for data wrangling, text analysis, model building and testing, and visualization',
#     'title': 'Pro bono data analysis for Janaagraha - IChangeMyCity'},
#    {'timePeriod': {'endDate': {'month': 11, 'year': 2014},
#      'startDate': {'month': 11, 'year': 2014}},
#     'description': '- Stock selection by balancing return and Sortino ratio \n- Tools: Python (NumPy, Pandas)',
#     'title': 'Stock Analysis'},
#    {'occupation': 'urn:li:fs_education:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,187975176)',
#     'timePeriod': {'endDate': {'month': 1, 'year': 2014},
#      'startDate': {'month': 1, 'year': 2014}},
#     'description': 'Financial Modeling using time value of money, cost of capital, and Monte Carlo analysis on MS Excel',
#     'title': 'Delhi Airport Metro Express Financial Modeling'},
#    {'occupation': 'urn:li:fs_education:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,187975176)',
#     'timePeriod': {'endDate': {'month': 8, 'year': 2013},
#      'startDate': {'month': 6, 'year': 2013}},
#     'description': 'We did strategic analysis, accounting analysis, financial analysis, cash flow analysis and valuation using FCFF and two stage divident growth model',
#     'title': 'Equity Research Report on HDFC Bank'},
#    {'occupation': 'urn:li:fs_education:(ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano,187975176)',
#     'timePeriod': {'endDate': {'month': 2, 'year': 2013},
#      'startDate': {'month': 11, 'year': 2012}},
#     'description': 'Market research for Anne French hair removal cream by Pfizer to understand buying behavior and product usage pattern. Data collection, analysis (Excel & Access), and reporting',
#     'title': 'Market research for Anne French hair removal cream, Pfizer'}],
#   'urn_id': 'ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano'},
#  {'summary': 'Experienced data scientist with a track record of translating complex data into actionable insights across diverse sectors spanning FMCG, Sports and Supply Chain.',
#   'industryName': 'Information Technology & Services',
#   'lastName': 'Srivastava',
#   'locationName': 'India',
#   'firstName': 'Vidur',
#   'headline': 'Data Scientist',
#   'public_id': 'vidur-srivastava-a45b85143',
#   'experience': [{'locationName': 'Gurugram, Haryana, India',
#     'geoLocationName': 'Gurugram, Haryana, India',
#     'companyName': 'Tredence Inc.',
#     'timePeriod': {'startDate': {'month': 7, 'year': 2024}},
#     'company': {'employeeCountRange': {'start': 1001, 'end': 5000},
#      'industries': ['Management Consulting']},
#     'title': 'Data Scientist'},
#    {'locationName': 'Bengaluru, Karnataka, India',
#     'geoLocationName': 'Bengaluru, Karnataka, India',
#     'companyName': 'Tiger Analytics',
#     'timePeriod': {'endDate': {'month': 5, 'year': 2024},
#      'startDate': {'month': 5, 'year': 2022}},
#     'company': {'employeeCountRange': {'start': 1001, 'end': 5000},
#      'industries': ['Management Consulting']},
#     'title': 'Senior Analyst'},
#    {'companyName': 'Wicky',
#     'timePeriod': {'endDate': {'month': 4, 'year': 2022},
#      'startDate': {'month': 1, 'year': 2022}},
#     'company': {'employeeCountRange': {'start': 2, 'end': 10},
#      'industries': ['Sports']},
#     'title': 'Software Engineer - MLE'},
#    {'locationName': 'Pune, Maharashtra, India',
#     'geoLocationName': 'Pune, Maharashtra, India',
#     'companyName': 'Infosys',
#     'timePeriod': {'endDate': {'month': 1, 'year': 2022},
#      'startDate': {'month': 1, 'year': 2022}},
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Information Technology and Services']},
#     'title': 'Senior System Engineer'},
#    {'locationName': 'Pune, Maharashtra, India',
#     'geoLocationName': 'Pune, Maharashtra, India',
#     'companyName': 'Infosys',
#     'timePeriod': {'endDate': {'month': 1, 'year': 2022},
#      'startDate': {'month': 12, 'year': 2019}},
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Information Technology and Services']},
#     'title': 'System Engineer'}],
#   'education': [{'school': {'objectUrn': 'urn:li:school:478063',
#      'entityUrn': 'urn:li:fs_miniSchool:478063',
#      'active': True,
#      'schoolName': 'BITS Pilani Work Integrated Learning Programmes',
#      'trackingId': 'rJEv7uc/R0i5OFhL57LoeA==',
#      'logoUrl': 'https://media.licdn.com/dms/image/v2/D560BAQFl6CQfOjKJkA/company-logo_'},
#     'timePeriod': {'endDate': {'month': 9, 'year': 2022},
#      'startDate': {'month': 9, 'year': 2021}},
#     'degreeName': 'Post Graduate Certificate',
#     'schoolName': 'BITS Pilani Work Integrated Learning Programmes',
#     'fieldOfStudy': 'Artificial Intelligence and Machine Learning'},
#    {'school': {'objectUrn': 'urn:li:school:213631',
#      'entityUrn': 'urn:li:fs_miniSchool:213631',
#      'active': True,
#      'schoolName': 'Jaypee Institute of Information Technology, Noida',
#      'trackingId': 'OKzNsLtIQwOUcgxKeIoz8A=='},
#     'timePeriod': {'endDate': {'year': 2019}, 'startDate': {'year': 2015}},
#     'degreeName': 'Bachelor of Technology',
#     'schoolName': 'Jaypee Institute of Information Technology, Noida',
#     'fieldOfStudy': 'Electronics and Communications Engineering',
#     'degreeUrn': 'urn:li:fs_degree:250'}],
#   'languages': [],
#   'publications': [],
#   'certifications': [],
#   'projects': [],
#   'urn_id': 'ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4'},
#  {'summary': 'Experience in Cognitive Computing with leverage of Machine Learning, Deep Learning, Artificial Intelligence, Natural Language Processing skills . Data driven analyst with the ability to apply ML/DL/NLP/Computer Vision Techniques and leverage algorithms to solve real world problems. Established ability in deploying effective predictive/NLP/Computer Vision models across banking/HealthCare industries to accurately forecast and deliver proven results. Strong understanding of Oracle DB and PLSQL with data migration expérience. Domain Knowledge of SupplyChain/finance/banking/Retail domain with communication skills, excellent product and process design knowledge. Domain HealthCare,Mortgage Banking, Consumer, Commercial Lending, Escrow, Loan processing and servicing, Deposits. Onsite experience (US/UK) with business domain experience in Retail and supply chain with special focus on Customer engagement and managing end-user expectations. Experience in Analysis, Design, Development, Customization, Bug fixes, Enhancement, Support and Implementation.\n\n\nData Science, Machine Learning, Deep Learning and AI technologies.Strong understanding of Databases Oracle, Progress 4GL, PLSQL. Excellent Domain Knowledge of finance/banking/Retail domain with communication skills, excellent product and process design knowledge.Strong knowledge of Data Migration and Implementation.. \n\nAreas of Expertise: Data Science Machine Learning, Deep Learning and AI technologies.\n\nWeb App - Flask, Django.\n\nDomain - Mortgage Banking,Insurance Claim Processing Money Laundering, Investment Banking, Lending, Escrow, Loan processing and servicing. Credit Cards,Healthcare\n\nDatabase - Oracle,Progress 4GL,Mongo Db\n\nLanguages - Python ,PLSQL,Progress4GL,Shell Script\n\nVersioning - SVN,Github\nCloud : IBM Cloud, AWS,AZURE,Kubernates\nOthers : Dockers,CICD\n\n\n\n\n10+ years of experience in exploring and understanding various business models in Finance,Healthcare,Retail and Supply chain domain with special focus on implementation according to client requirements.\n•\tExperience in client interaction for requirement gathering and feasibility analysis at various levels including end users, project managers, and business analysts. Possess good business acumen interacting with various 3rd parties in the same project. Onsite experience (UK) with business domain experience in Retail and supply chain with special focus on customer engagement and managing end-user expectations.',
#   'industryName': 'Information Technology & Services',
#   'lastName': 'Aneja',
#   'locationName': 'India',
#   'firstName': 'Isha',
#   'headline': 'Data Scientist IBM',
#   'img_253_253': '800_800/profile-displayphoto-shrink_800_800/0/1516520225939?e=1730937600&v=beta&t=Y-NS63ItyMgsdVJIR_DcgSb-qbTolbfpcsM606r7v6I',
#   'public_id': 'isha-aneja-642b7a32',
#   'experience': [{'locationName': 'Noida, Uttar Pradesh, India',
#     'geoLocationName': 'Noida, Uttar Pradesh, India',
#     'companyName': 'IBM',
#     'timePeriod': {'startDate': {'month': 12, 'year': 2021}},
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Information Technology and Services']},
#     'title': 'Data Scientist'},
#    {'locationName': 'New Delhi Area, India',
#     'geoLocationName': 'New Delhi Area, India',
#     'companyName': 'Fiserv',
#     'timePeriod': {'endDate': {'month': 1, 'year': 2022},
#      'startDate': {'month': 12, 'year': 2017}},
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Information Technology and Services']},
#     'title': 'Technical Lead'},
#    {'locationName': 'Noida Area, India',
#     'geoLocationName': 'Noida Area, India',
#     'companyName': 'Birlasoft',
#     'timePeriod': {'endDate': {'month': 12, 'year': 2017},
#      'startDate': {'month': 8, 'year': 2016}},
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Information Technology and Services']},
#     'title': 'Senior Software Engineer'},
#    {'locationName': 'banglore',
#     'geoLocationName': 'banglore',
#     'companyName': 'Capgemini',
#     'timePeriod': {'endDate': {'month': 8, 'year': 2016},
#      'startDate': {'month': 11, 'year': 2014}},
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Information Technology and Services']},
#     'title': 'Technical Team Lead'},
#    {'locationName': 'Noida Area, India',
#     'geoLocationName': 'Noida Area, India',
#     'companyName': 'JK Technosoft Limited.',
#     'timePeriod': {'endDate': {'month': 10, 'year': 2014},
#      'startDate': {'month': 9, 'year': 2011}},
#     'company': {'employeeCountRange': {'start': 501, 'end': 1000},
#      'industries': ['Management Consulting']},
#     'title': 'Senior Software Engineer'}],
#   'education': [{'school': {'objectUrn': 'urn:li:school:13535',
#      'entityUrn': 'urn:li:fs_miniSchool:13535',
#      'active': True,
#      'schoolName': 'Kurukshetra University',
#      'trackingId': 'dHzLVrgCR8OjqnvBQicOOA==',
#      'logoUrl': 'https://media.licdn.com/dms/image/v2/C510BAQFk-1FhZJmk9Q/company-logo_'},
#     'timePeriod': {'endDate': {'year': 2011}, 'startDate': {'year': 2008}},
#     'degreeName': 'Masters of Computer Applications',
#     'schoolName': 'Kurukshetra University',
#     'fieldOfStudy': 'Computer Science'},
#    {'school': {'objectUrn': 'urn:li:school:13535',
#      'entityUrn': 'urn:li:fs_miniSchool:13535',
#      'active': True,
#      'schoolName': 'Kurukshetra University',
#      'trackingId': 'cDJI7SEETUaLYybvgWuOuw==',
#      'logoUrl': 'https://media.licdn.com/dms/image/v2/C510BAQFk-1FhZJmk9Q/company-logo_'},
#     'timePeriod': {'endDate': {'year': 2008}, 'startDate': {'year': 2005}},
#     'degreeName': 'Bachelor of computer Applications',
#     'schoolName': 'Kurukshetra University',
#     'fieldOfStudy': 'Computer Science'}],
#   'languages': [{'name': 'English', 'proficiency': 'NATIVE_OR_BILINGUAL'}],
#   'publications': [],
#   'certifications': [{'authority': 'IBM',
#     'name': 'IBM Certified Advocate - Cloud v1',
#     'timePeriod': {'startDate': {'month': 3, 'year': 2022}}},
#    {'authority': 'expert.ai',
#     'name': 'Expert.ai Pro',
#     'timePeriod': {'startDate': {'month': 2, 'year': 2022}}},
#    {'authority': 'IBM',
#     'name': 'IBM Cloud Pak for Data V3.5.x Essentials',
#     'timePeriod': {'startDate': {'month': 7, 'year': 2022}}},
#    {'authority': 'IBM',
#     'name': 'IBM Cloud Pak for Data V3.5.x Data Science',
#     'timePeriod': {'startDate': {'month': 7, 'year': 2022}}},
#    {'authority': 'Amazon Web Services (AWS)',
#     'name': 'AWS Certified Cloud Practitioner',
#     'timePeriod': {'endDate': {'month': 8, 'year': 2025},
#      'startDate': {'month': 8, 'year': 2022}}},
#    {'authority': 'Amazon Web Services (AWS)',
#     'name': 'AWS Certified Machine Learning – Specialty',
#     'timePeriod': {'endDate': {'month': 9, 'year': 2025},
#      'startDate': {'month': 9, 'year': 2022}}},
#    {'authority': 'Microsoft',
#     'name': 'Microsoft Certified: Azure AI Engineer Associate',
#     'timePeriod': {'endDate': {'month': 9, 'year': 2024},
#      'startDate': {'month': 9, 'year': 2023}},
#     'licenseNumber': '4C3C15CAB831C53E'},
#    {'authority': 'Microsoft',
#     'name': 'Microsoft Certified: Azure Data Scientist Associate',
#     'timePeriod': {'endDate': {'month': 9, 'year': 2024},
#      'startDate': {'month': 9, 'year': 2023}},
#     'licenseNumber': '962F38933DAC4393'},
#    {'authority': 'IBM',
#     'name': 'Healthcare Insights and Solutions (Silver)',
#     'timePeriod': {'startDate': {'month': 5, 'year': 2024}}}],
#   'projects': [],
#   'urn_id': 'ACoAAAbvohIBhdiLqQ5FCbtA40AFvg3f-T7fKfk'},
#  {'summary': 'Experience Data Science professional with demonstrated history of working in IT service industry. Experienced in executing data driven solutions to increase efficiency, accuracy and utility of internal data processing. Skilled in natural language processing with practioner knowledge on Web Analytics. Strong information technology professional with a Bachelor of Technology (BTech) from Uttar Pradesh Technical University. ',
#   'industryName': 'Information Technology & Services',
#   'lastName': 'Mathur',
#   'locationName': 'India',
#   'firstName': 'Tushar',
#   'headline': 'Data Scientist',
#   'img_413_413': '800_800/profile-displayphoto-shrink_800_800/0/1627636616827?e=1730937600&v=beta&t=x9srqsltLWc2l7StlzDDIhorDInTYG12-UOqNW3FfWI',
#   'public_id': 'tushar-mathur-79a23120',
#   'experience': [{'locationName': 'Noida, Uttar Pradesh, India',
#     'geoLocationName': 'Noida, Uttar Pradesh, India',
#     'companyName': 'Coforge',
#     'timePeriod': {'startDate': {'month': 8, 'year': 2022}},
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Information Technology and Services']},
#     'title': 'Analytics Lead'},
#    {'locationName': 'Noida, Uttar Pradesh, India',
#     'geoLocationName': 'Noida, Uttar Pradesh, India',
#     'companyName': 'EXL',
#     'timePeriod': {'endDate': {'month': 8, 'year': 2022},
#      'startDate': {'month': 8, 'year': 2021}},
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Information Technology and Services']},
#     'title': 'Technical Lead'},
#    {'locationName': 'Noida Area, India',
#     'geoLocationName': 'Noida Area, India',
#     'companyName': 'Sopra Steria',
#     'timePeriod': {'endDate': {'month': 7, 'year': 2021},
#      'startDate': {'month': 7, 'year': 2019}},
#     'description': 'Working on information extraction project in which we focuses on creating structured representation of unstructured/structured texts by extracting relevant entities from them, using machine learning and AI process thereby making the data analysis realizable.',
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Information Technology and Services']},
#     'title': 'Module Lead'},
#    {'locationName': 'Noida Area, India',
#     'geoLocationName': 'Noida Area, India',
#     'companyName': 'Sopra Steria',
#     'timePeriod': {'endDate': {'month': 6, 'year': 2019},
#      'startDate': {'month': 10, 'year': 2017}},
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Information Technology and Services']},
#     'title': 'Senior Software Engineer',
#     'honors': ['urn:li:fs_honor:(ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY,1097608354)']},
#    {'locationName': 'Gurgaon, India',
#     'geoLocationName': 'Gurgaon, India',
#     'companyName': 'Infosys',
#     'timePeriod': {'endDate': {'month': 10, 'year': 2017},
#      'startDate': {'month': 10, 'year': 2016}},
#     'description': '•Working knowledge of Agile and Waterfall models.\n•Working in full project life cycle involving Requirement Analysis, Testing and Implementation phases.\n•Extensive coding and modifying programs using COBOL, DB2 and JCL as per the requests of business departments.\n•Involved in Preparing Unit test cases, doing test data setup and performing Unit testing, User Acceptance Testing.\n•Works on envisioning of requirement for future analysis.',
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Information Technology and Services']},
#     'title': 'Senior System Engineer',
#     'honors': ['urn:li:fs_honor:(ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY,1304876652)',
#      'urn:li:fs_honor:(ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY,1020421066)']}],
#   'education': [{'timePeriod': {'endDate': {'year': 2014},
#      'startDate': {'year': 2010}},
#     'degreeName': 'Bachelor of Technology (BTech)',
#     'schoolName': 'Uttar Pradesh Technical University',
#     'fieldOfStudy': 'Electrical, Electronics and Communications Engineering'}],
#   'languages': [{'name': 'English', 'proficiency': 'PROFESSIONAL_WORKING'},
#    {'name': 'Hindi', 'proficiency': 'NATIVE_OR_BILINGUAL'}],
#   'publications': [],
#   'certifications': [{'authority': 'Coursera',
#     'name': 'IBM Data Science Specialization',
#     'timePeriod': {'startDate': {'month': 9, 'year': 2019}},
#     'licenseNumber': '4X9MSFRHX56Z'},
#    {'authority': 'Google',
#     'name': 'Google Analytics Cerification',
#     'timePeriod': {'endDate': {'month': 7, 'year': 2021},
#      'startDate': {'month': 7, 'year': 2020}},
#     'licenseNumber': '55467797'}],
#   'projects': [],
#   'urn_id': 'ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY'},
#  {'summary': "4+ years of work experience solving business problems with the application of Data Science. Master of Data Science, Monash University (Melbourne). Proficient in Generative AI, Computer Vision and Predictive Modeling. With a strong grip over mathematics, deep learning and machine learning algorithms, capable to transform business requirements into data science formulations and implementing the solutions in an efficient and scalable fashion.\n\nCreating impactful AI solutions at R Systems, my focus is on designing cutting-edge generative AI technologies. With a Master's degree in Data Science from Monash University, I apply rigorous academic training to address complex client challenges. Our team's contribution has significantly enhanced the RAG Application's accuracy, showcasing a blend of innovation and practical application.\n\nMy core competencies lie in Large Language Models and transformative AI, underpinned by data collection, preprocessing, model development, and deployment. These skills have enabled us to deliver tailored solutions that not only meet but exceed our clients' business objectives. The dedication to continual learning and improvement is what drives the team and myself to achieve excellence in the ever-evolving field of data science.",
#   'industryName': 'Computer Software',
#   'lastName': 'Nain',
#   'locationName': 'India',
#   'birthDate': {'month': 1, 'day': 24},
#   'firstName': 'Rakesh',
#   'headline': "Data Scientist @ R Systems | Master's in Data Science",
#   'public_id': 'rakeshnain',
#   'experience': [{'locationName': 'Noida, Uttar Pradesh, India',
#     'geoLocationName': 'Noida, Uttar Pradesh, India',
#     'companyName': 'R Systems',
#     'timePeriod': {'startDate': {'month': 8, 'year': 2023}},
#     'description': 'Roles and Responsibilities:\n- Tackle client challenges by designing and implement end-to-end data science solutions using generative AI (LLMs, Large Multi-Modals and their finetuning based on the use cases) or traditional machine learning from data collection, preprocessing to model development and deployment\n- I ensure optimal model performance, engage in cross-functional collaboration, and deliver insights to clients through effective communication.\n- My role contributes to R systems consultancy prowess in delivering innovative and impactful solutions that address diverse business needs of clients.\n\nAchievements:\n- Increased the RAG Application accuracy by 40%.',
#     'company': {'employeeCountRange': {'start': 1001, 'end': 5000},
#      'industries': ['Information Technology and Services']},
#     'title': 'Data Scientist'},
#    {'companyName': 'Intello Labs',
#     'timePeriod': {'endDate': {'month': 8, 'year': 2023},
#      'startDate': {'month': 12, 'year': 2021}},
#     'description': 'Roles and Responsibilities:\n- Develop state-of-the-art machine learning and deep learning algorithms/models for visual recognition tasks, such as segmentation and detection.\n- Collaborate closely with multidisciplinary teams of software engineers, hardware engineers, business leaders and other key players to develop Artificial Intelligent machines.\n- Data Collection, EDA, Data Cleaning, ML Model Development(R&D) and deployment.\n\nAchievements:\n- Developed object detection and instance segmentation algorithm taking around 50 times less RAM in training with only twice extra time in inference as compared to present state-of-the-art algorithms in the market.\n- Improved grains classification results by 20%, and fruits defect detection results by 12%.',
#     'company': {'employeeCountRange': {'start': 51, 'end': 200},
#      'industries': ['Information Technology and Services']},
#     'title': 'Deep Learning Engineer'},
#    {'locationName': 'Noida, Uttar Pradesh, India',
#     'geoLocationName': 'Noida, Uttar Pradesh, India',
#     'companyName': 'DishTV',
#     'timePeriod': {'endDate': {'month': 10, 'year': 2018},
#      'startDate': {'month': 6, 'year': 2017}},
#     'description': 'Roles and Responsibilities:\nStarted as a Software Developer in the “My DishTV” Android App project but later shifted to Zee5 OTT Project as a Data Scientist, where key roles and responsibilities were:\n- Exploring and preparing machine learning approaches to perform personal recommendations.\n- Data collection, preprocessing, analysis, analyzing performance metrics, building and tuning hyperparameters of models.\n- Presenting information/results to higher management using data visualization techniques.\n\nAchievements:\n- Increased CTR by 15% and take-rate by 10%.\n\nTechnologies used: Python, Pandas, scikit-learn, NumPy, Matplotlib',
#     'company': {'employeeCountRange': {'start': 1001, 'end': 5000},
#      'industries': ['Broadcast Media']},
#     'title': 'Software Developer - Machine Learning'}],
#   'education': [{'projects': ['urn:li:fs_project:(ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY,268411520)',
#      'urn:li:fs_project:(ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY,1130990444)'],
#     'description': 'Coursework Units:\nFIT9132 Introduction to databases\nFIT9133 Programming foundations in python\nFIT9134 Computer architecture and operating systems\nMAT9004 Mathematical foundations for data science\nFIT5145 Introduction to data science\nFIT5147 Data exploration and visualisation\nFIT5195 Business intelligence and data warehousing\nFIT5197 Statistical data modelling\nFIT5047 Fundamentals of artificial intelligence\nFIT5149 Applied data analysis\nFIT5196 Data wrangling\nFIT5202 Data processing for big data\nFIT5120 Industry experience studio project\nFIT5122 Professional practice\nFIT5215 Deep Learning',
#     'degreeName': "Master's degree",
#     'school': {'objectUrn': 'urn:li:school:10231',
#      'entityUrn': 'urn:li:fs_miniSchool:10231',
#      'active': True,
#      'schoolName': 'Monash University',
#      'trackingId': 'dPCShfgxQ9ynGmCA6r9X+g==',
#      'logoUrl': 'https://media.licdn.com/dms/image/v2/D560BAQEp8cQSkbCXRw/company-logo_'},
#     'activities': 'Monash Data Science Society',
#     'grade': 'GPA 2.8 (4.0 GPA scale) | WAM 71.1 %',
#     'timePeriod': {'endDate': {'year': 2021}, 'startDate': {'year': 2019}},
#     'schoolName': 'Monash University',
#     'fieldOfStudy': 'Data Science',
#     'degreeUrn': 'urn:li:fs_degree:500'},
#    {'description': 'Coursework Units:\nApplied mathematics | Computer programming | Data structure | Theory of computation | Database management systems | Object oriented programming | Algorithm design and analysis | Digital Communication | Software engineering | Computer networks | Web engineering | Artificial intelligence | Advance DBMS | Software testing | Wireless communication | Mobile computing | Machine learning',
#     'degreeName': "Bachelor's degree",
#     'school': {'objectUrn': 'urn:li:school:13486',
#      'entityUrn': 'urn:li:fs_miniSchool:13486',
#      'active': True,
#      'schoolName': 'Guru Gobind Singh Indraprastha University',
#      'trackingId': 'qRRY8ZlsQzyvQ4Vq049r0w==',
#      'logoUrl': 'https://media.licdn.com/dms/image/v2/C510BAQGnw20J7HynZA/company-logo_'},
#     'activities': 'Techno-Cultural Fest Organiser Society. Coordinated Street Dance event in the Techno-Cultural Festival(Corona-The Carnival).',
#     'grade': '66.25%',
#     'timePeriod': {'endDate': {'year': 2017}, 'startDate': {'year': 2013}},
#     'fieldOfStudyUrn': 'urn:li:fs_fieldOfStudy:100189',
#     'schoolName': 'Guru Gobind Singh Indraprastha University',
#     'fieldOfStudy': 'Computer Science',
#     'degreeUrn': 'urn:li:fs_degree:200'}],
#   'languages': [{'name': 'English', 'proficiency': 'FULL_PROFESSIONAL'},
#    {'name': 'Hindi', 'proficiency': 'FULL_PROFESSIONAL'}],
#   'publications': [{'date': {'month': 1, 'year': 2021, 'day': 2},
#     'name': 'Big data Analysis of Road Crash Data using PySpark with PySpark Tutorial',
#     'publisher': 'medium.com',
#     'description': 'In this article, I will be using data about road crashes in South Australia. Data is given by The Department of Planning, Transport and Infrastructure ( DPTI ), South Australia. I will be using PySpark and try to do small Data Analysis using parallel computing with a brief overview of PySpark concepts.\nI will be demonstrating parallel computing using three types of data structures: RDDs, PySpark DataFrame, SparkSQL.',
#     'url': 'https://medium.com/rakesh-nain/big-data-analysis-of-road-crash-data-using-pyspark-with-pyspark-tutorial-c78ff2c35588?source=friends_link&sk=ffa8c610a9a4f411ead67e35aa1c50e9',
#     'authors': [{'member': {'firstName': 'Rakesh',
#        'lastName': 'Nain',
#        'dashEntityUrn': 'urn:li:fsd_profile:ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY',
#        'occupation': "Data Scientist @ R Systems | Master's in Data Science",
#        'objectUrn': 'urn:li:member:533688180',
#        'entityUrn': 'urn:li:fs_miniProfile:ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY',
#        'backgroundImage': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 800,
#            'fileIdentifyingUrlPathSegment': '200_800/profile-displaybackgroundimage-shrink_200_800/0/1612960954446?e=1730937600&v=beta&t=i2QRQJRutCGtKW0qhvu0PL_s_vkhg7sSfyv9dwukb-k',
#            'expiresAt': 1730937600000,
#            'height': 200},
#           {'width': 1400,
#            'fileIdentifyingUrlPathSegment': '350_1400/profile-displaybackgroundimage-shrink_350_1400/0/1612960954446?e=1730937600&v=beta&t=WCYvfDKrWIDuUHEOTB_6hjiDhaLIvIqlbIyYPXv77Mk',
#            'expiresAt': 1730937600000,
#            'height': 350}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C5616AQHdmILFQvk1eg/profile-displaybackgroundimage-shrink_'}},
#        'publicIdentifier': 'rakeshnain',
#        'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 400,
#            'fileIdentifyingUrlPathSegment': '400_400/profile-framedphoto-shrink_400_400/0/1723188501992?e=1726300800&v=beta&t=4Svr7unIjJlyEkn_pyXkhQeeCTx5lD77gUyJR7sPd3M',
#            'expiresAt': 1726300800000,
#            'height': 400},
#           {'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/profile-framedphoto-shrink_200_200/0/1723188501992?e=1726300800&v=beta&t=uC8lfQFgaK_DQ7_BMZBOM7opz1Vdlr95Y6NiGYm5fWU',
#            'expiresAt': 1726300800000,
#            'height': 200},
#           {'width': 800,
#            'fileIdentifyingUrlPathSegment': '800_800/profile-framedphoto-shrink_800_800/0/1723188501992?e=1726300800&v=beta&t=ccmNpaanF_RA_inQ3JfJGremNJMzjFtcm1PicZTQQsk',
#            'expiresAt': 1726300800000,
#            'height': 800},
#           {'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/profile-framedphoto-shrink_100_100/0/1723188501953?e=1726300800&v=beta&t=SvyrFVGBmj8MwDGsfDaRHzLanR5dj9vMCgMdX7VYVqU',
#            'expiresAt': 1726300800000,
#            'height': 100}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/D5635AQHtHFOJ6m9dAg/profile-framedphoto-shrink_'}},
#        'trackingId': 'xq+yxQLGQ8OlkTopZFuhhA=='},
#       'profileUrn': 'urn:li:fs_miniProfile:ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY'}]},
#    {'date': {'month': 12, 'year': 2020, 'day': 28},
#     'name': 'Using python collecting real-world data by web scraping real estate website and doing data wrangling',
#     'publisher': 'medium.com',
#     'description': 'In any data science project one of the most asked questions is how to get the data, where is the data. I would say there is plenty of data around you, you just need to extract it. For example, on the internet, there are millions of petabytes of data available and most of it is free. All you need to know is how to extract it and make it useful for your organisation. I would say any type of organisation can make use of the free data available on the internet for their business gains. They can use web scraping to extract it.\n\nFor demonstrating web scrapping in this article I will be scraping data from domian.com. Domain.com is a real estate website. I will be scrapping the price, number of bedrooms, number of bathrooms, number of parking, address and location(latitude and longitude) of each house in Melbourne, Australia.',
#     'url': 'https://medium.com/rakesh-nain/using-python-collecting-real-world-data-by-web-scraping-real-estate-website-and-doing-data-2feb50a3b94f?source=friends_link&sk=4de58062f5db6e5d6261971a2691c0df',
#     'authors': [{'member': {'firstName': 'Rakesh',
#        'lastName': 'Nain',
#        'dashEntityUrn': 'urn:li:fsd_profile:ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY',
#        'occupation': "Data Scientist @ R Systems | Master's in Data Science",
#        'objectUrn': 'urn:li:member:533688180',
#        'entityUrn': 'urn:li:fs_miniProfile:ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY',
#        'backgroundImage': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 800,
#            'fileIdentifyingUrlPathSegment': '200_800/profile-displaybackgroundimage-shrink_200_800/0/1612960954446?e=1730937600&v=beta&t=i2QRQJRutCGtKW0qhvu0PL_s_vkhg7sSfyv9dwukb-k',
#            'expiresAt': 1730937600000,
#            'height': 200},
#           {'width': 1400,
#            'fileIdentifyingUrlPathSegment': '350_1400/profile-displaybackgroundimage-shrink_350_1400/0/1612960954446?e=1730937600&v=beta&t=WCYvfDKrWIDuUHEOTB_6hjiDhaLIvIqlbIyYPXv77Mk',
#            'expiresAt': 1730937600000,
#            'height': 350}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C5616AQHdmILFQvk1eg/profile-displaybackgroundimage-shrink_'}},
#        'publicIdentifier': 'rakeshnain',
#        'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 400,
#            'fileIdentifyingUrlPathSegment': '400_400/profile-framedphoto-shrink_400_400/0/1723188501992?e=1726300800&v=beta&t=4Svr7unIjJlyEkn_pyXkhQeeCTx5lD77gUyJR7sPd3M',
#            'expiresAt': 1726300800000,
#            'height': 400},
#           {'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/profile-framedphoto-shrink_200_200/0/1723188501992?e=1726300800&v=beta&t=uC8lfQFgaK_DQ7_BMZBOM7opz1Vdlr95Y6NiGYm5fWU',
#            'expiresAt': 1726300800000,
#            'height': 200},
#           {'width': 800,
#            'fileIdentifyingUrlPathSegment': '800_800/profile-framedphoto-shrink_800_800/0/1723188501992?e=1726300800&v=beta&t=ccmNpaanF_RA_inQ3JfJGremNJMzjFtcm1PicZTQQsk',
#            'expiresAt': 1726300800000,
#            'height': 800},
#           {'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/profile-framedphoto-shrink_100_100/0/1723188501953?e=1726300800&v=beta&t=SvyrFVGBmj8MwDGsfDaRHzLanR5dj9vMCgMdX7VYVqU',
#            'expiresAt': 1726300800000,
#            'height': 100}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/D5635AQHtHFOJ6m9dAg/profile-framedphoto-shrink_'}},
#        'trackingId': 'xq+yxQLGQ8OlkTopZFuhhA=='},
#       'profileUrn': 'urn:li:fs_miniProfile:ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY'}]}],
#   'certifications': [{'authority': 'Coursera',
#     'name': 'What is Data Science?',
#     'timePeriod': {'startDate': {'month': 12, 'year': 2019}},
#     'licenseNumber': 'YHDPH7SBRSFF'},
#    {'authority': 'Coursera',
#     'name': 'Python for Data Science and AI',
#     'timePeriod': {'startDate': {'month': 12, 'year': 2019}},
#     'licenseNumber': 'HEA5DX74UHQP'},
#    {'authority': 'Coursera',
#     'name': 'R Programming',
#     'timePeriod': {'startDate': {'month': 12, 'year': 2019}},
#     'licenseNumber': 'WWWMTUUQBJ54'},
#    {'authority': 'Coursera',
#     'name': 'Machine Learning',
#     'timePeriod': {'startDate': {'month': 1, 'year': 2020}},
#     'licenseNumber': 'MYWSH3J3RZTS'},
#    {'authority': 'Coursera',
#     'name': 'Applied Text Mining in Python',
#     'timePeriod': {'startDate': {'month': 1, 'year': 2020}},
#     'licenseNumber': '8MFH3U7JNJMB'},
#    {'authority': 'Udemy',
#     'name': 'Artificial Intelligence A-Z',
#     'timePeriod': {'startDate': {'month': 1, 'year': 2020}},
#     'licenseNumber': 'UC-GRC6IIG7'},
#    {'authority': 'Udemy',
#     'name': 'Machine Learning A-Z: Hands-On Python & R In Data Science',
#     'timePeriod': {'startDate': {'month': 2, 'year': 2020}},
#     'licenseNumber': 'UC-f7f8311a-e79c-4915-b14e-8bcc2ad84fa4'},
#    {'authority': 'Coursera',
#     'name': 'Applied Machine Learning in Python',
#     'timePeriod': {'startDate': {'month': 1, 'year': 2020}},
#     'licenseNumber': 'E9WQQBDT5QQX'},
#    {'authority': 'Udemy',
#     'name': 'Deep Learning A-Z: Hands On Artificial Neural Networks',
#     'timePeriod': {'startDate': {'month': 3, 'year': 2020}},
#     'licenseNumber': 'UC-f2fc0c06-4d07-4bc8-8917-73939b77dff9'}],
#   'projects': [{'timePeriod': {'endDate': {'month': 12, 'year': 2022},
#      'startDate': {'month': 12, 'year': 2022}},
#     'description': 'Improving the automation of detection of breast cancer in screening mammograms and hence enabling radiologists to be more accurate and efficient. Dataset (314 GB, 54713 files) was provided by Radiological Society of North America.',
#     'title': 'Screening Mammography Breast Cancer Detection'},
#    {'timePeriod': {'endDate': {'month': 2, 'year': 2021},
#      'startDate': {'month': 1, 'year': 2021}},
#     'description': 'Scientific document classification is a key step for managing research articles and papers in forums like arxiv, Google Scholar and Microsoft Academic. In this project, we have given some abstracts crawled from arXiv, the task is to develop classification models which can make predictions and return the corresponding scientific fields of the source documents. Different from coarse grained classification tasks like sentiment analysis, this is a fine grained classification task where there are 100 filed classes in total.',
#     'title': 'Scientific Document Classification',
#     'url': 'https://github.com/RakeshNain/Scientific-Document-Classification.git'},
#    {'timePeriod': {'endDate': {'month': 1, 'year': 2021},
#      'startDate': {'month': 12, 'year': 2020}},
#     'description': 'In this project, we are interested in exploring machine learning approaches to predict the demands for bike sharing based on relevant data such as weather, season, holiday, etc, which are known to influence the demands for bike renting. The aim is to build statistical learning models that can predict how many bikes are required in a particular area at a particular time, and identify the major factors that affect the bike demand.',
#     'title': 'Predict Bike-Sharing need in Metropolitan Area',
#     'url': 'https://github.com/RakeshNain/Predict-Bike-Sharing-need-in-Metropolitan-Area.git'},
#    {'timePeriod': {'endDate': {'month': 12, 'year': 2020},
#      'startDate': {'month': 11, 'year': 2020}},
#     'description': 'Scraping advertised houses data from domain.com (real estate website) and then wrangling that data.\n\nI have scrapped  the price, number of bedrooms, number of bathrooms, number of parking, address and location(latitude and longitude) of each house in Melbourne, Australia. And then cleaned that data, impute the missing data using best techniques so that data will have minimum bias.',
#     'title': 'Web scraping and wrangling data from a realestate website(domain.com)',
#     'url': 'https://github.com/RakeshNain/realestate_data_web_scraping.git'},
#    {'timePeriod': {'endDate': {'month': 10, 'year': 2020},
#      'startDate': {'month': 9, 'year': 2020}},
#     'description': 'In this project, I am exploring machine learning approaches to predict the burned area of bushfires by using meteorological data that are known to influence the wild fires. The dataset that we are going to use here were originally collected from the northeast region of Portugal between January 2000 and December 2003. It contains geographical information, fire weather indices, and the corresponding weather conditions. The aim is to build statistical models that can predict the burned area of the bushfires.',
#     'title': 'Bushfire Analysis and Prediction using Meteorological Data',
#     'url': 'https://github.com/RakeshNain/Bushfire-Analysis-using-Meteorological-Data.git'},
#    {'occupation': 'urn:li:fs_education:(ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY,605578723)',
#     'timePeriod': {'endDate': {'month': 9, 'year': 2020},
#      'startDate': {'month': 8, 'year': 2020}},
#     'description': 'In this project, I have used data about road crashes in South Australia. Data is given by The Department of Planning, Transport and Infrastructure ( DPTI ), South Australia. I have used PySpark and try to do small Data Analysis using parallel computing and data parallelism.',
#     'title': 'Big data Analysis of South Australia Road Crash Data using PySpark',
#     'url': 'https://github.com/RakeshNain/Big-data-Analysis-of-Road-Crash-Data-using-PySpark-with-PySpark-Tutorial.git'},
#    {'timePeriod': {'endDate': {'month': 8, 'year': 2020},
#      'startDate': {'month': 7, 'year': 2020}},
#     'description': 'Investigating the open data(Big Data) from the Cyber Range Labs of UNSW Canberra and build models based on the data to identify abnormal system behaviour using PySpark and MLlib. In addition, integrate the machine learning models into the streaming platform using Apache Kafka and Apache Spark Streaming to detect any real-time threats, in order to stop the hacking.',
#     'title': 'Cyber Security Application - Detecting Linux system hacking activities',
#     'url': 'https://github.com/RakeshNain/Cyber-Security-Application---Detecting-Linux-system-hacking-activities.git'},
#    {'occupation': 'urn:li:fs_education:(ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY,605578723)',
#     'timePeriod': {'endDate': {'month': 6, 'year': 2020},
#      'startDate': {'month': 4, 'year': 2020}},
#     'description': 'A Shiny Web Application which has interactive Data Visvaliations. These Interactive data visualisations help the users understand the causes and effects of climate change.',
#     'title': 'Climate Change explained with Interactive Data Visualisations in Shiny App',
#     'url': 'https://github.com/RakeshNain/ClimateChange_ShinyApp'},
#    {'timePeriod': {'endDate': {'month': 4, 'year': 2020},
#      'startDate': {'month': 3, 'year': 2020}},
#     'description': 'Performing EDA and then building a pipeline to handle data cleaning, imputation, scaling, encoding and transformation. The final aim is to build a strong model which can accurately predict the house prices of California.',
#     'title': 'California house price prediction',
#     'url': 'https://github.com/RakeshNain/California_house_price_prediction.git'}],
#   'urn_id': 'ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY'},
#  {'industryName': 'Computer Software',
#   'lastName': 'Geda',
#   'locationName': 'India',
#   'firstName': 'Shreeyash',
#   'headline': 'Data Scientist | IIT Roorkee',
#   'img_444_444': '800_800/profile-displayphoto-shrink_800_800/0/1535872675158?e=1730937600&v=beta&t=3wuztGClM2JiWnU-pCmTBpPQDibLwUpt3-f2KPflaak',
#   'public_id': 'sgeda',
#   'experience': [{'locationName': 'Gurugram, Haryana, India',
#     'geoLocationName': 'Gurugram, Haryana, India',
#     'companyName': 'Trexquant Investment LP',
#     'timePeriod': {'startDate': {'month': 11, 'year': 2023}},
#     'company': {'employeeCountRange': {'start': 51, 'end': 200},
#      'industries': ['Financial Services']},
#     'title': 'Data Scientist '},
#    {'locationName': 'India',
#     'geoLocationName': 'India',
#     'companyName': 'Bidgely',
#     'timePeriod': {'endDate': {'month': 10, 'year': 2023},
# ...
#        'publicIdentifier': 'diksha-garg-1b5b7a125',
#        'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1660751582730?e=1730937600&v=beta&t=-RGN9x2V1GdHqeE9VQLG206vXQV8GEOMGELB4zz3guY',
#            'expiresAt': 1730937600000,
#            'height': 100},
#           {'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1660751582730?e=1730937600&v=beta&t=C7itH1E0GGSk0nd2ewpcuSl1KG--mxeOjRkY7T-k97I',
#            'expiresAt': 1730937600000,
#            'height': 200},
#           {'width': 400,
#            'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1660751582730?e=1730937600&v=beta&t=qGHooOiNTma6VKcQSAfcZv6ocPoolQ3UKQ75FwuG7Ts',
#            'expiresAt': 1730937600000,
#            'height': 400},
#           {'width': 800,
#            'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1660751582730?e=1730937600&v=beta&t=VA_yEY3MU1aKsn1S9sZ4n6hs76iRm_nNBYFEYE7Ceuo',
#            'expiresAt': 1730937600000,
#            'height': 800}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C4D03AQFCIsqVogTXrQ/profile-displayphoto-shrink_'}},
#        'trackingId': 'jX77d/m4RV+Oje4HlWmjCA=='},
#       'profileUrn': 'urn:li:fs_miniProfile:ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8'}]},
#    {'date': {'month': 12, 'year': 2020, 'day': 16},
#     'name': 'Batch-Constrained Distributional Reinforcement Learning for Session-based Recommendation',
#     'publisher': 'NeurIPS',
#     'url': 'https://arxiv.org/abs/2012.08984',
#     'authors': [{'member': {'firstName': 'Diksha',
#        'lastName': 'Garg',
#        'dashEntityUrn': 'urn:li:fsd_profile:ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8',
#        'occupation': 'Data Scientist at SAP Labs',
#        'objectUrn': 'urn:li:member:519475097',
#        'entityUrn': 'urn:li:fs_miniProfile:ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8',
#        'publicIdentifier': 'diksha-garg-1b5b7a125',
#        'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1660751582730?e=1730937600&v=beta&t=-RGN9x2V1GdHqeE9VQLG206vXQV8GEOMGELB4zz3guY',
#            'expiresAt': 1730937600000,
#            'height': 100},
#           {'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1660751582730?e=1730937600&v=beta&t=C7itH1E0GGSk0nd2ewpcuSl1KG--mxeOjRkY7T-k97I',
#            'expiresAt': 1730937600000,
#            'height': 200},
#           {'width': 400,
#            'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1660751582730?e=1730937600&v=beta&t=qGHooOiNTma6VKcQSAfcZv6ocPoolQ3UKQ75FwuG7Ts',
#            'expiresAt': 1730937600000,
#            'height': 400},
#           {'width': 800,
#            'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1660751582730?e=1730937600&v=beta&t=VA_yEY3MU1aKsn1S9sZ4n6hs76iRm_nNBYFEYE7Ceuo',
#            'expiresAt': 1730937600000,
#            'height': 800}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C4D03AQFCIsqVogTXrQ/profile-displayphoto-shrink_'}},
#        'trackingId': 'jX77d/m4RV+Oje4HlWmjCA=='},
#       'profileUrn': 'urn:li:fs_miniProfile:ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8'}]},
#    {'date': {'month': 11, 'year': 2019, 'day': 1},
#     'name': 'NISER: Normalized Item and Session Representations with Graph Neural Networks',
#     'publisher': 'CIKM',
#     'url': 'https://scholar.google.com/citations?view_op=view_citation&hl=en&user=3mgfhFQAAAAJ&citation_for_view=3mgfhFQAAAAJ:U3qCfcK-7lkC',
#     'authors': [{'member': {'firstName': 'Diksha',
#        'lastName': 'Garg',
#        'dashEntityUrn': 'urn:li:fsd_profile:ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8',
#        'occupation': 'Data Scientist at SAP Labs',
#        'objectUrn': 'urn:li:member:519475097',
#        'entityUrn': 'urn:li:fs_miniProfile:ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8',
#        'publicIdentifier': 'diksha-garg-1b5b7a125',
#        'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1660751582730?e=1730937600&v=beta&t=-RGN9x2V1GdHqeE9VQLG206vXQV8GEOMGELB4zz3guY',
#            'expiresAt': 1730937600000,
#            'height': 100},
#           {'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1660751582730?e=1730937600&v=beta&t=C7itH1E0GGSk0nd2ewpcuSl1KG--mxeOjRkY7T-k97I',
#            'expiresAt': 1730937600000,
#            'height': 200},
#           {'width': 400,
#            'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1660751582730?e=1730937600&v=beta&t=qGHooOiNTma6VKcQSAfcZv6ocPoolQ3UKQ75FwuG7Ts',
#            'expiresAt': 1730937600000,
#            'height': 400},
#           {'width': 800,
#            'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1660751582730?e=1730937600&v=beta&t=VA_yEY3MU1aKsn1S9sZ4n6hs76iRm_nNBYFEYE7Ceuo',
#            'expiresAt': 1730937600000,
#            'height': 800}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C4D03AQFCIsqVogTXrQ/profile-displayphoto-shrink_'}},
#        'trackingId': 'jX77d/m4RV+Oje4HlWmjCA=='},
#       'profileUrn': 'urn:li:fs_miniProfile:ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8'}]},
#    {'date': {'month': 7, 'year': 2019, 'day': 18},
#     'name': 'Sequence and time aware neighborhood for session-based recommendations: Stan',
#     'publisher': 'Sigir,19',
#     'url': 'https://dl.acm.org/doi/abs/10.1145/3331184.3331322',
#     'authors': [{'member': {'firstName': 'Diksha',
#        'lastName': 'Garg',
#        'dashEntityUrn': 'urn:li:fsd_profile:ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8',
#        'occupation': 'Data Scientist at SAP Labs',
#        'objectUrn': 'urn:li:member:519475097',
#        'entityUrn': 'urn:li:fs_miniProfile:ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8',
#        'publicIdentifier': 'diksha-garg-1b5b7a125',
#        'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1660751582730?e=1730937600&v=beta&t=-RGN9x2V1GdHqeE9VQLG206vXQV8GEOMGELB4zz3guY',
#            'expiresAt': 1730937600000,
#            'height': 100},
#           {'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1660751582730?e=1730937600&v=beta&t=C7itH1E0GGSk0nd2ewpcuSl1KG--mxeOjRkY7T-k97I',
#            'expiresAt': 1730937600000,
#            'height': 200},
#           {'width': 400,
#            'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1660751582730?e=1730937600&v=beta&t=qGHooOiNTma6VKcQSAfcZv6ocPoolQ3UKQ75FwuG7Ts',
#            'expiresAt': 1730937600000,
#            'height': 400},
#           {'width': 800,
#            'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1660751582730?e=1730937600&v=beta&t=VA_yEY3MU1aKsn1S9sZ4n6hs76iRm_nNBYFEYE7Ceuo',
#            'expiresAt': 1730937600000,
#            'height': 800}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C4D03AQFCIsqVogTXrQ/profile-displayphoto-shrink_'}},
#        'trackingId': 'jX77d/m4RV+Oje4HlWmjCA=='},
#       'profileUrn': 'urn:li:fs_miniProfile:ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8'}]},
#    {'date': {'month': 3, 'year': 2019, 'day': 23},
#     'name': 'Data-driven Prognostics with Predictive Uncertainty Estimation using Ensemble of Deep Ordinal Regression Models',
#     'publisher': 'IJPHM',
#     'url': 'https://arxiv.org/abs/1903.09795',
#     'authors': [{'member': {'firstName': 'Diksha',
#        'lastName': 'Garg',
#        'dashEntityUrn': 'urn:li:fsd_profile:ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8',
#        'occupation': 'Data Scientist at SAP Labs',
#        'objectUrn': 'urn:li:member:519475097',
#        'entityUrn': 'urn:li:fs_miniProfile:ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8',
#        'publicIdentifier': 'diksha-garg-1b5b7a125',
#        'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#            'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1660751582730?e=1730937600&v=beta&t=-RGN9x2V1GdHqeE9VQLG206vXQV8GEOMGELB4zz3guY',
#            'expiresAt': 1730937600000,
#            'height': 100},
#           {'width': 200,
#            'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1660751582730?e=1730937600&v=beta&t=C7itH1E0GGSk0nd2ewpcuSl1KG--mxeOjRkY7T-k97I',
#            'expiresAt': 1730937600000,
#            'height': 200},
#           {'width': 400,
#            'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1660751582730?e=1730937600&v=beta&t=qGHooOiNTma6VKcQSAfcZv6ocPoolQ3UKQ75FwuG7Ts',
#            'expiresAt': 1730937600000,
#            'height': 400},
#           {'width': 800,
#            'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1660751582730?e=1730937600&v=beta&t=VA_yEY3MU1aKsn1S9sZ4n6hs76iRm_nNBYFEYE7Ceuo',
#            'expiresAt': 1730937600000,
#            'height': 800}],
#          'rootUrl': 'https://media.licdn.com/dms/image/v2/C4D03AQFCIsqVogTXrQ/profile-displayphoto-shrink_'}},
#        'trackingId': 'jX77d/m4RV+Oje4HlWmjCA=='},
#       'profileUrn': 'urn:li:fs_miniProfile:ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8'}]}],
#   'certifications': [{'authority': 'Cutshort',
#     'name': 'Cutshort Certified C - Basic',
#     'timePeriod': {'startDate': {'month': 5, 'year': 2022}},
#     'licenseNumber': '66946'},
#    {'authority': 'Cutshort',
#     'name': 'Cutshort Certified Algorithms - Advanced',
#     'timePeriod': {'startDate': {'month': 5, 'year': 2022}},
#     'licenseNumber': '66934'}],
#   'projects': [],
#   'urn_id': 'ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8'},
#  {'summary': 'I work at AI Garage division at MasterCard as a Data Scientist\nI am interested in the domain of Machine Learning and Deep Learning. Previously, I worked as an intern in a startup where my work involved using Computer Vision and Deep Learning techniques for monitoring cancer growth. I also worked as a research intern at IIITD, which involved improving the current network architectures for skeleton detection.  I love to work on challenging problems which can be solved through AI\nI am interested in Applied Research Opportunities in Computer Vision and NLP',
#   'industryName': 'Financial Services',
#   'lastName': 'Sehgal',
#   'locationName': 'India',
#   'birthDate': {'month': 6, 'day': 23},
#   'firstName': 'Himank',
#   'headline': "Data Scientist @Mastercard AI Garage | IIT Roorkee @'23",
#   'public_id': 'himank-sehgal-43786b192',
#   'experience': [{'locationName': 'Gurugram, Haryana, India',
#     'geoLocationName': 'Gurugram, Haryana, India',
#     'companyName': 'Mastercard AI Garage',
#     'timePeriod': {'startDate': {'month': 6, 'year': 2023}},
#     'company': {'employeeCountRange': {'start': 51, 'end': 200},
#      'industries': ['Information Technology and Services']},
#     'title': 'Data Scientist'},
#    {'locationName': 'India',
#     'geoLocationName': 'India',
#     'companyName': 'Data Science Group, IIT Roorkee',
#     'timePeriod': {'endDate': {'month': 7, 'year': 2023},
#      'startDate': {'month': 4, 'year': 2021}},
#     'description': 'Data Science Group, IIT Roorkee is a student organization, part of the umbrella organization Software Development Section that aims to work on innovative open source projects in the domain of Machine Learning, Deep Learning & Reinforcement Learning, bridging the gap between research and industry.',
#     'company': {'employeeCountRange': {'start': 11, 'end': 50},
#      'industries': ['Computer Software']},
#     'title': 'Member'},
#    {'locationName': 'India',
#     'geoLocationName': 'India',
#     'companyName': 'onRec, IIT R',
#     'timePeriod': {'endDate': {'month': 7, 'year': 2023},
#      'startDate': {'month': 4, 'year': 2021}},
#     'company': {'employeeCountRange': {'start': 11, 'end': 50},
#      'industries': ['Computer Software']},
#     'title': 'Joint Secretary'},
#    {'locationName': 'Gurugram, Haryana, India',
#     'geoLocationName': 'Gurugram, Haryana, India',
#     'companyName': 'American Express',
#     'timePeriod': {'endDate': {'month': 7, 'year': 2022},
#      'startDate': {'month': 5, 'year': 2022}},
#     'company': {'employeeCountRange': {'start': 10001},
#      'industries': ['Financial Services']},
#     'title': 'Data Analyst Intern'},
#    {'locationName': 'India',
#     'geoLocationName': 'India',
#     'companyName': 'Skit.ai',
#     'timePeriod': {'endDate': {'month': 5, 'year': 2022},
#      'startDate': {'month': 3, 'year': 2022}},
#     'company': {'employeeCountRange': {'start': 201, 'end': 500},
#      'industries': ['Computer Software']},
#     'title': 'Machine Learning Intern'}],
#   'education': [{'projects': ['urn:li:fs_project:(ACoAAC1VcqsByzp1o1GEmybISevasiO7VjSe39U,1954625747)'],
#     'school': {'objectUrn': 'urn:li:school:13502',
#      'entityUrn': 'urn:li:fs_miniSchool:13502',
#      'active': True,
#      'schoolName': 'Indian Institute of Technology, Roorkee',
#      'trackingId': 'd9aDgxd1Rhy6Wapob+UlSQ==',
#      'logoUrl': 'https://media.licdn.com/dms/image/v2/C510BAQFxnsvax1W4UQ/company-logo_'},
#     'timePeriod': {'endDate': {'year': 2023}, 'startDate': {'year': 2019}},
#     'degreeName': 'electrical Engineering',
#     'schoolName': 'Indian Institute of Technology, Roorkee',
#     'fieldOfStudy': 'Electrical Engineering Technologies/Technicians'},
#    {'school': {'objectUrn': 'urn:li:school:3239487',
#      'entityUrn': 'urn:li:fs_miniSchool:3239487',
#      'active': True,
#      'schoolName': 'Stepping Stones Sr. Sec. School',
#      'trackingId': '2EL23xoWREa1hUqUpugBFg=='},
#     'grade': 'Class 12-94%',
#     'timePeriod': {'endDate': {'year': 2019}, 'startDate': {'year': 2017}},
#     'schoolName': 'Stepping Stones Sr. Sec. School'},
#    {'grade': 'CGPA-10', 'schoolName': 'Delhi Public School -Chandigarh'}],
#   'languages': [],
#   'publications': [],
#   'certifications': [{'authority': 'Coursera',
#     'name': 'Neural Networks and Deep Learning',
#     'timePeriod': {'startDate': {'month': 11, 'year': 2020}},
#     'licenseNumber': 'RK5NUWT55U9P'},
#    {'authority': 'Coursera',
#     'name': 'Improving Deep Neural Networks: Hyperparameter tuning, Regularization and Optimization',
#     'timePeriod': {'startDate': {'month': 11, 'year': 2020}},
#     'licenseNumber': 'BSLTSR3USEM2'},
#    {'authority': 'Coursera',
#     'name': 'Structuring Machine Learning Projects',
#     'timePeriod': {'startDate': {'month': 12, 'year': 2020}},
#     'licenseNumber': ' FRFCMXJCKC8D'},
#    {'authority': 'Coursera',
#     'name': 'Convolutional Neural Networks',
#     'timePeriod': {'startDate': {'month': 12, 'year': 2020}},
#     'licenseNumber': 'SF7V6BBJQHMD'},
#    {'authority': 'Coursera',
#     'name': 'Sequence Models',
#     'timePeriod': {'startDate': {'month': 2, 'year': 2021}},
#     'licenseNumber': 'CS4VKM2RNYYV'},
#    {'authority': 'Coursera',
#     'name': 'Deep Learning Specialisation',
#     'timePeriod': {'startDate': {'month': 2, 'year': 2021}},
#     'licenseNumber': ' PQS2B4L2JQ37'},
#    {'authority': 'Coursera',
#     'name': 'Predicting Employee Turnover with scikit-learn',
#     'timePeriod': {'startDate': {'month': 12, 'year': 2020}},
#     'licenseNumber': '4CM8HE2PTZ4G'},
#    {'authority': 'Coursera',
#     'name': 'Multiple Linear Regression with scikit-learn',
#     'timePeriod': {'startDate': {'month': 12, 'year': 2020}},
#     'licenseNumber': ' 9E2CJ7KNVMSY'}],
#   'projects': [{'occupation': 'urn:li:fs_education:(ACoAAC1VcqsByzp1o1GEmybISevasiO7VjSe39U,610306762)',
#     'timePeriod': {'startDate': {'month': 10, 'year': 2019}},
#     'description': 'A small sized 4-legged robot fitted with a camera which can be used for several purposes like spying , search and rescue operations.',
#     'title': 'Robotic Bug'}],
#   'urn_id': 'ACoAAC1VcqsByzp1o1GEmybISevasiO7VjSe39U'}]

# %%
skills_list = []
for skill in metadatas:
    skills_dict = {"skills": [item["name"] for item in skill["skills"]]}
    skills_list.append(skills_dict)

skills_list = [{'skills': ",".join(skill["skills"])} for skill in skills_list]

skills_list
# Out:
# [{'skills': 'Probability Theory,Probabilistic Programming,Amazon Web Services (AWS),Mathematics,Artificial Neural Networks,Natural Language Processing (NLP),Software Development,Credit Scoring,Business Development,Risk Based Pricing,Price Elasticity,Genetic Algorithms,Causal Inference,Time Series Forecasting,Recommender Systems,team lead,Team Mentoring,A/B Testing,Dynamic Pricing,Inventory Optimization,MLOps,Business Strategy,Machine Learning,Deep Learning,Statistical Data Analysis,Statistical Modeling,SQL,R,Microsoft Excel,Tableau,C,Java,Data Analytics,Data Science,Statistics,Artificial Intelligence (AI),Python (Programming Language),Data Mining,Algorithms,Data Visualization,Bayesian inference,Design of Experiments (DOE),Reinforcement Learning,Automated Machine Learning (AutoML),Graphical Models'},
#  {'skills': 'Data Mining,Deep Neural Networks (DNN),Computer Architecture,Optimization,TensorFlow,Apache Spark,Algorithm Design,Statistical Learning,Unstructured Data,Teamwork,Problem Solving,Cluster Analysis,Analytical Skills,Natural Language Processing (NLP),Predictive Analytics,Statistical Data Analysis,Statistics,Python (Programming Language),SQL,Java,Object-Oriented Programming (OOP),Machine Learning,Data Visualization,Cypher Query Language,Pandas,Transact-SQL (T-SQL),R (Programming Language),Tableau,Neo4j,Applied Machine Learning,Regression Analysis,Logistic Regression,Linear Regression'},
#  {'skills': 'Python (Programming Language),Machine Learning Algorithms,PL/SQL,Agile Methodologies,Software Development,Shell Scripting,Requirements Analysis,Data Analysis,Artificial Intelligence (AI),Machine Learning,Deep Learning,Oracle SQL Developer,Core Java,Unix,Linux,Progress 4GL,pl,Artificial Neural Networks,Character User Interface,Progress,Predictive Modeling,Neural Networks,TensorFlow,SQL,Data Science,Computer Vision'},
#  {'skills': 'Amazon Web Services (AWS),Financial Analysis,COBOL,COBOLII,JCL,CICS,DB2,Xpediter,Endeavor,Agile Application Development,Time Management,changeman,CA7,Control M,Ca datacom,CA-Librarian,Alchemist,Python (Programming Language),Machine Learning,Artificial Intelligence (AI),Artificial Neural Networks,Scikit-Learn,CRF design,CRFs,TensorFlow,Data Science,Data Analysis,Data Visualization,GNU Octave,MongoDB,IBM DB2,Job Control Language (JCL),Core Java,JavaScript,Microsoft SQL Server,Google Analytics,MySQL,linux,Git,Docker Products,Pandas (Software),Django REST Framework,Microsoft Azure,Ubuntu,NoSQL,Django'},
#  {'skills': 'LangChain,Amazon Web Services (AWS),openai,Microsoft Azure,Large Language Models (LLM),Generative AI,Data Science,Machine Learning,Deep Learning,Object Detection,Image Segmentation,Image Processing,Recommender Systems,Recurrent Neural Networks (RNN),Convolutional Neural Networks (CNN),Transformer Models,TensorFlow,Predictive Modeling,PyTorch,Computer Vision,Data Analysis,Data Wrangling,Docker Products,Data Visualization,Data Modeling,Data Warehousing,Artificial Intelligence (AI),Data Structures,Object-Oriented Programming (OOP),Big Data,Statistics,Programming,Public Relations,Big data,Python (Programming Language),Databases,R,Oracle Database,SQL,PySpark,Team Leadership,Communication,Time Management,Teamwork,Team Management,Problem Solving,Relationship Building,Artificial Neural Networks,RDBMS,Probability,Enjoy Challenges,Data Analytics,Natural Language Processing (NLP),NumPy,Neural Networks,Big Data Analytics'},
#  {'skills': 'Computer Vision,Machine Learning,Deep Learning,Python,Image Processing'},
#  {'skills': 'Dataiku DSS,PySpark,Deep Learning,Machine Learning,Natural Language Processing (NLP),Python (Programming Language),SQL,NoSQL,Google Cloud Platform (GCP),Elasticsearch,Flask,Public Speaking,Presentation Skills,Selenium WebDriver,OpenCV,C (Programming Language),C++,Communication,Teamwork'},
#  {'skills': 'Python,SQL,Flask,FastAPI,Machine Learning,Docker,Podman,Data Science,Elasticsearch,Amazon Web Services (AWS),Gitlab,Unix,Data Analytics,Linux,Analytical Skills,R Programming Language,Microsoft Power BI,Google BigQuery,Data Analysis,Data Visualization,MySQL,Tableau,Microsoft Excel,Teradata SQL'},
#  {'skills': 'Transformer Models,Generative AI,LLM,Machine Learning,Python,Predictive Modelling,Statistical Modeling,Statistics,Data Science,Deep Learning,SQL,Core Java,Pandas (Software),Keras,K-Nearest Neighbors (KNN),XGBoost,Flask,Google Cloud Platform (GCP),Amazon Web Services (AWS),Gensim,spaCy,Python (Programming Language),Java,Microsoft Excel,VBA,Tableau,R programming,Natural Language Processing (NLP),Scikit-Learn,Logistic Regression,Linear Regression,Text Classification,Ensemble Models,Naive bayes,Predictive Modeling,Support Vector Machine (SVM),Decision Trees,GBDT,Random Forest,MLP,word2vec,Chatbot Development,nltk,textblob,flair,stanford coreNLP,Topic Modeling,Machine Learning Algorithms,Speech Recognition,Linux'},
#  {'skills': 'Amazon Web Services (AWS),PySpark,Statistics,Machine Learning,Python,SQL,SPSS,R,Team Management,Exploratory Data Analysis'},
#  {'skills': 'Machine Learning,Python,Django,Social Media,HTML,SQL,Microsoft Word,Microsoft Excel,Microsoft Office,PowerPoint,PHP,Unix,Teamwork,Public Speaking,English,Artificial Intelligence (AI),Data Science,Anaconda,Pandas,NumPy,Scikit-Learn,Regression Models,Predictive Analytics,Predictive Modeling,Forecasting,K-Nearest Neighbors (KNN),Support Vector Machine (SVM),Decision Trees,Git,TensorFlow,OpenCV,Text Classification,Spacy,Natural Language Processing (NLP),NLTK,Sentiment Analysis,Principal Component Analysis,Clustering,Bagging,Boosting'},
#  {'skills': 'Data Analysis,Machine Learning,Python (Programming Language),Analytical Skills,Microsoft Office,SQL,Postman API'},
#  {'skills': 'ServiceNow,Business Process Improvement,Business Process,Knowledge Sharing,Client Requirements,Presentations,Extract, Transform, Load (ETL),Data Management,Business Process Outsourcing (BPO),Business Management,Documentation,Git,Microsoft Azure Machine Learning,PyTorch,Natural Language Processing (NLP),Business Intelligence (BI),Data Visualization,Data Validation,Digital Marketing,Team Leadership,Spoken English,Time Series Analysis,Data Science,Predictive Analytics,Predictive Maintenance,Artificial Intelligence (AI),Artificial Neural Networks,Neural Networks,Chatbot Development,Exploratory Data Analysis,Microsoft Excel,Snowflake,Client Relations,Data Analytics,SQL,Tableau,SAP Business Warehouse (SAP BW),Communication,C++,Data Analysis,Machine Learning,Algorithms,Blogging,Content Development,Writing,C (Programming Language),Python (Programming Language),Microsoft Office,Public Speaking,Leadership'},
#  {'skills': 'Azure Data Factory,Azure Databricks,PySpark,Flask,Time Series Analysis,Fastai,Automation,UiPath,Microsoft Power BI,SQL,Computer Vision,Python (Programming Language),Machine Learning,Programming,Image Processing,MySQL,Tableau,C++,Java,Windows'},
#  {'skills': 'Communication,Analytical Skills,Technical Presentations,Technical Architecture,Statistical Analysis,Debugging,Data Preparation,Data Engineering,Data Collection,Software Development,Software Design,Programming,Statistical Modeling,Data Analytics,Problem Solving,Optimization Techniques,Pandas (Software),Operating Systems,Git,Keras,MATLAB,NumPy,Matplotlib,Data Storage,Computer Science,Artificial Intelligence (AI),Pattern Recognition,Analytics,Data Science,Computer Vision,Deep Learning,Data Structures,Natural Language Processing,Machine Translation,Statistical Machine Translation,Machine Learning,Data Analysis,Speech Recognition,Algorithms,C++,Python (Programming Language),SQL,Statistics,Predictive Modeling,C (Programming Language),Linux,R,Agile Methodologies,TensorFlow,Natural Language Processing (NLP)'},
#  {'skills': 'Data Quality,Data Extraction,Problem Solving,Data Analytics,Analytical Skills,Data Analysis,Data Visualization,Microsoft Power BI,Computer Science,Microsoft Excel,EDA,Machine Learning,pandas ,XGBoost,NumPy,SQL,Snowflake,PostgreSQL,Turbo C++,Programming,Computer Networking,Core Java,HTML,Windows,Database Management System (DBMS),STRINGS,Object-Oriented Programming (OOP),Theory of Computation,Ubuntu,C (Programming Language),Data Structures,High Technical Aptitude,Python (Programming Language)'},
#  {'skills': 'XGBoost,Continuous Integration and Continuous Delivery (CI/CD),Exploratory Data Analysis,SHAP,Machine Learning,Data Science,Python,Statistics,Econometrics,Data Analysis,Basketball,Bioinformatics,Programming,Deep Learning,Forecasting,MySQL,C,Matlab,Microsoft Excel,Decision Modeling,Machine Learning Algorithms,C++,Algorithms,Predictive Modeling'},
#  {'skills': 'Data Visualization,MySQL,Machine Learning,Statistical Data Analysis,Data Analysis,Big Data,Data Science,Python (Programming Language),Big Data Analytics'},
#  {'skills': 'MLOps,Data Structures,Programming,Python (Programming Language),Deep Learning,Research,Reinforcement Learning,Machine Learning,Linux'},
#  {'skills': 'Engineering,Electrical Engineering,Case Studies,Management,Fundraising'}]

# %%
client = chromadb.PersistentClient(path="./vector_database")
# Out:
# INFO:chromadb.telemetry.product.posthog:Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.

# %%
collection = client.create_collection(
    name="linkedin_people_profiles",
    embedding_function=OpenAIEmbeddingFunction(api_key=os.environ["OPENAI_API_KEY"]),
)

# %%
for id, doc, metadata in zip(ids, documents, skills_list):
    try:
        collection.add(
            ids=id,
            documents=json.dumps(doc),
            metadatas=metadata,
        )
    except Exception:
        continue
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 400 Bad Request"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"

# %%
client.count_collections()
# Out:
# 1

# %%
client.list_collections()
# Out:
# []

# %%
for collection in client.list_collections():
    client.delete_collection(name=collection.name)

# %%
linkedin_collection = client.get_collection(name="linkedin_people_profiles", embedding_function=OpenAIEmbeddingFunction())

# %%
linkedin_collection.count()
# Out:
# 19

# %%
linkedin_collection.query(
    query_texts="People with experience of 5 years",
    include=["documents"]
)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# {'ids': [['ACoAAAbvohIBhdiLqQ5FCbtA40AFvg3f-T7fKfk',
#    'ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY',
#    'ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0',
#    'ACoAAAZZciMBmlehJoR3zG5AnILlz_0LDgRmano',
#    'ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8',
#    'ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY',
#    'ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w',
#    'ACoAACzqAZ8BNYEJjGPpk_l6DlwoAzZJUXVYd0Y',
#    'ACoAABIURlEB0IaIlQL8yLwChwLnQFDTIiBtFbY',
#    'ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4']],
#  'distances': None,
#  'metadatas': None,
#  'embeddings': None,
#  'documents': [['{"summary": "Experience in Cognitive Computing with leverage of Machine Learning, Deep Learning, Artificial Intelligence, Natural Language Processing skills . Data driven analyst with the ability to apply ML/DL/NLP/Computer Vision Techniques and leverage algorithms to solve real world problems. Established ability in deploying effective predictive/NLP/Computer Vision models across banking/HealthCare industries to accurately forecast and deliver proven results. Strong understanding of Oracle DB and PLSQL with data migration exp\\u00e9rience. Domain Knowledge of SupplyChain/finance/banking/Retail domain with communication skills, excellent product and process design knowledge. Domain HealthCare,Mortgage Banking, Consumer, Commercial Lending, Escrow, Loan processing and servicing, Deposits. Onsite experience (US/UK) with business domain experience in Retail and supply chain with special focus on Customer engagement and managing end-user expectations. Experience in Analysis, Design, Development, Customization, Bug fixes, Enhancement, Support and Implementation.\\n\\n\\nData Science, Machine Learning, Deep Learning and AI technologies.Strong understanding of Databases Oracle, Progress 4GL, PLSQL. Excellent Domain Knowledge of finance/banking/Retail domain with communication skills, excellent product and process design knowledge.Strong knowledge of Data Migration and Implementation.. \\n\\nAreas of Expertise: Data Science Machine Learning, Deep Learning and AI technologies.\\n\\nWeb App - Flask, Django.\\n\\nDomain - Mortgage Banking,Insurance Claim Processing Money Laundering, Investment Banking, Lending, Escrow, Loan processing and servicing. Credit Cards,Healthcare\\n\\nDatabase - Oracle,Progress 4GL,Mongo Db\\n\\nLanguages - Python ,PLSQL,Progress4GL,Shell Script\\n\\nVersioning - SVN,Github\\nCloud : IBM Cloud, AWS,AZURE,Kubernates\\nOthers : Dockers,CICD\\n\\n\\n\\n\\n10+ years of experience in exploring and understanding various business models in Finance,Healthcare,Retail and Supply chain domain with special focus on implementation according to client requirements.\\n\\u2022\\tExperience in client interaction for requirement gathering and feasibility analysis at various levels including end users, project managers, and business analysts. Possess good business acumen interacting with various 3rd parties in the same project. Onsite experience (UK) with business domain experience in Retail and supply chain with special focus on customer engagement and managing end-user expectations.", "industryName": "Information Technology & Services", "lastName": "Aneja", "locationName": "India", "firstName": "Isha", "headline": "Data Scientist IBM", "img_253_253": "800_800/profile-displayphoto-shrink_800_800/0/1516520225939?e=1730937600&v=beta&t=Y-NS63ItyMgsdVJIR_DcgSb-qbTolbfpcsM606r7v6I", "public_id": "isha-aneja-642b7a32", "experience": [{"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "IBM", "timePeriod": {"startDate": {"month": 12, "year": 2021}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"locationName": "New Delhi Area, India", "geoLocationName": "New Delhi Area, India", "companyName": "Fiserv", "timePeriod": {"endDate": {"month": 1, "year": 2022}, "startDate": {"month": 12, "year": 2017}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Technical Lead"}, {"locationName": "Noida Area, India", "geoLocationName": "Noida Area, India", "companyName": "Birlasoft", "timePeriod": {"endDate": {"month": 12, "year": 2017}, "startDate": {"month": 8, "year": 2016}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Senior Software Engineer"}, {"locationName": "banglore", "geoLocationName": "banglore", "companyName": "Capgemini", "timePerio ...
#    '{"summary": "Experience Data Science professional with demonstrated history of working in IT service industry. Experienced in executing data driven solutions to increase efficiency, accuracy and utility of internal data processing. Skilled in natural language processing with practioner knowledge on Web Analytics. Strong information technology professional with a Bachelor of Technology (BTech) from Uttar Pradesh Technical University. ", "industryName": "Information Technology & Services", "lastName": "Mathur", "locationName": "India", "firstName": "Tushar", "headline": "Data Scientist", "img_413_413": "800_800/profile-displayphoto-shrink_800_800/0/1627636616827?e=1730937600&v=beta&t=x9srqsltLWc2l7StlzDDIhorDInTYG12-UOqNW3FfWI", "public_id": "tushar-mathur-79a23120", "experience": [{"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "Coforge", "timePeriod": {"startDate": {"month": 8, "year": 2022}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Analytics Lead"}, {"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "EXL", "timePeriod": {"endDate": {"month": 8, "year": 2022}, "startDate": {"month": 8, "year": 2021}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Technical Lead"}, {"locationName": "Noida Area, India", "geoLocationName": "Noida Area, India", "companyName": "Sopra Steria", "timePeriod": {"endDate": {"month": 7, "year": 2021}, "startDate": {"month": 7, "year": 2019}}, "description": "Working on information extraction project in which we focuses on creating structured representation of unstructured/structured texts by extracting relevant entities from them, using machine learning and AI process thereby making the data analysis realizable.", "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Module Lead"}, {"locationName": "Noida Area, India", "geoLocationName": "Noida Area, India", "companyName": "Sopra Steria", "timePeriod": {"endDate": {"month": 6, "year": 2019}, "startDate": {"month": 10, "year": 2017}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Senior Software Engineer", "honors": ["urn:li:fs_honor:(ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY,1097608354)"]}, {"locationName": "Gurgaon, India", "geoLocationName": "Gurgaon, India", "companyName": "Infosys", "timePeriod": {"endDate": {"month": 10, "year": 2017}, "startDate": {"month": 10, "year": 2016}}, "description": "\\u2022Working knowledge of Agile and Waterfall models.\\n\\u2022Working in full project life cycle involving Requirement Analysis, Testing and Implementation phases.\\n\\u2022Extensive coding and modifying programs using COBOL, DB2 and JCL as per the requests of business departments.\\n\\u2022Involved in Preparing Unit test cases, doing test data setup and performing Unit testing, User Acceptance Testing.\\n\\u2022Works on envisioning of requirement for future analysis.", "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Senior System Engineer", "honors": ["urn:li:fs_honor:(ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY,1304876652)", "urn:li:fs_honor:(ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY,1020421066)"]}], "education": [{"timePeriod": {"endDate": {"year": 2014}, "startDate": {"year": 2010}}, "degreeName": "Bachelor of Technology (BTech)", "schoolName": "Uttar Pradesh Technical University", "fieldOfStudy": "Electrical, Electronics and Communications Engineering"}], "languages": [{"name": "English", "proficiency": "PROFESSIONAL_WORKING"}, {"name": "Hindi", "proficiency": "NATIVE_OR_BILINGUAL"}], "publications": [], "certifications": [{"authority": "Coursera", "name": "IBM Data Science Speciali ...
#    '{"summary": "\\u2022\\tExperience of 7 years as Data Scientist (August 2016 \\u2013 Till Date) in implementing advanced analytics and predictive modelling algorithms such as Sequence models, Machine translation, Text summarization, Voice enabled Bot (using GPT2, Deepspeech and Azure cognitive services),Text Extraction using BERT and Spacy, Text Classification, Credit Risk analysis, Logistic regression, Decision tree ,Ensemble models, KNN, PCA, t-SNE, Linear regression, Clustering (k-means, Agglomerative)\\n\\u2022\\tExperience of 1.6 years (Nov 2014 \\u2013 Aug 2016) in Siebel CRM.\\n\\u2022\\tWell converse with Python(Pandas, Numpy, Scikit-Learn, Keras, matplotlib.pyplot, seaborn), Flask API, ML model deployments, AWS Services, linux, SQL ,Core Java and Siebel CRM.", "industryName": "Information Technology & Services", "lastName": "Kharbanda", "locationName": "India", "firstName": "Sumeet", "headline": "Looking for Data Science Opportunities  | Manager - Data Scientist @ EXL | NLP | Freelancer", "img_450_450": "800_800/profile-displayphoto-shrink_800_800/0/1517470892367?e=1730937600&v=beta&t=p7uLveJo_W71BzPwKr0uGqMp2Y30lFAqnf2cMgVQ2fk", "public_id": "sumeet-data-scientist", "experience": [{"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "EXL", "timePeriod": {"startDate": {"month": 4, "year": 2022}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Manager - Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "EXL", "timePeriod": {"endDate": {"month": 4, "year": 2022}, "startDate": {"month": 11, "year": 2020}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Technical Lead - Data Scientist"}, {"courses": ["urn:li:fs_course:(ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0,504009401)", "urn:li:fs_course:(ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0,504035397)"], "locationName": "Gurgaon, Haryana, India", "geoLocationName": "Gurgaon, Haryana, India", "companyName": "UnitedHealth Group", "timePeriod": {"endDate": {"month": 11, "year": 2020}, "startDate": {"month": 8, "year": 2019}}, "description": "Development and deployment of machine learning models in python, text analytics,disease prediction, voice bot and chat bot.", "company": {"employeeCountRange": {"start": 10001}, "industries": ["Hospital & Health Care"]}, "title": "Associate Data Scientist"}, {"locationName": "Gurgaon, Haryana, India", "geoLocationName": "Gurgaon, Haryana, India", "companyName": "dunnhumby", "timePeriod": {"endDate": {"month": 8, "year": 2019}, "startDate": {"month": 6, "year": 2019}}, "description": "Adhoc analysis of retail client, worked on pyspark, python, SQL, excel dashboards", "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Marketing and Advertising"]}, "title": "Applied Data Scientist"}, {"courses": ["urn:li:fs_course:(ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0,503992293)"], "locationName": "Chandigarh Area, India", "geoLocationName": "Chandigarh Area, India", "companyName": "Infosys", "timePeriod": {"endDate": {"month": 5, "year": 2019}, "startDate": {"month": 4, "year": 2018}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Technology Analyst"}], "education": [{"school": {"objectUrn": "urn:li:school:354045", "entityUrn": "urn:li:fs_miniSchool:354045", "active": true, "schoolName": "International Institute of Information Technology Bangalore", "trackingId": "0VqE2YHXSv2HGiWpbbSzGw==", "logoUrl": "https://media.licdn.com/dms/image/v2/D560BAQEocmV8HEnx7w/company-logo_"}, "timePeriod": {"endDate": {"year": 2021}, "startDate": {"year": 2020}}, "degreeName": "PGC", "schoolName": "International Institute of Information Technology Bangalore", "fieldOfStudy": "Data Science"}, {"school": {"objectUrn" ...
#    '{"summary": "11+ years of experience with a proven track record of driving revenue growth and operational efficiency through data-driven solutions. Skilled in data manipulation, visualization, statistical inference, machine learning, and MLOps with strong theoretical foundations. Effective communication skills, adept at distilling complex ideas and concepts into easy-to- understand language. Experienced in leading end-to-end ML projects and solving the unique challenges that come with them.", "industryName": "Information Technology & Services", "lastName": "Maheshwari", "locationName": "India", "firstName": "Sahil", "headline": "Data Scientist @ Hunch", "public_id": "maheshwarisahil", "experience": [{"locationName": "Delhi, India", "geoLocationName": "Delhi, India", "companyName": "Hunch", "timePeriod": {"startDate": {"month": 11, "year": 2023}}, "company": {"employeeCountRange": {"start": 51, "end": 200}, "industries": ["Internet"]}, "title": "Head of Data Science"}, {"locationName": "Bengaluru, Karnataka, India", "geoLocationName": "Bengaluru, Karnataka, India", "companyName": "SIXT Research & Development India", "timePeriod": {"endDate": {"month": 8, "year": 2023}, "startDate": {"month": 10, "year": 2020}}, "description": "Led strategically important DS projects through their complete ML lifecycle. Also responsible for solution research and team mentoring.\\n\\nDynamic Pricing\\n\\u2022 Delivered a sustainable margin uplift of >3% using elasticity-based pricing models\\n\\u2022 Built a faster and more reliable AB testing framework solving problems in traditional AB testing like\\npeeking, high sample variance, independence of p-values and effect sizes, etc.\\n\\nFleet Optimization\\n\\u2022 Improved demand forecasting error using Bayesian hierarchical models\\n\\u2022 Developed a price-demand relationship model from natural price variations data using GMM to handle price endogeneity\\n\\u2022 Implemented ML-driven simulations to optimize long-term inventory planning", "company": {"employeeCountRange": {"start": 201, "end": 500}, "industries": ["Computer Software"]}, "title": "Staff Data Scientist"}, {"locationName": "Bengaluru Area, India", "geoLocationName": "Bengaluru Area, India", "companyName": "ThoughtWorks", "timePeriod": {"endDate": {"month": 10, "year": 2020}, "startDate": {"month": 9, "year": 2018}}, "description": "Led DS teams and collaborated with other cross-functional teams to build and deliver\\ncomprehensive solutions, with DS as a key component.\\n\\nDynamic Pricing for a brick-&-mortar Retail giant\\n\\u2022 Delivered an average margin increase of \\u20ac9K per month per store using a SARIMAX-based price-demand model\\n\\u2022 Built a risk control strategy in absence of the test data by defining custom metrics for model\\u2019s stability. \\n\\nSearch Optimization for a leading Knowledge Consulting Firm\\n\\u2022 Improved search results\\u2019 relevance considerably using word2Vec, hierarchical clustering with hashing, and tf-idf.", "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Lead Data Scientist"}, {"locationName": "Bengaluru Area, India", "geoLocationName": "Bengaluru Area, India", "companyName": "Happiest Minds Technologies", "timePeriod": {"endDate": {"month": 9, "year": 2018}, "startDate": {"month": 7, "year": 2017}}, "description": "\\u2022\\tTime series forecasting for multiple domains like energy, manufacturing, retail, etc. Handled high frequency data (minute level) which is usually not well handled by popular implementations of ARIMA\\n\\u2022\\tImage classification using Inception model to automate identification of damaged devices\\n\\u2022\\tOptimization of predictive model to handle incremental data by maintaining data preparation pipeline", "company": {"employeeCountRange": {"start": 5001, "end": 10000}, "industries": ["Information Technology and Services"]}, "title": "Senior Data Scientist"}, {"companyName": "Happi ...
#    '{"summary": "Experienced Researcher with a demonstrated history of working in the information technology and services industry. Skilled in Linux, Research, Programming, Python (Programming Language), and Reinforcement Learning. Strong research professional with a Master of Technology - MTech focused in Computer Science from Indraprastha Institute of Information Technology, Delhi. ", "industryName": "Computer Software", "lastName": "Garg", "locationName": "India", "firstName": "Diksha", "headline": "Data Scientist at SAP Labs", "public_id": "diksha-garg-1b5b7a125", "experience": [{"locationName": "Bengaluru, Karnataka, India", "geoLocationName": "Bengaluru, Karnataka, India", "companyName": "SAP Labs India", "timePeriod": {"startDate": {"month": 8, "year": 2022}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Computer Software"]}, "title": "Data Scientist"}, {"locationName": "Bengaluru, Karnataka, India", "geoLocationName": "Bengaluru, Karnataka, India", "companyName": "Tata Consultancy Services", "timePeriod": {"endDate": {"month": 8, "year": 2022}, "startDate": {"month": 7, "year": 2018}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Machine Learning Researcher", "honors": ["urn:li:fs_honor:(ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8,1101172354)", "urn:li:fs_honor:(ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8,1101273034)", "urn:li:fs_honor:(ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8,964835261)"]}], "education": [{"courses": ["urn:li:fs_course:(ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8,1101534940)"], "school": {"objectUrn": "urn:li:school:373028", "entityUrn": "urn:li:fs_miniSchool:373028", "active": true, "schoolName": "Indraprastha Institute of Information Technology, Delhi", "trackingId": "kDA+c2mFR9S/wDUlDYTKFw==", "logoUrl": "https://media.licdn.com/dms/image/v2/C560BAQG8G8yRaFuoBQ/company-logo_"}, "grade": "CGPA - 8.58", "timePeriod": {"endDate": {"month": 7, "year": 2018}, "startDate": {"month": 7, "year": 2016}}, "fieldOfStudyUrn": "urn:li:fs_fieldOfStudy:100189", "degreeName": "Master of Technology - MTech", "schoolName": "Indraprastha Institute of Information Technology, Delhi", "fieldOfStudy": "Computer Science", "degreeUrn": "urn:li:fs_degree:584"}, {"school": {"objectUrn": "urn:li:school:13426", "entityUrn": "urn:li:fs_miniSchool:13426", "active": true, "schoolName": "Banasthali Vidyapith", "trackingId": "Btowl/21RbynIRSzqYbWQw==", "logoUrl": "https://media.licdn.com/dms/image/v2/C4D0BAQE5b9Z6j_5cFA/company-logo_"}, "grade": "Gold Medalist", "timePeriod": {"endDate": {"month": 7, "year": 2016}, "startDate": {"month": 7, "year": 2012}}, "fieldOfStudyUrn": "urn:li:fs_fieldOfStudy:100176", "degreeName": "Bachelor of Technology - BTech", "schoolName": "Banasthali Vidyapith", "fieldOfStudy": "Information Technology", "honors": ["urn:li:fs_honor:(ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8,1102003546)"], "degreeUrn": "urn:li:fs_degree:250"}], "languages": [{"name": "English", "proficiency": "FULL_PROFESSIONAL"}, {"name": "Hindi", "proficiency": "NATIVE_OR_BILINGUAL"}], "publications": [{"date": {"month": 2, "year": 2022, "day": 17}, "name": "Learning to Liquidate Forex using Optimal Stopping via Adaptive Top-K Regression", "publisher": "AAAI-22", "authors": [{"member": {"firstName": "Diksha", "lastName": "Garg", "dashEntityUrn": "urn:li:fsd_profile:ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8", "occupation": "Data Scientist at SAP Labs", "objectUrn": "urn:li:member:519475097", "entityUrn": "urn:li:fs_miniProfile:ACoAAB72j5kB3LCVCtnZjP-7Bl4mpfNQhEi8GJ8", "publicIdentifier": "diksha-garg-1b5b7a125", "picture": {"com.linkedin.common.VectorImage": {"artifacts": [{"width": 100, "fileIdentifyingUrlPathSegment": "100_100/profile-displayphoto-shrink_100_100/0/1660751582730?e=1730937600&v=beta&t=-RGN9x2V1GdHqeE9VQLG206vXQV8GEOMGELB4zz3guY", "expiresAt": 1730937600000, "height": 100}, {"width": 200, "fileIdentifyingUrlPathSegment": "200_200/profile-displ ...
#    '{"summary": "4+ years of work experience solving business problems with the application of Data Science. Master of Data Science, Monash University (Melbourne). Proficient in Generative AI, Computer Vision and Predictive Modeling. With a strong grip over mathematics, deep learning and machine learning algorithms, capable to transform business requirements into data science formulations and implementing the solutions in an efficient and scalable fashion.\\n\\nCreating impactful AI solutions at R Systems, my focus is on designing cutting-edge generative AI technologies. With a Master\'s degree in Data Science from Monash University, I apply rigorous academic training to address complex client challenges. Our team\'s contribution has significantly enhanced the RAG Application\'s accuracy, showcasing a blend of innovation and practical application.\\n\\nMy core competencies lie in Large Language Models and transformative AI, underpinned by data collection, preprocessing, model development, and deployment. These skills have enabled us to deliver tailored solutions that not only meet but exceed our clients\' business objectives. The dedication to continual learning and improvement is what drives the team and myself to achieve excellence in the ever-evolving field of data science.", "industryName": "Computer Software", "lastName": "Nain", "locationName": "India", "birthDate": {"month": 1, "day": 24}, "firstName": "Rakesh", "headline": "Data Scientist @ R Systems | Master\'s in Data Science", "public_id": "rakeshnain", "experience": [{"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "R Systems", "timePeriod": {"startDate": {"month": 8, "year": 2023}}, "description": "Roles and Responsibilities:\\n- Tackle client challenges by designing and implement end-to-end data science solutions using generative AI (LLMs, Large Multi-Modals and their finetuning based on the use cases) or traditional machine learning from data collection, preprocessing to model development and deployment\\n- I ensure optimal model performance, engage in cross-functional collaboration, and deliver insights to clients through effective communication.\\n- My role contributes to R systems consultancy prowess in delivering innovative and impactful solutions that address diverse business needs of clients.\\n\\nAchievements:\\n- Increased the RAG Application accuracy by 40%.", "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"companyName": "Intello Labs", "timePeriod": {"endDate": {"month": 8, "year": 2023}, "startDate": {"month": 12, "year": 2021}}, "description": "Roles and Responsibilities:\\n- Develop state-of-the-art machine learning and deep learning algorithms/models for visual recognition tasks, such as segmentation and detection.\\n- Collaborate closely with multidisciplinary teams of software engineers, hardware engineers, business leaders and other key players to develop Artificial Intelligent machines.\\n- Data Collection, EDA, Data Cleaning, ML Model Development(R&D) and deployment.\\n\\nAchievements:\\n- Developed object detection and instance segmentation algorithm taking around 50 times less RAM in training with only twice extra time in inference as compared to present state-of-the-art algorithms in the market.\\n- Improved grains classification results by 20%, and fruits defect detection results by 12%.", "company": {"employeeCountRange": {"start": 51, "end": 200}, "industries": ["Information Technology and Services"]}, "title": "Deep Learning Engineer"}, {"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "DishTV", "timePeriod": {"endDate": {"month": 10, "year": 2018}, "startDate": {"month": 6, "year": 2017}}, "description": "Roles and Responsibilities:\\nStarted as a Software Developer in the \\u201cMy DishTV\\u201d Android App pr ...
#    '{"summary": "Data Scientist with experience in solving dynamic and large-scale business problems using Machine learning, exploratory analysis and deep learning. I have worked on computer vision, image processing, quantitative data and predictive modelling to build stable tools with business applications using Python, R programming and C++. I was ranked 3 in GATE-2016 and my unique research projects during my academic life confirm my research aptitude required for an evolving field like data science.\\n\\nLanguages and Frameworks: Python, SQL, C++ | scikit-learn, TensorFlow, Keras and PyTorch, Makefiles (bash), pyproject.toml\\nMachine Learning Models: All Classical models especially ensembled Decision Trees (Random Forest, XGBoost), Time Series, etc.\\nDeep Learning Models: DNNs for structured data, CNNs (VGGs, Inception etc.), YOLO, Transfer Learning and Fine Tuning\\nTheoretical Strengths: Statistics, Probability distributions, Experiment design (Hypothesis testing), Sampling, ML Fundamentals\\nMLOps Capacities: Git, Pytest, MLflow, Docker, Jenkins and the learning continues", "industryName": "Computer Software", "lastName": "Singh Soam", "locationName": "India", "firstName": "Tushar", "headline": "Data Scientist | IIT Kharagpur", "img_450_450": "800_800/profile-displayphoto-shrink_800_800/0/1517612761824?e=1730937600&v=beta&t=HChT1yzvis32yjIryUrexbLfCM_LMTaXozgt3dC-GoE", "public_id": "tusharsinghsoam", "experience": [{"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "Ventiv Technology", "timePeriod": {"startDate": {"month": 11, "year": 2022}}, "description": "Main Role: Building Ventiv Predict, an end-to-end, advance analytics solution software for risk and insurance industry\\n\\u25aa Built generic and client specific machine learning based models (XGBoost) for predicting claim\\u2019s litigation, reserve, duration etc.\\n\\u25aa Introduced concepts of Explainable AI to our product using tools like SHAP and LIME to increase trust of users in our models\\n\\u25aa Implemented advance hyperparameter tuning frameworks like Optuna, Hyperopt and GridSearchCV of scikit-learn.\\n\\u25aa Practised modular development in Python with advanced usage of Git, SQL for data extraction, REGEX for basic NLP", "company": {"employeeCountRange": {"start": 201, "end": 500}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"companyName": "Fiverr", "timePeriod": {"endDate": {"month": 8, "year": 2021}, "startDate": {"month": 8, "year": 2018}}, "description": "Topic: Wealth Management Algorithm and Statistics Expert at CHEGG, USA\\n\\u2022Built a loan repayment schedule engine to reduce the interest payments based on income and expenditure levels using Python\\n\\u2022Coordinated with the team from USA to develop the front-end for my algorithm to build an end-to-end website\\n\\u2022Solved worth 7.5 lakhs of advance statistics questions for USA\\u2019s UG and PG students", "company": {"employeeCountRange": {"start": 501, "end": 1000}, "industries": ["Computer Software"]}, "title": "Professional Freelancer"}, {"locationName": "Bengaluru Area, India", "geoLocationName": "Bengaluru Area, India", "companyName": "Wipro Limited", "timePeriod": {"endDate": {"month": 7, "year": 2018}, "startDate": {"month": 7, "year": 2017}}, "description": "Topic: Use of Computer Vision Algorithms for conversion of Engineering Drawings into Structured Digital Data\\n\\u2022Developed an object detection algorithm for tables in drawings using morphological transformations with precision ~99% in C++\\n\\u2022Built an image processing algorithm to convert simple tables into excel tables using Optical Character Recognition in OpenCV\\n\\u2022Designed an algorithm to classify tables as simple or complex based on the alignment of vertical and horizontal lines of the table", "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"] ...
#    '{"summary": "Experienced Data Scientist with ~4 years specializing in machine learning, NLP, and deep learning. Proficient in algorithms like Random Forest, Boosting, and Decision Tree Classifiers. Skilled in TensorFlow, Keras, and NLTK for developing high-performance applications in language modeling, predictive analytics, and statistical analysis. Seeking opportunities to apply expertise in Python programming and collaborate on impactful projects. Committed to delivering innovative solutions that drive positive change and excel in diverse challenges. Passionate about leveraging skills for groundbreaking advancements in machine learning and NLP domains, ready to make a meaningful impact through transformative outcomes", "industryName": "Computer Software", "lastName": "Bhatnagar", "locationName": "India", "firstName": "Riya", "headline": "Data Scientist", "img_364_364": "800_800/profile-displayphoto-shrink_800_800/0/1722322822594?e=1730937600&v=beta&t=do2oMnHsXNVUKTpwPVTk-aYK8A-XfUZnsF2Zcs5Rv_U", "public_id": "riya-bhatnagar-653434190", "experience": [{"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Fractal", "timePeriod": {"startDate": {"month": 1, "year": 2024}}, "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Management Consulting"]}, "title": "Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "ZS", "timePeriod": {"endDate": {"month": 11, "year": 2023}, "startDate": {"month": 12, "year": 2021}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Management Consulting"]}, "title": "Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Dew Solutions Pvt Ltd", "timePeriod": {"endDate": {"month": 12, "year": 2021}, "startDate": {"month": 6, "year": 2020}}, "company": {"employeeCountRange": {"start": 501, "end": 1000}, "industries": ["Information Technology and Services"]}, "title": "Data Science Engineer"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Dew Solutions Pvt Ltd", "timePeriod": {"endDate": {"month": 5, "year": 2020}, "startDate": {"month": 11, "year": 2019}}, "company": {"employeeCountRange": {"start": 501, "end": 1000}, "industries": ["Information Technology and Services"]}, "title": "Data Science Intern"}, {"locationName": "Jaipur, Rajasthan", "geoLocationName": "Jaipur, Rajasthan", "companyName": "CDAC ATC Jaipur", "timePeriod": {"endDate": {"month": 8, "year": 2018}, "startDate": {"month": 6, "year": 2018}}, "company": {"employeeCountRange": {"start": 11, "end": 50}, "industries": ["Computer Software"]}, "title": "Android Trainee"}], "education": [{"school": {"objectUrn": "urn:li:school:3185138", "entityUrn": "urn:li:fs_miniSchool:3185138", "active": true, "schoolName": "Rajasthan Technical University", "trackingId": "OV1DXTrpSIKD7Oy8R+ExKw==", "logoUrl": "https://media.licdn.com/dms/image/v2/C510BAQGUb3DKT_yHeQ/company-logo_"}, "fieldOfStudyUrn": "urn:li:fs_fieldOfStudy:100189", "degreeName": "Bachelor of Technology - BTech(Hons.)", "schoolName": "Rajasthan Technical University", "fieldOfStudy": "Computer Science"}, {"schoolName": "St.Mary\'s Convent Sr.Sec School"}], "languages": [{"name": "English", "proficiency": "FULL_PROFESSIONAL"}, {"name": "Hindi", "proficiency": "FULL_PROFESSIONAL"}], "publications": [], "certifications": [{"authority": "Coursera", "name": "Introduction to Data Science in Python", "timePeriod": {"startDate": {"month": 4, "year": 2019}}, "licenseNumber": "JT2NVMKHH6NP"}, {"authority": "Coursera", "name": "Machine Learning", "timePeriod": {"startDate": {"month": 4, "year": 2019}}, "licenseNumber": "CWJ2YXZHQFLU"}, {"authority": "Coursera", "name": "Neural Networks and Deep Learning", "timePeriod": {"startDate": {"month": 5, "year": 2019}}, "licenseNumber": "KFHKTR7ZQN6H"}, ...
#    '{"summary": "Experienced Data Scientist with a demonstrated history of working in the computer software industry. Skilled in Computer Vision, Power BI, Image Processing, Text Extraction using Python Programming. Strong engineering professional with a PG Diploma focused in Data Science from Great Lakes Institute of Management, Gurgaon. ", "industryName": "Computer Software", "lastName": "Khandelwal", "locationName": "India", "firstName": "Sushant", "headline": "Data Scientist | AI | ML | Python | SQL |  Automation | Analytics | Azure", "public_id": "sushant-khandelwal-7296b785", "experience": [{"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Optum", "timePeriod": {"startDate": {"month": 8, "year": 2022}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Hospital & Health Care"]}, "title": "Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Info-X Software Technology Pvt Ltd", "timePeriod": {"endDate": {"month": 8, "year": 2022}, "startDate": {"month": 12, "year": 2020}}, "description": "1. Document(s) Automation \\u2013 Automated the manual process of saving various documents with the help of python using libraries like numpy, pandas, google.cloud.vision and pyodbc. The python script automated the task by reading the relevant email, downloading the attachment, extracting the required text using OCR, and saving it into the database.\\n2. Created dashboards using PowerBI for Customers and Vendors visualization, and help them analyze the trends and generate various insights.\\n3. Managed container/vessel tracking process using UI Path, SQL, and Python scripts.", "company": {"employeeCountRange": {"start": 51, "end": 200}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"locationName": "Hyderabad Area, India", "geoLocationName": "Hyderabad Area, India", "companyName": "Sgmoid", "timePeriod": {"endDate": {"month": 8, "year": 2020}, "startDate": {"month": 11, "year": 2019}}, "description": "1. Created Image Classification models to detect retinal morbidity using Fastai.\\n2. Worked on an Image Regeneration project using GANs.\\n3. Managed data entry Automation projects using UI Path and Python scripts.", "company": {"employeeCountRange": {"start": 2, "end": 10}, "industries": ["Computer Software"]}, "title": "Data Scientist"}, {"locationName": "Delhi, India", "geoLocationName": "Delhi, India", "companyName": "MOHAN THREAD MILLS PRIVATE LIMITED", "timePeriod": {"endDate": {"month": 3, "year": 2019}, "startDate": {"month": 2, "year": 2017}}, "company": {"industries": ["Textiles"]}, "title": "Family Business"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Binary Semantics Ltd.", "timePeriod": {"endDate": {"month": 1, "year": 2017}, "startDate": {"month": 10, "year": 2014}}, "description": "Managed e-commerce projects for multiple clients using their data analytically and also ensuring a better user experience. Helped clients accelerate revenue growth by analysing performance and operational excellence such as feed optimization, new product feature adoption, and data/price monitoring.", "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Computer Software"]}, "title": "Analyst"}], "education": [{"school": {"objectUrn": "urn:li:school:3153365", "entityUrn": "urn:li:fs_miniSchool:3153365", "active": true, "schoolName": "Great Lakes Institute of Management Gurgaon", "trackingId": "cpfxNg/DR72/X4uTwR9mSQ==", "logoUrl": "https://media.licdn.com/dms/image/v2/D560BAQG2V_xZ3Ou0KQ/company-logo_"}, "timePeriod": {"endDate": {"month": 10, "year": 2019}, "startDate": {"month": 4, "year": 2019}}, "degreeName": "PG Diploma", "schoolName": "Great Lakes Institute of Management, Gurgaon", "fieldOfStudy": "Data Science"}, {"school": {"objectUrn": "urn:li:school:189141", "enti ...
#    '{"summary": "Experienced data scientist with a track record of translating complex data into actionable insights across diverse sectors spanning FMCG, Sports and Supply Chain.", "industryName": "Information Technology & Services", "lastName": "Srivastava", "locationName": "India", "firstName": "Vidur", "headline": "Data Scientist", "public_id": "vidur-srivastava-a45b85143", "experience": [{"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Tredence Inc.", "timePeriod": {"startDate": {"month": 7, "year": 2024}}, "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Management Consulting"]}, "title": "Data Scientist"}, {"locationName": "Bengaluru, Karnataka, India", "geoLocationName": "Bengaluru, Karnataka, India", "companyName": "Tiger Analytics", "timePeriod": {"endDate": {"month": 5, "year": 2024}, "startDate": {"month": 5, "year": 2022}}, "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Management Consulting"]}, "title": "Senior Analyst"}, {"companyName": "Wicky", "timePeriod": {"endDate": {"month": 4, "year": 2022}, "startDate": {"month": 1, "year": 2022}}, "company": {"employeeCountRange": {"start": 2, "end": 10}, "industries": ["Sports"]}, "title": "Software Engineer - MLE"}, {"locationName": "Pune, Maharashtra, India", "geoLocationName": "Pune, Maharashtra, India", "companyName": "Infosys", "timePeriod": {"endDate": {"month": 1, "year": 2022}, "startDate": {"month": 1, "year": 2022}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Senior System Engineer"}, {"locationName": "Pune, Maharashtra, India", "geoLocationName": "Pune, Maharashtra, India", "companyName": "Infosys", "timePeriod": {"endDate": {"month": 1, "year": 2022}, "startDate": {"month": 12, "year": 2019}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "System Engineer"}], "education": [{"school": {"objectUrn": "urn:li:school:478063", "entityUrn": "urn:li:fs_miniSchool:478063", "active": true, "schoolName": "BITS Pilani Work Integrated Learning Programmes", "trackingId": "rJEv7uc/R0i5OFhL57LoeA==", "logoUrl": "https://media.licdn.com/dms/image/v2/D560BAQFl6CQfOjKJkA/company-logo_"}, "timePeriod": {"endDate": {"month": 9, "year": 2022}, "startDate": {"month": 9, "year": 2021}}, "degreeName": "Post Graduate Certificate", "schoolName": "BITS Pilani Work Integrated Learning Programmes", "fieldOfStudy": "Artificial Intelligence and Machine Learning"}, {"school": {"objectUrn": "urn:li:school:213631", "entityUrn": "urn:li:fs_miniSchool:213631", "active": true, "schoolName": "Jaypee Institute of Information Technology, Noida", "trackingId": "OKzNsLtIQwOUcgxKeIoz8A=="}, "timePeriod": {"endDate": {"year": 2019}, "startDate": {"year": 2015}}, "degreeName": "Bachelor of Technology", "schoolName": "Jaypee Institute of Information Technology, Noida", "fieldOfStudy": "Electronics and Communications Engineering", "degreeUrn": "urn:li:fs_degree:250"}], "languages": [], "publications": [], "certifications": [], "projects": [], "urn_id": "ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4"}']],
#  'uris': None,
#  'data': None,
#  'included': ['documents']}
