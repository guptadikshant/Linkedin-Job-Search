# %%
import os
import json
import pandas as pd
from linkedin_api import Linkedin
import chromadb
from langchain_core.documents import Document
from chromadb.utils.embedding_functions.openai_embedding_function import OpenAIEmbeddingFunction
from dotenv import load_dotenv, find_dotenv

# %%
load_dotenv(find_dotenv())
# Out:
# True

# %%
# Authenticate using any Linkedin account credentials
api = Linkedin(
    username=os.environ["LINKEDIN_USERNAME"],
    password=os.environ["LINKEDIN_PASSWORD"]
)

# %%
SEARCH_KEYWORD = "Data Scientist"

# %%
all_peoples = api.search_people(
    keywords=SEARCH_KEYWORD,
    limit=20
)

all_peoples
# Out:
# [{'urn_id': 'ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist',
#   'location': 'Gurugram',
#   'name': 'Vidur Srivastava'},
#  {'urn_id': 'ACoAAAbvohIBhdiLqQ5FCbtA40AFvg3f-T7fKfk',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist IBM',
#   'location': 'Noida',
#   'name': 'Isha Aneja'},
#  {'urn_id': 'ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist',
#   'location': 'Noida',
#   'name': 'Tushar Mathur'},
#  {'urn_id': 'ACoAACMdmgABEKidiIRTUeY4ZC_etvTvOPPAWRA',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist at TCS',
#   'location': 'New Delhi',
#   'name': 'Shakshi Neha'},
#  {'urn_id': 'ACoAACqnIWQBi3JKxfm8FVwW8SfjZj6U2YmfUms',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist at KnowDis Data Science',
#   'location': 'India',
#   'name': 'Deepak Kumar'},
#  {'urn_id': 'ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY',
#   'distance': 'DISTANCE_2',
#   'jobtitle': "Data Scientist @ R Systems | Master's in Data Science",
#   'location': 'Gurugram',
#   'name': 'Rakesh Nain'},
#  {'urn_id': 'ACoAAA1k1eUB0Ylj--mqKdQ67o6wnie7-A5afjY',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist / AI Consultant @ IBM Consulting | ISB | INSEAD',
#   'location': 'Greater Delhi Area',
#   'name': 'Rakshit Singh'},
#  {'urn_id': 'ACoAACzqAZ8BNYEJjGPpk_l6DlwoAzZJUXVYd0Y',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist',
#   'location': 'Gurgaon',
#   'name': 'Riya Bhatnagar'},
#  {'urn_id': 'ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Looking for Data Science Opportunities | Manager - Data Scientist @ EXL | NLP | Freelancer',
#   'location': 'Gurgaon',
#   'name': 'Sumeet Kharbanda'},
#  {'urn_id': 'ACoAACbYB28BGp07ec7sQFVsqdcNnzxVsBhwScc',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist',
#   'location': 'Gurugram',
#   'name': 'Navdeep Singh'},
#  {'urn_id': 'ACoAABJ97q0BFcxSTVQ9_y1dgDAXNMpNiUtF93k',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist | IIIT Bangalore',
#   'location': 'Gurugram',
#   'name': 'Deepankar Kotnala'},
#  {'urn_id': 'ACoAACUNkNwBsZws6K44VX40ECBT3woAaJttIhQ',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist at Wipro | Generative AI & Data Science | Conversational AI | NLP | Chatbot | Free lancer',
#   'location': 'Hyderabad',
#   'name': 'Rajesh Venaganti'},
#  {'urn_id': 'ACoAABBPpTkBE83UntVzca-RXL5ggcsfztv9RRs',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist',
#   'location': 'Delhi, India',
#   'name': 'Manjit Singh'},
#  {'urn_id': 'ACoAACu4NbUBH95IDJX8ynU_hDNCiu4uWC3F4qI',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist at Piramal Finance',
#   'location': 'North Delhi',
#   'name': 'Abhishek Gupta'},
#  {'urn_id': 'ACoAACA43R8Buv3_11zWBpYvQ0u3_u_S89F3Clc',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist',
#   'location': 'Gurugram',
#   'name': 'Ajay Anand Verma'},
#  {'urn_id': 'ACoAACuf0GEBxqLlm79WsFe0eagVOHzxvQhltaA',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data scientist | AI | ML | DL',
#   'location': 'Gurugram',
#   'name': 'Nishchay S.'},
#  {'urn_id': 'ACoAABIURlEB0IaIlQL8yLwChwLnQFDTIiBtFbY',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist | AI | ML | Python | SQL | Automation | Analytics | Azure',
#   'location': 'Faridabad',
#   'name': 'Sushant Khandelwal'},
#  {'urn_id': 'ACoAAA_8N7UBcb426isJoolyZrF0Lgh2oyOZbcc',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist/Principal at Gartner',
#   'location': 'Gurgaon',
#   'name': 'Puneet Aggarwal'},
#  {'urn_id': 'ACoAABr-5jIB9VLlcHDFacNUqBWr7BWroxPEhRI',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist at TCS',
#   'location': 'Delhi, India',
#   'name': 'Sagar Narula'},
#  {'urn_id': 'ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w',
#   'distance': 'DISTANCE_2',
#   'jobtitle': 'Data Scientist | IIT Kharagpur',
#   'location': 'New Delhi',
#   'name': 'Tushar Singh Soam'}]

# %%
all_peoples_df = pd.DataFrame(all_peoples)

all_peoples_df
# Out:
#                                      urn_id    distance  \
# 0   ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4  DISTANCE_2
# 1   ACoAAAbvohIBhdiLqQ5FCbtA40AFvg3f-T7fKfk  DISTANCE_2
# 2   ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY  DISTANCE_2
# 3   ACoAACMdmgABEKidiIRTUeY4ZC_etvTvOPPAWRA  DISTANCE_2
# 4   ACoAACqnIWQBi3JKxfm8FVwW8SfjZj6U2YmfUms  DISTANCE_2
# 5   ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY  DISTANCE_2
# 6   ACoAAA1k1eUB0Ylj--mqKdQ67o6wnie7-A5afjY  DISTANCE_2
# 7   ACoAACzqAZ8BNYEJjGPpk_l6DlwoAzZJUXVYd0Y  DISTANCE_2
# 8   ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0  DISTANCE_2
# 9   ACoAACbYB28BGp07ec7sQFVsqdcNnzxVsBhwScc  DISTANCE_2
# 10  ACoAABJ97q0BFcxSTVQ9_y1dgDAXNMpNiUtF93k  DISTANCE_2
# 11  ACoAACUNkNwBsZws6K44VX40ECBT3woAaJttIhQ  DISTANCE_2
# 12  ACoAABBPpTkBE83UntVzca-RXL5ggcsfztv9RRs  DISTANCE_2
# 13  ACoAACu4NbUBH95IDJX8ynU_hDNCiu4uWC3F4qI  DISTANCE_2
# 14  ACoAACA43R8Buv3_11zWBpYvQ0u3_u_S89F3Clc  DISTANCE_2
# 15  ACoAACuf0GEBxqLlm79WsFe0eagVOHzxvQhltaA  DISTANCE_2
# 16  ACoAABIURlEB0IaIlQL8yLwChwLnQFDTIiBtFbY  DISTANCE_2
# 17  ACoAAA_8N7UBcb426isJoolyZrF0Lgh2oyOZbcc  DISTANCE_2
# 18  ACoAABr-5jIB9VLlcHDFacNUqBWr7BWroxPEhRI  DISTANCE_2
# 19  ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w  DISTANCE_2
#
#                                              jobtitle            location  \
# 0                                      Data Scientist            Gurugram
# 1                                  Data Scientist IBM               Noida
# 2                                      Data Scientist               Noida
# 3                               Data Scientist at TCS           New Delhi
# 4              Data Scientist at KnowDis Data Science               India
# 5   Data Scientist @ R Systems | Master's in Data ...            Gurugram
# 6   Data Scientist / AI Consultant @ IBM Consultin...  Greater Delhi Area
# 7                                      Data Scientist             Gurgaon
# 8   Looking for Data Science Opportunities | Manag...             Gurgaon
# 9                                      Data Scientist            Gurugram
# 10                    Data Scientist | IIIT Bangalore            Gurugram
# 11  Data Scientist at Wipro | Generative AI & Data...           Hyderabad
# 12                                     Data Scientist        Delhi, India
# 13                  Data Scientist at Piramal Finance         North Delhi
# 14                                     Data Scientist            Gurugram
# 15                      Data scientist | AI | ML | DL            Gurugram
# 16  Data Scientist | AI | ML | Python | SQL | Auto...           Faridabad
# 17                Data Scientist/Principal at Gartner             Gurgaon
# 18                              Data Scientist at TCS        Delhi, India
# 19                     Data Scientist | IIT Kharagpur           New Delhi
#
#                   name
# 0     Vidur Srivastava
# 1           Isha Aneja
# 2        Tushar Mathur
# 3         Shakshi Neha
# 4         Deepak Kumar
# 5          Rakesh Nain
# 6        Rakshit Singh
# 7       Riya Bhatnagar
# 8     Sumeet Kharbanda
# 9        Navdeep Singh
# 10   Deepankar Kotnala
# 11    Rajesh Venaganti
# 12        Manjit Singh
# 13      Abhishek Gupta
# 14    Ajay Anand Verma
# 15         Nishchay S.
# 16  Sushant Khandelwal
# 17     Puneet Aggarwal
# 18        Sagar Narula
# 19   Tushar Singh Soam

# %%
people_urn_ids = []
for row, col in all_peoples_df.iterrows():
    people_urn_ids.append(col["urn_id"])

people_urn_ids
# Out:
# ['ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4',
#  'ACoAAAbvohIBhdiLqQ5FCbtA40AFvg3f-T7fKfk',
#  'ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY',
#  'ACoAACMdmgABEKidiIRTUeY4ZC_etvTvOPPAWRA',
#  'ACoAACqnIWQBi3JKxfm8FVwW8SfjZj6U2YmfUms',
#  'ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY',
#  'ACoAAA1k1eUB0Ylj--mqKdQ67o6wnie7-A5afjY',
#  'ACoAACzqAZ8BNYEJjGPpk_l6DlwoAzZJUXVYd0Y',
#  'ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0',
#  'ACoAACbYB28BGp07ec7sQFVsqdcNnzxVsBhwScc',
#  'ACoAABJ97q0BFcxSTVQ9_y1dgDAXNMpNiUtF93k',
#  'ACoAACUNkNwBsZws6K44VX40ECBT3woAaJttIhQ',
#  'ACoAABBPpTkBE83UntVzca-RXL5ggcsfztv9RRs',
#  'ACoAACu4NbUBH95IDJX8ynU_hDNCiu4uWC3F4qI',
#  'ACoAACA43R8Buv3_11zWBpYvQ0u3_u_S89F3Clc',
#  'ACoAACuf0GEBxqLlm79WsFe0eagVOHzxvQhltaA',
#  'ACoAABIURlEB0IaIlQL8yLwChwLnQFDTIiBtFbY',
#  'ACoAAA_8N7UBcb426isJoolyZrF0Lgh2oyOZbcc',
#  'ACoAABr-5jIB9VLlcHDFacNUqBWr7BWroxPEhRI',
#  'ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w']

# %%
from collections import defaultdict

peoples_profiles: dict[str, list] = defaultdict(list)

for urn_id in people_urn_ids:
    try:
        profile_details = api.get_profile(urn_id=urn_id)
        skills = api.get_profile_skills(urn_id=urn_id)
        peoples_profiles[urn_id].append(
            {
                "profile_details": profile_details,
                "skills": skills
            }
        )
    except KeyError:
        continue

peoples_profiles
# Out:
# defaultdict(list,
#             {'ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4': [{'profile_details': {'summary': 'Experienced data scientist with a track record of translating complex data into actionable insights across diverse sectors spanning FMCG, Sports and Supply Chain.',
#                 'industryName': 'Information Technology & Services',
#                 'lastName': 'Srivastava',
#                 'locationName': 'India',
#                 'student': False,
#                 'geoCountryName': 'India',
#                 'geoCountryUrn': 'urn:li:fs_geo:102713980',
#                 'geoLocationBackfilled': False,
#                 'elt': False,
#                 'industryUrn': 'urn:li:fs_industry:96',
#                 'firstName': 'Vidur',
#                 'entityUrn': 'urn:li:fs_profile:ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4',
#                 'geoLocation': {'geoUrn': 'urn:li:fs_geo:115884833'},
#                 'geoLocationName': 'Gurugram, Haryana',
#                 'location': {'basicLocation': {'countryCode': 'in'}},
#                 'headline': 'Data Scientist',
#                 'displayPictureUrl': 'https://media.licdn.com/dms/image/v2/D4D03AQG459-q4wJe2A/profile-displayphoto-shrink_',
#                 'img_100_100': '100_100/profile-displayphoto-shrink_100_100/0/1691662091391?e=1731542400&v=beta&t=UW5l4aGCvzEEvxaQvme2dz3arzpUZ0ssKWsS-BvQWhM',
#                 'img_200_200': '200_200/profile-displayphoto-shrink_200_200/0/1691662091391?e=1731542400&v=beta&t=ZikQB0oJj2xz0xYGN-c1oM-5YBCH7TWIKZWD5r2zR6w',
#                 'img_400_400': '400_400/profile-displayphoto-shrink_400_400/0/1691662091391?e=1731542400&v=beta&t=SZwgxwc-IV8y_imwzjnkK25TyS9wykk6OJuV60Lp3Xo',
#                 'img_800_800': '800_800/profile-displayphoto-shrink_800_800/0/1691662091391?e=1731542400&v=beta&t=0D3NqLMC8SvYYNUG5Z4w_w3XiEvcNMT0H0BP7gXcXaQ',
#                 'profile_id': 'ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4',
#                 'profile_urn': 'urn:li:fs_miniProfile:ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4',
#                 'member_urn': 'urn:li:member:585180053',
#                 'public_id': 'vidur-srivastava-a45b85143',
#                 'experience': [{'locationName': 'Gurugram, Haryana, India',
#                   'entityUrn': 'urn:li:fs_position:(ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4,2429449395)',
#                   'geoLocationName': 'Gurugram, Haryana, India',
#                   'geoUrn': 'urn:li:fs_geo:115884833',
#                   'companyName': 'Tredence Inc.',
#                   'timePeriod': {'startDate': {'month': 7, 'year': 2024}},
#                   'company': {'employeeCountRange': {'start': 1001,
#                     'end': 5000},
#                    'industries': ['Management Consulting']},
#                   'title': 'Data Scientist',
#                   'region': 'urn:li:fs_region:(in,0)',
#                   'companyUrn': 'urn:li:fs_miniCompany:5208967',
#                   'companyLogoUrl': 'https://media.licdn.com/dms/image/v2/D560BAQHN5ybYDC4z2Q/company-logo_'},
#                  {'locationName': 'Bengaluru, Karnataka, India',
#                   'entityUrn': 'urn:li:fs_position:(ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4,1959401568)',
#                   'geoLocationName': 'Bengaluru, Karnataka, India',
#                   'geoUrn': 'urn:li:fs_geo:105214831',
#                   'companyName': 'Tiger Analytics',
#                   'timePeriod': {'endDate': {'month': 5, 'year': 2024},
#                    'startDate': {'month': 5, 'year': 2022}},
#                   'company': {'employeeCountRange': {'start': 1001,
#                     'end': 5000},
#                    'industries': ['Management Consulting']},
#                   'title': 'Senior Analyst',
#                   'region': 'urn:li:fs_region:(in,0)',
#                   'companyUrn': 'urn:li:fs_miniCompany:2010798',
#                   'companyLogoUrl': 'https://media.licdn.com/dms/image/v2/D4D0BAQE2M3YNGvX6Qg/company-logo_'},
#                  {'entityUrn': 'urn:li:fs_position:(ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4,1902263993)',
#                   'companyName': 'Wicky',
#                   'timePeriod': {'endDate': {'month': 4, 'year': 2022},
#                    'startDate': {'month': 1, 'year': 2022}},
#                   'company': {'employeeCountRange': {'start': 2, 'end': 10},
#                    'industries': ['Sports']},
#                   'title': 'Software Engineer - MLE',
#                   'companyUrn': 'urn:li:fs_miniCompany:42283060',
#                   'companyLogoUrl': 'https://media.licdn.com/dms/image/v2/C560BAQGi2Phmi7E1uQ/company-logo_'},
#                  {'locationName': 'Pune, Maharashtra, India',
#                   'entityUrn': 'urn:li:fs_position:(ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4,1895494174)',
#                   'geoLocationName': 'Pune, Maharashtra, India',
#                   'geoUrn': 'urn:li:fs_geo:103671728',
#                   'companyName': 'Infosys',
#                   'timePeriod': {'endDate': {'month': 1, 'year': 2022},
#                    'startDate': {'month': 1, 'year': 2022}},
#                   'company': {'employeeCountRange': {'start': 10001},
#                    'industries': ['Information Technology and Services']},
#                   'title': 'Senior System Engineer',
#                   'region': 'urn:li:fs_region:(in,0)',
#                   'companyUrn': 'urn:li:fs_miniCompany:1283',
#                   'companyLogoUrl': 'https://media.licdn.com/dms/image/v2/D4D0BAQE7Zf1-vvfbUA/company-logo_'},
#                  {'locationName': 'Pune, Maharashtra, India',
#                   'entityUrn': 'urn:li:fs_position:(ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4,1847642150)',
#                   'geoLocationName': 'Pune, Maharashtra, India',
#                   'geoUrn': 'urn:li:fs_geo:103671728',
#                   'companyName': 'Infosys',
#                   'timePeriod': {'endDate': {'month': 1, 'year': 2022},
#                    'startDate': {'month': 12, 'year': 2019}},
#                   'company': {'employeeCountRange': {'start': 10001},
#                    'industries': ['Information Technology and Services']},
#                   'title': 'System Engineer',
#                   'region': 'urn:li:fs_region:(in,0)',
#                   'companyUrn': 'urn:li:fs_miniCompany:1283',
#                   'companyLogoUrl': 'https://media.licdn.com/dms/image/v2/D4D0BAQE7Zf1-vvfbUA/company-logo_'}],
#                 'education': [{'entityUrn': 'urn:li:fs_education:(ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4,747260809)',
#                   'school': {'objectUrn': 'urn:li:school:478063',
#                    'entityUrn': 'urn:li:fs_miniSchool:478063',
#                    'active': True,
#                    'schoolName': 'BITS Pilani Work Integrated Learning Programmes',
#                    'trackingId': 'S5+oZ3IATSO+UpvCjusTEw==',
#                    'logoUrl': 'https://media.licdn.com/dms/image/v2/D560BAQFl6CQfOjKJkA/company-logo_'},
#                   'timePeriod': {'endDate': {'month': 9, 'year': 2022},
#                    'startDate': {'month': 9, 'year': 2021}},
#                   'degreeName': 'Post Graduate Certificate',
#                   'schoolName': 'BITS Pilani Work Integrated Learning Programmes',
#                   'fieldOfStudy': 'Artificial Intelligence and Machine Learning',
#                   'schoolUrn': 'urn:li:fs_miniSchool:478063'},
#                  {'entityUrn': 'urn:li:fs_education:(ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4,425250635)',
#                   'school': {'objectUrn': 'urn:li:school:213631',
#                    'entityUrn': 'urn:li:fs_miniSchool:213631',
#                    'active': True,
#                    'schoolName': 'Jaypee Institute of Information Technology, Noida',
#                    'trackingId': 'ZYobDLsiR4e5YwlRqAG7tQ=='},
#                   'timePeriod': {'endDate': {'year': 2019},
#                    'startDate': {'year': 2015}},
#                   'degreeName': 'Bachelor of Technology',
#                   'schoolName': 'Jaypee Institute of Information Technology, Noida',
#                   'fieldOfStudy': 'Electronics and Communications Engineering',
#                   'degreeUrn': 'urn:li:fs_degree:250',
#                   'schoolUrn': 'urn:li:fs_miniSchool:213631'}],
#                 'languages': [],
#                 'publications': [],
#                 'certifications': [],
#                 'volunteer': [],
#                 'honors': [],
#                 'projects': [],
#                 'skills': [{'name': 'Data Mining'},
#                  {'name': 'Deep Neural Networks (DNN)'},
#                  {'name': 'Computer Architecture'},
#                  {'name': 'Optimization'}],
#                 'urn_id': 'ACoAACLhI5UB5P9yeNUgC5weJ_vgDPQFZQOanX4'},
#                'skills': [{'name': 'Data Mining'},
#                 {'name': 'Deep Neural Networks (DNN)'},
#                 {'name': 'Computer Architecture'},
#                 {'name': 'Optimization'},
#                 {'name': 'TensorFlow'},
#                 {'name': 'Apache Spark'},
#                 {'name': 'Algorithm Design'},
#                 {'name': 'Statistical Learning'},
#                 {'name': 'Unstructured Data'},
#                 {'name': 'Teamwork'},
#                 {'name': 'Problem Solving'},
#                 {'name': 'Cluster Analysis'},
#                 {'name': 'Analytical Skills'},
#                 {'name': 'Natural Language Processing (NLP)'},
#                 {'name': 'Predictive Analytics'},
#                 {'name': 'Statistical Data Analysis'},
#                 {'name': 'Statistics'},
#                 {'name': 'Python (Programming Language)',
#                  'standardizedSkillUrn': 'urn:li:fs_miniSkill:1346',
#                  'standardizedSkill': {'name': 'Python (Programming Language)',
#                   'entityUrn': 'urn:li:fs_miniSkill:1346'}},
#                 {'name': 'SQL'},
#                 {'name': 'Java'},
#                 {'name': 'Object-Oriented Programming (OOP)'},
#                 {'name': 'Machine Learning'},
#                 {'name': 'Data Visualization'},
#                 {'name': 'Cypher Query Language'},
#                 {'name': 'Pandas'},
#                 {'name': 'Transact-SQL (T-SQL)'},
#                 {'name': 'R (Programming Language)'},
#                 {'name': 'Tableau'},
#                 {'name': 'Neo4j'},
#                 {'name': 'Applied Machine Learning'},
#                 {'name': 'Regression Analysis'},
#                 {'name': 'Logistic Regression'},
#                 {'name': 'Linear Regression'}]}],
#              'ACoAAAbvohIBhdiLqQ5FCbtA40AFvg3f-T7fKfk': [{'profile_details': {'summary': 'Experience in Cognitive Computing with leverage of Machine Learning, Deep Learning, Artificial Intelligence, Natural Language Processing skills . Data driven analyst with the ability to apply ML/DL/NLP/Computer Vision Techniques and leverage algorithms to solve real world problems. Established ability in deploying effective predictive/NLP/Computer Vision models across banking/HealthCare industries to accurately forecast and deliver proven results. Strong understanding of Oracle DB and PLSQL with data migration expérience. Domain Knowledge of SupplyChain/finance/banking/Retail domain with communication skills, excellent product and process design knowledge. Domain HealthCare,Mortgage Banking, Consumer, Commercial Lending, Escrow, Loan processing and servicing, Deposits. Onsite experience (US/UK) with business domain experience in Retail and supply chain with special focus on Customer engagement and managing end-user expectations. Experience in Analysis, Design, Development, Customization, Bug fixes, Enhancement, Support and Implementation.\n\n\nData Science, Machine Learning, Deep Learning and AI technologies.Strong understanding of Databases Oracle, Progress 4GL, PLSQL. Excellent Domain Knowledge of finance/banking/Retail domain with communication skills, excellent product and process design knowledge.Strong knowledge of Data Migration and Implementation.. \n\nAreas of Expertise: Data Science Machine Learning, Deep Learning and AI technologies.\n\nWeb App - Flask, Django.\n\nDomain - Mortgage Banking,Insurance Claim Processing Money Laundering, Investment Banking, Lending, Escrow, Loan processing and servicing. Credit Cards,Healthcare\n\nDatabase - Oracle,Progress 4GL,Mongo Db\n\nLanguages - Python ,PLSQL,Progress4GL,Shell Script\n\nVersioning - SVN,Github\nCloud : IBM Cloud, AWS,AZURE,Kubernates\nOthers : Dockers,CICD\n\n\n\n\n10+ years of experience in exploring and understanding various business models in Finance,Healthcare,Retail and Supply chain domain with special focus on implementation according to client requirements.\n•\tExperience in client interaction for requirement gathering and feasibility analysis at various levels including end users, project managers, and business analysts. Possess good business acumen interacting with various 3rd parties in the same project. Onsite experience (UK) with business domain experience in Retail and supply chain with special focus on customer engagement and managing end-user expectations.',
#                 'industryName': 'Information Technology & Services',
#                 'lastName': 'Aneja',
#                 'locationName': 'India',
#                 'student': False,
#                 'geoCountryName': 'India',
#                 'geoCountryUrn': 'urn:li:fs_geo:102713980',
#                 'geoLocationBackfilled': False,
#                 'elt': False,
#                 'industryUrn': 'urn:li:fs_industry:96',
#                 'firstName': 'Isha',
#                 'entityUrn': 'urn:li:fs_profile:ACoAAAbvohIBhdiLqQ5FCbtA40AFvg3f-T7fKfk',
#                 'geoLocation': {'geoUrn': 'urn:li:fs_geo:104869687'},
#                 'geoLocationName': 'Noida, Uttar Pradesh',
#                 'location': {'basicLocation': {'countryCode': 'in'}},
#                 'headline': 'Data Scientist IBM',
#                 'displayPictureUrl': 'https://media.licdn.com/dms/image/v2/C5603AQHMwvU_9cR79w/profile-displayphoto-shrink_',
#                 'img_100_100': '100_100/profile-displayphoto-shrink_100_100/0/1516520225929?e=1731542400&v=beta&t=nRE7JgSiO2y0WI8SZxaFqryhA7uB27F9JUSRwwqM-EU',
#                 'img_200_200': '200_200/profile-displayphoto-shrink_200_200/0/1516520225931?e=1731542400&v=beta&t=qxBwS0RHAj8zJ5U8qErgQpuYc4Vqmopj20JAtHOz8Dk',
#                 'img_253_253': '800_800/profile-displayphoto-shrink_800_800/0/1516520225939?e=1731542400&v=beta&t=MK0pDwNOQmYNXZS1hxvX1-2NsHeY1lAP4O8njFxDsMs',
#                 'profile_id': 'ACoAAAbvohIBhdiLqQ5FCbtA40AFvg3f-T7fKfk',
#                 'profile_urn': 'urn:li:fs_miniProfile:ACoAAAbvohIBhdiLqQ5FCbtA40AFvg3f-T7fKfk',
#                 'member_urn': 'urn:li:member:116367890',
#                 'public_id': 'isha-aneja-642b7a32',
#                 'experience': [{'locationName': 'Noida, Uttar Pradesh, India',
#                   'entityUrn': 'urn:li:fs_position:(ACoAAAbvohIBhdiLqQ5FCbtA40AFvg3f-T7fKfk,1904314909)',
#                   'geoLocationName': 'Noida, Uttar Pradesh, India',
#                   'geoUrn': 'urn:li:fs_geo:104869687',
#                   'companyName': 'IBM',
#                   'timePeriod': {'startDate': {'month': 12, 'year': 2021}},
#                   'company': {'employeeCountRange': {'start': 10001},
#                    'industries': ['Information Technology and Services']},
#                   'title': 'Data Scientist',
#                   'region': 'urn:li:fs_region:(in,7392)',
#                   'companyUrn': 'urn:li:fs_miniCompany:1009',
#                   'companyLogoUrl': 'https://media.licdn.com/dms/image/v2/D560BAQGiz5ecgpCtkA/company-logo_'},
#                  {'locationName': 'New Delhi Area, India',
#                   'entityUrn': 'urn:li:fs_position:(ACoAAAbvohIBhdiLqQ5FCbtA40AFvg3f-T7fKfk,1419963703)',
#                   'geoLocationName': 'New Delhi Area, India',
#                   'geoUrn': 'urn:li:fs_geo:90009626',
#                   'companyName': 'Fiserv',
#                   'timePeriod': {'endDate': {'month': 1, 'year': 2022},
#                    'startDate': {'month': 12, 'year': 2017}},
#                   'company': {'employeeCountRange': {'start': 10001},
#                    'industries': ['Information Technology and Services']},
#                   'title': 'Technical Lead',
#                   'region': 'urn:li:fs_region:(in,7151)',
#                   'companyUrn': 'urn:li:fs_miniCompany:3364',
#                   'companyLogoUrl': 'https://media.licdn.com/dms/image/v2/C4E0BAQGRIlSWC39LfQ/company-logo_'},
#                  {'locationName': 'Noida Area, India',
#                   'entityUrn': 'urn:li:fs_position:(ACoAAAbvohIBhdiLqQ5FCbtA40AFvg3f-T7fKfk,1419965186)',
#                   'geoLocationName': 'Noida Area, India',
#                   'geoUrn': 'urn:li:fs_geo:104869687',
#                   'companyName': 'Birlasoft',
#                   'timePeriod': {'endDate': {'month': 12, 'year': 2017},
#                    'startDate': {'month': 8, 'year': 2016}},
#                   'company': {'employeeCountRange': {'start': 10001},
#                    'industries': ['Information Technology and Services']},
#                   'title': 'Senior Software Engineer',
#                   'region': 'urn:li:fs_region:(in,7392)',
#                   'companyUrn': 'urn:li:fs_miniCompany:4661',
#                   'companyLogoUrl': 'https://media.licdn.com/dms/image/v2/C4E0BAQFJ26tVfkJeKg/company-logo_'},
#                  {'locationName': 'banglore',
#                   'entityUrn': 'urn:li:fs_position:(ACoAAAbvohIBhdiLqQ5FCbtA40AFvg3f-T7fKfk,776024480)',
#                   'geoLocationName': 'banglore',
#                   'companyName': 'Capgemini',
#                   'timePeriod': {'endDate': {'month': 8, 'year': 2016},
#                    'startDate': {'month': 11, 'year': 2014}},
#                   'company': {'employeeCountRange': {'start': 10001},
#                    'industries': ['Information Technology and Services']},
#                   'title': 'Technical Team Lead',
#                   'companyUrn': 'urn:li:fs_miniCompany:157240',
#                   'companyLogoUrl': 'https://media.licdn.com/dms/image/v2/D4D0BAQH-ZV832H4sdA/company-logo_'},
#                  {'locationName': 'Noida Area, India',
#                   'entityUrn': 'urn:li:fs_position:(ACoAAAbvohIBhdiLqQ5FCbtA40AFvg3f-T7fKfk,773855251)',
#                   'geoLocationName': 'Noida Area, India',
#                   'geoUrn': 'urn:li:fs_geo:104869687',
#                   'companyName': 'JK Technosoft Limited.',
#                   'timePeriod': {'endDate': {'month': 10, 'year': 2014},
#                    'startDate': {'month': 9, 'year': 2011}},
#                   'company': {'employeeCountRange': {'start': 501,
#                     'end': 1000},
#                    'industries': ['Management Consulting']},
#                   'title': 'Senior Software Engineer',
#                   'region': 'urn:li:fs_region:(in,7392)',
#                   'companyUrn': 'urn:li:fs_miniCompany:164538',
#                   'companyLogoUrl': 'https://media.licdn.com/dms/image/v2/D4D0BAQFBKA9GayuWAQ/company-logo_'}],
#                 'education': [{'entityUrn': 'urn:li:fs_education:(ACoAAAbvohIBhdiLqQ5FCbtA40AFvg3f-T7fKfk,329324571)',
#                   'school': {'objectUrn': 'urn:li:school:13535',
#                    'entityUrn': 'urn:li:fs_miniSchool:13535',
#                    'active': True,
#                    'schoolName': 'Kurukshetra University',
#                    'trackingId': 'ZJUL+E5QQ/OvBX2q1F+//Q==',
#                    'logoUrl': 'https://media.licdn.com/dms/image/v2/C510BAQFk-1FhZJmk9Q/company-logo_'},
#                   'timePeriod': {'endDate': {'year': 2011},
#                    'startDate': {'year': 2008}},
#                   'degreeName': 'Masters of Computer Applications',
#                   'schoolName': 'Kurukshetra University',
#                   'fieldOfStudy': 'Computer Science',
#                   'schoolUrn': 'urn:li:fs_miniSchool:13535'},
#                  {'entityUrn': 'urn:li:fs_education:(ACoAAAbvohIBhdiLqQ5FCbtA40AFvg3f-T7fKfk,329327176)',
#                   'school': {'objectUrn': 'urn:li:school:13535',
#                    'entityUrn': 'urn:li:fs_miniSchool:13535',
#                    'active': True,
#                    'schoolName': 'Kurukshetra University',
#                    'trackingId': 'P6aYPkoyTJu2TNVflg3IlQ==',
#                    'logoUrl': 'https://media.licdn.com/dms/image/v2/C510BAQFk-1FhZJmk9Q/company-logo_'},
#                   'timePeriod': {'endDate': {'year': 2008},
#                    'startDate': {'year': 2005}},
#                   'degreeName': 'Bachelor of computer Applications',
#                   'schoolName': 'Kurukshetra University',
#                   'fieldOfStudy': 'Computer Science',
#                   'schoolUrn': 'urn:li:fs_miniSchool:13535'}],
#                 'languages': [{'name': 'English',
#                   'proficiency': 'NATIVE_OR_BILINGUAL'}],
#                 'publications': [],
#                 'certifications': [{'authority': 'IBM',
#                   'name': 'IBM Certified Advocate - Cloud v1',
#                   'timePeriod': {'startDate': {'month': 3, 'year': 2022}},
#                   'company': {'objectUrn': 'urn:li:company:1009',
#                    'entityUrn': 'urn:li:fs_miniCompany:1009',
#                    'name': 'IBM',
#                    'showcase': False,
#                    'active': True,
#                    'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#                        'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1688684715866/ibm_logo?e=1733961600&v=beta&t=_Vk-rjN25-Y4F_WLD2ZfMdU78axI8gvVG4c2s8DBJUI',
#                        'expiresAt': 1733961600000,
#                        'height': 200},
#                       {'width': 100,
#                        'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1688684715866/ibm_logo?e=1733961600&v=beta&t=5smSYYM2_he2sIHAJWOdx0sS6KPP566YeCNyyvkzjxI',
#                        'expiresAt': 1733961600000,
#                        'height': 100},
#                       {'width': 400,
#                        'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1688684715866/ibm_logo?e=1733961600&v=beta&t=ZROJUKm2uDm5LLnrn6MOSXhJe3gDhV-PvoRyf1-MF-g',
#                        'expiresAt': 1733961600000,
#                        'height': 400}],
#                      'rootUrl': 'https://media.licdn.com/dms/image/v2/D560BAQGiz5ecgpCtkA/company-logo_'}},
#                    'universalName': 'ibm',
#                    'dashCompanyUrn': 'urn:li:fsd_company:1009',
#                    'trackingId': 'CirIplzVSc6LFBxHhX6Ayw=='},
#                   'displaySource': 'credly.com',
#                   'companyUrn': 'urn:li:fs_miniCompany:1009',
#                   'url': 'https://www.credly.com/badges/843f2333-c4d2-4c85-abc6-4bf7c4eed4a1?source=linked_in_profile'},
#                  {'authority': 'expert.ai',
#                   'name': 'Expert.ai Pro',
#                   'timePeriod': {'startDate': {'month': 2, 'year': 2022}},
#                   'company': {'objectUrn': 'urn:li:company:68858659',
#                    'entityUrn': 'urn:li:fs_miniCompany:68858659',
#                    'name': 'expert.ai',
#                    'showcase': False,
#                    'active': True,
#                    'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#                        'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1630506804889/expert_ai_logo?e=1733961600&v=beta&t=Uy96LXdcdi22J6qmAGDO1ME2-VS0JafKAgXRBntV6nE',
#                        'expiresAt': 1733961600000,
#                        'height': 200},
#                       {'width': 100,
#                        'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1630506804889/expert_ai_logo?e=1733961600&v=beta&t=-dFd08m7ZTKT5AzIb7vcOW3WG9xcfGP6KqPMj6djvcM',
#                        'expiresAt': 1733961600000,
#                        'height': 100},
#                       {'width': 400,
#                        'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1630506804889/expert_ai_logo?e=1733961600&v=beta&t=FgA6JO3WkR4Sa4-ZNh4l_x74TDK5PYxsJhMaPlFgBh8',
#                        'expiresAt': 1733961600000,
#                        'height': 400}],
#                      'rootUrl': 'https://media.licdn.com/dms/image/v2/C4D0BAQGVitfEUFgxjA/company-logo_'}},
#                    'universalName': 'expert-ai',
#                    'dashCompanyUrn': 'urn:li:fsd_company:68858659',
#                    'trackingId': 'oRQuCpgSTTKBhX+TxtACeA=='},
#                   'companyUrn': 'urn:li:fs_miniCompany:68858659'},
#                  {'authority': 'IBM',
#                   'name': 'IBM Cloud Pak for Data V3.5.x Essentials',
#                   'timePeriod': {'startDate': {'month': 7, 'year': 2022}},
#                   'company': {'objectUrn': 'urn:li:company:1009',
#                    'entityUrn': 'urn:li:fs_miniCompany:1009',
#                    'name': 'IBM',
#                    'showcase': False,
#                    'active': True,
#                    'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#                        'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1688684715866/ibm_logo?e=1733961600&v=beta&t=_Vk-rjN25-Y4F_WLD2ZfMdU78axI8gvVG4c2s8DBJUI',
#                        'expiresAt': 1733961600000,
#                        'height': 200},
#                       {'width': 100,
#                        'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1688684715866/ibm_logo?e=1733961600&v=beta&t=5smSYYM2_he2sIHAJWOdx0sS6KPP566YeCNyyvkzjxI',
#                        'expiresAt': 1733961600000,
#                        'height': 100},
#                       {'width': 400,
#                        'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1688684715866/ibm_logo?e=1733961600&v=beta&t=ZROJUKm2uDm5LLnrn6MOSXhJe3gDhV-PvoRyf1-MF-g',
#                        'expiresAt': 1733961600000,
#                        'height': 400}],
#                      'rootUrl': 'https://media.licdn.com/dms/image/v2/D560BAQGiz5ecgpCtkA/company-logo_'}},
#                    'universalName': 'ibm',
#                    'dashCompanyUrn': 'urn:li:fsd_company:1009',
#                    'trackingId': 'hbcu98Y5SEGItF9/E0YngA=='},
#                   'displaySource': 'credly.com',
#                   'companyUrn': 'urn:li:fs_miniCompany:1009',
#                   'url': 'https://www.credly.com/badges/eb36b27f-0254-4839-9e2f-3cbaf84e39cf?source=linked_in_profile'},
#                  {'authority': 'IBM',
#                   'name': 'IBM Cloud Pak for Data V3.5.x Data Science',
#                   'timePeriod': {'startDate': {'month': 7, 'year': 2022}},
#                   'company': {'objectUrn': 'urn:li:company:1009',
#                    'entityUrn': 'urn:li:fs_miniCompany:1009',
#                    'name': 'IBM',
#                    'showcase': False,
#                    'active': True,
#                    'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#                        'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1688684715866/ibm_logo?e=1733961600&v=beta&t=_Vk-rjN25-Y4F_WLD2ZfMdU78axI8gvVG4c2s8DBJUI',
#                        'expiresAt': 1733961600000,
#                        'height': 200},
#                       {'width': 100,
#                        'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1688684715866/ibm_logo?e=1733961600&v=beta&t=5smSYYM2_he2sIHAJWOdx0sS6KPP566YeCNyyvkzjxI',
#                        'expiresAt': 1733961600000,
#                        'height': 100},
#                       {'width': 400,
#                        'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1688684715866/ibm_logo?e=1733961600&v=beta&t=ZROJUKm2uDm5LLnrn6MOSXhJe3gDhV-PvoRyf1-MF-g',
#                        'expiresAt': 1733961600000,
#                        'height': 400}],
#                      'rootUrl': 'https://media.licdn.com/dms/image/v2/D560BAQGiz5ecgpCtkA/company-logo_'}},
#                    'universalName': 'ibm',
#                    'dashCompanyUrn': 'urn:li:fsd_company:1009',
#                    'trackingId': 'vtOoaTntSF+FyYFlX1g3XA=='},
#                   'displaySource': 'credly.com',
#                   'companyUrn': 'urn:li:fs_miniCompany:1009',
#                   'url': 'https://www.credly.com/badges/6ba941b7-b8f2-41fd-a7f3-7c790d24dbe4?source=linked_in_profile'},
#                  {'authority': 'Amazon Web Services (AWS)',
#                   'name': 'AWS Certified Cloud Practitioner',
#                   'timePeriod': {'endDate': {'month': 8, 'year': 2025},
#                    'startDate': {'month': 8, 'year': 2022}},
#                   'company': {'objectUrn': 'urn:li:company:2382910',
#                    'entityUrn': 'urn:li:fs_miniCompany:2382910',
#                    'name': 'Amazon Web Services (AWS)',
#                    'showcase': False,
#                    'active': True,
#                    'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#                        'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1670264051233/amazon_web_services_logo?e=1733961600&v=beta&t=sZrrylMwfmfvJPk0hPuo8CHP_7pPLURDXgFRkzLCvU8',
#                        'expiresAt': 1733961600000,
#                        'height': 200},
#                       {'width': 100,
#                        'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1670264051233/amazon_web_services_logo?e=1733961600&v=beta&t=Jht9xPi2isK65slZ4sxhyrtnHE_8WKhn9S1xaLc9-68',
#                        'expiresAt': 1733961600000,
#                        'height': 100},
#                       {'width': 400,
#                        'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1670264051233/amazon_web_services_logo?e=1733961600&v=beta&t=lmQNwMmbQB53-J2MlHwnF1BVb93xt6EEHx9d5qzXlvk',
#                        'expiresAt': 1733961600000,
#                        'height': 400}],
#                      'rootUrl': 'https://media.licdn.com/dms/image/v2/C560BAQER_QnUTXrPJw/company-logo_'}},
#                    'universalName': 'amazon-web-services',
#                    'dashCompanyUrn': 'urn:li:fsd_company:2382910',
#                    'trackingId': 'TPRDfwvXQ9aHK2csNbmFNg=='},
#                   'displaySource': 'credly.com',
#                   'companyUrn': 'urn:li:fs_miniCompany:2382910',
#                   'url': 'https://www.credly.com/badges/df130182-bad3-4e88-bb04-a3c0738e1f8d/linked_in_profile'},
#                  {'authority': 'Amazon Web Services (AWS)',
#                   'name': 'AWS Certified Machine Learning – Specialty',
#                   'timePeriod': {'endDate': {'month': 9, 'year': 2025},
#                    'startDate': {'month': 9, 'year': 2022}},
#                   'company': {'objectUrn': 'urn:li:company:2382910',
#                    'entityUrn': 'urn:li:fs_miniCompany:2382910',
#                    'name': 'Amazon Web Services (AWS)',
#                    'showcase': False,
#                    'active': True,
#                    'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#                        'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1670264051233/amazon_web_services_logo?e=1733961600&v=beta&t=sZrrylMwfmfvJPk0hPuo8CHP_7pPLURDXgFRkzLCvU8',
#                        'expiresAt': 1733961600000,
#                        'height': 200},
#                       {'width': 100,
#                        'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1670264051233/amazon_web_services_logo?e=1733961600&v=beta&t=Jht9xPi2isK65slZ4sxhyrtnHE_8WKhn9S1xaLc9-68',
#                        'expiresAt': 1733961600000,
#                        'height': 100},
#                       {'width': 400,
#                        'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1670264051233/amazon_web_services_logo?e=1733961600&v=beta&t=lmQNwMmbQB53-J2MlHwnF1BVb93xt6EEHx9d5qzXlvk',
#                        'expiresAt': 1733961600000,
#                        'height': 400}],
#                      'rootUrl': 'https://media.licdn.com/dms/image/v2/C560BAQER_QnUTXrPJw/company-logo_'}},
#                    'universalName': 'amazon-web-services',
#                    'dashCompanyUrn': 'urn:li:fsd_company:2382910',
#                    'trackingId': 'VheIUg1VT8m7/oYMottX7w=='},
#                   'displaySource': 'credly.com',
#                   'companyUrn': 'urn:li:fs_miniCompany:2382910',
#                   'url': 'https://www.credly.com/badges/5e1d64eb-9106-4205-9b80-380e2cab0023/linked_in_profile'},
#                  {'authority': 'Microsoft',
#                   'name': 'Microsoft Certified: Azure AI Engineer Associate',
#                   'timePeriod': {'endDate': {'month': 9, 'year': 2024},
#                    'startDate': {'month': 9, 'year': 2023}},
#                   'licenseNumber': '4C3C15CAB831C53E',
#                   'company': {'objectUrn': 'urn:li:company:1035',
#                    'entityUrn': 'urn:li:fs_miniCompany:1035',
#                    'name': 'Microsoft',
#                    'showcase': False,
#                    'active': True,
#                    'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#                        'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1630652622688/microsoft_logo?e=1733961600&v=beta&t=Dyvq5VWIA7GpPMfM8aayOcZF3Ubgo4326YZ8HS91a34',
#                        'expiresAt': 1733961600000,
#                        'height': 200},
#                       {'width': 100,
#                        'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1630652622688/microsoft_logo?e=1733961600&v=beta&t=l2Y9wEBC8e-SdtTFOALTv0L3p01YeUBvJXfaLoRVTkc',
#                        'expiresAt': 1733961600000,
#                        'height': 100},
#                       {'width': 400,
#                        'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1630652622688/microsoft_logo?e=1733961600&v=beta&t=s2FRdZW5_FA97TqvmjIQ_EEueRPZGrgzKjJtxtNdPtE',
#                        'expiresAt': 1733961600000,
#                        'height': 400}],
#                      'rootUrl': 'https://media.licdn.com/dms/image/v2/C560BAQE88xCsONDULQ/company-logo_'}},
#                    'universalName': 'microsoft',
#                    'dashCompanyUrn': 'urn:li:fsd_company:1035',
#                    'trackingId': 'AfNzdP2jQ2WUIQj6DRkxmg=='},
#                   'displaySource': 'microsoft.com',
#                   'companyUrn': 'urn:li:fs_miniCompany:1035',
#                   'url': 'https://learn.microsoft.com/api/credentials/share/en-us/IshaIsha-1778/4C3C15CAB831C53E?sharingId'},
#                  {'authority': 'Microsoft',
#                   'name': 'Microsoft Certified: Azure Data Scientist Associate',
#                   'timePeriod': {'endDate': {'month': 9, 'year': 2024},
#                    'startDate': {'month': 9, 'year': 2023}},
#                   'licenseNumber': '962F38933DAC4393',
#                   'company': {'objectUrn': 'urn:li:company:1035',
#                    'entityUrn': 'urn:li:fs_miniCompany:1035',
#                    'name': 'Microsoft',
#                    'showcase': False,
#                    'active': True,
#                    'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#                        'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1630652622688/microsoft_logo?e=1733961600&v=beta&t=Dyvq5VWIA7GpPMfM8aayOcZF3Ubgo4326YZ8HS91a34',
#                        'expiresAt': 1733961600000,
#                        'height': 200},
#                       {'width': 100,
#                        'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1630652622688/microsoft_logo?e=1733961600&v=beta&t=l2Y9wEBC8e-SdtTFOALTv0L3p01YeUBvJXfaLoRVTkc',
#                        'expiresAt': 1733961600000,
#                        'height': 100},
#                       {'width': 400,
#                        'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1630652622688/microsoft_logo?e=1733961600&v=beta&t=s2FRdZW5_FA97TqvmjIQ_EEueRPZGrgzKjJtxtNdPtE',
#                        'expiresAt': 1733961600000,
#                        'height': 400}],
#                      'rootUrl': 'https://media.licdn.com/dms/image/v2/C560BAQE88xCsONDULQ/company-logo_'}},
#                    'universalName': 'microsoft',
#                    'dashCompanyUrn': 'urn:li:fsd_company:1035',
#                    'trackingId': 'h7GdNnMESSObehniyNmElA=='},
#                   'displaySource': 'microsoft.com',
#                   'companyUrn': 'urn:li:fs_miniCompany:1035',
#                   'url': 'https://learn.microsoft.com/api/credentials/share/en-us/IshaIsha-1778/962F38933DAC4393?sharingId'},
#                  {'authority': 'IBM',
#                   'name': 'Healthcare Insights and Solutions (Silver)',
#                   'timePeriod': {'startDate': {'month': 5, 'year': 2024}},
#                   'company': {'objectUrn': 'urn:li:company:1009',
#                    'entityUrn': 'urn:li:fs_miniCompany:1009',
#                    'name': 'IBM',
#                    'showcase': False,
#                    'active': True,
#                    'logo': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 200,
#                        'fileIdentifyingUrlPathSegment': '200_200/company-logo_200_200/0/1688684715866/ibm_logo?e=1733961600&v=beta&t=_Vk-rjN25-Y4F_WLD2ZfMdU78axI8gvVG4c2s8DBJUI',
#                        'expiresAt': 1733961600000,
#                        'height': 200},
#                       {'width': 100,
#                        'fileIdentifyingUrlPathSegment': '100_100/company-logo_100_100/0/1688684715866/ibm_logo?e=1733961600&v=beta&t=5smSYYM2_he2sIHAJWOdx0sS6KPP566YeCNyyvkzjxI',
#                        'expiresAt': 1733961600000,
#                        'height': 100},
#                       {'width': 400,
#                        'fileIdentifyingUrlPathSegment': '400_400/company-logo_400_400/0/1688684715866/ibm_logo?e=1733961600&v=beta&t=ZROJUKm2uDm5LLnrn6MOSXhJe3gDhV-PvoRyf1-MF-g',
#                        'expiresAt': 1733961600000,
#                        'height': 400}],
#                      'rootUrl': 'https://media.licdn.com/dms/image/v2/D560BAQGiz5ecgpCtkA/company-logo_'}},
#                    'universalName': 'ibm',
#                    'dashCompanyUrn': 'urn:li:fsd_company:1009',
#                    'trackingId': 'usHmMzxaQ2SRWBi8hovu3w=='},
#                   'displaySource': 'credly.com',
#                   'companyUrn': 'urn:li:fs_miniCompany:1009',
#                   'url': 'https://www.credly.com/badges/2bfd8fc7-f794-4b1a-b6b1-484dcd653fb0/linked_in_profile'}],
#                 'volunteer': [],
#                 'honors': [],
#                 'projects': [],
#                 'skills': [{'name': 'Python (Programming Language)',
#                   'standardizedSkillUrn': 'urn:li:fs_miniSkill:1346',
#                   'standardizedSkill': {'name': 'Python (Programming Language)',
#                    'entityUrn': 'urn:li:fs_miniSkill:1346'}},
#                  {'name': 'Machine Learning Algorithms'},
#                  {'name': 'PL/SQL'},
#                  {'name': 'Agile Methodologies'}],
#                 'urn_id': 'ACoAAAbvohIBhdiLqQ5FCbtA40AFvg3f-T7fKfk'},
#                'skills': [{'name': 'Python (Programming Language)',
#                  'standardizedSkillUrn': 'urn:li:fs_miniSkill:1346',
#                  'standardizedSkill': {'name': 'Python (Programming Language)',
#                   'entityUrn': 'urn:li:fs_miniSkill:1346'}},
#                 {'name': 'Machine Learning Algorithms'},
#                 {'name': 'PL/SQL'},
#                 {'name': 'Agile Methodologies'},
#                 {'name': 'Software Development'},
#                 {'name': 'Shell Scripting'},
#                 {'name': 'Requirements Analysis'},
#                 {'name': 'Data Analysis',
#                  'standardizedSkillUrn': 'urn:li:fs_miniSkill:2470',
#                  'standardizedSkill': {'name': 'Data Analysis',
#                   'entityUrn': 'urn:li:fs_miniSkill:2470'}},
#                 {'name': 'Artificial Intelligence (AI)',
#                  'standardizedSkillUrn': 'urn:li:fs_miniSkill:2407',
#                  'standardizedSkill': {'name': 'Artificial Intelligence (AI)',
#                   'entityUrn': 'urn:li:fs_miniSkill:2407'}},
#                 {'name': 'Machine Learning',
#                  'standardizedSkillUrn': 'urn:li:fs_miniSkill:3289',
#                  'standardizedSkill': {'name': 'Machine Learning',
#                   'entityUrn': 'urn:li:fs_miniSkill:3289'}},
#                 {'name': 'Deep Learning'},
#                 {'name': 'Oracle SQL Developer'},
#                 {'name': 'Core Java'},
#                 {'name': 'Unix'},
#                 {'name': 'Linux'},
#                 {'name': 'Progress 4GL'},
#                 {'name': 'pl'},
#                 {'name': 'Artificial Neural Networks'},
#                 {'name': 'Character User Interface,Progress'},
#                 {'name': 'Predictive Modeling'},
#                 {'name': 'Neural Networks'},
#                 {'name': 'TensorFlow'},
#                 {'name': 'SQL'},
#                 {'name': 'Data Science'},
#                 {'name': 'Computer Vision'}]}],
#              'ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY': [{'profile_details': {'summary': 'Experience Data Science professional with demonstrated history of working in IT service industry. Experienced in executing data driven solutions to increase efficiency, accuracy and utility of internal data processing. Skilled in natural language processing with practioner knowledge on Web Analytics. Strong information technology professional with a Bachelor of Technology (BTech) from Uttar Pradesh Technical University. ',
#                 'industryName': 'Information Technology & Services',
#                 'lastName': 'Mathur',
#                 'locationName': 'India',
#                 'student': False,
#                 'geoCountryName': 'India',
#                 'geoCountryUrn': 'urn:li:fs_geo:102713980',
#                 'geoLocationBackfilled': False,
#                 'elt': False,
#                 'industryUrn': 'urn:li:fs_industry:96',
#                 'firstName': 'Tushar',
#                 'entityUrn': 'urn:li:fs_profile:ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY',
#                 'geoLocation': {'geoUrn': 'urn:li:fs_geo:104869687'},
#                 'geoLocationName': 'Noida, Uttar Pradesh',
#                 'location': {'basicLocation': {'countryCode': 'in'}},
#                 'headline': 'Data Scientist',
#                 'displayPictureUrl': 'https://media.licdn.com/dms/image/v2/C5603AQHkWw6rLa4ikw/profile-displayphoto-shrink_',
#                 'img_100_100': '100_100/profile-displayphoto-shrink_100_100/0/1627636616827?e=1731542400&v=beta&t=xBSzo2gPa3OIABP27O-2bQNgaHmCmTMPtrdiV-6Tyb0',
#                 'img_200_200': '200_200/profile-displayphoto-shrink_200_200/0/1627636616827?e=1731542400&v=beta&t=jhoAjgmtVAfxkVaQwlF8JcaZ9M7EIlRF8dCk3R2ciPM',
#                 'img_400_400': '400_400/profile-displayphoto-shrink_400_400/0/1627636616827?e=1731542400&v=beta&t=KQrUkcFtCnf7n1ww5B6WZdCdTzrYee--ZQ2JAPPmodY',
#                 'img_413_413': '800_800/profile-displayphoto-shrink_800_800/0/1627636616827?e=1731542400&v=beta&t=622aY-HtcQSxqycM6kkJLZJgkr1xzh3_7jhWSE28UXg',
#                 'profile_id': 'ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY',
#                 'profile_urn': 'urn:li:fs_miniProfile:ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY',
#                 'member_urn': 'urn:li:member:72226342',
#                 'public_id': 'tushar-mathur-79a23120',
#                 'experience': [{'locationName': 'Noida, Uttar Pradesh, India',
#                   'entityUrn': 'urn:li:fs_position:(ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY,2056746012)',
#                   'geoLocationName': 'Noida, Uttar Pradesh, India',
#                   'geoUrn': 'urn:li:fs_geo:104869687',
#                   'companyName': 'Coforge',
#                   'timePeriod': {'startDate': {'month': 8, 'year': 2022}},
#                   'company': {'employeeCountRange': {'start': 10001},
#                    'industries': ['Information Technology and Services']},
#                   'title': 'Analytics Lead',
#                   'region': 'urn:li:fs_region:(in,7392)',
#                   'companyUrn': 'urn:li:fs_miniCompany:31537981',
#                   'companyLogoUrl': 'https://media.licdn.com/dms/image/v2/D4E0BAQFCnpNRw6_ETA/company-logo_'},
#                  {'locationName': 'Noida, Uttar Pradesh, India',
#                   'entityUrn': 'urn:li:fs_position:(ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY,1816865031)',
#                   'geoLocationName': 'Noida, Uttar Pradesh, India',
#                   'geoUrn': 'urn:li:fs_geo:104869687',
#                   'companyName': 'EXL',
#                   'timePeriod': {'endDate': {'month': 8, 'year': 2022},
#                    'startDate': {'month': 8, 'year': 2021}},
#                   'company': {'employeeCountRange': {'start': 10001},
#                    'industries': ['Information Technology and Services']},
#                   'title': 'Technical Lead',
#                   'region': 'urn:li:fs_region:(in,7392)',
#                   'companyUrn': 'urn:li:fs_miniCompany:163743',
#                   'companyLogoUrl': 'https://media.licdn.com/dms/image/v2/D4E0BAQHZga8kSwpMTQ/company-logo_'},
#                  {'locationName': 'Noida Area, India',
#                   'entityUrn': 'urn:li:fs_position:(ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY,1495024176)',
#                   'geoLocationName': 'Noida Area, India',
#                   'geoUrn': 'urn:li:fs_geo:104869687',
#                   'companyName': 'Sopra Steria',
#                   'timePeriod': {'endDate': {'month': 7, 'year': 2021},
#                    'startDate': {'month': 7, 'year': 2019}},
#                   'description': 'Working on information extraction project in which we focuses on creating structured representation of unstructured/structured texts by extracting relevant entities from them, using machine learning and AI process thereby making the data analysis realizable.',
#                   'company': {'employeeCountRange': {'start': 10001},
#                    'industries': ['Information Technology and Services']},
#                   'title': 'Module Lead',
#                   'region': 'urn:li:fs_region:(in,7392)',
#                   'companyUrn': 'urn:li:fs_miniCompany:3054',
#                   'companyLogoUrl': 'https://media.licdn.com/dms/image/v2/D4E0BAQF_0JqR2CRpJw/company-logo_'},
#                  {'locationName': 'Noida Area, India',
#                   'entityUrn': 'urn:li:fs_position:(ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY,1166641314)',
#                   'geoLocationName': 'Noida Area, India',
#                   'geoUrn': 'urn:li:fs_geo:104869687',
#                   'companyName': 'Sopra Steria',
#                   'timePeriod': {'endDate': {'month': 6, 'year': 2019},
#                    'startDate': {'month': 10, 'year': 2017}},
#                   'company': {'employeeCountRange': {'start': 10001},
#                    'industries': ['Information Technology and Services']},
#                   'title': 'Senior Software Engineer',
#                   'region': 'urn:li:fs_region:(in,7392)',
#                   'companyUrn': 'urn:li:fs_miniCompany:3054',
#                   'honors': ['urn:li:fs_honor:(ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY,1097608354)'],
#                   'companyLogoUrl': 'https://media.licdn.com/dms/image/v2/D4E0BAQF_0JqR2CRpJw/company-logo_'},
#                  {'locationName': 'Gurgaon, India',
#                   'entityUrn': 'urn:li:fs_position:(ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY,862996743)',
#                   'geoLocationName': 'Gurgaon, India',
#                   'companyName': 'Infosys',
#                   'timePeriod': {'endDate': {'month': 10, 'year': 2017},
#                    'startDate': {'month': 10, 'year': 2016}},
# ...
#                   'title': 'Professional Freelancer',
#                   'companyUrn': 'urn:li:fs_miniCompany:861427',
#                   'companyLogoUrl': 'https://media.licdn.com/dms/image/v2/C4D0BAQFHz9agyy675A/company-logo_'},
#                  {'locationName': 'Bengaluru Area, India',
#                   'entityUrn': 'urn:li:fs_position:(ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w,1058271989)',
#                   'geoLocationName': 'Bengaluru Area, India',
#                   'geoUrn': 'urn:li:fs_geo:105307040',
#                   'companyName': 'Wipro Limited',
#                   'timePeriod': {'endDate': {'month': 7, 'year': 2018},
#                    'startDate': {'month': 7, 'year': 2017}},
#                   'description': 'Topic: Use of Computer Vision Algorithms for conversion of Engineering Drawings into Structured Digital Data\n•Developed an object detection algorithm for tables in drawings using morphological transformations with precision ~99% in C++\n•Built an image processing algorithm to convert simple tables into excel tables using Optical Character Recognition in OpenCV\n•Designed an algorithm to classify tables as simple or complex based on the alignment of vertical and horizontal lines of the table',
#                   'company': {'employeeCountRange': {'start': 10001},
#                    'industries': ['Information Technology and Services']},
#                   'title': 'Project Engineer',
#                   'region': 'urn:li:fs_region:(in,7127)',
#                   'companyUrn': 'urn:li:fs_miniCompany:1318',
#                   'companyLogoUrl': 'https://media.licdn.com/dms/image/v2/D4E0BAQEkfMUEE4caDQ/company-logo_'},
#                  {'locationName': 'Hyderabad Area, India',
#                   'entityUrn': 'urn:li:fs_position:(ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w,800004718)',
#                   'geoLocationName': 'Hyderabad Area, India',
#                   'geoUrn': 'urn:li:fs_geo:90009650',
#                   'companyName': 'Mtuity - A Paradigm Company',
#                   'timePeriod': {'endDate': {'month': 7, 'year': 2016},
#                    'startDate': {'month': 5, 'year': 2016}},
#                   'description': "Topic: Forecasting of Electronic Parts' Price Based on Foreign Exchange Rate using Holt-Winters Exponential Smoothing Algorithm\n•Designed a recommendation-cum-price prediction engine to make intelligent decisions using Time Series Modelling in Python\n•Compared predictive performance of Autoregressive Integrated Moving Average (ARIMA) & Holt-Winters models on Forex rates\n•Performed exploratory analysis to confirm dependency of electronic parts' price on Forex rates, raw materials, gold and oil rates\n•Tool facilitated addition of 2 new clients with the company; Levadata Inc., issued pre-placement offer (PPO) as Data Scientist",
#                   'company': {'employeeCountRange': {'start': 51, 'end': 200},
#                    'industries': ['Information Technology and Services']},
#                   'title': 'Data Science Intern',
#                   'region': 'urn:li:fs_region:(in,6508)',
#                   'companyUrn': 'urn:li:fs_miniCompany:1193045',
#                   'companyLogoUrl': 'https://media.licdn.com/dms/image/v2/C560BAQG8VIbB2A1lyw/company-logo_'},
#                  {'locationName': 'Bengaluru Area, India',
#                   'entityUrn': 'urn:li:fs_position:(ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w,339674593)',
#                   'geoLocationName': 'Bengaluru Area, India',
#                   'geoUrn': 'urn:li:fs_geo:105307040',
#                   'companyName': 'Locus',
#                   'timePeriod': {'endDate': {'month': 1, 'year': 2016},
#                    'startDate': {'month': 12, 'year': 2015}},
#                   'description': 'Topic: Benchmarking and Improvement of an AI-Enabled Logistics Engine based on Simulated Annealing Algorithm\n•Developed a channel for automated importing of SOLOMON & TSPLIB datasets into JSON format and sending requests to the server\n•Benchmarked Simulated Annealing Algorithm against NP-Hard Travelling Salesman Problem’s known global optima datasets\n•Enhanced the efficiency of the algorithm by redefining the cooling schedule and parameter tuning by 30%',
#                   'company': {'employeeCountRange': {'start': 201, 'end': 500},
#                    'industries': ['Computer Software']},
#                   'title': 'Intern - Algorithm Benchmarking',
#                   'region': 'urn:li:fs_region:(in,7127)',
#                   'companyUrn': 'urn:li:fs_miniCompany:10155969',
#                   'companyLogoUrl': 'https://media.licdn.com/dms/image/v2/D560BAQGWAHHkbMlIwg/company-logo_'}],
#                 'education': [{'courses': ['urn:li:fs_course:(ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w,1)',
#                    'urn:li:fs_course:(ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w,2)',
#                    'urn:li:fs_course:(ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w,3)',
#                    'urn:li:fs_course:(ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w,4)',
#                    'urn:li:fs_course:(ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w,5)'],
#                   'projects': ['urn:li:fs_project:(ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w,1393173949)',
#                    'urn:li:fs_project:(ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w,901060937)'],
#                   'degreeName': 'Integrated B.Tech & M.Tech',
#                   'honors': ['urn:li:fs_honor:(ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w,1471655897)'],
#                   'schoolUrn': 'urn:li:fs_miniSchool:13500',
#                   'entityUrn': 'urn:li:fs_education:(ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w,132520031)',
#                   'school': {'objectUrn': 'urn:li:school:13500',
#                    'entityUrn': 'urn:li:fs_miniSchool:13500',
#                    'active': True,
#                    'schoolName': 'Indian Institute of Technology, Kharagpur',
#                    'trackingId': 'BX+9/turRj2LFwoKWVsXqw==',
#                    'logoUrl': 'https://media.licdn.com/dms/image/v2/C4D0BAQE0lxIeTKBTAw/company-logo_'},
#                   'activities': 'General Secretary - Sports and Games, RK Hall; Captain - Basketball, RK Hall; Entrepreneurship Cell',
#                   'timePeriod': {'endDate': {'year': 2017},
#                    'startDate': {'year': 2012}},
#                   'testScores': ['urn:li:fs_testScore:(ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w,1749227419)'],
#                   'schoolName': 'Indian Institute of Technology, Kharagpur',
#                   'fieldOfStudy': 'Biotechnology and Biochemical Engineering'},
#                  {'entityUrn': 'urn:li:fs_education:(ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w,341353331)',
#                   'timePeriod': {'endDate': {'year': 2011},
#                    'startDate': {'year': 2004}},
#                   'degreeName': 'Intermediate ',
#                   'schoolName': 'K. K. Public School, Sardhana, Meerut (UP)'}],
#                 'languages': [{'name': 'C++',
#                   'proficiency': 'FULL_PROFESSIONAL'},
#                  {'name': 'English', 'proficiency': 'FULL_PROFESSIONAL'},
#                  {'name': 'Hindi', 'proficiency': 'NATIVE_OR_BILINGUAL'},
#                  {'name': 'Python', 'proficiency': 'FULL_PROFESSIONAL'}],
#                 'publications': [],
#                 'certifications': [],
#                 'volunteer': [{'role': 'Volunteer',
#                   'companyName': 'National Service Scheme',
#                   'timePeriod': {'endDate': {'month': 7, 'year': 2014},
#                    'startDate': {'month': 7, 'year': 2012}},
#                   'description': 'Teaching, organizing various sports & cultural activities for local school children'}],
#                 'honors': [{'description': '•Ensured conduction of trials to highlight the budding talent and constructed team for the coming tournament\n•Supervised and coordinated a team of 15 members for the participation in Sports and Games, General Championship\n•Conducted special practice and drilling sessions to improve the skills of a rather inexperienced team',
#                   'occupation': 'urn:li:fs_position:(ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w,815857579)',
#                   'title': 'Captain Basketball Team',
#                   'issueDate': {'month': 7, 'year': 2015},
#                   'issuer': 'RK Hall, IIT Kharagpur'},
#                  {'description': 'Felicitated with Best Fresher Award, RK Hall of Residence, in a batch of 160 sophomores for outstanding all-round achievement and contribution to the Hall for the session 2013-14.',
#                   'occupation': 'urn:li:fs_education:(ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w,132520031)',
#                   'title': 'Best Fresher, RK Hall of Residence',
#                   'issueDate': {'month': 4, 'year': 2014},
#                   'issuer': 'RK Hall of Residence'}],
#                 'projects': [{'occupation': 'urn:li:fs_education:(ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w,132520031)',
#                   'members': [{'member': {'firstName': 'Tushar',
#                      'lastName': 'Singh Soam',
#                      'dashEntityUrn': 'urn:li:fsd_profile:ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w',
#                      'occupation': 'Data Scientist | IIT Kharagpur',
#                      'objectUrn': 'urn:li:member:214397566',
#                      'entityUrn': 'urn:li:fs_miniProfile:ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w',
#                      'publicIdentifier': 'tusharsinghsoam',
#                      'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#                          'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1517612760725?e=1731542400&v=beta&t=NrmuaFBFwkGyj9EYrTYy78zxmvpx1RAThiWC5vLUjoY',
#                          'expiresAt': 1731542400000,
#                          'height': 100},
#                         {'width': 200,
#                          'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1517612760741?e=1731542400&v=beta&t=kQte_3rvwb8RLz4hpOpNhThThsmH44DzjCE9DOzNJ8U',
#                          'expiresAt': 1731542400000,
#                          'height': 200},
#                         {'width': 400,
#                          'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1517612760799?e=1731542400&v=beta&t=NzjSciE0ki6mF9AOFuJcnIpEVxDHYL3lSpmoJM-zIh4',
#                          'expiresAt': 1731542400000,
#                          'height': 400},
#                         {'width': 450,
#                          'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1517612761824?e=1731542400&v=beta&t=Ssgsy02Gq3UvVr4tgL1xfCV2aORUbsFdNChVQpz4p14',
#                          'expiresAt': 1731542400000,
#                          'height': 450}],
#                        'rootUrl': 'https://media.licdn.com/dms/image/v2/C5103AQFroFibXBU3qA/profile-displayphoto-shrink_'}},
#                      'trackingId': 'cHA3FCdQQdOTFmx8OlCP4A=='},
#                     'entityUrn': 'urn:li:fs_contributor:(ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w,1393173949,126994787)',
#                     'profileUrn': 'urn:li:fs_miniProfile:ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w'}],
#                   'timePeriod': {'endDate': {'month': 5, 'year': 2016},
#                    'startDate': {'month': 1, 'year': 2016}},
#                   'description': '•Constructed a statistical model to predict pan-genome of the whole Rhodococcus Sp. to improve knowledge about the species\n•Automated construction of phylogenetic tree to study evolutionary relationship between biological species using Python',
#                   'title': 'Comparative and Functional Genomics study of a Rhodococcus strain to Facilitate Efficient Bioremediation'},
#                  {'occupation': 'urn:li:fs_education:(ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w,132520031)',
#                   'members': [{'member': {'firstName': 'Tushar',
#                      'lastName': 'Singh Soam',
#                      'dashEntityUrn': 'urn:li:fsd_profile:ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w',
#                      'occupation': 'Data Scientist | IIT Kharagpur',
#                      'objectUrn': 'urn:li:member:214397566',
#                      'entityUrn': 'urn:li:fs_miniProfile:ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w',
#                      'publicIdentifier': 'tusharsinghsoam',
#                      'picture': {'com.linkedin.common.VectorImage': {'artifacts': [{'width': 100,
#                          'fileIdentifyingUrlPathSegment': '100_100/profile-displayphoto-shrink_100_100/0/1517612760725?e=1731542400&v=beta&t=NrmuaFBFwkGyj9EYrTYy78zxmvpx1RAThiWC5vLUjoY',
#                          'expiresAt': 1731542400000,
#                          'height': 100},
#                         {'width': 200,
#                          'fileIdentifyingUrlPathSegment': '200_200/profile-displayphoto-shrink_200_200/0/1517612760741?e=1731542400&v=beta&t=kQte_3rvwb8RLz4hpOpNhThThsmH44DzjCE9DOzNJ8U',
#                          'expiresAt': 1731542400000,
#                          'height': 200},
#                         {'width': 400,
#                          'fileIdentifyingUrlPathSegment': '400_400/profile-displayphoto-shrink_400_400/0/1517612760799?e=1731542400&v=beta&t=NzjSciE0ki6mF9AOFuJcnIpEVxDHYL3lSpmoJM-zIh4',
#                          'expiresAt': 1731542400000,
#                          'height': 400},
#                         {'width': 450,
#                          'fileIdentifyingUrlPathSegment': '800_800/profile-displayphoto-shrink_800_800/0/1517612761824?e=1731542400&v=beta&t=Ssgsy02Gq3UvVr4tgL1xfCV2aORUbsFdNChVQpz4p14',
#                          'expiresAt': 1731542400000,
#                          'height': 450}],
#                        'rootUrl': 'https://media.licdn.com/dms/image/v2/C5103AQFroFibXBU3qA/profile-displayphoto-shrink_'}},
#                      'trackingId': 'cHA3FCdQQdOTFmx8OlCP4A=='},
#                     'entityUrn': 'urn:li:fs_contributor:(ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w,901060937,126993930)',
#                     'profileUrn': 'urn:li:fs_miniProfile:ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w'}],
#                   'timePeriod': {'endDate': {'month': 3, 'year': 2016},
#                    'startDate': {'month': 1, 'year': 2016}},
#                   'description': '•Developed multinomial regression model between gene expression & Gleason Score to enable characterization of disease at the genetic level\n•Employed Principal Component Analysis technique as 12,000 genes were used as regressors on 300 Gleason scores of patients',
#                   'title': 'Regression Analysis on Genes and Cancer (Gleason) Score to Identify Therapeutic Targets and Diagnosis of the Disease'}],
#                 'skills': [{'name': 'XGBoost'},
#                  {'name': 'Continuous Integration and Continuous Delivery (CI/CD)'},
#                  {'name': 'Exploratory Data Analysis'},
#                  {'name': 'SHAP'}],
#                 'urn_id': 'ACoAAAzHcn4BGz95j9zh8hNbBxgBM2kdM9L7I9w'},
#                'skills': [{'name': 'XGBoost'},
#                 {'name': 'Continuous Integration and Continuous Delivery (CI/CD)'},
#                 {'name': 'Exploratory Data Analysis'},
#                 {'name': 'SHAP'},
#                 {'name': 'Machine Learning'},
#                 {'name': 'Data Science'},
#                 {'name': 'Python'},
#                 {'name': 'Statistics'},
#                 {'name': 'Econometrics'},
#                 {'name': 'Data Analysis'},
#                 {'name': 'Basketball'},
#                 {'name': 'Bioinformatics'},
#                 {'name': 'Programming'},
#                 {'name': 'Deep Learning'},
#                 {'name': 'Forecasting'},
#                 {'name': 'MySQL'},
#                 {'name': 'C'},
#                 {'name': 'Matlab'},
#                 {'name': 'Microsoft Excel'},
#                 {'name': 'Decision Modeling'},
#                 {'name': 'Machine Learning Algorithms'},
#                 {'name': 'C++'},
#                 {'name': 'Algorithms'},
#                 {'name': 'Predictive Modeling'}]}]})

# %%
# code to clean up unnecessary details
for key, values in peoples_profiles.items():
    for val in values:
        for k1, v1 in val.items():
            if isinstance(v1, dict):
                if "student" in v1:
                    del v1["student"]
                if "geoCountryUrn" in v1:
                    del v1["geoCountryUrn"]
                if "geoLocationBackfilled" in v1:
                    del v1["geoLocationBackfilled"]
                if "entityUrn" in v1:
                    del v1["entityUrn"]
                if "geoCountryName" in v1:
                    del v1["geoCountryName"]
                if "elt" in v1:
                    del v1["elt"]
                if "profilePictureOriginalImage" in v1:
                    del v1["profilePictureOriginalImage"]
                if "industryUrn" in v1:
                    del v1["industryUrn"]
                if "profilePicture" in v1:
                    del v1["profilePicture"]
                if "geoLocation" in v1:
                    del v1["geoLocation"]
                if "geoLocationName" in v1:
                    del v1["geoLocationName"]
                if "location" in v1:
                    del v1["location"]
                if "backgroundPicture" in v1:
                    del v1["backgroundPicture"]
                if "backgroundPictureOriginalImage" in v1:
                    del v1["backgroundPictureOriginalImage"]
                if "displayPictureUrl" in v1:
                    del v1["displayPictureUrl"]
                if "img_400_400" in v1:
                    del v1["img_400_400"]
                if "img_200_200" in v1:
                    del v1["img_200_200"]
                if "img_800_800" in v1:
                    del v1["img_800_800"]
                if "img_100_100" in v1:
                    del v1["img_100_100"]
                if "img_767_767" in v1:
                    del v1["img_767_767"]
                if "profile_id" in v1:
                    del v1["profile_id"]
                if "profile_urn" in v1:
                    del v1["profile_urn"]
                if "member_urn" in v1:
                    del v1["member_urn"]
                if "volunteer" in v1:
                    del v1["volunteer"]
                if "honors" in v1:
                    del v1["honors"]
                if "experience" in v1:
                    for ele in v1["experience"]:
                        if "entityUrn" in ele:
                            del ele["entityUrn"]
                        if "geoUrn" in ele:
                            del ele["geoUrn"]
                        if "region" in ele:
                            del ele["region"]
                        if "companyUrn" in ele:
                            del ele["companyUrn"]
                        if "companyLogoUrl" in ele:
                            del ele["companyLogoUrl"]
                if "education" in v1:
                    for ele in v1["education"]:
                        if "entityUrn" in ele:
                            del ele["entityUrn"]
                        for sch in ele.get("school", []):
                            if "objectUrn" in ele:
                                del ele["objectUrn"]
                            if "entityUrn" in ele:
                                del ele["entityUrn"]
                            if "trackingId" in ele:
                                del ele["trackingId"]
                            if "logoUrl" in ele:
                                del ele["logoUrl"]
                            if "schoolUrn" in ele:
                                del ele["schoolUrn"]
                if "certifications" in v1:
                    for ele in v1["certifications"]:
                        if "company" in ele:
                                del ele["company"]
                        if "displaySource" in ele:
                                del ele["displaySource"]
                        if "companyUrn" in ele:
                                del ele["companyUrn"]
                        if "url" in ele:
                                del ele["url"]
                if "projects" in v1:
                    for ele in v1["projects"]:
                        if "members" in ele:
                                del ele["members"]

# %%
# Store data into chromadb
all_documents = []
ids = []
for urn_id, profile_info in peoples_profiles.items():
    for info in profile_info:
        metadatas = {}
        ids.append(urn_id)
        # documents.append({k1: v1 for k, v in info.items() if k == "profile_details" for k1, v1 in v.items() if k1 != "skills"})
        for skill_name in info["skills"]:
            if "name" in skill_name:
                metadatas.update({skill_name["name"]: skill_name["name"]})

    all_documents.append(Document(page_content=json.dumps(info), metadata=metadatas))

# %%
all_documents
# Out:
# [Document(metadata={'Data Mining': 'Data Mining', 'Deep Neural Networks (DNN)': 'Deep Neural Networks (DNN)', 'Computer Architecture': 'Computer Architecture', 'Optimization': 'Optimization', 'TensorFlow': 'TensorFlow', 'Apache Spark': 'Apache Spark', 'Algorithm Design': 'Algorithm Design', 'Statistical Learning': 'Statistical Learning', 'Unstructured Data': 'Unstructured Data', 'Teamwork': 'Teamwork', 'Problem Solving': 'Problem Solving', 'Cluster Analysis': 'Cluster Analysis', 'Analytical Skills': 'Analytical Skills', 'Natural Language Processing (NLP)': 'Natural Language Processing (NLP)', 'Predictive Analytics': 'Predictive Analytics', 'Statistical Data Analysis': 'Statistical Data Analysis', 'Statistics': 'Statistics', 'Python (Programming Language)': 'Python (Programming Language)', 'SQL': 'SQL', 'Java': 'Java', 'Object-Oriented Programming (OOP)': 'Object-Oriented Programming (OOP)', 'Machine Learning': 'Machine Learning', 'Data Visualization': 'Data Visualization', 'Cypher Query Language': 'Cypher Query Language', 'Pandas': 'Pandas', 'Transact-SQL (T-SQL)': 'Transact-SQL (T-SQL)', 'R (Programming Language)': 'R (Programming Language)', 'Tableau': 'Tableau', 'Neo4j': 'Neo4j', 'Applied Machine Learning': 'Applied Machine Learning', 'Regression Analysis': 'Regression Analysis', 'Logistic Regression': 'Logistic Regression', 'Linear Regression': 'Linear Regression'}, page_content='{"profile_details": {"summary": "Experienced data scientist with a track record of translating complex data into actionable insights across diverse sectors spanning FMCG, Sports and Supply Chain.", "industryName": "Information Technology & Services", "lastName": "Srivastava", "locationName": "India", "firstName": "Vidur", "headline": "Data Scientist", "public_id": "vidur-srivastava-a45b85143", "experience": [{"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Tredence Inc.", "timePeriod": {"startDate": {"month": 7, "year": 2024}}, "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Management Consulting"]}, "title": "Data Scientist"}, {"locationName": "Bengaluru, Karnataka, India", "geoLocationName": "Bengaluru, Karnataka, India", "companyName": "Tiger Analytics", "timePeriod": {"endDate": {"month": 5, "year": 2024}, "startDate": {"month": 5, "year": 2022}}, "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Management Consulting"]}, "title": "Senior Analyst"}, {"companyName": "Wicky", "timePeriod": {"endDate": {"month": 4, "year": 2022}, "startDate": {"month": 1, "year": 2022}}, "company": {"employeeCountRange": {"start": 2, "end": 10}, "industries": ["Sports"]}, "title": "Software Engineer - MLE"}, {"locationName": "Pune, Maharashtra, India", "geoLocationName": "Pune, Maharashtra, India", "companyName": "Infosys", "timePeriod": {"endDate": {"month": 1, "year": 2022}, "startDate": {"month": 1, "year": 2022}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Senior System Engineer"}, {"locationName": "Pune, Maharashtra, India", "geoLocationName": "Pune, Maharashtra, India", "companyName": "Infosys", "timePeriod": {"endDate": {"month": 1, "year": 2022}, "startDate": {"month": 12, "year": 2019}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "System Engineer"}], "education": [{"school": {"objectUrn": "urn:li:school:478063", "entityUrn": "urn:li:fs_miniSchool:478063", "active": true, "schoolName": "BITS Pilani Work Integrated Learning Programmes", "trackingId": "S5+oZ3IATSO+UpvCjusTEw==", "logoUrl": "https://media.licdn.com/dms/image/v2/D560BAQFl6CQfOjKJkA/company-logo_"}, "timePeriod": {"endDate": {"month": 9, "year": 2022}, "startDate": {"month": 9, "year": 2021}}, "degreeName": "Post Graduate Certificate", "schoolName": "BITS Pilani Work Integrated Learning Programmes", "fieldOfStudy": "Artificial I ...
#  Document(metadata={'Python (Programming Language)': 'Python (Programming Language)', 'Machine Learning Algorithms': 'Machine Learning Algorithms', 'PL/SQL': 'PL/SQL', 'Agile Methodologies': 'Agile Methodologies', 'Software Development': 'Software Development', 'Shell Scripting': 'Shell Scripting', 'Requirements Analysis': 'Requirements Analysis', 'Data Analysis': 'Data Analysis', 'Artificial Intelligence (AI)': 'Artificial Intelligence (AI)', 'Machine Learning': 'Machine Learning', 'Deep Learning': 'Deep Learning', 'Oracle SQL Developer': 'Oracle SQL Developer', 'Core Java': 'Core Java', 'Unix': 'Unix', 'Linux': 'Linux', 'Progress 4GL': 'Progress 4GL', 'pl': 'pl', 'Artificial Neural Networks': 'Artificial Neural Networks', 'Character User Interface,Progress': 'Character User Interface,Progress', 'Predictive Modeling': 'Predictive Modeling', 'Neural Networks': 'Neural Networks', 'TensorFlow': 'TensorFlow', 'SQL': 'SQL', 'Data Science': 'Data Science', 'Computer Vision': 'Computer Vision'}, page_content='{"profile_details": {"summary": "Experience in Cognitive Computing with leverage of Machine Learning, Deep Learning, Artificial Intelligence, Natural Language Processing skills . Data driven analyst with the ability to apply ML/DL/NLP/Computer Vision Techniques and leverage algorithms to solve real world problems. Established ability in deploying effective predictive/NLP/Computer Vision models across banking/HealthCare industries to accurately forecast and deliver proven results. Strong understanding of Oracle DB and PLSQL with data migration exp\\u00e9rience. Domain Knowledge of SupplyChain/finance/banking/Retail domain with communication skills, excellent product and process design knowledge. Domain HealthCare,Mortgage Banking, Consumer, Commercial Lending, Escrow, Loan processing and servicing, Deposits. Onsite experience (US/UK) with business domain experience in Retail and supply chain with special focus on Customer engagement and managing end-user expectations. Experience in Analysis, Design, Development, Customization, Bug fixes, Enhancement, Support and Implementation.\\n\\n\\nData Science, Machine Learning, Deep Learning and AI technologies.Strong understanding of Databases Oracle, Progress 4GL, PLSQL. Excellent Domain Knowledge of finance/banking/Retail domain with communication skills, excellent product and process design knowledge.Strong knowledge of Data Migration and Implementation.. \\n\\nAreas of Expertise: Data Science Machine Learning, Deep Learning and AI technologies.\\n\\nWeb App - Flask, Django.\\n\\nDomain - Mortgage Banking,Insurance Claim Processing Money Laundering, Investment Banking, Lending, Escrow, Loan processing and servicing. Credit Cards,Healthcare\\n\\nDatabase - Oracle,Progress 4GL,Mongo Db\\n\\nLanguages - Python ,PLSQL,Progress4GL,Shell Script\\n\\nVersioning - SVN,Github\\nCloud : IBM Cloud, AWS,AZURE,Kubernates\\nOthers : Dockers,CICD\\n\\n\\n\\n\\n10+ years of experience in exploring and understanding various business models in Finance,Healthcare,Retail and Supply chain domain with special focus on implementation according to client requirements.\\n\\u2022\\tExperience in client interaction for requirement gathering and feasibility analysis at various levels including end users, project managers, and business analysts. Possess good business acumen interacting with various 3rd parties in the same project. Onsite experience (UK) with business domain experience in Retail and supply chain with special focus on customer engagement and managing end-user expectations.", "industryName": "Information Technology & Services", "lastName": "Aneja", "locationName": "India", "firstName": "Isha", "headline": "Data Scientist IBM", "img_253_253": "800_800/profile-displayphoto-shrink_800_800/0/1516520225939?e=1731542400&v=beta&t=MK0pDwNOQmYNXZS1hxvX1-2NsHeY1lAP4O8njFxDsMs", "public_id": "isha-aneja-642b7a32", "experience": [{"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pr ...
#  Document(metadata={'Amazon Web Services (AWS)': 'Amazon Web Services (AWS)', 'Financial Analysis': 'Financial Analysis', 'COBOL': 'COBOL', 'COBOLII': 'COBOLII', 'JCL': 'JCL', 'CICS': 'CICS', 'DB2': 'DB2', 'Xpediter': 'Xpediter', 'Endeavor': 'Endeavor', 'Agile Application Development': 'Agile Application Development', 'Time Management': 'Time Management', 'changeman': 'changeman', 'CA7': 'CA7', 'Control M': 'Control M', 'Ca datacom': 'Ca datacom', 'CA-Librarian': 'CA-Librarian', 'Alchemist': 'Alchemist', 'Python (Programming Language)': 'Python (Programming Language)', 'Machine Learning': 'Machine Learning', 'Artificial Intelligence (AI)': 'Artificial Intelligence (AI)', 'Artificial Neural Networks': 'Artificial Neural Networks', 'Scikit-Learn': 'Scikit-Learn', 'CRF design': 'CRF design', 'CRFs': 'CRFs', 'TensorFlow': 'TensorFlow', 'Data Science': 'Data Science', 'Data Analysis': 'Data Analysis', 'Data Visualization': 'Data Visualization', 'GNU Octave': 'GNU Octave', 'MongoDB': 'MongoDB', 'IBM DB2': 'IBM DB2', 'Job Control Language (JCL)': 'Job Control Language (JCL)', 'Core Java': 'Core Java', 'JavaScript': 'JavaScript', 'Microsoft SQL Server': 'Microsoft SQL Server', 'Google Analytics': 'Google Analytics', 'MySQL': 'MySQL', 'linux': 'linux', 'Git': 'Git', 'Docker Products': 'Docker Products', 'Pandas (Software)': 'Pandas (Software)', 'Django REST Framework': 'Django REST Framework', 'Microsoft Azure': 'Microsoft Azure', 'Ubuntu': 'Ubuntu', 'NoSQL': 'NoSQL', 'Django': 'Django'}, page_content='{"profile_details": {"summary": "Experience Data Science professional with demonstrated history of working in IT service industry. Experienced in executing data driven solutions to increase efficiency, accuracy and utility of internal data processing. Skilled in natural language processing with practioner knowledge on Web Analytics. Strong information technology professional with a Bachelor of Technology (BTech) from Uttar Pradesh Technical University. ", "industryName": "Information Technology & Services", "lastName": "Mathur", "locationName": "India", "firstName": "Tushar", "headline": "Data Scientist", "img_413_413": "800_800/profile-displayphoto-shrink_800_800/0/1627636616827?e=1731542400&v=beta&t=622aY-HtcQSxqycM6kkJLZJgkr1xzh3_7jhWSE28UXg", "public_id": "tushar-mathur-79a23120", "experience": [{"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "Coforge", "timePeriod": {"startDate": {"month": 8, "year": 2022}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Analytics Lead"}, {"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "EXL", "timePeriod": {"endDate": {"month": 8, "year": 2022}, "startDate": {"month": 8, "year": 2021}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Technical Lead"}, {"locationName": "Noida Area, India", "geoLocationName": "Noida Area, India", "companyName": "Sopra Steria", "timePeriod": {"endDate": {"month": 7, "year": 2021}, "startDate": {"month": 7, "year": 2019}}, "description": "Working on information extraction project in which we focuses on creating structured representation of unstructured/structured texts by extracting relevant entities from them, using machine learning and AI process thereby making the data analysis realizable.", "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Module Lead"}, {"locationName": "Noida Area, India", "geoLocationName": "Noida Area, India", "companyName": "Sopra Steria", "timePeriod": {"endDate": {"month": 6, "year": 2019}, "startDate": {"month": 10, "year": 2017}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Senior Software Engineer", "honors": ["urn:li:fs_honor:(ACoAAA ...
#  Document(metadata={'ServiceNow': 'ServiceNow', 'Business Process Improvement': 'Business Process Improvement', 'Business Process': 'Business Process', 'Knowledge Sharing': 'Knowledge Sharing', 'Client Requirements': 'Client Requirements', 'Presentations': 'Presentations', 'Extract, Transform, Load (ETL)': 'Extract, Transform, Load (ETL)', 'Data Management': 'Data Management', 'Business Process Outsourcing (BPO)': 'Business Process Outsourcing (BPO)', 'Business Management': 'Business Management', 'Documentation': 'Documentation', 'Git': 'Git', 'Microsoft Azure Machine Learning': 'Microsoft Azure Machine Learning', 'PyTorch': 'PyTorch', 'Natural Language Processing (NLP)': 'Natural Language Processing (NLP)', 'Business Intelligence (BI)': 'Business Intelligence (BI)', 'Data Visualization': 'Data Visualization', 'Data Validation': 'Data Validation', 'Digital Marketing': 'Digital Marketing', 'Team Leadership': 'Team Leadership', 'Spoken English': 'Spoken English', 'Time Series Analysis': 'Time Series Analysis', 'Data Science': 'Data Science', 'Predictive Analytics': 'Predictive Analytics', 'Predictive Maintenance': 'Predictive Maintenance', 'Artificial Intelligence (AI)': 'Artificial Intelligence (AI)', 'Artificial Neural Networks': 'Artificial Neural Networks', 'Neural Networks': 'Neural Networks', 'Chatbot Development': 'Chatbot Development', 'Exploratory Data Analysis': 'Exploratory Data Analysis', 'Microsoft Excel': 'Microsoft Excel', 'Snowflake': 'Snowflake', 'Client Relations': 'Client Relations', 'Data Analytics': 'Data Analytics', 'SQL': 'SQL', 'Tableau': 'Tableau', 'SAP Business Warehouse (SAP BW)': 'SAP Business Warehouse (SAP BW)', 'Communication': 'Communication', 'C++': 'C++', 'Data Analysis': 'Data Analysis', 'Machine Learning': 'Machine Learning', 'Algorithms': 'Algorithms', 'Blogging': 'Blogging', 'Content Development': 'Content Development', 'Writing': 'Writing', 'C (Programming Language)': 'C (Programming Language)', 'Python (Programming Language)': 'Python (Programming Language)', 'Microsoft Office': 'Microsoft Office', 'Public Speaking': 'Public Speaking', 'Leadership': 'Leadership'}, page_content='{"profile_details": {"summary": "Hello,\\n\\nI\'m a data scientist and machine learning engineer working in the IT Service Industry since 2021, currently contributing my expertise at TCS. My passion lies in the dynamic realm of Artificial Intelligence and Machine Learning (AIML).\\n\\nMy professional journey has exposed me to a diverse range of technologies and responsibilities. I specialize in developing predictive maintenance models, incorporating cutting-edge edge computing technology to detect machinery failures. Currently, I\'m also actively engaged in a fascinating project involving ticket classification and clustering, further expanding my skills and knowledge in AIML.\\n\\nMy proficiency extends to time series analysis, where I\'ve mastered models like ARIMA, SARIMA, Darts, and other relevant libraries. My data-driven approach also involves in-depth exploratory data analytics.\\n\\nIn my day-to-day work, I rely on essential machine learning libraries such as Pandas, Numpy, Scikit Learn, Matplotlib, Seaborn, and NLTK to turn data into actionable insights. Beyond my current projects, I am always exploring new dimensions in the field of Artificial Intelligence and Machine Learning, driven by a passion for innovation and continuous learning.\\n\\nNotably, I\'ve ventured into the realm of speech-to-text models, and I excel in chatbot development. I\'ve successfully created chatbots using Python and its associated libraries, deploying them seamlessly on platforms such as SAP CAI, IBM Watson, and Slack.\\n\\nI\'m currently on the lookout for exciting opportunities in the AIML and Data Science space. Feel free to connect with me to explore potential collaborations!", "industryName": "Information Technology & Services", "lastName": "Neha", "locationName": "India", "birthDate": {"month": 7, "day": 17}, "firstName": "S ...
#  Document(metadata={'Natural Language Processing (NLP)': 'Natural Language Processing (NLP)', 'Python (Programming Language)': 'Python (Programming Language)', 'Data Structures': 'Data Structures', 'java': 'java', 'Machine Learning': 'Machine Learning', 'Statistical Data Analysis': 'Statistical Data Analysis', 'C (Programming Language)': 'C (Programming Language)', 'Database Management System (DBMS)': 'Database Management System (DBMS)', 'Competitive Programming': 'Competitive Programming', 'Computer Vision': 'Computer Vision', 'Web Crawling': 'Web Crawling', 'Django': 'Django', 'HTML5': 'HTML5', 'Cascading Style Sheets (CSS)': 'Cascading Style Sheets (CSS)', 'JavaScript': 'JavaScript'}, page_content='{"profile_details": {"summary": "Deepak is interested in the broad areas of Natural Language Processing (NLP).He currently works as a Data Scientist at KnowDis Data Science and holds a B.Tech. degree in Computer Science from IIIT Jabalpur. He is working on NER systems and recommender systems for the e-commerce domain. He is specifically interested in applying NLP techniques to Indian languages. He has also worked on several ML models to increase the business revenue of his clients, exemplifying his ability to leverage data-driven insights effectively.", "industryName": "Information Technology & Services", "lastName": "Kumar", "locationName": "India", "firstName": "Deepak", "headline": "Data Scientist at KnowDis Data Science ", "public_id": "deepak-kumar-17079a17b", "experience": [{"locationName": "New Delhi, Delhi, India", "geoLocationName": "New Delhi, Delhi, India", "companyName": "KnowDis Data Science ", "timePeriod": {"startDate": {"month": 6, "year": 2021}}, "company": {"employeeCountRange": {"start": 11, "end": 50}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}], "education": [{"school": {"objectUrn": "urn:li:school:162000", "entityUrn": "urn:li:fs_miniSchool:162000", "active": true, "schoolName": "Indian Institute of Information Technology, Design and Manufacturing, Jabalpur", "trackingId": "iOuR8+atQyOGMMqVeUq+LQ==", "logoUrl": "https://media.licdn.com/dms/image/v2/C4D0BAQG2LjL0bUoxvA/company-logo_"}, "timePeriod": {"endDate": {"year": 2021}, "startDate": {"year": 2017}}, "fieldOfStudyUrn": "urn:li:fs_fieldOfStudy:100189", "degreeName": "Bachelor of Technology - BTech", "schoolName": "Indian Institute of Information Technology, Design and Manufacturing, Jabalpur", "fieldOfStudy": "Computer Science", "degreeUrn": "urn:li:fs_degree:250"}], "languages": [], "publications": [], "certifications": [], "projects": [{"timePeriod": {"startDate": {"month": 6, "year": 2019}}, "description": "Multivariate Time Series Forecasting using Deep Learning for the next 1 hour and 24 hours on as scale of 15 minutes forecast for SLDC MP Load Dispatch Centre", "title": "Madhya Pradesh Electricity Demand Forecasting "}, {"timePeriod": {"endDate": {"month": 3, "year": 2020}, "startDate": {"month": 1, "year": 2020}}, "description": "This Sub-Word Long Short Term Memory model learn sentiments in a noisy Hindi-English\\nCode Mixed dataset.", "title": "Sub-Word LSTM"}, {"timePeriod": {"endDate": {"month": 2, "year": 2020}, "startDate": {"month": 12, "year": 2019}}, "description": "Using Hierarchical Clustering and PCA the model categorise the countries using some socio-economic and health factors that determine the overall development of the country.", "title": "Country Cluster Identification"}, {"timePeriod": {"endDate": {"month": 10, "year": 2019}, "startDate": {"month": 8, "year": 2019}}, "description": "Recommend a list of n items for a user based off of information we can obtain from the user-item table.", "title": "Amazon Instant Video User-User Collaborative Filtering"}], "skills": [{"name": "Natural Language Processing (NLP)"}, {"name": "Python (Programming Language)"}, {"name": "Data Structures"}, {"name": "java"}], "urn_id": "ACoAACqnIWQBi3JKxfm8FVwW8SfjZj6U2YmfUms"}, "skills": [{"name": "Natural Languag ...
#  Document(metadata={'LangChain': 'LangChain', 'Amazon Web Services (AWS)': 'Amazon Web Services (AWS)', 'openai': 'openai', 'Microsoft Azure': 'Microsoft Azure', 'Large Language Models (LLM)': 'Large Language Models (LLM)', 'Generative AI': 'Generative AI', 'Data Science': 'Data Science', 'Machine Learning': 'Machine Learning', 'Deep Learning': 'Deep Learning', 'Object Detection': 'Object Detection', 'Image Segmentation': 'Image Segmentation', 'Image Processing': 'Image Processing', 'Recommender Systems': 'Recommender Systems', 'Recurrent Neural Networks (RNN)': 'Recurrent Neural Networks (RNN)', 'Convolutional Neural Networks (CNN)': 'Convolutional Neural Networks (CNN)', 'Transformer Models': 'Transformer Models', 'TensorFlow': 'TensorFlow', 'Predictive Modeling': 'Predictive Modeling', 'PyTorch': 'PyTorch', 'Computer Vision': 'Computer Vision', 'Data Analysis': 'Data Analysis', 'Data Wrangling': 'Data Wrangling', 'Docker Products': 'Docker Products', 'Data Visualization': 'Data Visualization', 'Data Modeling': 'Data Modeling', 'Data Warehousing': 'Data Warehousing', 'Artificial Intelligence (AI)': 'Artificial Intelligence (AI)', 'Data Structures': 'Data Structures', 'Object-Oriented Programming (OOP)': 'Object-Oriented Programming (OOP)', 'Big Data': 'Big Data', 'Statistics': 'Statistics', 'Programming': 'Programming', 'Public Relations': 'Public Relations', 'Big data': 'Big data', 'Python (Programming Language)': 'Python (Programming Language)', 'Databases': 'Databases', 'R': 'R', 'Oracle Database': 'Oracle Database', 'SQL': 'SQL', 'PySpark': 'PySpark', 'Team Leadership': 'Team Leadership', 'Communication': 'Communication', 'Time Management': 'Time Management', 'Teamwork': 'Teamwork', 'Team Management': 'Team Management', 'Problem Solving': 'Problem Solving', 'Relationship Building': 'Relationship Building', 'Artificial Neural Networks': 'Artificial Neural Networks', 'RDBMS': 'RDBMS', 'Probability': 'Probability', 'Enjoy Challenges': 'Enjoy Challenges', 'Data Analytics': 'Data Analytics', 'Natural Language Processing (NLP)': 'Natural Language Processing (NLP)', 'NumPy': 'NumPy', 'Neural Networks': 'Neural Networks', 'Big Data Analytics': 'Big Data Analytics'}, page_content='{"profile_details": {"summary": "4+ years of work experience solving business problems with the application of Data Science. Master of Data Science, Monash University (Melbourne). Proficient in Generative AI, Computer Vision and Predictive Modeling. With a strong grip over mathematics, deep learning and machine learning algorithms, capable to transform business requirements into data science formulations and implementing the solutions in an efficient and scalable fashion.\\n\\nCreating impactful AI solutions at R Systems, my focus is on designing cutting-edge generative AI technologies. With a Master\'s degree in Data Science from Monash University, I apply rigorous academic training to address complex client challenges. Our team\'s contribution has significantly enhanced the RAG Application\'s accuracy, showcasing a blend of innovation and practical application.\\n\\nMy core competencies lie in Large Language Models and transformative AI, underpinned by data collection, preprocessing, model development, and deployment. These skills have enabled us to deliver tailored solutions that not only meet but exceed our clients\' business objectives. The dedication to continual learning and improvement is what drives the team and myself to achieve excellence in the ever-evolving field of data science.", "industryName": "Computer Software", "lastName": "Nain", "locationName": "India", "birthDate": {"month": 1, "day": 24}, "firstName": "Rakesh", "headline": "Data Scientist @ R Systems | Master\'s in Data Science", "public_id": "rakeshnain", "experience": [{"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "R Systems", "timePeriod": {"startDate": {"month": 8, "year": 2023}}, "description": "Roles and Res ...
#  Document(metadata={'Financial Analysis': 'Financial Analysis', 'Microsoft Azure': 'Microsoft Azure', 'Microsoft Azure Machine Learning': 'Microsoft Azure Machine Learning', 'Data Engineering': 'Data Engineering', 'TensorFlow': 'TensorFlow', 'Predictive Modeling': 'Predictive Modeling', 'Python (Programming Language)': 'Python (Programming Language)', 'Business Analysis': 'Business Analysis', 'Data Analytics': 'Data Analytics', 'Problem Solving': 'Problem Solving', 'Market Analysis': 'Market Analysis', 'Communication': 'Communication', 'Analytical Skills': 'Analytical Skills', 'Product Strategy': 'Product Strategy', 'Big Data': 'Big Data', 'Computer Vision': 'Computer Vision', 'Pivot Tables': 'Pivot Tables', 'Machine Learning': 'Machine Learning', 'Deep Learning': 'Deep Learning', 'Natural Language Processing (NLP)': 'Natural Language Processing (NLP)', 'Data Science': 'Data Science', 'Artificial Intelligence (AI)': 'Artificial Intelligence (AI)', 'HTML': 'HTML', 'Microsoft Office': 'Microsoft Office', 'C': 'C', 'C++': 'C++', 'Microsoft Excel': 'Microsoft Excel', 'Java': 'Java', 'Programming': 'Programming', 'PowerPoint': 'PowerPoint', 'Microsoft Word': 'Microsoft Word', 'MySQL': 'MySQL', 'JavaScript': 'JavaScript', 'Team Leadership': 'Team Leadership', 'Project Planning': 'Project Planning', 'SQL': 'SQL', 'Matlab': 'Matlab', 'Teamwork': 'Teamwork', 'PHP': 'PHP', 'Linux': 'Linux', 'NetBeans': 'NetBeans', 'Statistical Data Analysis': 'Statistical Data Analysis', 'Big Data Analytics': 'Big Data Analytics', 'Data Mining': 'Data Mining', 'R': 'R', 'Microsoft PowerPoint': 'Microsoft PowerPoint'}, page_content='{"profile_details": {"summary": "Experienced Data Scientist/Full Stack Developer with a demonstrated history of working in the information technology and services industry. Comfortable working on python flask, django and node, skilled in Watson Explorer, Appbuilder and Watson services, UI/UX, data analysis, nlp, text analytics, social media analytics and also in AI Solutioning/Architecture and Analytics based consulting. Strong information technology professional with a Bachelor of Technology, focused in Computer Science from NIIT UNIVERSITY and currently pursing Executive MBA equivalent PGPpro program from ISB Hyderabad in Strategy, Leadership and Marketing.", "industryName": "Computer Software", "lastName": "Singh", "locationName": "India", "firstName": "Rakshit", "headline": "Data Scientist / AI Consultant @ IBM Consulting | ISB | INSEAD ", "public_id": "rakshit-singh-91930963", "experience": [{"locationName": "Gurgaon, Haryana, India", "geoLocationName": "Gurgaon, Haryana, India", "companyName": "IBM", "timePeriod": {"startDate": {"month": 8, "year": 2016}}, "description": "Data Scientist - AI/ML", "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"locationName": "Silokhera,Gurgaon", "geoLocationName": "Silokhera,Gurgaon", "companyName": "IBM", "timePeriod": {"endDate": {"month": 7, "year": 2016}, "startDate": {"month": 2, "year": 2016}}, "description": "Data Analytics and Predictive modeling", "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Intern"}, {"locationName": "Noida Area, India", "geoLocationName": "Noida Area, India", "companyName": "GAIL (India) Limited", "timePeriod": {"endDate": {"month": 7, "year": 2015}, "startDate": {"month": 6, "year": 2015}}, "description": "\\u2022 CENTRALIZED MONITORING OF SERVICE CONTRACTS.\\n\\u2022 ANALYSIS USING DATA VISUALISATION OF POLYMER DIVISION OF COMPANY.\\n\\u2022 Created a module in SAP to monitor and calculate the status of the service contracts using  ABAP programming language.\\n\\u2022 Created ALV reports and adobe forms to represent data in a more human readable form.\\n\\u2022 Used SAP Lumira to visualise data of two years and find meaningful information which will help the company increase its profits and also h ...
#  Document(metadata={'Dataiku DSS': 'Dataiku DSS', 'PySpark': 'PySpark', 'Deep Learning': 'Deep Learning', 'Machine Learning': 'Machine Learning', 'Natural Language Processing (NLP)': 'Natural Language Processing (NLP)', 'Python (Programming Language)': 'Python (Programming Language)', 'SQL': 'SQL', 'NoSQL': 'NoSQL', 'Google Cloud Platform (GCP)': 'Google Cloud Platform (GCP)', 'Elasticsearch': 'Elasticsearch', 'Flask': 'Flask', 'Public Speaking': 'Public Speaking', 'Presentation Skills': 'Presentation Skills', 'Selenium WebDriver': 'Selenium WebDriver', 'OpenCV': 'OpenCV', 'C (Programming Language)': 'C (Programming Language)', 'C++': 'C++', 'Communication': 'Communication', 'Teamwork': 'Teamwork'}, page_content='{"profile_details": {"summary": "Experienced Data Scientist with ~4 years specializing in machine learning, NLP, and deep learning. Proficient in algorithms like Random Forest, Boosting, and Decision Tree Classifiers. Skilled in TensorFlow, Keras, and NLTK for developing high-performance applications in language modeling, predictive analytics, and statistical analysis. Seeking opportunities to apply expertise in Python programming and collaborate on impactful projects. Committed to delivering innovative solutions that drive positive change and excel in diverse challenges. Passionate about leveraging skills for groundbreaking advancements in machine learning and NLP domains, ready to make a meaningful impact through transformative outcomes", "industryName": "Computer Software", "lastName": "Bhatnagar", "locationName": "India", "firstName": "Riya", "headline": "Data Scientist", "img_364_364": "800_800/profile-displayphoto-shrink_800_800/0/1722322822594?e=1731542400&v=beta&t=KMBpt7qjNpOBlrzuhlFTslOk6BLEx_geDeR4zXpRwBI", "public_id": "riya-bhatnagar-653434190", "experience": [{"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Fractal", "timePeriod": {"startDate": {"month": 1, "year": 2024}}, "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Management Consulting"]}, "title": "Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "ZS", "timePeriod": {"endDate": {"month": 11, "year": 2023}, "startDate": {"month": 12, "year": 2021}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Management Consulting"]}, "title": "Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Dew Solutions Pvt Ltd", "timePeriod": {"endDate": {"month": 12, "year": 2021}, "startDate": {"month": 6, "year": 2020}}, "company": {"employeeCountRange": {"start": 501, "end": 1000}, "industries": ["Information Technology and Services"]}, "title": "Data Science Engineer"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Dew Solutions Pvt Ltd", "timePeriod": {"endDate": {"month": 5, "year": 2020}, "startDate": {"month": 11, "year": 2019}}, "company": {"employeeCountRange": {"start": 501, "end": 1000}, "industries": ["Information Technology and Services"]}, "title": "Data Science Intern"}, {"locationName": "Jaipur, Rajasthan", "geoLocationName": "Jaipur, Rajasthan", "companyName": "CDAC ATC Jaipur", "timePeriod": {"endDate": {"month": 8, "year": 2018}, "startDate": {"month": 6, "year": 2018}}, "company": {"employeeCountRange": {"start": 11, "end": 50}, "industries": ["Computer Software"]}, "title": "Android Trainee"}], "education": [{"school": {"objectUrn": "urn:li:school:3185138", "entityUrn": "urn:li:fs_miniSchool:3185138", "active": true, "schoolName": "Rajasthan Technical University", "trackingId": "u07WAABZT02fp18YpJ/mZA==", "logoUrl": "https://media.licdn.com/dms/image/v2/C510BAQGUb3DKT_yHeQ/company-logo_"}, "fieldOfStudyUrn": "urn:li:fs_fieldOfStudy:100189", "degreeName": "Bachelor of Technology - BTech(Hons.)", "schoolName": "Rajasthan Technical Uni ...
#  Document(metadata={'Transformer Models': 'Transformer Models', 'Generative AI': 'Generative AI', 'LLM': 'LLM', 'Machine Learning': 'Machine Learning', 'Python': 'Python', 'Predictive Modelling': 'Predictive Modelling', 'Statistical Modeling': 'Statistical Modeling', 'Statistics': 'Statistics', 'Data Science': 'Data Science', 'Deep Learning': 'Deep Learning', 'SQL': 'SQL', 'Core Java': 'Core Java', 'Pandas (Software)': 'Pandas (Software)', 'Keras': 'Keras', 'K-Nearest Neighbors (KNN)': 'K-Nearest Neighbors (KNN)', 'XGBoost': 'XGBoost', 'Flask': 'Flask', 'Google Cloud Platform (GCP)': 'Google Cloud Platform (GCP)', 'Amazon Web Services (AWS)': 'Amazon Web Services (AWS)', 'Gensim': 'Gensim', 'spaCy': 'spaCy', 'Python (Programming Language)': 'Python (Programming Language)', 'Java': 'Java', 'Microsoft Excel': 'Microsoft Excel', 'VBA': 'VBA', 'Tableau': 'Tableau', 'R programming': 'R programming', 'Natural Language Processing (NLP)': 'Natural Language Processing (NLP)', 'Scikit-Learn': 'Scikit-Learn', 'Logistic Regression': 'Logistic Regression', 'Linear Regression': 'Linear Regression', 'Text Classification': 'Text Classification', 'Ensemble Models': 'Ensemble Models', 'Naive bayes': 'Naive bayes', 'Predictive Modeling': 'Predictive Modeling', 'Support Vector Machine (SVM)': 'Support Vector Machine (SVM)', 'Decision Trees': 'Decision Trees', 'GBDT': 'GBDT', 'Random Forest': 'Random Forest', 'MLP': 'MLP', 'word2vec': 'word2vec', 'Chatbot Development': 'Chatbot Development', 'nltk': 'nltk', 'textblob': 'textblob', 'flair': 'flair', 'stanford coreNLP': 'stanford coreNLP', 'Topic Modeling': 'Topic Modeling', 'Machine Learning Algorithms': 'Machine Learning Algorithms', 'Speech Recognition': 'Speech Recognition', 'Linux': 'Linux'}, page_content='{"profile_details": {"summary": "\\u2022\\tExperience of 7 years as Data Scientist (August 2016 \\u2013 Till Date) in implementing advanced analytics and predictive modelling algorithms such as Sequence models, Machine translation, Text summarization, Voice enabled Bot (using GPT2, Deepspeech and Azure cognitive services),Text Extraction using BERT and Spacy, Text Classification, Credit Risk analysis, Logistic regression, Decision tree ,Ensemble models, KNN, PCA, t-SNE, Linear regression, Clustering (k-means, Agglomerative)\\n\\u2022\\tExperience of 1.6 years (Nov 2014 \\u2013 Aug 2016) in Siebel CRM.\\n\\u2022\\tWell converse with Python(Pandas, Numpy, Scikit-Learn, Keras, matplotlib.pyplot, seaborn), Flask API, ML model deployments, AWS Services, linux, SQL ,Core Java and Siebel CRM.", "industryName": "Information Technology & Services", "lastName": "Kharbanda", "locationName": "India", "firstName": "Sumeet", "headline": "Looking for Data Science Opportunities  | Manager - Data Scientist @ EXL | NLP | Freelancer", "img_450_450": "800_800/profile-displayphoto-shrink_800_800/0/1517470892367?e=1731542400&v=beta&t=WkpZbUOBkt9zAX7RDthG9tVfXjgi3i-bat3dRDqpGgw", "public_id": "sumeet-data-scientist", "experience": [{"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "EXL", "timePeriod": {"startDate": {"month": 4, "year": 2022}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Manager - Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "EXL", "timePeriod": {"endDate": {"month": 4, "year": 2022}, "startDate": {"month": 11, "year": 2020}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Technical Lead - Data Scientist"}, {"courses": ["urn:li:fs_course:(ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0,504009401)", "urn:li:fs_course:(ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0,504035397)"], "locationName": "Gurgaon, Haryana, India", "geoLocationName": "Gurgaon, Haryana, India", "companyName": "UnitedHealth Group", "timePeriod": {"endDate": {"month": 1 ...
#  Document(metadata={'Databricks ': 'Databricks ', 'PySpark': 'PySpark', 'SQL': 'SQL', 'Statistics': 'Statistics', 'Statistical Data Analysis': 'Statistical Data Analysis', 'Machine Learning': 'Machine Learning', 'Data Visualization': 'Data Visualization', 'Data Management': 'Data Management', 'Python (Programming Language)': 'Python (Programming Language)', 'R': 'R', 'Tableau': 'Tableau', 'Team Leadership': 'Team Leadership', 'Natural Language Processing (NLP)': 'Natural Language Processing (NLP)', 'Team Management': 'Team Management', 'Data Science': 'Data Science'}, page_content='{"profile_details": {"summary": "Experienced Data Scientist with a demonstrated history of working in the information technology and services industry. Skilled in Statistical Data Analysis, Data Science, Data Visualization, R, and Tableau. Strong information technology professional with a Master of Business Administration - MBA focused in Data Science from NIIT University..", "industryName": "Information Technology & Services", "lastName": "Singh", "locationName": "India", "firstName": "Navdeep", "headline": "Data Scientist", "public_id": "navdeep-singh-613300162", "experience": [{"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "adidas", "timePeriod": {"startDate": {"month": 6, "year": 2023}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Sporting Goods"]}, "title": "Data Scientist"}, {"locationName": "Greater Noida", "geoLocationName": "Greater Noida", "companyName": "Coforge", "timePeriod": {"endDate": {"month": 6, "year": 2023}, "startDate": {"month": 11, "year": 2020}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"locationName": "Greater Noida", "geoLocationName": "Greater Noida", "companyName": "NIIT Technologies Limited", "timePeriod": {"endDate": {"month": 10, "year": 2020}, "startDate": {"month": 11, "year": 2019}}, "company": {"employeeCountRange": {"start": 5001, "end": 10000}, "industries": ["Information Technology and Services"]}, "title": "Data Science Intern"}, {"companyName": "BT", "timePeriod": {"endDate": {"month": 7, "year": 2018}, "startDate": {"month": 9, "year": 2015}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Telecommunications"]}, "title": "Network design and planning Subject Matter Expert"}, {"companyName": "iYogi", "timePeriod": {"endDate": {"month": 9, "year": 2015}, "startDate": {"month": 2, "year": 2015}}, "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Information Technology and Services"]}, "title": "Technical Support Analyst"}], "education": [{"school": {"objectUrn": "urn:li:school:3244301", "entityUrn": "urn:li:fs_miniSchool:3244301", "active": true, "schoolName": "NIIT University", "trackingId": "Uu5nnChVQG6TgUuNclSgwQ==", "logoUrl": "https://media.licdn.com/dms/image/v2/C510BAQFTJxBhS3gthg/company-logo_"}, "timePeriod": {"endDate": {"year": 2020}, "startDate": {"year": 2018}}, "degreeName": "Master of Business Administration - MBA", "schoolName": "NIIT University", "fieldOfStudy": "Data Science", "degreeUrn": "urn:li:fs_degree:700"}, {"school": {"objectUrn": "urn:li:school:362046", "entityUrn": "urn:li:fs_miniSchool:362046", "active": true, "schoolName": "Maharishi Markandeshwar (Deemed to be University) Official", "trackingId": "AeaN0yLlR0WMvRDeCa9pQA==", "logoUrl": "https://media.licdn.com/dms/image/v2/C4D0BAQF9HmCerZ7k-g/company-logo_"}, "timePeriod": {"endDate": {"year": 2012}, "startDate": {"year": 2008}}, "degreeName": "Bachelor of Technology - BTech", "schoolName": "Maharishi Markandeshwar University, Mullana", "fieldOfStudy": "Electronics and Communications Engineering", "degreeUrn": "urn:li:fs_degree:250"}], "languages": [], "publications": [], "certifications": [], "projects": [], "skills": [{"name": "Databricks "}, {"name": "PySpark"}, {"name": "SQL"}, {"name": "Statistics"}],  ...
#  Document(metadata={'Python': 'Python', 'SQL': 'SQL', 'Flask': 'Flask', 'FastAPI': 'FastAPI', 'Machine Learning': 'Machine Learning', 'Docker': 'Docker', 'Podman': 'Podman', 'Data Science': 'Data Science', 'Elasticsearch': 'Elasticsearch', 'Amazon Web Services (AWS)': 'Amazon Web Services (AWS)', 'Gitlab': 'Gitlab', 'Unix': 'Unix', 'Data Analytics': 'Data Analytics', 'Linux': 'Linux', 'Analytical Skills': 'Analytical Skills', 'R Programming Language': 'R Programming Language', 'Microsoft Power BI': 'Microsoft Power BI', 'Google BigQuery': 'Google BigQuery', 'Data Analysis': 'Data Analysis', 'Data Visualization': 'Data Visualization', 'MySQL': 'MySQL', 'Tableau': 'Tableau', 'Microsoft Excel': 'Microsoft Excel', 'Teradata SQL': 'Teradata SQL'}, page_content='{"profile_details": {"summary": "Analytics professional who thrives on data and insights. I like to leverage my problem solving and analytical skills to help businesses in making key strategic decisions. I consider myself a highly motivated professional who looks forward to getting out of the comfort zone and doing some real rigorous work!\\n\\nPrimary Skills:\\n\\u2022 Python - Data Analysis (Numpy, Pandas, Scikit-learn, etc.) \\n\\u2022 SQL, Google BigQuery \\n\\u2022 Visualizations - Power BI, Tableau \\n\\u2022 Python scripting and automations\\n\\u2022 Linux/UNIX server management\\n\\u2022 Docker for application deployment", "industryName": "Information Technology & Services", "lastName": "Kotnala", "locationName": "India", "firstName": "Deepankar", "headline": "Data Scientist | IIIT Bangalore", "img_401_401": "800_800/profile-framedphoto-shrink_800_800/0/1724930913918?e=1726376400&v=beta&t=alXF4FJ_QwuJzXEcjonRx6vO0Rzs952GMxYjRdufXx0", "public_id": "deepankarkotnala", "experience": [{"locationName": "India", "geoLocationName": "India", "companyName": "TCG Digital", "timePeriod": {"startDate": {"month": 8, "year": 2022}}, "company": {"employeeCountRange": {"start": 201, "end": 500}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"locationName": "India", "geoLocationName": "India", "companyName": "Genpact", "timePeriod": {"endDate": {"month": 8, "year": 2022}, "startDate": {"month": 10, "year": 2020}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Management Consulting"]}, "title": "Data Analyst"}, {"locationName": "Mumbai", "geoLocationName": "Mumbai", "companyName": "Capgemini", "timePeriod": {"endDate": {"month": 4, "year": 2019}, "startDate": {"month": 2, "year": 2016}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Associate Consultant", "honors": ["urn:li:fs_honor:(ACoAABJ97q0BFcxSTVQ9_y1dgDAXNMpNiUtF93k,1124134592)"]}], "education": [{"courses": ["urn:li:fs_course:(ACoAABJ97q0BFcxSTVQ9_y1dgDAXNMpNiUtF93k,1598967561)"], "school": {"objectUrn": "urn:li:school:354045", "entityUrn": "urn:li:fs_miniSchool:354045", "active": true, "schoolName": "International Institute of Information Technology Bangalore", "trackingId": "NlAmwagrQJG+vvCogBA/MA==", "logoUrl": "https://media.licdn.com/dms/image/v2/D560BAQEocmV8HEnx7w/company-logo_"}, "grade": "A (3.7/4 CGPA)", "timePeriod": {"endDate": {"year": 2019}, "startDate": {"year": 2018}}, "description": "PGD in Data Science and Machine Learning \\nGathering and manipulating data, applying concepts of data analytics to extract meaningful insights, building machine learning models for predictions, APIs and Flask ML applications \\nTools used: Python, R, MySQL, Excel, Tableau", "degreeName": "Post Graduate Diploma", "schoolName": "International Institute of Information Technology \\u2013 Bangalore", "fieldOfStudy": "Data Science and Machine Learning"}, {"school": {"objectUrn": "urn:li:school:827010", "entityUrn": "urn:li:fs_miniSchool:827010", "active": true, "schoolName": "COER University", "trackingId": "9bXb1MK0TGmpFVdAbbI56g==", "logoUrl": "https://media.licdn.com/dms/image/v2/C4D0BAQG75W6BLYdJAQ/co ...
# ...
#  Document(metadata={'Machine Learning': 'Machine Learning', 'Python': 'Python', 'Django': 'Django', 'Social Media': 'Social Media', 'HTML': 'HTML', 'SQL': 'SQL', 'Microsoft Word': 'Microsoft Word', 'Microsoft Excel': 'Microsoft Excel', 'Microsoft Office': 'Microsoft Office', 'PowerPoint': 'PowerPoint', 'PHP': 'PHP', 'Unix': 'Unix', 'Teamwork': 'Teamwork', 'Public Speaking': 'Public Speaking', 'English': 'English', 'Artificial Intelligence (AI)': 'Artificial Intelligence (AI)', 'Data Science': 'Data Science', 'Anaconda': 'Anaconda', 'Pandas': 'Pandas', 'NumPy': 'NumPy', 'Scikit-Learn': 'Scikit-Learn', 'Regression Models': 'Regression Models', 'Predictive Analytics': 'Predictive Analytics', 'Predictive Modeling': 'Predictive Modeling', 'Forecasting': 'Forecasting', 'K-Nearest Neighbors (KNN)': 'K-Nearest Neighbors (KNN)', 'Support Vector Machine (SVM)': 'Support Vector Machine (SVM)', 'Decision Trees': 'Decision Trees', 'Git': 'Git', 'TensorFlow': 'TensorFlow', 'OpenCV': 'OpenCV', 'Text Classification': 'Text Classification', 'Spacy': 'Spacy', 'Natural Language Processing (NLP)': 'Natural Language Processing (NLP)', 'NLTK': 'NLTK', 'Sentiment Analysis': 'Sentiment Analysis', 'Principal Component Analysis': 'Principal Component Analysis', 'Clustering': 'Clustering', 'Bagging': 'Bagging', 'Boosting': 'Boosting'}, page_content='{"profile_details": {"summary": "To continually find new horizons of my career by accepting challenges and confronting them with the best of my abilities so that it can help on excelling in my technical, analytical abilities. ", "industryName": "Information Technology & Services", "lastName": "Aggarwal", "locationName": "India", "firstName": "Puneet", "headline": "Data Scientist/Principal at Gartner", "public_id": "puneet-aggarwal-18599575", "experience": [{"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Gartner", "timePeriod": {"startDate": {"month": 10, "year": 2022}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Services"]}, "title": "Data Scientist/Principal"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "Accenture", "timePeriod": {"endDate": {"month": 10, "year": 2022}, "startDate": {"month": 12, "year": 2021}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Management Consulting"]}, "title": "Application Development Team Lead", "honors": ["urn:li:fs_honor:(ACoAAA_8N7UBcb426isJoolyZrF0Lgh2oyOZbcc,1141058452)"]}, {"locationName": "Bengaluru, Karnataka, India", "geoLocationName": "Bengaluru, Karnataka, India", "companyName": "Accenture", "timePeriod": {"endDate": {"month": 12, "year": 2021}, "startDate": {"month": 1, "year": 2019}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Management Consulting"]}, "title": "Application Development Senior Analyst"}, {"locationName": "Bangalore", "projects": ["urn:li:fs_project:(ACoAAA_8N7UBcb426isJoolyZrF0Lgh2oyOZbcc,1905872456)", "urn:li:fs_project:(ACoAAA_8N7UBcb426isJoolyZrF0Lgh2oyOZbcc,1040290690)"], "geoLocationName": "Bangalore", "companyName": "IBM India Private Limited", "timePeriod": {"endDate": {"month": 1, "year": 2019}, "startDate": {"month": 10, "year": 2016}}, "description": "Responsibility:\\nDevelopment and implementation of various front and back end modules of ECM tool to ensure compliance in the organization.\\n\\nEngagement Areas:\\nDevelopment of module which ensures download of Compliance report by customers for specific geographical regions.\\nDevelopment of requirements provided by the customer.\\nEnsured data validation in reports generated corresponding to data in the database.\\nLeading team of 3 members on the development of ETL module of the ECM tool.\\nProvided defect fixes and code reviews.\\nReported and analyzed bugs on Change and Configuration Management tool.", "company": {"employeeCountRange": {"start": 10001}, "industries": ["Informat ...
#  Document(metadata={'Amazon Web Services (AWS)': 'Amazon Web Services (AWS)', 'Machine Learning': 'Machine Learning', 'Deep Learning': 'Deep Learning', 'Python (Programming Language)': 'Python (Programming Language)', 'Data Science': 'Data Science', 'HTML': 'HTML', 'SQL': 'SQL'}, page_content='{"profile_details": {"summary": "An enthusiastic Data Science professional experienced in leveraging Machine Learning and Deep Learning capabilities majorly in utility and automotive sector to help the digitalization of clients business. . Prior to joining data science field, worked extensively on software testing and automation process.\\n\\nProjects handled recently using Machine learning and Deep Learning capabilities:\\n1. Remaining Useful Life prediction of turbine components like rotor blades, stator blades, pilot nozzle etc.. (Survival and Regression Analysis) to expand the plant operating time b/w two inspection or maintenance period and to reduce the maintenance costs. (Digital Twin project)\\n2. Optimizing boiler efficiency of thermal power plant to save the operational cost by reducing the coal and auxiliary power consumption. (Digital Twin project)\\n3. Pipelines damage detection due to earthquake for quickly inspecting the damaged pipes and restoring the pipeline service in shorter time span after earthquake occurs.\\n\\nWork activities of latest projects:\\n1. Understanding Business scope, problem statement and data gathering from client.\\n2. Data cleaning, preparation and visualization activities.\\n3. Steady state data extraction from raw sensor data.\\n4. Soft sensor feature extraction from direct sensor tags and automating the extraction process.\\n5. Creating Pipelines for Data Preprocessing activities.\\n6. Feature Engineering, Feature selection, Machine learning and Deep learning Model building activities.\\n7. Evaluating and improving model performance by fine tuning hyperparameters.\\n8. Creating Pipelines for Model building and Prediction activities.\\n9. Explaining Data insights/pattern, AI model results and interpretation to Business stakeholders.\\n10. Supporting deployment of ML models, Performance Monitoring and Re-training activities.\\n\\nSkills: Amazon Web Services (AWS), Python, SQL, Neural Networks, Computer Vision, Scikit-learn, Pandas, Numpy, Matplotlib, Seaborn, Plotly, Tensorflow, Keras, Machine Learning, Deep Learning.", "industryName": "Information Technology & Services", "lastName": "Narula", "locationName": "India", "firstName": "Sagar", "headline": "Data Scientist at TCS", "img_298_298": "800_800/profile-displayphoto-shrink_800_800/0/1517397246333?e=1731542400&v=beta&t=phrlq7oRgevg3OvaRkcTcx_WFCSw-HNBsUHddoSx9aQ", "public_id": "sagarnarula", "experience": [{"companyName": "Tata Consultancy Services", "timePeriod": {"startDate": {"month": 11, "year": 2021}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"locationName": "Gurgaon, Haryana, India", "geoLocationName": "Gurgaon, Haryana, India", "companyName": "Accenture", "timePeriod": {"endDate": {"month": 11, "year": 2021}, "startDate": {"month": 3, "year": 2016}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Management Consulting"]}, "title": "Senior Software Engineer"}], "education": [{"timePeriod": {"endDate": {"year": 2015}, "startDate": {"year": 2011}}, "degreeName": "Bachelor of Technology (B.Tech.)", "schoolName": "Ajay Kumar Garg Engineering College Ghaziabad", "fieldOfStudy": "Information Technology"}], "languages": [{"name": "English"}, {"name": "Hindi"}], "publications": [], "certifications": [{"authority": "Microsoft", "name": "Microsoft Certified: Azure Fundamentals", "timePeriod": {"startDate": {"month": 7, "year": 2020}}}], "projects": [], "skills": [{"name": "Amazon Web Services (AWS)"}, {"name": "Machine Learning"}, {"name": "Deep Learning"}, {"name": "Python (Programming Language)"}], "urn_id": "ACoAABr-5jIB9VLlcHDFac ...
#  Document(metadata={'XGBoost': 'XGBoost', 'Continuous Integration and Continuous Delivery (CI/CD)': 'Continuous Integration and Continuous Delivery (CI/CD)', 'Exploratory Data Analysis': 'Exploratory Data Analysis', 'SHAP': 'SHAP', 'Machine Learning': 'Machine Learning', 'Data Science': 'Data Science', 'Python': 'Python', 'Statistics': 'Statistics', 'Econometrics': 'Econometrics', 'Data Analysis': 'Data Analysis', 'Basketball': 'Basketball', 'Bioinformatics': 'Bioinformatics', 'Programming': 'Programming', 'Deep Learning': 'Deep Learning', 'Forecasting': 'Forecasting', 'MySQL': 'MySQL', 'C': 'C', 'Matlab': 'Matlab', 'Microsoft Excel': 'Microsoft Excel', 'Decision Modeling': 'Decision Modeling', 'Machine Learning Algorithms': 'Machine Learning Algorithms', 'C++': 'C++', 'Algorithms': 'Algorithms', 'Predictive Modeling': 'Predictive Modeling'}, page_content='{"profile_details": {"summary": "Data Scientist with experience in solving dynamic and large-scale business problems using Machine learning, exploratory analysis and deep learning. I have worked on computer vision, image processing, quantitative data and predictive modelling to build stable tools with business applications using Python, R programming and C++. I was ranked 3 in GATE-2016 and my unique research projects during my academic life confirm my research aptitude required for an evolving field like data science.\\n\\nLanguages and Frameworks: Python, SQL, C++ | scikit-learn, TensorFlow, Keras and PyTorch, Makefiles (bash), pyproject.toml\\nMachine Learning Models: All Classical models especially ensembled Decision Trees (Random Forest, XGBoost), Time Series, etc.\\nDeep Learning Models: DNNs for structured data, CNNs (VGGs, Inception etc.), YOLO, Transfer Learning and Fine Tuning\\nTheoretical Strengths: Statistics, Probability distributions, Experiment design (Hypothesis testing), Sampling, ML Fundamentals\\nMLOps Capacities: Git, Pytest, MLflow, Docker, Jenkins and the learning continues", "industryName": "Computer Software", "lastName": "Singh Soam", "locationName": "India", "firstName": "Tushar", "headline": "Data Scientist | IIT Kharagpur", "img_450_450": "800_800/profile-displayphoto-shrink_800_800/0/1517612761824?e=1731542400&v=beta&t=Ssgsy02Gq3UvVr4tgL1xfCV2aORUbsFdNChVQpz4p14", "public_id": "tusharsinghsoam", "experience": [{"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "Ventiv Technology", "timePeriod": {"startDate": {"month": 11, "year": 2022}}, "description": "Main Role: Building Ventiv Predict, an end-to-end, advance analytics solution software for risk and insurance industry\\n\\u25aa Built generic and client specific machine learning based models (XGBoost) for predicting claim\\u2019s litigation, reserve, duration etc.\\n\\u25aa Introduced concepts of Explainable AI to our product using tools like SHAP and LIME to increase trust of users in our models\\n\\u25aa Implemented advance hyperparameter tuning frameworks like Optuna, Hyperopt and GridSearchCV of scikit-learn.\\n\\u25aa Practised modular development in Python with advanced usage of Git, SQL for data extraction, REGEX for basic NLP", "company": {"employeeCountRange": {"start": 201, "end": 500}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"companyName": "Fiverr", "timePeriod": {"endDate": {"month": 8, "year": 2021}, "startDate": {"month": 8, "year": 2018}}, "description": "Topic: Wealth Management Algorithm and Statistics Expert at CHEGG, USA\\n\\u2022Built a loan repayment schedule engine to reduce the interest payments based on income and expenditure levels using Python\\n\\u2022Coordinated with the team from USA to develop the front-end for my algorithm to build an end-to-end website\\n\\u2022Solved worth 7.5 lakhs of advance statistics questions for USA\\u2019s UG and PG students", "company": {"employeeCountRange": {"start": 501, "end": 1000}, "industries": ["Computer Software"]}, "title" ...

# %%
client = chromadb.PersistentClient(path="./vector_database2")
# Out:
# INFO:chromadb.telemetry.product.posthog:Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.

# %%
collection = client.create_collection(
    name="linkedin_people_profiles_3",
    embedding_function=OpenAIEmbeddingFunction(api_key=os.environ["OPENAI_API_KEY"]),
)

# %%
for id, doc in zip(ids, all_documents):
    try:
        collection.add(
            ids=id,
            documents=doc.page_content,
            metadatas=doc.metadata,
        )
    except Exception:
        continue
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 400 Bad Request"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"

# %%
client.count_collections()
# Out:
# 3

# %%
client.list_collections()
# Out:
# [Collection(id=2e261f40-ab3b-4ff6-b7d5-428835c428c3, name=linkedin_people_profiles_3),
#  Collection(id=47ff5815-b380-4ed3-9074-c9b35deb06bc, name=linkedin_people_profiles_2),
#  Collection(id=71f01971-885a-4a7a-b06f-6fc82ed6005e, name=linkedin_people_profiles)]

# %%
for collection in client.list_collections():
    client.delete_collection(name=collection.name)

# %%
linkedin_collection = client.get_collection(name="linkedin_people_profiles_3", embedding_function=OpenAIEmbeddingFunction())

# %%
linkedin_collection.count()
# Out:
# 19

# %%
retrieved_documents = linkedin_collection.query(
    query_texts="People with experience of 5 years",
    include=["documents"],
    where={"Amazon Web Services (AWS)": "Amazon Web Services (AWS)"}
)["documents"]
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"

# %%
json.loads(retrieved_documents[0][1])["skills"]
# Out:
# [{'name': 'LangChain'},
#  {'name': 'Amazon Web Services (AWS)'},
#  {'name': 'openai'},
#  {'name': 'Microsoft Azure'},
#  {'name': 'Large Language Models (LLM)'},
#  {'name': 'Generative AI'},
#  {'name': 'Data Science'},
#  {'name': 'Machine Learning'},
#  {'name': 'Deep Learning'},
#  {'name': 'Object Detection'},
#  {'name': 'Image Segmentation'},
#  {'name': 'Image Processing'},
#  {'name': 'Recommender Systems'},
#  {'name': 'Recurrent Neural Networks (RNN)'},
#  {'name': 'Convolutional Neural Networks (CNN)'},
#  {'name': 'Transformer Models'},
#  {'name': 'TensorFlow'},
#  {'name': 'Predictive Modeling'},
#  {'name': 'PyTorch'},
#  {'name': 'Computer Vision'},
#  {'name': 'Data Analysis'},
#  {'name': 'Data Wrangling'},
#  {'name': 'Docker Products'},
#  {'name': 'Data Visualization'},
#  {'name': 'Data Modeling'},
#  {'name': 'Data Warehousing'},
#  {'name': 'Artificial Intelligence (AI)'},
#  {'name': 'Data Structures'},
#  {'name': 'Object-Oriented Programming (OOP)'},
#  {'name': 'Big Data'},
#  {'name': 'Statistics'},
#  {'name': 'Programming'},
#  {'name': 'Public Relations'},
#  {'name': 'Big data'},
#  {'name': 'Python (Programming Language)'},
#  {'name': 'Databases'},
#  {'name': 'R'},
#  {'name': 'Oracle Database'},
#  {'name': 'SQL'},
#  {'name': 'PySpark'},
#  {'name': 'Team Leadership'},
#  {'name': 'Communication'},
#  {'name': 'Time Management'},
#  {'name': 'Teamwork'},
#  {'name': 'Team Management'},
#  {'name': 'Problem Solving'},
#  {'name': 'Relationship Building'},
#  {'name': 'Artificial Neural Networks'},
#  {'name': 'RDBMS'},
#  {'name': 'Probability'},
#  {'name': 'Enjoy Challenges'},
#  {'name': 'Data Analytics'},
#  {'name': 'Natural Language Processing (NLP)'},
#  {'name': 'NumPy'},
#  {'name': 'Neural Networks'},
#  {'name': 'Big Data Analytics'}]

# %%
linkedin_collection.query(
    query_texts="People with experience of 5 years",
    include=["documents"],
    where_document={"$contains": "AWS"}
)
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# {'ids': [['ACoAAAbvohIBhdiLqQ5FCbtA40AFvg3f-T7fKfk',
#    'ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY',
#    'ACoAAB_Pb3QB2wyW1d2XQVv2cjEDJPM4lRD9WQY',
#    'ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0',
#    'ACoAABr-5jIB9VLlcHDFacNUqBWr7BWroxPEhRI',
#    'ACoAABJ97q0BFcxSTVQ9_y1dgDAXNMpNiUtF93k']],
#  'distances': None,
#  'metadatas': None,
#  'embeddings': None,
#  'documents': [['{"profile_details": {"summary": "Experience in Cognitive Computing with leverage of Machine Learning, Deep Learning, Artificial Intelligence, Natural Language Processing skills . Data driven analyst with the ability to apply ML/DL/NLP/Computer Vision Techniques and leverage algorithms to solve real world problems. Established ability in deploying effective predictive/NLP/Computer Vision models across banking/HealthCare industries to accurately forecast and deliver proven results. Strong understanding of Oracle DB and PLSQL with data migration exp\\u00e9rience. Domain Knowledge of SupplyChain/finance/banking/Retail domain with communication skills, excellent product and process design knowledge. Domain HealthCare,Mortgage Banking, Consumer, Commercial Lending, Escrow, Loan processing and servicing, Deposits. Onsite experience (US/UK) with business domain experience in Retail and supply chain with special focus on Customer engagement and managing end-user expectations. Experience in Analysis, Design, Development, Customization, Bug fixes, Enhancement, Support and Implementation.\\n\\n\\nData Science, Machine Learning, Deep Learning and AI technologies.Strong understanding of Databases Oracle, Progress 4GL, PLSQL. Excellent Domain Knowledge of finance/banking/Retail domain with communication skills, excellent product and process design knowledge.Strong knowledge of Data Migration and Implementation.. \\n\\nAreas of Expertise: Data Science Machine Learning, Deep Learning and AI technologies.\\n\\nWeb App - Flask, Django.\\n\\nDomain - Mortgage Banking,Insurance Claim Processing Money Laundering, Investment Banking, Lending, Escrow, Loan processing and servicing. Credit Cards,Healthcare\\n\\nDatabase - Oracle,Progress 4GL,Mongo Db\\n\\nLanguages - Python ,PLSQL,Progress4GL,Shell Script\\n\\nVersioning - SVN,Github\\nCloud : IBM Cloud, AWS,AZURE,Kubernates\\nOthers : Dockers,CICD\\n\\n\\n\\n\\n10+ years of experience in exploring and understanding various business models in Finance,Healthcare,Retail and Supply chain domain with special focus on implementation according to client requirements.\\n\\u2022\\tExperience in client interaction for requirement gathering and feasibility analysis at various levels including end users, project managers, and business analysts. Possess good business acumen interacting with various 3rd parties in the same project. Onsite experience (UK) with business domain experience in Retail and supply chain with special focus on customer engagement and managing end-user expectations.", "industryName": "Information Technology & Services", "lastName": "Aneja", "locationName": "India", "firstName": "Isha", "headline": "Data Scientist IBM", "img_253_253": "800_800/profile-displayphoto-shrink_800_800/0/1516520225939?e=1731542400&v=beta&t=MK0pDwNOQmYNXZS1hxvX1-2NsHeY1lAP4O8njFxDsMs", "public_id": "isha-aneja-642b7a32", "experience": [{"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "IBM", "timePeriod": {"startDate": {"month": 12, "year": 2021}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"locationName": "New Delhi Area, India", "geoLocationName": "New Delhi Area, India", "companyName": "Fiserv", "timePeriod": {"endDate": {"month": 1, "year": 2022}, "startDate": {"month": 12, "year": 2017}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Technical Lead"}, {"locationName": "Noida Area, India", "geoLocationName": "Noida Area, India", "companyName": "Birlasoft", "timePeriod": {"endDate": {"month": 12, "year": 2017}, "startDate": {"month": 8, "year": 2016}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Senior Software Engineer"}, {"locationName": "banglore", "geoLocationName": "banglore", "companyName": "Ca ...
#    '{"profile_details": {"summary": "Experience Data Science professional with demonstrated history of working in IT service industry. Experienced in executing data driven solutions to increase efficiency, accuracy and utility of internal data processing. Skilled in natural language processing with practioner knowledge on Web Analytics. Strong information technology professional with a Bachelor of Technology (BTech) from Uttar Pradesh Technical University. ", "industryName": "Information Technology & Services", "lastName": "Mathur", "locationName": "India", "firstName": "Tushar", "headline": "Data Scientist", "img_413_413": "800_800/profile-displayphoto-shrink_800_800/0/1627636616827?e=1731542400&v=beta&t=622aY-HtcQSxqycM6kkJLZJgkr1xzh3_7jhWSE28UXg", "public_id": "tushar-mathur-79a23120", "experience": [{"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "Coforge", "timePeriod": {"startDate": {"month": 8, "year": 2022}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Analytics Lead"}, {"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "EXL", "timePeriod": {"endDate": {"month": 8, "year": 2022}, "startDate": {"month": 8, "year": 2021}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Technical Lead"}, {"locationName": "Noida Area, India", "geoLocationName": "Noida Area, India", "companyName": "Sopra Steria", "timePeriod": {"endDate": {"month": 7, "year": 2021}, "startDate": {"month": 7, "year": 2019}}, "description": "Working on information extraction project in which we focuses on creating structured representation of unstructured/structured texts by extracting relevant entities from them, using machine learning and AI process thereby making the data analysis realizable.", "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Module Lead"}, {"locationName": "Noida Area, India", "geoLocationName": "Noida Area, India", "companyName": "Sopra Steria", "timePeriod": {"endDate": {"month": 6, "year": 2019}, "startDate": {"month": 10, "year": 2017}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Senior Software Engineer", "honors": ["urn:li:fs_honor:(ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY,1097608354)"]}, {"locationName": "Gurgaon, India", "geoLocationName": "Gurgaon, India", "companyName": "Infosys", "timePeriod": {"endDate": {"month": 10, "year": 2017}, "startDate": {"month": 10, "year": 2016}}, "description": "\\u2022Working knowledge of Agile and Waterfall models.\\n\\u2022Working in full project life cycle involving Requirement Analysis, Testing and Implementation phases.\\n\\u2022Extensive coding and modifying programs using COBOL, DB2 and JCL as per the requests of business departments.\\n\\u2022Involved in Preparing Unit test cases, doing test data setup and performing Unit testing, User Acceptance Testing.\\n\\u2022Works on envisioning of requirement for future analysis.", "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Senior System Engineer", "honors": ["urn:li:fs_honor:(ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY,1304876652)", "urn:li:fs_honor:(ACoAAAROFiYBT5QvFHuxzGcEIeV9MLsZrg66TyY,1020421066)"]}], "education": [{"timePeriod": {"endDate": {"year": 2014}, "startDate": {"year": 2010}}, "degreeName": "Bachelor of Technology (BTech)", "schoolName": "Uttar Pradesh Technical University", "fieldOfStudy": "Electrical, Electronics and Communications Engineering"}], "languages": [{"name": "English", "proficiency": "PROFESSIONAL_WORKING"}, {"name": "Hindi", "proficiency": "NATIVE_OR_BILINGUAL"}], "publications": [], "certifications": [{"authority": "Coursera", "name": "IBM D ...
#    '{"profile_details": {"summary": "4+ years of work experience solving business problems with the application of Data Science. Master of Data Science, Monash University (Melbourne). Proficient in Generative AI, Computer Vision and Predictive Modeling. With a strong grip over mathematics, deep learning and machine learning algorithms, capable to transform business requirements into data science formulations and implementing the solutions in an efficient and scalable fashion.\\n\\nCreating impactful AI solutions at R Systems, my focus is on designing cutting-edge generative AI technologies. With a Master\'s degree in Data Science from Monash University, I apply rigorous academic training to address complex client challenges. Our team\'s contribution has significantly enhanced the RAG Application\'s accuracy, showcasing a blend of innovation and practical application.\\n\\nMy core competencies lie in Large Language Models and transformative AI, underpinned by data collection, preprocessing, model development, and deployment. These skills have enabled us to deliver tailored solutions that not only meet but exceed our clients\' business objectives. The dedication to continual learning and improvement is what drives the team and myself to achieve excellence in the ever-evolving field of data science.", "industryName": "Computer Software", "lastName": "Nain", "locationName": "India", "birthDate": {"month": 1, "day": 24}, "firstName": "Rakesh", "headline": "Data Scientist @ R Systems | Master\'s in Data Science", "public_id": "rakeshnain", "experience": [{"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "R Systems", "timePeriod": {"startDate": {"month": 8, "year": 2023}}, "description": "Roles and Responsibilities:\\n- Tackle client challenges by designing and implement end-to-end data science solutions using generative AI (LLMs, Large Multi-Modals and their finetuning based on the use cases) or traditional machine learning from data collection, preprocessing to model development and deployment\\n- I ensure optimal model performance, engage in cross-functional collaboration, and deliver insights to clients through effective communication.\\n- My role contributes to R systems consultancy prowess in delivering innovative and impactful solutions that address diverse business needs of clients.\\n\\nAchievements:\\n- Increased the RAG Application accuracy by 40%.", "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"companyName": "Intello Labs", "timePeriod": {"endDate": {"month": 8, "year": 2023}, "startDate": {"month": 12, "year": 2021}}, "description": "Roles and Responsibilities:\\n- Develop state-of-the-art machine learning and deep learning algorithms/models for visual recognition tasks, such as segmentation and detection.\\n- Collaborate closely with multidisciplinary teams of software engineers, hardware engineers, business leaders and other key players to develop Artificial Intelligent machines.\\n- Data Collection, EDA, Data Cleaning, ML Model Development(R&D) and deployment.\\n\\nAchievements:\\n- Developed object detection and instance segmentation algorithm taking around 50 times less RAM in training with only twice extra time in inference as compared to present state-of-the-art algorithms in the market.\\n- Improved grains classification results by 20%, and fruits defect detection results by 12%.", "company": {"employeeCountRange": {"start": 51, "end": 200}, "industries": ["Information Technology and Services"]}, "title": "Deep Learning Engineer"}, {"locationName": "Noida, Uttar Pradesh, India", "geoLocationName": "Noida, Uttar Pradesh, India", "companyName": "DishTV", "timePeriod": {"endDate": {"month": 10, "year": 2018}, "startDate": {"month": 6, "year": 2017}}, "description": "Roles and Responsibilities:\\nStarted as a Software Developer in the \\u201cMy DishTV\\ ...
#    '{"profile_details": {"summary": "\\u2022\\tExperience of 7 years as Data Scientist (August 2016 \\u2013 Till Date) in implementing advanced analytics and predictive modelling algorithms such as Sequence models, Machine translation, Text summarization, Voice enabled Bot (using GPT2, Deepspeech and Azure cognitive services),Text Extraction using BERT and Spacy, Text Classification, Credit Risk analysis, Logistic regression, Decision tree ,Ensemble models, KNN, PCA, t-SNE, Linear regression, Clustering (k-means, Agglomerative)\\n\\u2022\\tExperience of 1.6 years (Nov 2014 \\u2013 Aug 2016) in Siebel CRM.\\n\\u2022\\tWell converse with Python(Pandas, Numpy, Scikit-Learn, Keras, matplotlib.pyplot, seaborn), Flask API, ML model deployments, AWS Services, linux, SQL ,Core Java and Siebel CRM.", "industryName": "Information Technology & Services", "lastName": "Kharbanda", "locationName": "India", "firstName": "Sumeet", "headline": "Looking for Data Science Opportunities  | Manager - Data Scientist @ EXL | NLP | Freelancer", "img_450_450": "800_800/profile-displayphoto-shrink_800_800/0/1517470892367?e=1731542400&v=beta&t=WkpZbUOBkt9zAX7RDthG9tVfXjgi3i-bat3dRDqpGgw", "public_id": "sumeet-data-scientist", "experience": [{"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "EXL", "timePeriod": {"startDate": {"month": 4, "year": 2022}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Manager - Data Scientist"}, {"locationName": "Gurugram, Haryana, India", "geoLocationName": "Gurugram, Haryana, India", "companyName": "EXL", "timePeriod": {"endDate": {"month": 4, "year": 2022}, "startDate": {"month": 11, "year": 2020}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Technical Lead - Data Scientist"}, {"courses": ["urn:li:fs_course:(ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0,504009401)", "urn:li:fs_course:(ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0,504035397)"], "locationName": "Gurgaon, Haryana, India", "geoLocationName": "Gurgaon, Haryana, India", "companyName": "UnitedHealth Group", "timePeriod": {"endDate": {"month": 11, "year": 2020}, "startDate": {"month": 8, "year": 2019}}, "description": "Development and deployment of machine learning models in python, text analytics,disease prediction, voice bot and chat bot.", "company": {"employeeCountRange": {"start": 10001}, "industries": ["Hospital & Health Care"]}, "title": "Associate Data Scientist"}, {"locationName": "Gurgaon, Haryana, India", "geoLocationName": "Gurgaon, Haryana, India", "companyName": "dunnhumby", "timePeriod": {"endDate": {"month": 8, "year": 2019}, "startDate": {"month": 6, "year": 2019}}, "description": "Adhoc analysis of retail client, worked on pyspark, python, SQL, excel dashboards", "company": {"employeeCountRange": {"start": 1001, "end": 5000}, "industries": ["Marketing and Advertising"]}, "title": "Applied Data Scientist"}, {"courses": ["urn:li:fs_course:(ACoAABuJAnYBOub-HVz9rxZx0YCscxv0KDx7be0,503992293)"], "locationName": "Chandigarh Area, India", "geoLocationName": "Chandigarh Area, India", "companyName": "Infosys", "timePeriod": {"endDate": {"month": 5, "year": 2019}, "startDate": {"month": 4, "year": 2018}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Technology Analyst"}], "education": [{"school": {"objectUrn": "urn:li:school:354045", "entityUrn": "urn:li:fs_miniSchool:354045", "active": true, "schoolName": "International Institute of Information Technology Bangalore", "trackingId": "knbQbdzNQaetTV9aTV2Fuw==", "logoUrl": "https://media.licdn.com/dms/image/v2/D560BAQEocmV8HEnx7w/company-logo_"}, "timePeriod": {"endDate": {"year": 2021}, "startDate": {"year": 2020}}, "degreeName": "PGC", "schoolName": "International Institute of Information Technology Bangalore", "fieldOfStudy": "Data Science"}, {"s ...
#    '{"profile_details": {"summary": "An enthusiastic Data Science professional experienced in leveraging Machine Learning and Deep Learning capabilities majorly in utility and automotive sector to help the digitalization of clients business. . Prior to joining data science field, worked extensively on software testing and automation process.\\n\\nProjects handled recently using Machine learning and Deep Learning capabilities:\\n1. Remaining Useful Life prediction of turbine components like rotor blades, stator blades, pilot nozzle etc.. (Survival and Regression Analysis) to expand the plant operating time b/w two inspection or maintenance period and to reduce the maintenance costs. (Digital Twin project)\\n2. Optimizing boiler efficiency of thermal power plant to save the operational cost by reducing the coal and auxiliary power consumption. (Digital Twin project)\\n3. Pipelines damage detection due to earthquake for quickly inspecting the damaged pipes and restoring the pipeline service in shorter time span after earthquake occurs.\\n\\nWork activities of latest projects:\\n1. Understanding Business scope, problem statement and data gathering from client.\\n2. Data cleaning, preparation and visualization activities.\\n3. Steady state data extraction from raw sensor data.\\n4. Soft sensor feature extraction from direct sensor tags and automating the extraction process.\\n5. Creating Pipelines for Data Preprocessing activities.\\n6. Feature Engineering, Feature selection, Machine learning and Deep learning Model building activities.\\n7. Evaluating and improving model performance by fine tuning hyperparameters.\\n8. Creating Pipelines for Model building and Prediction activities.\\n9. Explaining Data insights/pattern, AI model results and interpretation to Business stakeholders.\\n10. Supporting deployment of ML models, Performance Monitoring and Re-training activities.\\n\\nSkills: Amazon Web Services (AWS), Python, SQL, Neural Networks, Computer Vision, Scikit-learn, Pandas, Numpy, Matplotlib, Seaborn, Plotly, Tensorflow, Keras, Machine Learning, Deep Learning.", "industryName": "Information Technology & Services", "lastName": "Narula", "locationName": "India", "firstName": "Sagar", "headline": "Data Scientist at TCS", "img_298_298": "800_800/profile-displayphoto-shrink_800_800/0/1517397246333?e=1731542400&v=beta&t=phrlq7oRgevg3OvaRkcTcx_WFCSw-HNBsUHddoSx9aQ", "public_id": "sagarnarula", "experience": [{"companyName": "Tata Consultancy Services", "timePeriod": {"startDate": {"month": 11, "year": 2021}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"locationName": "Gurgaon, Haryana, India", "geoLocationName": "Gurgaon, Haryana, India", "companyName": "Accenture", "timePeriod": {"endDate": {"month": 11, "year": 2021}, "startDate": {"month": 3, "year": 2016}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Management Consulting"]}, "title": "Senior Software Engineer"}], "education": [{"timePeriod": {"endDate": {"year": 2015}, "startDate": {"year": 2011}}, "degreeName": "Bachelor of Technology (B.Tech.)", "schoolName": "Ajay Kumar Garg Engineering College Ghaziabad", "fieldOfStudy": "Information Technology"}], "languages": [{"name": "English"}, {"name": "Hindi"}], "publications": [], "certifications": [{"authority": "Microsoft", "name": "Microsoft Certified: Azure Fundamentals", "timePeriod": {"startDate": {"month": 7, "year": 2020}}}], "projects": [], "skills": [{"name": "Amazon Web Services (AWS)"}, {"name": "Machine Learning"}, {"name": "Deep Learning"}, {"name": "Python (Programming Language)"}], "urn_id": "ACoAABr-5jIB9VLlcHDFacNUqBWr7BWroxPEhRI"}, "skills": [{"name": "Amazon Web Services (AWS)"}, {"name": "Machine Learning"}, {"name": "Deep Learning"}, {"name": "Python (Programming Language)"}, {"name": "Data Science"}, {"name": "HTML"}, {"name": "SQL"}]}',
#    '{"profile_details": {"summary": "Analytics professional who thrives on data and insights. I like to leverage my problem solving and analytical skills to help businesses in making key strategic decisions. I consider myself a highly motivated professional who looks forward to getting out of the comfort zone and doing some real rigorous work!\\n\\nPrimary Skills:\\n\\u2022 Python - Data Analysis (Numpy, Pandas, Scikit-learn, etc.) \\n\\u2022 SQL, Google BigQuery \\n\\u2022 Visualizations - Power BI, Tableau \\n\\u2022 Python scripting and automations\\n\\u2022 Linux/UNIX server management\\n\\u2022 Docker for application deployment", "industryName": "Information Technology & Services", "lastName": "Kotnala", "locationName": "India", "firstName": "Deepankar", "headline": "Data Scientist | IIIT Bangalore", "img_401_401": "800_800/profile-framedphoto-shrink_800_800/0/1724930913918?e=1726376400&v=beta&t=alXF4FJ_QwuJzXEcjonRx6vO0Rzs952GMxYjRdufXx0", "public_id": "deepankarkotnala", "experience": [{"locationName": "India", "geoLocationName": "India", "companyName": "TCG Digital", "timePeriod": {"startDate": {"month": 8, "year": 2022}}, "company": {"employeeCountRange": {"start": 201, "end": 500}, "industries": ["Information Technology and Services"]}, "title": "Data Scientist"}, {"locationName": "India", "geoLocationName": "India", "companyName": "Genpact", "timePeriod": {"endDate": {"month": 8, "year": 2022}, "startDate": {"month": 10, "year": 2020}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Management Consulting"]}, "title": "Data Analyst"}, {"locationName": "Mumbai", "geoLocationName": "Mumbai", "companyName": "Capgemini", "timePeriod": {"endDate": {"month": 4, "year": 2019}, "startDate": {"month": 2, "year": 2016}}, "company": {"employeeCountRange": {"start": 10001}, "industries": ["Information Technology and Services"]}, "title": "Associate Consultant", "honors": ["urn:li:fs_honor:(ACoAABJ97q0BFcxSTVQ9_y1dgDAXNMpNiUtF93k,1124134592)"]}], "education": [{"courses": ["urn:li:fs_course:(ACoAABJ97q0BFcxSTVQ9_y1dgDAXNMpNiUtF93k,1598967561)"], "school": {"objectUrn": "urn:li:school:354045", "entityUrn": "urn:li:fs_miniSchool:354045", "active": true, "schoolName": "International Institute of Information Technology Bangalore", "trackingId": "NlAmwagrQJG+vvCogBA/MA==", "logoUrl": "https://media.licdn.com/dms/image/v2/D560BAQEocmV8HEnx7w/company-logo_"}, "grade": "A (3.7/4 CGPA)", "timePeriod": {"endDate": {"year": 2019}, "startDate": {"year": 2018}}, "description": "PGD in Data Science and Machine Learning \\nGathering and manipulating data, applying concepts of data analytics to extract meaningful insights, building machine learning models for predictions, APIs and Flask ML applications \\nTools used: Python, R, MySQL, Excel, Tableau", "degreeName": "Post Graduate Diploma", "schoolName": "International Institute of Information Technology \\u2013 Bangalore", "fieldOfStudy": "Data Science and Machine Learning"}, {"school": {"objectUrn": "urn:li:school:827010", "entityUrn": "urn:li:fs_miniSchool:827010", "active": true, "schoolName": "COER University", "trackingId": "9bXb1MK0TGmpFVdAbbI56g==", "logoUrl": "https://media.licdn.com/dms/image/v2/C4D0BAQG75W6BLYdJAQ/company-logo_"}, "timePeriod": {"endDate": {"year": 2015}, "startDate": {"year": 2011}}, "degreeName": "Bachelor of Technology (B.Tech.)", "schoolName": "College of Engineering Roorkee", "fieldOfStudy": "Electronics and Telecommunication Engineering"}], "languages": [{"name": "English", "proficiency": "FULL_PROFESSIONAL"}, {"name": "Hindi", "proficiency": "FULL_PROFESSIONAL"}], "publications": [], "certifications": [{"authority": "International Institute of Information Technology Bangalore", "name": "Post Graduate Diploma in Data Science & Machine Learning", "timePeriod": {"startDate": {"month": 7, "year": 2019}}, "licenseNumber": "13397060"}, {"authority": "NVIDIA", "name": "NVIDIA - Fundamentals of Accelerated Data Science with RAPIDS", "timePeriod": {" ...
#  'uris': None,
#  'data': None,
#  'included': ['documents']}
